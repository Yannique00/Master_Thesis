# %%
import pandas as pd
import re

from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import stopwords
dutch_stopwords = stopwords.words('dutch')

# %%
# Read the preprocessed data
df_specific = pd.read_csv('a:/df_cleaned.csv')
df_specific.head()
# Out:
#                                   pseudo_id             verslagen_report_tags  \
# 0  046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6                   Klinische Brief
# 1  046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6  Consult, Kliniek: vervolgconsult
# 2  046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6               Poliklinische Brief
# 3  046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6               Poliklinische Brief
# 4  046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6  Consult, Kliniek: vervolgconsult
#
#                             verslagen_report_content  \
# 0  Dhr. A.J. Dingemans, huisarts\r\n[STREETNAME] ...
# 1  Samenvatting: \nRectaal bloedverlies obv diver...
# 2  COLOSCOPIE\r\n\r\nBetreft\r\nMw. [INITIALS] [L...
# 3  GASTROSCOPIE\r\n\r\nBetreft\r\nMw. [INITIALS] ...
# 4  Samenvatting: \nRectaal bloedverlies ; eenmali...
#
#   verslagen_report_start_date                 date  \
# 0         2020-11-26 15:06:00  2020-11-26 15:06:00
# 1         2020-11-26 09:53:00  2020-11-26 09:53:00
# 2         2020-11-25 14:13:00  2020-11-25 14:13:00
# 3         2020-11-25 13:48:00  2020-11-25 13:48:00
# 4         2020-11-25 08:47:00  2020-11-25 08:47:00
#
#                                              alltext  \
# 0  dhr aj dingemans huisarts streetnaam city datu...
# 1  samenvatting rectaal bloedverlie obvn divertik...
# 2  coloscopie betreffen mw initials lastname adre...
# 3  gastroscopie betreffen mw initials lastname ad...
# 4  samenvatting rectaal bloedverlie eenmalig hd h...
#
#                                               tokens
# 0  ['dhr', 'aj', 'dingemans', 'huisarts', 'street...
# 1  ['samenvatting', 'rectaal', 'bloedverlie', 'ob...
# 2  ['coloscopie', 'betreffen', 'mw', 'initials', ...
# 3  ['gastroscopie', 'betreffen', 'mw', 'initials'...
# 4  ['samenvatting', 'rectaal', 'bloedverlie', 'ee...

# %%
# Define regex pattern
# pattern = re.compile(r"\b(maagdarmbloeding|gastro[- ]intestinale bloeding|bloeding uit het maag[- ]darmkanaal|gib|bloedverlies gastro[- ]intestinaal)\b", re.IGNORECASE)

terms = [
    r"maagdarmbloeding",
    r"gastro[-\s]?intestinale bloeding",
    # r"bloeding\s*uit\s*het\s*maag[-\s]?darmkanaal",
    # r"bloedverlies\s*gastro[-\s]?intestinaal",
    # r"a?gib?",
    # r" gi ",
    r" gib ",
    r" agib ",
    # r"\bgastro\b",
    r"gi\s*bloeding",
]


# Escape multi-word phrases properly
# pattern_str = "|".join([fr"\b{t}\b" if " " not in t and "[- ]" not in t else t for t in terms])
pattern_str = "|".join(terms)
agib_pattern = re.compile(pattern_str, re.IGNORECASE)

# %%
def extract_relevant_sections(text, relevant_headers=None):
    if relevant_headers is None:
        relevant_headers = ["anamnese", "conclusie", "beleid", "tractusanamnese", "triagekeuze"]

    # Split op kopjes
    sections = re.split(r"(?<=\n)([A-Z][a-z]+(?:\s*[A-Z][a-z]+)*):", text)
    
    # Combine sections into dict: {header: content}
    it = iter(sections)
    section_dict = {}
    current = next(it, None)
    while current:
        header = current.strip().lower()
        content = next(it, "")
        section_dict[header] = content.strip()
        current = next(it, None)

    # Extract relevant parts only
    combined = ""
    for header in relevant_headers:
        if header in section_dict:
            combined += section_dict[header] + "\n"
    
    return combined

# %%
def extract_context(text, pattern, window=5):
    matches = []
    for match in pattern.finditer(text):
        start, end = match.start(), match.end()
        before = text[:start]
        after = text[end:]

        # Get words before match
        before_words = re.findall(r'\w+', before)[-window:]
        # Get words after match
        after_words = re.findall(r'\w+', after)[:window]

        context = ' '.join(before_words + [match.group()] + after_words)
        matches.append(context)

    return matches[0] if matches else None

# %%
# Apply regex
df_specific['agib_mention'] = df_specific['alltext'].apply(lambda x: bool(agib_pattern.search(str(x))))

# Optionally exclude negated matches
negation_pattern = re.compile(r"\b(geen|niet|zonder)\b.{0,20}?\b(bloed(braken)?|hematemesis|melena|maagdarmbloeding|gastro[- ]intestinale bloeding|rectaal bloedverlies|vers bloed per anum|bloeding uit het maag[- ]darmkanaal)\b", re.IGNORECASE)
df_specific['negated'] = df_specific['alltext'].apply(lambda x: bool(negation_pattern.search(str(x))))
df_specific['agib_final'] = df_specific['agib_mention'] & ~df_specific['negated']


# Apply function
df_specific['agib_context'] = df_specific['alltext'].apply(lambda x: extract_context(str(x), agib_pattern))
df_specific.head()
# Function to extract the exact match
def extract_match(text, pattern):
    match = pattern.search(text)
    return match.group() if match else None

# Apply function to extract the exact match
df_specific['agib_match'] = df_specific['alltext'].apply(lambda x: extract_match(str(x), agib_pattern))
df_specific
# Out:
#                                      pseudo_id  \
# 0     046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 1     046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 2     046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 3     046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 4     046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# ...                                        ...
# 9572  FD8C682C1F4FDA1E5EC0B760D30875556419BD71
# 9573  FD8C682C1F4FDA1E5EC0B760D30875556419BD71
# 9574  FD8C682C1F4FDA1E5EC0B760D30875556419BD71
# 9575  FD8C682C1F4FDA1E5EC0B760D30875556419BD71
# 9576  FD8C682C1F4FDA1E5EC0B760D30875556419BD71
#
#                  verslagen_report_tags  \
# 0                      Klinische Brief
# 1     Consult, Kliniek: vervolgconsult
# 2                  Poliklinische Brief
# 3                  Poliklinische Brief
# 4     Consult, Kliniek: vervolgconsult
# ...                                ...
# 9572                           Consult
# 9573  Consult, Kliniek: vervolgconsult
# 9574                      Consult, SEH
# 9575                      Consult, SEH
# 9576                      Consult, SEH
#
#                                verslagen_report_content  \
# 0     Dhr. A.J. Dingemans, huisarts\r\n[STREETNAME] ...
# 1     Samenvatting: \nRectaal bloedverlies obv diver...
# 2     COLOSCOPIE\r\n\r\nBetreft\r\nMw. [INITIALS] [L...
# 3     GASTROSCOPIE\r\n\r\nBetreft\r\nMw. [INITIALS] ...
# 4     Samenvatting: \nRectaal bloedverlies ; eenmali...
# ...                                                 ...
# 9572  Samenvatting: \n1e consult\r\n-Type 1e consult...
# 9573  Samenvatting: \nDecursus\r\n-Type decursus: De...
# 9574  Samenvatting: \nVerpleegkundige verslaglegging...
# 9575  Samenvatting: \nMedisch Dossier\r\n[ Vk Sputov...
# 9576  Samenvatting: \nVerpleegkundige verslaglegging...
#
#      verslagen_report_start_date                 date  \
# 0            2020-11-26 15:06:00  2020-11-26 15:06:00
# 1            2020-11-26 09:53:00  2020-11-26 09:53:00
# 2            2020-11-25 14:13:00  2020-11-25 14:13:00
# 3            2020-11-25 13:48:00  2020-11-25 13:48:00
# 4            2020-11-25 08:47:00  2020-11-25 08:47:00
# ...                          ...                  ...
# 9572         2015-03-20 08:13:00  2015-03-20 08:13:00
# 9573         2015-01-14 15:39:00  2015-01-14 15:39:00
# 9574         2014-12-21 09:31:00  2014-12-21 09:31:00
# 9575         2010-11-10 21:03:00  2010-11-10 21:03:00
# 9576         2010-11-10 20:29:00  2010-11-10 20:29:00
#
#                                                 alltext  \
# 0     dhr aj dingemans huisarts streetnaam city datu...
# 1     samenvatting rectaal bloedverlie obvn divertik...
# 2     coloscopie betreffen mw initials lastname adre...
# 3     gastroscopie betreffen mw initials lastname ad...
# 4     samenvatting rectaal bloedverlie eenmalig hd h...
# ...                                                 ...
# 9572  samenvatting consult type consult uitbreiden a...
# 9573  samenvatting decursus type decursus decursus s...
# 9574  samenvatting verpleegkundig verslaglegging ver...
# 9575  samenvatting medisch dossier vk sputovamo leef...
# 9576  samenvatting verpleegkundig verslaglegging ver...
#
#                                                  tokens  agib_mention  \
# 0     ['dhr', 'aj', 'dingemans', 'huisarts', 'street...         False
# 1     ['samenvatting', 'rectaal', 'bloedverlie', 'ob...         False
# 2     ['coloscopie', 'betreffen', 'mw', 'initials', ...         False
# 3     ['gastroscopie', 'betreffen', 'mw', 'initials'...         False
# 4     ['samenvatting', 'rectaal', 'bloedverlie', 'ee...         False
# ...                                                 ...           ...
# 9572  ['samenvatting', 'consult', 'type', 'consult',...         False
# 9573  ['samenvatting', 'decursus', 'type', 'decursus...         False
# 9574  ['samenvatting', 'verpleegkundig', 'verslagleg...         False
# 9575  ['samenvatting', 'medisch', 'dossier', 'vk', '...         False
# 9576  ['samenvatting', 'verpleegkundig', 'verslagleg...         False
#
#       negated  agib_final agib_context agib_match
# 0       False       False         None       None
# 1       False       False         None       None
# 2       False       False         None       None
# 3       False       False         None       None
# 4       False       False         None       None
# ...       ...         ...          ...        ...
# 9572    False       False         None       None
# 9573    False       False         None       None
# 9574    False       False         None       None
# 9575    False       False         None       None
# 9576    False       False         None       None
#
# [9577 rows x 12 columns]

# %%
# Nieuwe kolom met alleen relevante tekst
df_specific['agib_relevant_text'] = df_specific['alltext'].apply(lambda x: extract_relevant_sections(str(x)))

# Match alleen in relevante tekst
df_specific['agib_mention_relevant'] = df_specific['agib_relevant_text'].apply(lambda x: bool(agib_pattern.search(x)))

# Context + match optioneel:
df_specific['agib_match'] = df_specific['agib_relevant_text'].apply(lambda x: extract_match(str(x), agib_pattern))
df_specific['agib_context'] = df_specific['agib_relevant_text'].apply(lambda x: extract_context(str(x), agib_pattern))

# %%
# # Apply regex
# df_specific['agib_mention'] = df_specific['alltext'].apply(lambda x: bool(agib_pattern.search(str(x))))

# # Optionally exclude negated matches
# negation_pattern = re.compile(r"\b(geen|niet|zonder)\b.{0,20}?\b(bloed(braken)?|hematemesis|melena|maagdarmbloeding|gastro[- ]intestinale bloeding|rectaal bloedverlies|vers bloed per anum|bloeding uit het maag[- ]darmkanaal)\b", re.IGNORECASE)
# df_specific['negated'] = df_specific['alltext'].apply(lambda x: bool(negation_pattern.search(str(x))))
# df_specific['agib_final'] = df_specific['agib_mention'] & ~df['negated']

# %%
def extract_context(text, pattern, window=5):
    matches = []
    for match in pattern.finditer(text):
        start, end = match.start(), match.end()
        before = text[:start]
        after = text[end:]

        # Get words before match
        before_words = re.findall(r'\w+', before)[-window:]
        # Get words after match
        after_words = re.findall(r'\w+', after)[:window]

        context = ' '.join(before_words + [match.group()] + after_words)
        matches.append(context)

    return matches[0] if matches else None



# Apply function
df_specific['agib_context'] = df_specific['alltext'].apply(lambda x: extract_context(str(x), agib_pattern))
df_specific.head()
# Function to extract the exact match
def extract_match(text, pattern):
    match = pattern.search(text)
    return match.group() if match else None

# Apply function to extract the exact match
df_specific['agib_match'] = df_specific['alltext'].apply(lambda x: extract_match(str(x), agib_pattern))
df_specific
# Out:
#                                      pseudo_id  \
# 0     046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 1     046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 2     046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 3     046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 4     046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# ...                                        ...
# 9572  FD8C682C1F4FDA1E5EC0B760D30875556419BD71
# 9573  FD8C682C1F4FDA1E5EC0B760D30875556419BD71
# 9574  FD8C682C1F4FDA1E5EC0B760D30875556419BD71
# 9575  FD8C682C1F4FDA1E5EC0B760D30875556419BD71
# 9576  FD8C682C1F4FDA1E5EC0B760D30875556419BD71
#
#                  verslagen_report_tags  \
# 0                      Klinische Brief
# 1     Consult, Kliniek: vervolgconsult
# 2                  Poliklinische Brief
# 3                  Poliklinische Brief
# 4     Consult, Kliniek: vervolgconsult
# ...                                ...
# 9572                           Consult
# 9573  Consult, Kliniek: vervolgconsult
# 9574                      Consult, SEH
# 9575                      Consult, SEH
# 9576                      Consult, SEH
#
#                                verslagen_report_content  \
# 0     Dhr. A.J. Dingemans, huisarts\r\n[STREETNAME] ...
# 1     Samenvatting: \nRectaal bloedverlies obv diver...
# 2     COLOSCOPIE\r\n\r\nBetreft\r\nMw. [INITIALS] [L...
# 3     GASTROSCOPIE\r\n\r\nBetreft\r\nMw. [INITIALS] ...
# 4     Samenvatting: \nRectaal bloedverlies ; eenmali...
# ...                                                 ...
# 9572  Samenvatting: \n1e consult\r\n-Type 1e consult...
# 9573  Samenvatting: \nDecursus\r\n-Type decursus: De...
# 9574  Samenvatting: \nVerpleegkundige verslaglegging...
# 9575  Samenvatting: \nMedisch Dossier\r\n[ Vk Sputov...
# 9576  Samenvatting: \nVerpleegkundige verslaglegging...
#
#      verslagen_report_start_date                 date  \
# 0            2020-11-26 15:06:00  2020-11-26 15:06:00
# 1            2020-11-26 09:53:00  2020-11-26 09:53:00
# 2            2020-11-25 14:13:00  2020-11-25 14:13:00
# 3            2020-11-25 13:48:00  2020-11-25 13:48:00
# 4            2020-11-25 08:47:00  2020-11-25 08:47:00
# ...                          ...                  ...
# 9572         2015-03-20 08:13:00  2015-03-20 08:13:00
# 9573         2015-01-14 15:39:00  2015-01-14 15:39:00
# 9574         2014-12-21 09:31:00  2014-12-21 09:31:00
# 9575         2010-11-10 21:03:00  2010-11-10 21:03:00
# 9576         2010-11-10 20:29:00  2010-11-10 20:29:00
#
#                                                 alltext  \
# 0     dhr aj dingemans huisarts streetnaam city datu...
# 1     samenvatting rectaal bloedverlie obvn divertik...
# 2     coloscopie betreffen mw initials lastname adre...
# 3     gastroscopie betreffen mw initials lastname ad...
# 4     samenvatting rectaal bloedverlie eenmalig hd h...
# ...                                                 ...
# 9572  samenvatting consult type consult uitbreiden a...
# 9573  samenvatting decursus type decursus decursus s...
# 9574  samenvatting verpleegkundig verslaglegging ver...
# 9575  samenvatting medisch dossier vk sputovamo leef...
# 9576  samenvatting verpleegkundig verslaglegging ver...
#
#                                                  tokens  agib_mention  \
# 0     ['dhr', 'aj', 'dingemans', 'huisarts', 'street...         False
# 1     ['samenvatting', 'rectaal', 'bloedverlie', 'ob...         False
# 2     ['coloscopie', 'betreffen', 'mw', 'initials', ...         False
# 3     ['gastroscopie', 'betreffen', 'mw', 'initials'...         False
# 4     ['samenvatting', 'rectaal', 'bloedverlie', 'ee...         False
# ...                                                 ...           ...
# 9572  ['samenvatting', 'consult', 'type', 'consult',...         False
# 9573  ['samenvatting', 'decursus', 'type', 'decursus...         False
# 9574  ['samenvatting', 'verpleegkundig', 'verslagleg...         False
# 9575  ['samenvatting', 'medisch', 'dossier', 'vk', '...         False
# 9576  ['samenvatting', 'verpleegkundig', 'verslagleg...         False
#
#       negated  agib_final agib_context agib_match agib_relevant_text  \
# 0       False       False         None       None
# 1       False       False         None       None
# 2       False       False         None       None
# 3       False       False         None       None
# 4       False       False         None       None
# ...       ...         ...          ...        ...                ...
# 9572    False       False         None       None
# 9573    False       False         None       None
# 9574    False       False         None       None
# 9575    False       False         None       None
# 9576    False       False         None       None
#
#       agib_mention_relevant
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
# ...                     ...
# 9572                  False
# 9573                  False
# 9574                  False
# 9575                  False
# 9576                  False
#
# [9577 rows x 14 columns]

# %%
print("Aantal agib_mention == True:", df_specific['agib_mention'].sum())
# Out:
# Aantal agib_mention == True: 197

# %%
for i, row in df_specific[df_specific['agib_match'].notnull()].iterrows():
    print(f"🩸 Date: {row['date']}")
    print(f"🩸 Match: {row['agib_match']}")
    print(f"📍 Context: {row['agib_context']}")
    print(f"📜 Content: {row['verslagen_report_content']}")
    print("-----")
# Out:
# 🩸 Date: 2016-08-22 15:14:00
# 🩸 Match: gibloeding
# 📍 Context: telefoonnumm phonenumber mts triage triagekeus gibloeding gibloeding zwart donkerrode ontlasting triage
# 📜 Content: Samenvatting:
# Verpleegkundige verslaglegging
# -Verantwoordelijk verpleegkundige:: <ObjectGegevens>
# [ Vplk SPUTOVAMO ]
# -Leeftijd: 83
# [ Collumcare ]
# [ Sepsis ]
# [ Anamnese ]
# -Leeftijd anamnese: 83
# -(Hoofd)klacht: <ObjectGegevens>
# -A = Allergieën (alleen verpleegkundig): AMOXICILLINE / PENICILLINES / AMOXICILLINE/AMPICILLINE /
# -M = Medication: zie lijst
# -P = Past: AF
# -L = Last meal: 12.30 uur
# -E = Event: Rectaal bloedverlies donker  sinds zaterdag    begonnen met buikpijn   na gebruik antibiotica  zwaar gevoel in de buik A vrij B gb C rectaal bloedverlies D alert
# [ Neurologische score ]
# [ Trombosedienst ]
# -Pijnscore invullen?: Ja
# -Patientkenmerk: SEH patiënt
# [ Pijnscore ]
# -Pijnscore: 1
# -Score tbv grafiek: 1
# -Verpleegkundige handelingen: IV canule (V), Lab, Urinesediment en Urinekweek
# [ Contacten ]
# [ Contactpersonen ]
# -Met wie dienen, indien nodig, verpleging en/of artsen contact op te nemen als u in het ziekenhuis ligt?: Danny van Asten
# -Wat is de relatie met deze persoon?: zoon en/of dochter
# -Wat is zijn/haar telefoonnummer?: [PHONENUMBER]
# [ MTS triage ]
# -Triagekeuze: GI-bloeding
# -GI-bloeding: Zwarte of donkerrode ontlasting
# -Triage: Nee
# -Triage: Nee
# -Triage: Ja
# -Triage: Nee
# -Triage: Nee
# -----
# 🩸 Date: 2017-10-03 09:48:00
# 🩸 Match: gibloeding
# 📍 Context: Dabigatran ip dabigatran laagsen risico gibloeding waardoor swicht zinvol achten vraag
# 📜 Content: Samenvatting:
# Decursus
# -Reden van opname: diepe anemie met collaps
# -Speciële anamnese: Overleg cardio: akkoord 1 week staken dabigatran, heeft reeds 110mg dabigatran. Ip dabigatran laagste risico op GI-bloedingen waardoor swicht niet zinvol geacht.
#
# Vraag vanuit familie ferro; heeft tijdens opname ferinject gehad.
# [ Conclusie ]
# -Samenvatting: Bloedend ulcus duodeni waarvoor radiologische en endoscopische interventies en duodenumsonde; gewichtsverlies. H pylori negatief. VG/ AF met CHADS 4, ITP, hypertensie met LVH. Moeder [LASTNAME].
# -----
# 🩸 Date: 2019-05-08 09:54:00
# 🩸 Match: gi bloeding
# 📍 Context: angiodysplasie coecum overweging differentiaal diagnose gi bloeding bovenste gibloeding maagulcus maagcarcinoom malloryweiss
# 📜 Content: Samenvatting:
# Voorgeschiedenis:
# Hypertensie. Hypercholesterolemie. Gestoorde glucosetolerantie. Overgewicht.
# Uitgebreid perifeer arterieel vaatlijden waarvoor meerdere operaties.
# Chronische nierinsufficiëntie stadium IV. Schrompelnier rechts, waarschijnlijk op vasculair basis. Milde secundaire hyperparathyreoïdie en renale anemie.
# 2002 	Legionellose Spanje.
# 2006 	CVA.
# 2011 	Carotis endarterectomie links.
# 2011 	Spoed CABG LIMA-D-LAD, v-MO-RPL, forse plaques aorta.
# 2013 	Dialysevoorlichting, kiest APD.
# 2015 	Colonoscopie: Drietal poliepen verwijderd, 3 adenomen.
# 2016 	Opname cardiologie: Deels specifieke, deels aspecifieke klachten met dubieus dynamisch troponine bij nierfunctiestoornis en dubieus ECG veranderingen. In overleg met patiënt poliklinische myocardscan, geen CAG.
# 2016 	Poli cardiologie: Thoracale klachten, deels specifiek. Myocardscan 3 segmenten ischemie bij oud onderwandinfarct. EF 60%.
# 2016 	Poli vaatchirurgie: voor claudicatie geen indicatie tot behandeling mede gezien ernstige nierfunctiestoornissen en reëel risico op dialyse na gebruik van contrast. Loopadvies.
#
# RvO Neuro: TIA/minor stroke.
# RvC MDL: Rectaal bloedverlies WD Angiodysplasie coecum obv coloscopie. Gastro gb.
#
#
# Beloop:
# Overleg dr. Stalpers, neurologie: Neurologisch event doorgemaakt, derhalve clopidogrel liefst zsm herstarten (zeker gezien neurologische en cardiologische voorgeschiedenis).
#
# Aan bed:
# Vanaf vrijdag 3/5 donkerrood bloed op ontlasting. Ook bij afvegen bloed op papier. Sindsdien geen ontlasting meer gehad zonder bloed erbij. Ontlasting was zwart, maar dit is al langer zo bij ferrofumaraat-gebruik. Verder geen veranderingen in def, regelmatig, 1dd, gevormd, geen diarree of harde ontlasting. Sinds vandaag geur typisch voor melaena, heeft dit niet eerder gehad, denkt dat dit komt door de darmvoorbereiding. Niet bekend met hemorroïden. Geen buikklachten. N-V-P-R-. Hematemesis -.
# Gebruikt bloedverdunners, recent geen NSAID's gebruikt. Drinkt geen alcohol.
#
# Tractusanamnese:
# Algemeen: Geen duizeligheid of hoofdpijn. Geen collapsneiging. Geen gewichtsverlies bemerkt.
# Tr. circ: Cardiaal belast met onder meer een onderwandinfarct. EF 60%. Heeft regelmatig POB, dit trekt altijd snel weer weg, [STREETNAME] niet uit, nu niets in veranderd.
# Tr. resp: Geen benauwdheid/hoesten/slijm ophoesten. Geen bloed opgehoest. Geen neusbloedingen.
# Tr. urogen: Geen bloed bij urine, geen pijn bij plassen.
#
# Intoxicaties: Rookt +, 30 pakjaren.  Alcohol -.
#
# Uitleg gegeven over colo- en gastroscopie, complicaties besproken. Patiënt is akkoord.
# NB. Gastroscopie 05/05: Geen duidelijk bloedingsfocus; DD divertikelbloeding danwel angiodysplasie.
# ---------------------
# Overleg dd ass cardiologie: Meest waarschijnlijk sprake van type II ischemie bij anemie, streef Hb>6.0.
# TC cardiologie reeds gepland.
#
# Tijdens colo/gastro opnieuw POB, ECG aangevraagd door dr. Straathof.
# Later aan bed: Nu geen POB meer, herkende de klachten van eerder. Uitleg gegeven over uitslag gastro/colo en POB bij anemie.
#
#
# Lichamelijk onderzoek:
# Vitale functies:
# Temp	°C	36 oor rechts
# HR	bpm	80 Regulair
# SpO2	%	100
# NIBP	mmHg	161/71(101)
#
# Cor: S1S2 souffle -
# Pulmones: Beiderzijds vesiculair ademgeruis goed inkomend zonder bijgeluiden
# Abdomen: Levendige peristaltiek, soepel abdomen, wisselend tympane percussie, buik is soepel en niet drukpijnlijk.
#
# Po-inspectie: Zwarte waterige ontlasting. Melaenageur.
#
#
# Aanvullend onderzoek:
# Lab 08:00: Hb 5.8 (na 2PC gisteravond)
# Lab 16:00: Hb 6.0
#
# Gastro/colo: Normale duodeno-gastroscopie. Actieve bloeding coecum dd angiodysplasie, waarvoor clips en adrenaline. 1 cm poliep colon transversum niet verwijderd allen spot wel indicatie voor verwijdering indien comorbiditeit dit toe laat. Coloscopie tot in het terminale ileum.
#
# ECG na gastro/colo: Normalisering van de eerdere negatieve T's over laterale afleidingen, een extrasystole. Geen verandering op beleid.
#
#
# Conclusie:
# 1. Rectaal bloedverlies/melaena WD Angiodysplasie coecum.
#
#
# Overweging / Differentiaal diagnose:
# GI bloeding:
# Bovenste GI-bloeding: Maagulcus, Maagcarcinoom, Mallory-Weiss, Laesie van Dieulafoy, Slokdarmvarices, Epistaxis, Duodenale ulcer, Angiodysplasie
# Onderste GI-bloeding: Divertikelbloeding, Angiodysplasie, Ischemie, Coloncarcinoom, Infectieus, Poliep, IBD, Amyloïdose, Hemorroïden, Fissura ani,
#
#
# Beleid:
# Iom dr. Kamphuis:
# - Herstart clopidogrel
# - Omeprazol ophogen naar 2dd40mg
# - Ferrosulfaat pauzeren gezien gastro/colo
# - Vanmorgen nog voorbereiden met 1L helder vloeibaar/1L movipraep
# - Vanmiddag/vanavond Hb-co en morgenochtend opnieuw
# - Vandaag gastro/colo
# ------------
# - Morgen lab Hb
#
#
# Overdracht:
# Overdracht: RvO Neuro: TIA/minor stroke.
# RvC MDL: Rectaal bloedverlies WD Angiodysplasie coecum obv coloscopie. Gastro gb.
# -----
# 🩸 Date: 2019-05-07 21:54:00
# 🩸 Match: gi bloeding
# 📍 Context: anemie rectaal bloedverlie hb dd gi bloeding angiodysplasieen caecum divertikelbloeding dd hoog
# 📜 Content: Reden van komst / Verwijzing:
# Reden van komst (brief): Uitval links
#
# Anamnese:
# Voorgeschiedenis:
# 4-5-2019: Normocytaire anemie + rectaal bloedverlies Hb 6.2
# dd GI bloeding (opnieuw angiodysplasieen caecum, divertikelbloeding dd hoge GI bloeding, ureum echter niet gestegen). HD stabiel.
# Hypertensie. Nierinsufficientie. Verwijdering darmpoliepen.
# 2006 CVA
# 2011 Carotis endarteriëctomie li
# 2011 Onderwandinfarct. CABG LIMA-D-LAD, vene MO-RPL, forse plaques aorta
# 2014 PTA
# 2016 Thoracale pijnklachten bij anemie. Myocardscan 3 segmenten ischemie bij oud onderwandinfarct, EF 60%. Nefroloog voorbereiding niertransplantatie
# 2017 Diepe anemie. Type 2 NSTEMI en LBBB. Bloedend angiodysplasie caecum, clips. Clopidogrel ipv ASA-dipyridamol.
# 2018, dec TEA AFC li, postop anemie en aspec thor pijn.
#
# Anamnese:
# Vandaag rond 19:45 uur gevoel alsof linkerhand niet van hem was. Kracht van arm wel normaal. Schuifelde ook met linkerbeen, maar kan moeilijk aangeven of dit kwam door krachtsverlies. Geen spraakstoornissen, begrip intact. Geen hoofdpijn. Klachten verminderd, maar gevoel van hand links nog wel aanwezig. Geen hoofdpijn, geen koorts, geen koude rillingen. Geen visusstoornissen. Nog sprake van rectaal bloedverlies. Clopidogrel maandag weer herstart
# Trac circ: geen POB, geen palpitaties
# Trac uro: geen dysurie, geen pollakisurie
# Trac dig: eten en drinken gata goed, niet misselijk, niet overgegeven, sinds zaterdag rectaal bloedverlies, wordt wel al minder
#
# Med:
# Paracetamol tablet  500mg; oraal; 4 x per dag 2 stuk
# Doxazosine tablet mga 8mg; oraal; 1 x per dag 1 stuk
# Lisinopril tablet 30mg; oraal; 1 x per dag 1 stuk
# Metoprolol tablet mga 200mg (succinaat); oraal; 1 x per dag 1 stuk
# Alfacalcidol capsule 0,25ug; oraal; 1 x per dag 1 stuk
# Allopurinol tablet 100mg; oraal; 1 x per dag 1 stuk
# Furosemide tablet 40mg; oraal; 2 x per dag 2 stuk
# Ferrosulfaat tablet mga 105mgfe; oraal; 1 x per dag 1 stuk =ferogradumet
# Foliumzuur tablet 5mg; oraal; 1 x per dag 1 stuk
# Nifedipine tablet mga 60mg; oraal; 1 x per dag 1 stuk
# Atorvastatine tablet 20mg; oraal; 1 x per dag 1 stuk
# Sevelameer tablet fo 800mg (hcl); oraal; 2 x per dag 1 stuk
# Omeprazol capsule msr 20mg; oraal; 1 x per dag 1 stuk
# Clopidogrel tablet   75mg; oraal; 1 x per dag 1 stuk
# Ferricarboxymaltose injvlst 50mgfe/ml fl 20ml; iv; 1 x per week 1000 milligram eenmalig via dagopname, gedurende 7 dagen, stopdatum: 09-05-2019
# Furosemide injectievlst 10mg/ml amp 2ml; iv; 1 x per week 20 milligram eenmalig via dagopname na 1e pc, gedurende 7 dagen, stopdatum: 09-05-2019
# Darbepoetine alfa injv wwsp  60ug=0,3ml (200ug/ml); subcutaan; 1 x per week 1 stuk, gedurende 120 dagen, stopdatum: 30-08-2019
#
#
#
# Lichamelijk onderzoek:
# 7-5-2019
# Resp	/min	14
# Temp	°C	36,2
# HR	bpm	76
# SpO2	%	100
# NIBP	mmHg	143/63(90)
# EMV		15
#
# Neurologisch onderzoek:
# Georienteerd in triplo. Geen dysartrie of afasie. Geen imprentingsstoornis.
# HZ: pupillen isocoor lichtreactief, OVB ongestoord, geen nystagmus/diplopie,  sensomotoriek gelaat ongestoord, SCM/trapezius MRC 5/5.
# Coordinatie: VTNP ongestoord
# Motoriek: barre en mingazinni zakken niet uit. Biceps/triceps/vingerflexoren MRC 5/5. Quadriceps/hamstrings/ileopsoas MRC 5/5. Voetheffers/strekkers MRC 5/5. Spreiden vingers 5/5
# Sensibiliteit: Globaal intact (ook hand links normaal ivm rechts)
# Reflex: VZR indifferent bdz. KPR 0/0, BPR 1/1
#
#
#
# Aanvullend onderzoek:
# Lab:
# 195139
# 07-05-2019
# 21:38
# Mignot
# Info:	Nucht
# CRP	10	mg/L
# Hemoglobine	4.6	mmol/L
# Hematocriet	0.23	L/L
# Erytrocyten	2.34	x10^12/L
# MCV	100	fL
# Leukocyten	9.9	x10^9/L
# Trombocyten	200	x10^9/L
# APTT	34	sec
# PT	14.2	sec
# INR	1.0
# Glucose	5.8	mmol/l
# Natrium	146	mmol/L
# Kalium	4.8	mmol/L
# Ureum	34.0	mmol/L
# Kreatinine	368	µmol/L
# eGFR CKD-EPI	14	ml/m/1.73m^2
# Alkalische Fosfatase (AF)	54	U/L
# GGT	30	U/L
# ALAT	17	U/L
# Cholesterol	(2.3)	mmol/L
# Triglyceriden	2.9	mmol/L
# HDL Cholesterol	0.7	mmol/L
# Chol/HDLchol	3.5
# LDL Cholesterol	0.3	mmol/L
#
# ECG: 74/min, sinusritme, normale hartas, normale geleidingstijden, geen ST veranderingen. Extra ventriculaire slag
#
# 2de ECG: 74/min, normale hartas, normale geleidingstijden, neg T in I, II, bifasisch in V5 en V6
#
# CT cerebrum: geen afwjkingen
#
#
#
# Conclusie:
# 1. Verminderd gevoel/krachtsverlies linkerhand dd TIA abcd2 score 6 / CVA
# 2. Anemie dd bij rectaal bloedverlies
#
#
# Beleid:
# Algemeen: Opname stroke unit (Te accepteren)
# Stroke protocol (Te accepteren)
# Duplex herhalen (Te accepteren)
# 2 PC, morgen Hb controle. (Te accepteren)
# Clopidogrel tno stoppen. Vanavond 1 liter moviprep en 1 liter helder vloeibaar. Ip morgen coloscopie + gastroscopie inplannen. Morgen 1 liter moviprea (Te accepteren)
# Geen vast voedsel (Te accepteren)
# Troponines vervolgen~ (Te accepteren)
# Morgenvroeg ECG herhalen (Te accepteren)
#
# Beleid:
# iom dr Wagener dd neuroloog
# Opname stroke unit
# Stroke protocol
# Duplex herhalen
# Overleg MDL over continueren Clopiogrel
#
# Iom dr Kamphuis dd MDL arts
# icc MDL: 2 PC, morgen Hb controle.
# Clopidogrel tno stoppen. Vanavond 1 liter moviprep en 1 liter helder vloeibaar. Ip morgen coloscopie + gastroscopie inplannen. Morgen 1 liter movipreap + helder vloeibaar. herhalen.  Po inspectie
# Vanaf nu geen vast voedsel
#
# Vanaf 23:00 uur POB, drukkend van aard. Geen uitstraling
# iom dr cardioloog dd Verbunt
# Troponines vervolgen
# Morgenvroeg ECG herhalen
# -----
# 🩸 Date: 2019-05-04 13:42:00
# 🩸 Match: gi bloeding
# 📍 Context: anemie rectaal bloedverlie hb dd gi bloeding angiodysplasieen caecum divertikelbloeding dd hoog
# 📜 Content: Mw. M.J.C. Lankhorst, huisarts
# [STREETNAME] BJ  [CITY]
#
#
#
#
#
# datum
#   -  -
# kenmerk
# 0006597784 / [PATIENTID]
# BSN nr.
# [BSN]
# betreft
# de heer [INITIALS] [LASTNAME], geb. [BIRTHDATE] (69)
# [STREETNAME], [ZIP]  [CITY]
# tel. [PHONENUMBER]
#
#
# Geachte collega,
#
# Bovengenoemde patiënt bezocht op 04-05-2019 de spoedeisende hulp.
#
#
# Reden van komst
# Rectaal bloedverlies, donkere stolsels.
#
# Conclusie
# Normocytaire anemie + rectaal bloedverlies Hb 6.2
# dd GI bloeding (opnieuw angiodysplasieen caecum, divertikelbloeding dd hoge GI bloeding, ureum echter niet gestegen). HD stabiel.
#
# Beleid
# Iom Dr Erdtsieck:
# MDL ICC
# Hb controle
# Voor nu nog geen transfusie nodig
# Clopidogrel tno stop
#
# Iom Dr Verhulst MDL-arts:
# Meest waarschijnlijk lage GI bloeding (ureum niet gestegen)
# Coloscopie maandag, indien opnieuw bloedverlies zn eerder
# Alvast starten met moviprep voorbereiding (voor geval scopie eerder nodig is)
# Na voorbereiding helder vloeibaar dieet
# Hb controle morgenochtend, indien eerder opnieuw verlies van stolsels eerder Hb controle
# EWS a 2 uur
# Lopend infuus NaCl 0.9% 500cc, nadien indien HD stabiel en geen actief bloedverlies meer geen infusie meer nodig (alleen waaknaald)
# ICC internist; beleid tav medicatie, anemie
#
# Anamnese
# Meneer heeft sinds 3 weken last van pijn in de bovenbuik. Sinds gisterenavond stolsels (donker rood) in ontlasting gezien. Vanochtend grote stolsels in ontlasting. Heeft altijd al donkere/zwarte ontlasting bij gebruik ferro. Voelt zich duizelig. Volgens partner wel iets sneller kortademig dan normaal. Gisteren 2PC's gehad (via internist, analyse ivm HB daling). Daarvoor POB, nu niet meer.
#
# In het verleden rectaal bloedverlies bij angiodysplasieen caecum gehad, waarbij IC opname en kortdurende reanimatie. Nu bang dat het weer zo ernstig wordt.
#
# Voorgeschiedenis
# Hypertensie. Nierinsufficientie. Verwijdering darmpoliepen.
# 2006 CVA
# 2011 Carotis endarteriëctomie li
# 2011 Onderwandinfarct. CABG LIMA-D-LAD, vene MO-RPL, forse plaques aorta
# 2014 PTA
# 2016 Thoracale pijnklachten bij anemie. Myocardscan 3 segmenten ischemie bij oud onderwandinfarct, EF 60%. Nefroloog voorbereiding niertransplantatie
# 2017 Diepe anemie. Type 2 NSTEMI en LBBB. Bloedend angiodysplasie caecum, clips. Clopidogrel ipv ASA-dipyridamol.
# 2018, dec TEA AFC li, postop anemie en aspec thor pijn.
#
# Medicatie
# Paracetamol tablet  500mg; oraal; 4 x per dag 2 stuk
# Doxazosine tablet mga 8mg; oraal; 1 x per dag 1 stuk
# Lisinopril tablet 30mg; oraal; 1 x per dag 1 stuk
# Metoprolol tablet mga 200mg (succinaat); oraal; 1 x per dag 1 stuk
# Alfacalcidol capsule 0,25ug; oraal; 1 x per dag 1 stuk
# Allopurinol tablet 100mg; oraal; 1 x per dag 1 stuk
# Furosemide tablet 40mg; oraal; 2 x per dag 2 stuk
# Ferrosulfaat tablet mga 105mgfe; oraal; 1 x per dag 1 stuk =ferogradumet
# Foliumzuur tablet 5mg; oraal; 1 x per dag 1 stuk
# Nifedipine tablet mga 60mg; oraal; 1 x per dag 1 stuk
# Atorvastatine tablet 20mg; oraal; 1 x per dag 1 stuk
# Sevelameer tablet fo 800mg (hcl); oraal; 2 x per dag 1 stuk
# Omeprazol capsule msr 20mg; oraal; 1 x per dag 1 stuk
# Clopidogrel tablet   75mg; oraal; 1 x per dag 1 stuk
# Ferricarboxymaltose injvlst 50mgfe/ml fl 20ml; iv; 1 x per week 1000 milligram eenmalig via dagopname, gedurende 7 dagen, stopdatum: 09-05-2019
# Furosemide injectievlst 10mg/ml amp 2ml; iv; 1 x per week 20 milligram eenmalig via dagopname na 1e pc, gedurende 7 dagen, stopdatum: 09-05-2019
# Darbepoetine alfa injv wwsp  60ug=0,3ml (200ug/ml); subcutaan; 1 x per week 1 stuk, gedurende 120 dagen, stopdatum: 30-08-2019
#
# Lichamelijk onderzoek
# Niet acuut ziek ogend. Iets bleek.
#
# Controles:
# Resp	/min	18
# SpO2	%	100
# HR	bpm	64
# NIBP	mmHg	203/83(123)
# Temp	°C	36
# EWS score		4
#
# Cor: S1S2, geen souffle.
# Pulm: VAG bdz, geen bijgeluiden.
# Abd: levendige peristaltiek, soepele buik, geen evidente drukpijn, niet geprikkeld.
# RT: wat zwarte ontlasting aan de handschoen, geen helder rood bloed, geen weerstand palpabel.
#
# Aanvullend onderzoek
# Lab:
# CRP	27	mg/L
# Hemoglobine	6.2	mmol/L
# Hematocriet	0.32	L/L
# MCV	99	fL
# Leukocyten	7.2	x10^9/L
# Trombocyten	203	x10^9/L
# APTT	(41)	sec
# PT	15	sec
# INR	1.1
# Glucose	8.1	mmol/l
# Natrium	145	mmol/L
# Kalium	5.0	mmol/L
# Kreatinine	328	µmol/L
# eGFR CKD-EPI	16	ml/m/1.73m^2
# Bilirubine totaal	4	µmol/L
# Alkalische Fosfatase (AF)	58	U/L
# GGT	23	U/L
# ASAT	10	U/L
# ALAT	9	U/L
# Lipase	57	U/L
#
# Medicatie actueel
# Darbepoetine alfa injv wwsp  60ug=0,3ml (200ug/ml); subcutaan; 1 x per week 1 stuk, gedurende 120 dagen, stopdatum: 30-08-2019
#
# Paracetamol tablet  500mg; oraal; 4 x per dag 2 stuk
#
# Doxazosine tablet mga 8mg; oraal; 1 x per dag 1 stuk
#
# Lisinopril tablet 30mg; oraal; 1 x per dag 1 stuk
#
# Metoprolol tablet mga 200mg (succinaat); oraal; 1 x per dag 1 stuk
#
# Alfacalcidol capsule 0,25ug; oraal; 1 x per dag 1 stuk
#
# Allopurinol tablet 100mg; oraal; 1 x per dag 1 stuk
#
# Furosemide tablet 40mg; oraal; 2 x per dag 2 stuk
#
# Ferrosulfaat tablet mga 105mgfe; oraal; 1 x per dag 1 stuk =ferogradumet
#
# Foliumzuur tablet 5mg; oraal; 1 x per dag 1 stuk
#
# Nifedipine tablet mga 60mg; oraal; 1 x per dag 1 stuk
#
# Atorvastatine tablet 20mg; oraal; 1 x per dag 1 stuk
#
# Sevelameer tablet fo 800mg (hcl); oraal; 2 x per dag 1 stuk
#
# Omeprazol capsule msr 20mg; oraal; 1 x per dag 1 stuk
#
# Ferricarboxymaltose injvlst 50mgfe/ml fl 20ml; iv; 1 x per week 1000 milligram eenmalig via dagopname, gedurende 5 dagen, stopdatum: 09-05-2019
#
# Furosemide injectievlst 10mg/ml amp 2ml; iv; 1 x per week 20 milligram eenmalig via dagopname na 1e pc, gedurende 5 dagen, stopdatum: 09-05-2019
#
# Clopidogrel tablet   75mg; oraal; 1 x per dag 1 stuk, stopdatum: T.N.O. gestopt
#
#
#
#
# Met vriendelijke groet,
#
#  E. van der Spek-Ciliacus, SEH arts assistent
#
# Namens
# M.M. Campen-Hoekstra, SEH arts
#
# Deze brief is elektronisch geaccordeerd en daarom niet ondertekend.
# -----
# 🩸 Date: 2019-05-04 12:21:00
# 🩸 Match: gi bloeding
# 📍 Context: anemie rectaal bloedverlie hb dd gi bloeding angiodysplasieen caecum divertikelbloeding dd hoog
# 📜 Content: Reden van komst / Verwijzing:
# Reden van komst (brief): Rectaal bloedverlies, donkere stolsels.
#
# Beloop:
# Op SEH geen bloedverlies meer gehad
#
#
# Anamnese:
# Meneer heeft sinds 3 weken last van pijn in de bovenbuik. Sinds gisterenavond stolsels (donker rood) in ontlasting gezien. Vanochtend grote stolsels in ontlasting. Heeft altijd al donkere/zwarte ontlasting bij gebruik ferro. Voelt zich duizelig. Volgens partner wel iets sneller kortademig dan normaal. Gisteren 2PC's gehad (via internist, analyse ivm HB daling). Daarvoor POB, nu niet meer.
#
# In het verleden rectaal bloedverlies bij angiodysplasieen caecum gehad, waarbij IC opname en kortdurende reanimatie. Nu bang dat het weer zo ernstig wordt.
#
# Voorgeschiedenis
# Hypertensie. Nierinsufficientie. Verwijdering darmpoliepen.
# 2006 CVA
# 2011 Carotis endarteriëctomie li
# 2011 Onderwandinfarct. CABG LIMA-D-LAD, vene MO-RPL, forse plaques aorta
# 2014 PTA
# 2016 Thoracale pijnklachten bij anemie. Myocardscan 3 segmenten ischemie bij oud onderwandinfarct, EF 60%. Nefroloog voorbereiding niertransplantatie
# 2017 Diepe anemie. Type 2 NSTEMI en LBBB. Bloedend angiodysplasie caecum, clips. Clopidogrel ipv ASA-dipyridamol.
# 2018, dec TEA AFC li, postop anemie en aspec thor pijn.
#
# Medicatie
# Paracetamol tablet  500mg; oraal; 4 x per dag 2 stuk
# Doxazosine tablet mga 8mg; oraal; 1 x per dag 1 stuk
# Lisinopril tablet 30mg; oraal; 1 x per dag 1 stuk
# Metoprolol tablet mga 200mg (succinaat); oraal; 1 x per dag 1 stuk
# Alfacalcidol capsule 0,25ug; oraal; 1 x per dag 1 stuk
# Allopurinol tablet 100mg; oraal; 1 x per dag 1 stuk
# Furosemide tablet 40mg; oraal; 2 x per dag 2 stuk
# Ferrosulfaat tablet mga 105mgfe; oraal; 1 x per dag 1 stuk =ferogradumet
# Foliumzuur tablet 5mg; oraal; 1 x per dag 1 stuk
# Nifedipine tablet mga 60mg; oraal; 1 x per dag 1 stuk
# Atorvastatine tablet 20mg; oraal; 1 x per dag 1 stuk
# Sevelameer tablet fo 800mg (hcl); oraal; 2 x per dag 1 stuk
# Omeprazol capsule msr 20mg; oraal; 1 x per dag 1 stuk
# Clopidogrel tablet   75mg; oraal; 1 x per dag 1 stuk
# Ferricarboxymaltose injvlst 50mgfe/ml fl 20ml; iv; 1 x per week 1000 milligram eenmalig via dagopname, gedurende 7 dagen, stopdatum: 09-05-2019
# Furosemide injectievlst 10mg/ml amp 2ml; iv; 1 x per week 20 milligram eenmalig via dagopname na 1e pc, gedurende 7 dagen, stopdatum: 09-05-2019
# Darbepoetine alfa injv wwsp  60ug=0,3ml (200ug/ml); subcutaan; 1 x per week 1 stuk, gedurende 120 dagen, stopdatum: 30-08-2019
#
#
#
# Lichamelijk onderzoek:
# Niet acuut ziek ogend. Iets bleek.
#
# Controles:
# Resp	/min	18
# SpO2	%	100
# HR	bpm	64
# NIBP	mmHg	203/83(123)
# Temp	°C	36
# EWS score		4
#
# Cor: S1S2, geen souffle.
# Pulm: VAG bdz, geen bijgeluiden.
# Abd: levendige peristaltiek, soepele buik, geen evidente drukpijn, niet geprikkeld.
# RT: wat zwarte ontlasting aan de handschoen, geen helder rood bloed, geen weerstand palpabel.
#
#
# Aanvullend onderzoek:
# Lab:
# CRP	27	mg/L
# Hemoglobine	6.2	mmol/L
# Hematocriet	0.32	L/L
# MCV	99	fL
# Leukocyten	7.2	x10^9/L
# Trombocyten	203	x10^9/L
# APTT	(41)	sec
# PT	15	sec
# INR	1.1
# Glucose	8.1	mmol/l
# Natrium	145	mmol/L
# Kalium	5.0	mmol/L
# Kreatinine	328	µmol/L
# eGFR CKD-EPI	16	ml/m/1.73m^2
# Bilirubine totaal	4	µmol/L
# Alkalische Fosfatase (AF)	58	U/L
# GGT	23	U/L
# ASAT	10	U/L
# ALAT	9	U/L
# Lipase	57	U/L
#
#
# Conclusie:
# Normocytaire anemie + rectaal bloedverlies Hb 6.2
# dd GI bloeding (opnieuw angiodysplasieen caecum, divertikelbloeding dd hoge GI bloeding, ureum echter niet gestegen). HD stabiel.
#
#
# Beleid:
# Algemeen: Lopend infuus NaCl 0.9% 500cc, nadien (na scopie) indien HD stabiel en geen actief bloedverlies meer geen infusie meer nodig (Te accepteren)
# EWS a 2 uur (Voltooid)
# morgenvroeg Hb controle, indien opnieuw verlies stolsels eerder Hb controle (Voltooid)
# NPO tno (Voltooid)
# vandaag nog scopie (Voltooid)
# morgen beslissen of clopidogrel weer herstart mag worden (Te accepteren)
# vandaag ip toch geen scopie, alleen indien opnieuw (veel) bloedverlies, dan overleg Dr Verhulst (Te accepteren)
# Lopend infuus NaCl 0.9% 500cc, nadien indien HD stabiel en geen actief bloedverlies meer geen infusie meer nodig (alleen waaknaald) (Te accepteren)
# Alvast starten met moviprep voorbereiding (voor geval scopie eerder nodig is) (Te accepteren)
# scopie ip maandag, alleen indien nodig eerder vandaag/morgen (Te accepteren)
# Na voorbereiding helder vloeibaar dieet (Te accepteren)
#
# Beleid:
# Iom Dr Erdtsieck:
# MDL ICC
# Hb controle
# Voor nu nog geen transfusie nodig
# Clopidogrel tno stop
#
# Iom Dr Verhulst MDL-arts:
# Meest waarschijnlijk lage GI bloeding (ureum niet gestegen)
# Coloscopie maandag, indien opnieuw bloedverlies zn eerder
# Alvast starten met moviprep voorbereiding (voor geval scopie eerder nodig is)
# Na voorbereiding helder vloeibaar dieet
# Hb controle morgenochtend, indien eerder opnieuw verlies van stolsels eerder Hb controle
# EWS a 2 uur
# Lopend infuus NaCl 0.9% 500cc, nadien indien HD stabiel en geen actief bloedverlies meer geen infusie meer nodig (alleen waaknaald)
# ICC internist; beleid tav medicatie, anemie
# -----
# 🩸 Date: 2019-05-02 11:17:00
# 🩸 Match: gi bloeding
# 📍 Context: skelet conclusie macrocytair anemie renaal gi bloeding achteruitgang Nierfuctie egfr overweging differentiaal
# 📜 Content: Samenvatting:
# Hypertensie
# Chronisch nierfunctieverlies
# 2006 CVA
# 2011 carotis endarteriectomie links
# 2011 myocardinfarct, CABG
# 2013 dotter art iliaca rechts
# 2014 dotter coronaire
# 2016 anemie
# 2017 NSTEMI bij anemie, angiodysplasie caecum waarvoor clips
# 2018 nov. PTA aorta-iliacale stents, post-operatief bloeding
# 2018 dec. bloedtransfusie via MDL
#
#
# Beloop:
# echtgenote belde:
# wilde labuitslagen bespreken. Maakt zich zorgen. Hr heeft continu pijn op de borst met een toename van klachten in de nacht bij plat liggen. Al langere tijd wat kortademig. Geen toename van gewicht.
# Vraagt of ze eerder langs kunnen komen.
# afspraak verzet naar vanmiddag 15.00 u
#
# bloedverlies: geen zichtbaar bloedverlies gehad,
# eetlust: verminderde eetlust, niet misselijk, geen braken. Lukt wel om te eten.
# ontlastingspatroon: wisselend, soms vast, soms wat dun. Geen bloed of slijm bijmenging. Zwarte ontlasting bij ferrogradumet.
# Vermoeid na inspanning, geen kortademigheid
# geen last van hartkloppingen
# pijn op de borst: zeurende pijn, trekt door naar [STREETNAME]. Geen druk op de borst. Herkent de pijn van eerder, toen ook laag Hb, pijn helemaal over na bloedtransfusie.
#
#
# Aanvullend onderzoek:
# CRP	46	mg/L
# Hemoglobine	5.7	mmol/L
# Hematocriet	0.30	L/L
# MCV	104	fL
# Glucose	5.4	mmol/L
# Natrium	144	mmol/L
# Kalium	5.2	mmol/L
# Ureum	38.1	mmol/L
# Kreatinine	410	µmol/L
# eGFR CKD-EPI	12	ml/m/1.73m^2
# ASAT	9	U/L
# ALAT	8	U/L
#
# x thorax 1-5:
# Verslag:
# Vergeleken wordt met 03-10-2018.
# Ongewijzigd normaal beeld van hart, hili en mediastinum. Scherp afgrensbare diafragmakoepels, heldere sinus pleurae. Heldere longvelden. Geen infiltraten of overvulling. Geen nodulaire verdichtingen. Status na sternotomie. Degeneratief skelet.
#
#
# Conclusie:
# macrocytaire anemie, renaal of toch gi bloeding
# achteruitgang nierfuctie, eGFR 12
#
#
# Overweging / Differentiaal diagnose:
# Hb daling onder epo (niet transplantabel, eerder beoordeeld in Maastricht), macrocytair ( in jan vit B12 en foliumzuur op peil )
# CRP stijging
# continu pijn op de borst met toename bij plat liggen, mgl gerelateerd aan anemie
#
#
# Beleid:
# pm gastroscopie/echo abdomen
# iom Dr Beerenhout:
# omeprazol verhogen naar 1d2 indien transfusie niet heeft geholpen.
# epo verhogen naar 1 maal per week en 2PC/ferinject iv via dagbehandeling, eenmalig 20 mg furo toedienen na eerste pc.
# tc 8-5 met lab controle
#
#
# Overige acties:
# - Laboratorium: Hemoglobine, MCV, Kreatinine + evt. eGFR CKD EPI
#
# Overige acties:
# - Afspraak
# -----
# 🩸 Date: 2015-12-04 09:53:00
# 🩸 Match: gibloeding
# 📍 Context: telefoonnumm phonenumber mts triage triagekeus gibloeding gibloeding zwart donkerrode ontlasting triage
# 📜 Content: Samenvatting:
# Verpleegkundige verslaglegging
# -Verantwoordelijk verpleegkundige:: <ObjectGegevens>
# [ Vplk SPUTOVAMO ]
# -Leeftijd: 62
# [ Collumcare ]
# [ Sepsis ]
# [ Anamnese ]
# -Leeftijd anamnese: 62
# -(Hoofd)klacht: <ObjectGegevens>
# -A = Allergieën (alleen verpleegkundig): ferinject
# -M = Medication: zie docs
# -P = Past: z v Crohn, maandelijks ijzerinfuus.
# -E = Event: Mw heeft laatste tijd meer bloedverlies per anum. Gisteren Hb laten prikken(4,6).
# Heeft chronisch anaemie en lagere tensies.
# [ Neurologische score ]
# [ Trombosedienst ]
# -Pijnscore invullen?: Ja
# [ Pijnscore ]
# -Pijnscore: 1
# -Score tbv grafiek: 1
# -Verpleegkundige handelingen: IV canule (V) en Lab
# -Aanvullende informatie: 1e PC om 12.15uur aangesloten
# -Bestemming na SEH: Opgenomen
# -Afdeling: aoa
# -Pijnscore bij ontslag: Ja
# -Pijnscore: 1
# [ Contacten ]
# [ Contactpersonen ]
# -Met wie dienen, indien nodig, verpleging en/of artsen contact op te nemen als u in het ziekenhuis ligt?: echtgenoot
# -Wat is de relatie met deze persoon?: partner
# -Wat is zijn/haar telefoonnummer?: [PHONENUMBER]
# [ MTS triage ]
# -Triagekeuze: GI-bloeding
# -GI-bloeding: Zwarte of donkerrode ontlasting
# -Triage: Nee
# -Triage: Nee
# -Triage: Ja
# -Triage: Nee
# -Triage: Nee
# -----
# 🩸 Date: 2021-12-06 16:49:00
# 🩸 Match: gi bloeding
# 📍 Context: dr tick ibrutinib stoppen middel gi bloeding beschrijven bijwerking ontlasting melkchocolade kleur
# 📜 Content: Samenvatting:
# Recidiverende anemie bij 80 jarige vrouw met CLL.
# Op verzoek INT uitsluiten gastro-intestinaal verlies:
# gastro en coloscopie (juli 2021): gda, VCE (sept 2021): gb.
# VG/ CLL, ernstige aortaklepstenose, COPD Gold 1, longembolie.
#
#
# Beloop:
# Heeft vorige week twee zakjes bloed gehad van dr Tick  ivm Hb van 5.6, het Hb is nu 7.2.
# Heeft recent weer donkere ontlasting gehad, tegen het zwarte aan. Heeft op advies van dr Tick de ibrutinib gestopt (bij dit middel zijn GI bloedingen wel beschreven als bijwerking).
# De ontlasting is nu weer melkchocolade van kleur.
#
#
# Conclusie:
# Mogelijk recent opnieuw GI bloedverlies gehad.
#
#
# Beleid:
# Wat mij betreft nu even expectatief.  Geen indicatie voor nieuwe endoscopische onderzoeken, die recent allemaal verricht zijn.
# Bij recidief melaena graag overleg.
# -----
# 🩸 Date: 2014-12-26 10:17:00
# 🩸 Match: gi bloeding
# 📍 Context: assistent smeets rijden firstnaam komst gi bloeding anamnees vg nierfunctiestoornis analyse buikklachten
# 📜 Content: Samenvatting:
# Opnameregistratie
# -Verwijzer: SEH
# -SEH informatie laatste bezoek: Datum: 25-12-2014
# Verantwoordelijk arts:M.J. ter Borg
# Arts assistent: E. Smeets
# Reden [FIRSTNAME] komst: gi bloeding
#
#
# Anamnese: VG/
# 2013 Nierfunctiestoornis
# 2012 Analyse buikklachten; gastroscopie grote sliding hernia diaphragmatica
# 2012 Pancreatitis
# 2011 Jicht
# 2009 TIA
# 2008 Pancreatitis
# 2008 Schouderoperatie links
# 2008 Brijige ontlasting; coloscopie diverticulose, haemorroiden
# 2007 Prostaatcarcinoom waarvoor radiotherapie
# 2007 Hypertensie
# Diverticulose
#
# Med/ oa ascal
#
# All/ geen
#
# A/ Sinds vannacht 2 x fors veel bloederige ontlasting. Sinds weken wat buikpijn ROB, 14 dgn geleden hematemesis + braken. Op SEH opnieuw hele pot vol helder rood bloedverlies waarna zweten, bleek en kortdurend wegraking.
#
# Tr: N-, V-, geen hematemesis gehad, nu geen buikpijn
# Tr circ: POB-, palpitaties-
# Tr resp: dyspnoe-
#
# Soc: emotioneel, vrouw erg ziek geweest, wil haar niet alleen laten.
#
# Lichamelijk onderzoek: Bij triage HD stabiel, direct daarna collaps na forse hoeveelheid helder rode ontlasting
#
# Bleek, klam, goed aanspreekbaar, wel zwak
# A/ vrij
# B/ AF 28/min, sat 97 % O2-, zacht VAG bdz
# C/ p 80 reg, RR 90/60, bleek, perifeer lauw, niet gemarmerd, abd levendige p, soepel, geen evidente druk of loslaatpijn, liespulsaties zwak palpabel bdz
# D/ EMV15, PEARRL, geen lateralisatie
# E/ T 36, kuiten soepel, spoortje oedeem bdz
#
# Trekt bij op SEH; minder bleek, voelt zich beter, p 80/reg, RR 120/60 stabiel
#
# Laboratorium: Lab: Hb 8.6, trombo's 255, kreat 103, ureum 9.7
#
# Samenvatting:Man [FIRSTNAME] 77 jaar bekend met oa TIA wv ascal, prostaat carcinoom wv radiotherapie en diverticulose bij coloscopie presenteert met laatste weken wat buikklachten ROB en sinds vannacht tweemaal fors helder rood bloedverlies per anum. Op SEH een derde maal waarbij collaps RR 90/60, p 80/min, bleek. Op SEH bijtrekken; minder bleek, RR 120/60 stabiel. Abd soepel niet drukpijnlijk. Hb 8.9 -> 8.1
# (Werk)diagnose: Fors rectaal bloedverlies dd divertikel bloeding / post-radiatie
#
# Behandeling op SEH: O2, 2 x perifeer infuus 1L NaCl 0.9 %, 1 x PC, desmopressine 24 mcg IV
# Beleid bij vertrek SEH: Iom dd MDL-arts (dr. ter Borg):
# - 1 x PC, 1 x trombo's, desompressine 0.3 mcg / kg = 24 mcg  IV
# - opname aoa MDL
# - controles a 1 u
# - infuus 1 L in 2 u, daarna 2 L/24u infuus
# - herhalen Hb m 16u
# - tno stop ascal + nifedipine
# - tno nuchter
# - nu geen scopie: dd MDL-arts komt in huis voor beoordeling
# -Reden [FIRSTNAME] opname: Gaat goed. Geen hoofdpijn meer.
# Volledig dieet. Eet goed.
# [ Conclusie ]
# -Samenvatting: Acute pancreatitis, mogelijk biliair. Geen galblaasstenen.
# -----
# 🩸 Date: 2018-07-09 13:18:00
# 🩸 Match: gi bloeding
# 📍 Context: matig nierfunctie cf anemie recent gi bloeding conclusie beleid starten predialyse traject
# 📜 Content: Samenvatting:
# 2010 TIA; moeizaam praten en scheve mond; persantin en ascal gekregen. persantin is omgezet in clopidogrel nadien.
# artrose
# 2006 Hypertensie
# 1989 Angina pectoris
# 2011 Anemie
# 2011 Nierfunctiestoornis
# 2011 Aneurysma aorta  nu 3.7 cm
# 2015 colonoscopie ivm positieve test bevolkingsonderzoek (Bernhoven) poliepen vastgesteld
# 2016 CT colon: geen afwijking
# 2017 jan korte opname chirurgie ivm buikklachten, tevens groei aneurysma
# 2017 febr. EVAR ivm aneurysma aortae, postoperatief obstipatie
# 2017 maart verslechtering nierfunctie, proteinurie, echo geen verklaring
# 2018 hyperparathyreoidie: start alfacalcidol
# 2018 mei opname MDL ivm bloeding bij maagulcera
# 2018 juni heropname ivm obstipatie: coloscopie niet afwijkend. Tevens anemie waarvoor transfusie
# 2018 juni verslechtering nierfunctie
# 2018 juli start predialyse traject
#
#
# Beloop:
# Beloop: Voelt zich prima, geen moeheid of andere klachten.
# Is verbaasd over matige nierfunctie.
#
#
# Lichamelijk onderzoek:
# RR 130/60
#
#
# Conclusie:
# Conclusie: matige nierfunctie cf eerder
# anemie
# recente GI bloeding
#
#
# Conclusie:
# Beleid: start predialyse traject
# controle over 3 maanden
# PM over naar CZE tzt?
#
#
# Overige acties:
# - Laboratorium: CRP, Hemoglobine, Natrium, Kalium, Kreatinine + evt. eGFR CKD EPI/eGFR MDRD, Bicarbonaat, Albumine, Calcium, Fosfaat
# - Laboratorium: Natrium U, Volume 24 uurs urine, Eiwit (totaal), Kreatinine U
# - Afspraak: 3 maanden
#
# Overige acties:
# - Aanmelding (pre) dialyse
# -----
# 🩸 Date: 2019-01-11 10:31:00
# 🩸 Match: gibloeding
# 📍 Context: recent negatief gastroscopie coloscopie dd gibloeding ppulmonaal ecg rechtsoverbelasting beleid ad
# 📜 Content: Aan de weledelgeleerde vrouwe
# drs. E.B. Ambachtsheer, huisarts
# [STREETNAME] XV  [CITY]
#
#
#
#
#
# datum
# 25-01-2019
# kenmerk
# 0006397433 / [PATIENTID]
# BSN nr.
# [BSN]
# betreft
# mevrouw [INITIALS] [LASTNAME], geb. [BIRTHDATE] (79)
# [STREETNAME], [ZIP]  [CITY]
# tel. [PHONENUMBER]
#
#
# Geachte collega,
#
# Bovengenoemde patiënte was opgenomen van 07-01-2019 tot en met 11-01-2019 op de afdeling Interne Geneeskunde in verband met anemie.
#
# Conclusie
# 1. Pneumonie AMBU 1 met component overvulling en exacerbatie COPD
#
# 2. Langer bestaande ferriprieve anemie eci met redelijk recent negatieve gastroscopie en coloscopie DD toch GI-bloeding?
#
# 3. P-pulmonale op ECG bij mogelijk rechtsoverbelasting
#
# Beleid
# Ad 1. Amoxicilline oraal t/m 15-1, prednison 30mg t/m 13-1. Tevens ontwatert met furosemide.
# Ad 2. Twee erytrocytentransfusies en verwijzing MDL voor videocapsuleonderzoek
# Ad 3. Iom cardiologie echografie poliklinisch
#
# Voorgeschiedenis
# 1995 mammacarcinoom rechts T2N1M0 waarvoor ablatie en tamoxifen
# cataractoperatie bdz
# 2008 THP rechts
# 2014 Aortabuisprothese met reconstructie a. renalis links
# 2016 TIA
# 2016 polyneuropathie
# 2017 ferriprieve anemie eci . Gastroscopie geen afwijkingen. Coloscopie, 3 tal poliepen. PA: tubulair adenoom met laaggradige dysplasie. Hb 4,1 wv 3 PC's
# 2018 Goed functionerende buisprothese met wel stenotische AIE rechts (=asympt)
#
# Anamnese/lichamelijk onderzoek
# Zie correspondentie 8-1-2019
#
# Aanvullend onderzoek
# Laboratorium
# 08-01-2019
# HEMATOLOGIE: Bezinking (H): 35 mm (< 30), CRP (H): 51 mg/L (< 5), Hemoglobine (L): 7.1 mmol/L (7.5 - 10.0), MCV (L): 79 fL (80 - 100), Leukocyten: 7.9 x10^9/L (4.0 - 10.0)
# CHEMIE: Natrium: 139 mmol/L (135 - 145), Kalium: 4.2 mmol/L (3.5 - 5.0), Kreatinine: 75 µmol/L (49 - 90), eGFR CKD-EPI (L): 65 ml/m/1.73m^2 (> 90)
# Bloedgassen: Materiaal:: cap., pH: 7.43 (7.35 - 7.45), pCO2 (H): 46 mm Hg (32 - 45), pO2 (L): 56 mm Hg (65 - 95), Bicarbonaat (H): 30 mmol/L (22 - 29), Base excess (H): 5 mmol/L (-3.0 - 3.0), O2 saturatie (L): 89 % (95 - 98)
#
# Radiologie
# 07-01-2019
# Verslag - Thorax - 07-01-2019 15:50:00:
# Verslag:
# Zittende AP thorax. Geen tekenen van infiltraat, pleuravocht of vaatovervulling. COPD-beeld.
#
# 09-01-2019
# Verslag - Thorax - 09-01-2019 10:59:00:
# Verslag:
# Thoraxopname AP. Licht toegenomen longconsolidatie links basaal, niet zichtbaar bij voorgaand onderzoek. Suspect voor beginnend infiltraatje.
#
# Microbiologie
# Bloedkweek 7/1 en 9/1: negatief
# Urinekweek 7/1: negatief
# Keeluitstrijk 8/1: negatief
#
# Bespreking
# Bovengenoemde patiënte werd opgenomen met dyspnoe. Alhier werd initieel gedacht dat patiënte overvuld was, waarop met furosemide werd ontwaterd. Later bleek ook sprake van een COPD-beeld op de X-thorax en een pneumonie links. Patiënte werd derhalve behandeld met amoxicilline per os en een stootkuur prednison voor 5 dagen. Patiënte knapte daarbij goed op en kon naar huis worden ontslagen. Poliklinisch zal nog een afspraak volgen bij de cardioloog voor een echo cor omwille van een p-pulmonale op het ecg (mogelijk rechtsoverbelasting).
# Tevens werd bij opname een ferriprieve anemie gevonden met een Hb van 5.0. Redelijk recent werd omwille van dezelfde problematiek een gastroscopie en coloscopie verricht die geen verklaring lieten zien. Alhier kreeg patiënte 2 erytrocytentransfusies en ferinject en patiënte zal poliklinisch door een MDL-arts worden beoordeeld. Eventueel kan dan een videocapsuleonderzoek volgen.
#
# NB: Er werd 1x/week thuiszorg opgestart voor hulp bij verzorging.
#
# Behandelbeperking
# Gekozen behandelbeperking: Reanimeren: nee IC opname: niet beslist Beademen: niet beslist
#
#
# Met vriendelijke groet,
#
# D.S.J. Wintjens, arts assistent
#
# Namens
# dr. P.C.M. Wouters-van Poppel, internist
#
# Deze brief is elektronisch geaccordeerd en daarom niet ondertekend.
# -----
# 🩸 Date: 2019-01-10 12:19:00
# 🩸 Match: gibloeding
# 📍 Context: recent negatief gastroscopie coloscopie dd gibloeding ppulmonaal ecg rechtsoverbelasting beleid ad
# 📜 Content: Aan de weledelgeleerde vrouwe
# drs. E.B. Ambachtsheer, huisarts
# [STREETNAME] XV  [CITY]
#
#
#
#
#
# datum
# 11-01-2019
# kenmerk
# 0006395466 / [PATIENTID]
# BSN nr.
# [BSN]
# betreft
# mevrouw [INITIALS] [LASTNAME], geb. [BIRTHDATE] (79)
# [STREETNAME], [ZIP]  [CITY]
# tel. [PHONENUMBER]
#
#
# Geachte collega,
#
# Bovengenoemde patiënte was opgenomen van 07-01-2019 tot en met 11-01-2019 op de afdeling Interne Geneeskunde in verband met anemie.
#
# Conclusie
# 1. Pneumonie AMBU 1 met component overvulling en exacerbatie COPD
#
# 2. Langer bestaande ferriprieve anemie eci met redelijk recent negatieve gastroscopie en coloscopie DD toch GI-bloeding?
#
# 3. P-pulmonale op ECG bij mogelijk rechtsoverbelasting
#
# Beleid
# Ad 1. Amoxicilline oraal t/m 15-1, prednison 30mg t/m 13-1. Tevens ontwatert met furosemide.
# Ad 2. Twee erytrocytentransfusies en verwijzing MDL voor videocapsuleonderzoek
# Ad 3. Iom cardiologie echografie poliklinisch
#
# Voorgeschiedenis
# 1995 mammacarcinoom rechts T2N1M0 waarvoor ablatie en tamoxifen
# cataractoperatie bdz
# 2008 THP rechts
# 2014 Aortabuisprothese met reconstructie a. renalis links
# 2016 TIA
# 2016 polyneuropathie
# 2017 ferriprieve anemie eci . Gastroscopie geen afwijkingen. Coloscopie, 3 tal poliepen. PA: tubulair adenoom met laaggradige dysplasie. Hb 4,1 wv 3 PC's
# 2018 Goed functionerende buisprothese met wel stenotische AIE rechts (=asympt)
#
# Anamnese/lichamelijk onderzoek
# Zie correspondentie 8-1-2019
#
# Aanvullend onderzoek
# Laboratorium
# 08-01-2019
# HEMATOLOGIE: Bezinking (H): 35 mm (< 30), CRP (H): 51 mg/L (< 5), Hemoglobine (L): 7.1 mmol/L (7.5 - 10.0), MCV (L): 79 fL (80 - 100), Leukocyten: 7.9 x10^9/L (4.0 - 10.0)
# CHEMIE: Natrium: 139 mmol/L (135 - 145), Kalium: 4.2 mmol/L (3.5 - 5.0), Kreatinine: 75 µmol/L (49 - 90), eGFR CKD-EPI (L): 65 ml/m/1.73m^2 (> 90)
# Bloedgassen: Materiaal:: cap., pH: 7.43 (7.35 - 7.45), pCO2 (H): 46 mm Hg (32 - 45), pO2 (L): 56 mm Hg (65 - 95), Bicarbonaat (H): 30 mmol/L (22 - 29), Base excess (H): 5 mmol/L (-3.0 - 3.0), O2 saturatie (L): 89 % (95 - 98)
#
# Radiologie
# 07-01-2019
# Verslag - Thorax - 07-01-2019 15:50:00:
# Verslag:
# Zittende AP thorax. Geen tekenen van infiltraat, pleuravocht of vaatovervulling. COPD-beeld.
#
# 09-01-2019
# Verslag - Thorax - 09-01-2019 10:59:00:
# Verslag:
# Thoraxopname AP. Licht toegenomen longconsolidatie links basaal, niet zichtbaar bij voorgaand onderzoek. Suspect voor beginnend infiltraatje.
#
# Microbiologie
# Bloedkweek 7/1 en 9/1: negatief
# Urinekweek 7/1: negatief
# Keeluitstrijk 8/1: negatief
#
# Bespreking
# Bovengenoemde patiënte werd opgenomen met dyspnoe. Alhier werd initieel gedacht dat patiënte overvuld was, waarop met furosemide werd ontwaterd. Later bleek ook sprake van een COPD-beeld op de X-thorax en een pneumonie links. Patiënte werd derhalve behandeld met amoxicilline per os en een stootkuur prednison voor 5 dagen. Patiënte knapte daarbij goed op en kon naar huis worden ontslagen. Poliklinisch zal nog een afspraak volgen bij de cardioloog voor een echo cor omwille van een p-pulmonale op het ecg (mogelijk rechtsoverbelasting).
# Tevens werd bij opname een ferriprieve anemie gevonden met een Hb van 5.0. Redelijk recent werd omwille van dezelfde problematiek een gastroscopie en coloscopie verricht die geen verklaring lieten zien. Alhier kreeg patiënte 2 erytrocytentransfusies en ferinject en patiënte zal poliklinisch door een MDL-arts worden beoordeeld. Eventueel kan dan een videocapsuleonderzoek volgen.
#
# NB: Er werd 1x/week thuiszorg opgestart voor hulp bij verzorging.
#
# Behandelbeperking
# Gekozen behandelbeperking: Reanimeren: nee IC opname: niet beslist Beademen: niet beslist
#
#
# Met vriendelijke groet,
#
# D.S.J. Wintjens, arts assistent
#
# Namens
# dr. P.C.M. Wouters-van Poppel, internist
#
# Deze brief is elektronisch geaccordeerd en daarom niet ondertekend.
# -----
# 🩸 Date: 2014-08-01 19:31:00
# 🩸 Match: gibloeding
# 📍 Context: phonenumber phonenumber mts triage triagekeus gibloeding gibloeding bloedbraken anamnees triage nee
# 📜 Content: Samenvatting:
# Verpleegkundige verslaglegging
# -Verantwoordelijk verpleegkundige:: <ObjectGegevens>
# [ Vplk SPUTOVAMO ]
# -Leeftijd: 62
# [ Collumcare ]
# -Collumcare patiënt: Nee
# [ Sepsis ]
# -Bestaat er op basis van de anamnese een verdenking op een infectie: Nee
# [ Anamnese ]
# -Leeftijd anamnese: 62
# -(Hoofd)klacht: <ObjectGegevens>
# -A = Allergieën (alleen verpleegkundig): /
# -P = Past: DM
# Hematemesis
# -E = Event: Vandaag al gehele dag niet lekker
# 4x bruin gebraakt, niet helderrood
# N+/v+
# Geen buikpijn
# Def donkerbruin, donkerder als normaal sinds 1 dag geen melena
# ruikt sterker
# Mictie gb
# A: vrij
# B: normopneu, vag
# C: warme, klamme huid
# D: A
# [ Neurologische score ]
# [ Trombosedienst ]
# -Pijnscore invullen?: Ja
# [ Pijnscore ]
# -Pijnscore: 0
# -Score tbv grafiek: 0
# -Verpleegkundige handelingen: IV canule (V) en Lab
# [ Contacten ]
# [ Contactpersonen ]
# -Met wie dienen, indien nodig, verpleging en/of artsen contact op te nemen als u in het ziekenhuis ligt?: mieke smets
# -Wat is de relatie met deze persoon?: kennis
# -Wat is zijn/haar telefoonnummer?: [PHONENUMBER]
# [PHONENUMBER]
# [ MTS triage ]
# -Triagekeuze: GI-bloeding
# -GI-bloeding: Bloedbraken in anamnese
# -Triage: Nee
# -Triage: Nee
# -Triage: Ja
# -Triage: Nee
# -Triage: Nee
# -----
# 🩸 Date: 2014-03-14 09:41:00
# 🩸 Match: gibloeding
# 📍 Context: check bld mts triage triagekeus gibloeding gibloeding zwart donkerrode ontlasting triage
# 📜 Content: Samenvatting:
# Verpleegkundige verslaglegging
# -Verantwoordelijk verpleegkundige:: <ObjectGegevens>
# [ Vplk SPUTOVAMO ]
# -Leeftijd: 61
# [ Collumcare ]
# [ Sepsis ]
# [ Anamnese ]
# -Leeftijd anamnese: 61
# -(Hoofd)klacht: <ObjectGegevens>
# -A = Allergieën (alleen verpleegkundig): niet bekend
# -E = Event: hr heeft twee dagen last van melenae / ziet wat bleek / geen pijnklachten / zou een nog niet bekende diabetes hebben / eten - / drinken ++ /
# -Pijnscore invullen?: Ja
# [ Pijnscore ]
# -Labaanvraag SEH: Labaanvraag SEH, Labaanvraag SEH, Labaanvraag SEH
# -Verpleegkundige handelingen: IV canule (V), Lab, Monitorbewaking en ECG (V)
# [ Verrichtingen registreren 2 ]
# -Verrichting invoeren: Geen
# -Aanvullende informatie: accu check blds 19.4
# [ MTS triage ]
# -Triagekeuze: GI-bloeding
# -GI-bloeding: Zwarte of donkerrode ontlasting
# -Triage: Nee
# -Triage: Nee
# -Triage: Ja
# -Triage: Nee
# -Triage: Nee
# -----
# 🩸 Date: 2019-11-07 09:32:00
# 🩸 Match: gibloeding
# 📍 Context: urosepsis waarvoor ciprofloxaciline verdenking hoog gibloeding duidelijk bloedingsfocus gastro coloscopie klein
# 📜 Content: Samenvatting:
# Voorgeschiedenis
# Rookster
# Claudicatio intermittens
# CVA - Vasculaire dementie
# Atriumfibrilleren
# COPD GOLD II
# 2017 Anemie op basis van Dieulafoy laesie in het pars horizontale van het duodenum waarvoor clips en adrenaline
# 2018 Pseudomonas urosepsis waarvoor ciprofloxaciline
# 2019-01 Verdenking hoge GI-bloeding zonder duidelijk bloedingsfocus bij gastro- en coloscopie. Wel kleine angiodysplasieën in het coecum.
# 2019-02 Heropname met melena, spontaan gestopt na pauzeren antistolling.
# 09-10-2019 Opname ivm exacerbatie COPD
#
# RvO LONG 03-11/ Exacerbatie COPD waarvoor prednison stootkuur.
#
# RvC interne/ Ontregelde glucoses bij prednison stootkuur. Patiënte is niet bekend met DM2.
#
#
# Beloop:
# Gaat morgen met ontslag.
# Prednisolonkuur tot 13.11.2019.
#
#
# Aanvullend onderzoek:
# Glucose 06.11: N 4.8 - VL 8.4 - VA 13.0 (2IE NR) - VS 9.2
# Glucose 07.11: N 4.6
#
#
# Conclusie:
# Mild ontregelde glucosen bij prednisolon stootkuur. Patient eerder niet bekend met DM.
#
#
# Beleid:
# iom dr Willems
# - Morgen gaat patiënt met ontslag
# - Bijspuitschema niet nodig in thuissituatie bij slechts milde ontregeling
# - Prednisolon stopt op 13.11
# - einde consult interne
# -----
# 🩸 Date: 2019-11-06 08:56:00
# 🩸 Match: gibloeding
# 📍 Context: urosepsis waarvoor ciprofloxaciline verdenking hoog gibloeding duidelijk bloedingsfocus gastro coloscopie klein
# 📜 Content: Samenvatting:
# Voorgeschiedenis
# Rookster
# Claudicatio intermittens
# CVA - Vasculaire dementie
# Atriumfibrilleren
# COPD GOLD II
# 2017 Anemie op basis van Dieulafoy laesie in het pars horizontale van het duodenum waarvoor clips en adrenaline
# 2018 Pseudomonas urosepsis waarvoor ciprofloxaciline
# 2019-01 Verdenking hoge GI-bloeding zonder duidelijk bloedingsfocus bij gastro- en coloscopie. Wel kleine angiodysplasieën in het coecum.
# 2019-02 Heropname met melena, spontaan gestopt na pauzeren antistolling.
# 09-10-2019 Opname ivm exacerbatie COPD
#
# RvO LONG 03-11/ Exacerbatie COPD waarvoor prednison stootkuur.
#
# RvC interne/ Ontregelde glucoses bij prednison stootkuur. Patiënte is niet bekend met DM2.
#
#
# Beloop:
# Mild ontregelde glucosen bij prednisolongebruik, met name in de avond. Niet bekend met DM2.
#
#
# Aanvullend onderzoek:
# Glucose 05.11: N 5.4 - VL 7.4 - VA 11.1 - VS 6.6
# Glucose 06.11: N 4.8
#
#
# Beleid:
# iom dr Willems
# - Glucosecurve continueren
# - Bijspuitschema NR ingevoerd
# - Verder nu geen aanpassingen beleid
# -----
# 🩸 Date: 2019-11-05 18:26:00
# 🩸 Match: gibloeding
# 📍 Context: urosepsis waarvoor ciprofloxaciline verdenking hoog gibloeding duidelijk bloedingsfocus gastro coloscopie klein
# 📜 Content: Samenvatting:
# Voorgeschiedenis
# Rookster
# Claudicatio intermittens
# CVA - Vasculaire dementie
# Atriumfibrilleren
# COPD GOLD II
# 2017 Anemie op basis van Dieulafoy laesie in het pars horizontale van het duodenum waarvoor clips en adrenaline
# 2018 Pseudomonas urosepsis waarvoor ciprofloxaciline
# 2019-01 Verdenking hoge GI-bloeding zonder duidelijk bloedingsfocus bij gastro- en coloscopie. Wel kleine angiodysplasieën in het coecum.
# 2019-02 Heropname met melena, spontaan gestopt na pauzeren antistolling.
# 09-10-2019 Opname ivm exacerbatie COPD
#
# RvO LONG 03-11/ Exacerbatie COPD waarvoor prednison stootkuur.
#
# RvC interne/ Ontregelde glucoses bij prednison stootkuur. Patiënte is niet bekend met DM2.
#
#
# Aanvullend onderzoek:
# Glucoses 05-11: 5.4 - 7.4 - 11.1
#
#
# Beleid:
# I.o.m. dr. Willems:
# - 4 punts glucose dagcurve.
# - PM: start novorapid bijspuitschema.
# -----
# 🩸 Date: 2019-11-03 17:33:00
# 🩸 Match: gibloeding
# 📍 Context: Chadsvasc start Dabigatran verdenking hoog gibloeding duidelijk bloedingsfocus gastro coloscopie klein
# 📜 Content: Mw. M.J.C. Lankhorst, huisarts
# Oude Torenstraat 1
# 5581 BJ  WAALRE
#
#
#
#
#
# datum
# 03-11-2019
# kenmerk
# 0006897864 / [PATIENTID]
# BSN nr.
# [BSN]
# betreft
# mevrouw [INITIALS] [LASTNAME], geb. [BIRTHDATE] (85)
# [STREETNAME], [ZIP]  Waalre
# tel. [PHONENUMBER]
#
#
# Geachte collega,
#
# Bovengenoemde patiënt bezocht op 03-11-2019 de spoedeisende hulp.
#
# Reden van komst
# Exacerbatie COPD
#
# Conclusie
# 85-jarige patiente met in VG o.a. nicotine- en alcoholabusus, COPD en AF, presenteert zich met;
#
# 1. Toenemende dyspnoe, hoesten CRP 51, L 8.1 , NT-proBNP 544
# WD exacerbatie COPD met een compoment decompensatio cordis bij AF vvf 100
#
# 2. Waterdunne defecatie, N+V- dd bij gastro-enteritis dd amoxicilline-gebruik
#
# Beleid
# i.o.m. Lips SEH-arts (SEH-arts) ;
# i.o.m. v. Henten (longarts);
# - Opname Pul
# - 4ddEWS
# - streefsaturatie > 90%
# - combivent vernevelingen 6dd
# - amoxicilline stop
# - dagelijks wegen
# - morgen knuk
# - icc transferverpleegkundige
# - morgen contact met huisarts t.a.v. palliatief traject en comfort gericht beleid
# - oramorph 4d5 ml
# ...
# Rectaal bloedverlies bij ascal gebruik dd recidief divertikel bloeding, Hb 8.1, hemodynamisch stabiel
#
# Beleid
# Iom L Mignot (SEH-arts) en Straathof (MDL-arts)
# - Opname AOA
# - Po observatie
# - Ascal tno stop
# - Morgen Hb herhalen
# - Nog geen scopie, normale verwachting van beloopt\ is dat divertikel bloeding vanzelf stopt
# - Hoeft niet nuchter te blijven
# - EWS 3x per dag
# - 1L NaCl 0.9%/24u
#
# Voorgeschiedenis
# 2004 Hypertensie
# 2005 -  PTCA, MOCX; dissectie ; ernstige laesie kleine MO
# 06-2019 NSTEMI en GI bloeding wv 2PC
# 08-2019 divertikelbloeding onder ticagrelor
#
# Medicatie
# OMEPRAZOL CAPSULE MSR 40MG (ORAAL), 1 x per dag 1 stuk
# MACROGOL/ZOUTEN PDR V DRANK (MOVICOLON+GENERIEK) (ORAAL), 1 x per dag 1 stuk
# ACETYLSALICYLZUUR DISPERTABLET 80MG (ORAAL), 1 x per dag 1 stuk
# METOPROLOL TABLET   50MG (ORAAL), 1 x per dag 1 stuk
# ROSUVASTATINE TABLET FO 20MG (ALS CA-ZOUT) (ORAAL), 1 x per dag 1 stuk
#
# Allergieën
# Geen bekend
#
# Anamnese
# Sinds vorige opname geen rectaal bloedverlies of melena meer gehad. Sinds vanmiddag weer rectaal bloedverlies, 4 keer, helderrood/met stolsels, waarvan 3x zonder ontlasting. Geen buikpijn, geen diarree. N- V-. Nog redelijk kunnen eten en drinken. Niet echt duizelig.
#
#
# Lichamelijk onderzoek
# Helder en adequaat, niet ziek
#
# SpO2	%	98
# HR	bpm	58
# NIBP	mmHg	171/84(113)
# Temp	°C	36,2
#
# Abdomen: adipeus, normale peristaltiek, wisselende tympanie, soepel, niet drukpijnlijk
#
# Aanvullend onderzoek
# Lab:
# CRP	1.2	mg/L
# Hemoglobine	8.1	mmol/L
# Hematocriet	0.39	L/L
# MCV	95	fL
# Leukocyten	7.4	x10^9/L
# Trombocyten	219	x10^9/L
# Bloedgroep	A neg
# DAT	neg.
# IAT	neg.
# Glucose	7.7	mmol/l
# Natrium	142	mmol/L
# Kalium	4.4	mmol/L
# Ureum	7.6	mmol/L
# Kreatinine	91	µmol/L
# eGFR CKD-EPI	66	ml/m/1.73m^2
# GGT	18	U/L
# ALAT	16	U/L
# LD	190	U/L
# -----
# 🩸 Date: 2020-02-04 18:45:00
# 🩸 Match: gi bloeding
# 📍 Context: ernstig laesie klein mo nstemi gi bloeding wv divertikelbloeding ticagrelor medicatie omeprazol
# 📜 Content: Reden van komst / Verwijzing:
# Reden van komst (brief): Rectaal bloedverlies
#
# Anamnese:
# Voorgeschiedenis
# 2004 Hypertensie
# 2005 -  PTCA, MOCX; dissectie ; ernstige laesie kleine MO
# 06-2019 NSTEMI en GI bloeding wv 2PC
# 08-2019 divertikelbloeding onder ticagrelor
#
# Medicatie
# OMEPRAZOL CAPSULE MSR 40MG (ORAAL), 1 x per dag 1 stuk
# MACROGOL/ZOUTEN PDR V DRANK (MOVICOLON+GENERIEK) (ORAAL), 1 x per dag 1 stuk
# ACETYLSALICYLZUUR DISPERTABLET 80MG (ORAAL), 1 x per dag 1 stuk
# METOPROLOL TABLET   50MG (ORAAL), 1 x per dag 1 stuk
# ROSUVASTATINE TABLET FO 20MG (ALS CA-ZOUT) (ORAAL), 1 x per dag 1 stuk
#
# Allergieën
# Geen bekend
#
# Anamnese
# Sinds vorige opname geen rectaal bloedverlies of melena meer gehad. Sinds vanmiddag weer rectaal bloedverlies, 4 keer, helderrood/met stolsels, waarvan 3x zonder ontlasting. Geen buikpijn, geen diarree. N- V-. Nog redelijk kunnen eten en drinken. Niet echt duizelig.
#
#
# Lichamelijk onderzoek:
# Helder en adequaat, niet ziek
#
# SpO2	%	98
# HR	bpm	58
# NIBP	mmHg	171/84(113)
# Temp	°C	36,2
#
# Abdomen: adipeus, normale peristaltiek, wisselende tympanie, soepel, niet drukpijnlijk
#
#
# Aanvullend onderzoek:
# Lab:
# CRP	1.2	mg/L
# Hemoglobine	8.1	mmol/L
# Hematocriet	0.39	L/L
# MCV	95	fL
# Leukocyten	7.4	x10^9/L
# Trombocyten	219	x10^9/L
# Bloedgroep	A neg
# DAT	neg.
# IAT	neg.
# Glucose	7.7	mmol/l
# Natrium	142	mmol/L
# Kalium	4.4	mmol/L
# Ureum	7.6	mmol/L
# Kreatinine	91	µmol/L
# eGFR CKD-EPI	66	ml/m/1.73m^2
# GGT	18	U/L
# ALAT	16	U/L
# LD	190	U/L
#
#
#
# Conclusie:
# 85-jarige pt bekend met MI en recidiverende divertikelbloedingen, presenteert zich nu met:
# Rectaal bloedverlies bij ascal gebruik dd recidief divertikel bloeding, Hb 8.1, hemodynamisch stabiel
#
#
# Beleid:
# Algemeen: Opname AOA (Voltooid)
# Po observatie (Voltooid)
# Ascal tno stop (Voltooid)
# Morgen Hb herhalen (Voltooid)
# Hoeft niet nuchter te blijven (Voltooid)
# EWS 3x per dag (Voltooid)
# 1L NaCl 0.9%/24u (Voltooid)
#
# Beleid:
# Iom L Mignot (SEH-arts) en Straathof (MDL-arts)
# - Opname AOA
# - Po observatie
# - Ascal tno stop
# - Morgen Hb herhalen
# - Nog geen scopie, normale verwachting van beloopt\ is dat divertikel bloeding vanzelf stopt
# - Hoeft niet nuchter te blijven
# - EWS 3x per dag
# - 1L NaCl 0.9%/24u
# -----
# 🩸 Date: 2017-08-17 08:36:00
# 🩸 Match: gibloeding
# 📍 Context: wv palcket cells dd hoog gibloeding obvn ulcus Pepticusduodeni obv alcoholgebruik
# 📜 Content: Samenvatting:
# Decursus
# [ Melding patient controle niet opgenomen ]
# -Reden van opname: Melena
# [ Bevindingen / Bespreking ]
# -Bespreking: VPK: gi in loop avond gespannen (alcoholonttrekking?), oxazepam wilde hij niet. Zenuwachtig voor onderzoek. Vaak naar toilet; vandaag def lichter van kleur. Bezig met 2e portie moviprep. Mictie: onbekend.
#
# Controles: pols 70, RR 95/53 mmHg (later 126/75 mmHg), AH 12, saturatie 99% bij kamerlucht, temperatuur 36.9.
#
# Krappe tensie (95/63 mmHg), geen koorts.
# [ Conclusie ]
# -Samenvatting: Sinds 4 dagen zwarte ontlasting, geobjectiveerd bij LO , bij een voorgeschiedenis van alcoholabusus en CVA. Hb 4.1 wv 2 packet cells. DD hoge GI-bloeding obv ulcus pepticus/duodeni, mogelijk obv alcoholgebruik. Echter bij gastroscopie geen aanwijzing voor bloeding. DD lage GI bloeding wv coloscopie.
# [ Beleid ]
# -Beleid: Infuus stop als tensies goed zijn.
#
# Naar huis:
# Poliklinisch FU 1 mnd Boekema.
# PM tzt nieuwe scopie na 7 d staken dipyridamol, capsule enteroscopie.
# R/ ferro, herstart acetylsalicylzuur en dipyridamol.
# -----
# 🩸 Date: 2017-08-17 08:36:00
# 🩸 Match: gibloeding
# 📍 Context: wv palcket cells dd hoog gibloeding obvn ulcus Pepticusduodeni obv alcoholgebruik
# 📜 Content: Samenvatting:
# Conclusie
# -Samenvatting: Sinds 4 dagen zwarte ontlasting, geobjectiveerd bij LO , bij een voorgeschiedenis van alcoholabusus en CVA. Hb 4.1 wv 2 packet cells. DD hoge GI-bloeding obv ulcus pepticus/duodeni, mogelijk obv alcoholgebruik. Echter bij gastroscopie geen aanwijzing voor bloeding. DD lage GI bloeding wv coloscopie.
# [ Beleid ]
# -Beleid: Infuus stop als tensies goed zijn.
#
# Naar huis:
# Poliklinisch FU 1 mnd Boekema.
# PM tzt nieuwe scopie na 7 d staken dipyridamol, capsule enteroscopie.
# R/ ferro, herstart acetylsalicylzuur en dipyridamol.
# -----
# 🩸 Date: 2017-08-16 16:41:00
# 🩸 Match: gibloeding
# 📍 Context: reg zuurstof lab hb dd gibloeding obvn ulcus pepticusduodeni alcoholgebruik werkdiagnose
# 📜 Content: Samenvatting:
# Opnameregistratie
# -Verwijzer: SEH
# -SEH informatie laatste bezoek: Datum: 16-08-2017
# Verantwoordelijk arts:Seh Arts Mdl
# Arts assistent: J.A.C.A. Dibbits
# Reden van komst: Melena
#
#
# Anamnese: Rvk: melena
#
# VG:
# 2010: ischemisch CVA links lacunair
#
# Anamnese:
# Sinds 4 dagen zwarte diarree/brijige ontlasting, ongeveer 1-2x per dag, geen helderrood bloed. Heeft voorafgaand aan de diarree wat krampende pijn in onderbuik, na ontlasting gehad te hebben zijn de klachten weer verdwenen. Verminderde eetlust, eet 's ochtends twee plakjes worst en 's avonds 1 frikandel. Geeft ongeveer 1x per dag over, enkele uren na het eten, zonder bloed. Zuurbranden+. Sinds vannacht toenemend duizelig/licht in het hoofd en slap in de benen bij opstaan. Waarop de HA gebeld. Heeft gisteren eenmalig ibuprofen gebruikt, bruistablet.
#
# Tr. circ: POB-, palpitaties-, uitstraling-
# Tr. resp: hoesten-, dyspnoe-
# Tr. uro: dysurie-, hematurie-, pollakisurie-
# Sociaal: sinds kort weduwnaar, vader van 11-jarige zoon.
# Intoxicaties: rookt 20 sig/dag, drinkt 1L bier per dag
#
# Medicatie: Simvastatine omh 40mg 1d1
# Dipyridamol ret c mga 200mg 2d1
# Acetylsalicylzuur 80mg 1d1
#
# Lichamelijk onderzoek: Niet acuut zieke, wat bleke patient
#
# A: vrij, nexus-
# B: Symmetrische thoraxexcursies, VAG bdz, geen bijgeluiden. SaO2 100% zonder zuurstof.
# C: 132/89, p 90/min. Stabiele thorax/bekken/femora. Abdomen: spaarzame peristaltiek, wisselende tympanie, geen drukpijn, geen loslaatpijn, geen slagpijn nierloges. Soepele buik. RT: zwarte ontlasting aan handschoen.
# D: E4M6V5, geen lateralisatie. Geen aanwijzingen voor meningisme.
# E: T 37.2. Wat bleke sclerae.
#
# Laboratorium: Hb 4.1, Ht 0.20, MCV 82, leuko 12.8, trombo 276, ureum 7.0, glucose 6.6, Na 135, K 3.8, kreat 96, GFR>60, bili tot 3, alk fos 55, ggt 38, asat 24, alat 23, LD 140, lipase 42.
# Functieonderzoek: ECG: sinusritme 89/min, normale hartas, normale geleidingstijden, negatieve p-toppen in AVR en negatief complex V1, geen ST-elevatie of depressie, negatieve t-toppen in III, AVR, geen Q's. Conclusie: normaal ECG
#
# Samenvatting:58-jarige patient met in VG een CVA, komt op SEH met sinds 4 dagen zwarte ontlasting. Is daarbij toenemend licht in het hoofd. Bij LO bleke patient met goede controles: 129/72, p 91/min reg en SaO2 97% zonder zuurstof. In het lab een Hb van 4.1. DD GI-bloeding obv ulcus pepticus/duodeni en alcoholgebruik.
# (Werk)diagnose: Hb 4.1, melena DD hoge GI-bloeding
# Beleid bij vertrek SEH: - Opname AOA voor MDL
# - Erytrocytenconcentraat 2x (bij ASA II patient)
# - Gastroscopie volgt (aanvraag door ass. MDL)
# - Nuchter tot nader order
# - 1.5L NaCl 0.9% gedurende 24 uur
# - Pantoprazol 80mg iv. (op SEH gegeven). Gevolgd door perfusor 8mg/uur.
# - EWS 6dd
# - Hb-controle na 2e erytrocytenconcentraat
# - Volledig beleid, iom patient
# - Continueren thuismedicatie
# -Reden van opname: Melena
# [ Conclusie ]
# -Samenvatting: Sinds 4 dagen zwarte ontlasting, geobjectiveerd bij LO , bij een voorgeschiedenis van alcoholabusus en CVA. Hb 4.1 wv 2 packet cells. DD hoge GI-bloeding obv ulcus pepticus/duodeni, mogelijk obv alcoholgebruik.
# -----
# 🩸 Date: 2017-08-16 15:15:00
# 🩸 Match: gibloeding
# 📍 Context: wv palcket cells dd hoog gibloeding obvn ulcus Pepticusduodeni obv alcoholgebruik
# 📜 Content: Samenvatting:
# Decursus
# [ Melding patient controle niet opgenomen ]
# -Reden van opname: Melena
# -Speciële anamnese: Si 4d zwarte, brijige diarree (1-2 maal daags) en overgeven, dacht eerst dat het door eten van Chinees kwam, maar bleef aanhouden. Nooit eerder zwarte ontlasting gehad. Niet ziek geweest. Nu zeurende pijn in li onderbuik, geen def gehad si gisteren. Si 2d draaiduizelig bij opstaan.
# Gi eenmaal ibuprofen gebruikt voor hoofdpijn.
# Gewicht: anamnestisch geen tekenen van gewichtsverlies, weegt zich nooit.
#
# Intox: roken +, drinkt 1.5 L bier/dag (voorheen 4L).
#
# Sociaal: vriendin (moeder van zoon) 4 mnd geleden overleden op 48-jarige leeftijd; zoon woont bij hem thuis, krijgt veel hulp van vrienden. 100% afgekeurd si 2008 (vrachtwagenchauffeur) ivm rug- en voetklachten. Zoon wordt nu opgevangen door kennis.
# -Algemeen LO: Controles: pols 86, RR 134/75 mmHg, AH 18, saturatie 96% bij kamerlucht, temperatuur 36.7
#
# Matig verzorgd, wat grauw.
# Abdomen: normale peristaltiek, WT, geen drukpijn of palpabele weerstanden.
# [ Bevindingen / Bespreking ]
# -Uitslagen: Gastroscopie 16-08-2017:
# Bulbitis, enige antrumgastritis, geen focus voor bloedverlies.
# [ Conclusie ]
# -Samenvatting: Sinds 4 dagen zwarte ontlasting, geobjectiveerd bij LO , bij een voorgeschiedenis van alcoholabusus en CVA. Hb 4.1 wv 2 packet cells. DD hoge GI-bloeding obv ulcus pepticus/duodeni, mogelijk obv alcoholgebruik. Echter bij gastroscopie geen aanwijzing voor bloeding. DD lage GI bloeding wv coloscopie.
# [ Beleid ]
# -Beleid: Zoals ingezet op SEH.
# Refeedinglab en thiamine.
# Oxazepam z.n. ivm mogelijke alcoholonttrekking.
# Morgen colonoscopie, start voorbereiding vanavond.
# -----
# 🩸 Date: 2017-08-16 15:15:00
# 🩸 Match: gibloeding
# 📍 Context: wv palcket cells dd hoog gibloeding obvn ulcus Pepticusduodeni obv alcoholgebruik
# 📜 Content: Samenvatting:
# Conclusie
# -Samenvatting: Sinds 4 dagen zwarte ontlasting, geobjectiveerd bij LO , bij een voorgeschiedenis van alcoholabusus en CVA. Hb 4.1 wv 2 packet cells. DD hoge GI-bloeding obv ulcus pepticus/duodeni, mogelijk obv alcoholgebruik. Echter bij gastroscopie geen aanwijzing voor bloeding. DD lage GI bloeding wv coloscopie.
# [ Beleid ]
# -Beleid: Zoals ingezet op SEH.
# Refeedinglab en thiamine.
# Oxazepam z.n. ivm mogelijke alcoholonttrekking.
# Morgen colonoscopie, start voorbereiding vanavond.
# -----
# 🩸 Date: 2017-08-16 10:31:00
# 🩸 Match: gibloeding
# 📍 Context: reg zuurstof lab hb dd gibloeding obvn ulcus pepticusduodeni alcoholgebruik werkdiagnose
# 📜 Content: Samenvatting:
# Medisch Dossier
# [ Vk Sputovamo ]
# -Leeftijd in jaren: 58
# -Registratie datum SEH: 16-08-2017
# -Verantwoordelijk assistent: <ObjectGegevens>
# -Verantwoordelijk arts: <ObjectGegevens>
# -Dienstdoend specialist: <ObjectGegevens>
# -Reden van komst: Melena
# -ECG-direct afgenomen op: 16-08-2017
# [ Medisch dossier ]
# [ Anamnese ]
# -Anamnese: Rvk: melena
#
# VG:
# 2010: ischemisch CVA links lacunair
#
# Anamnese:
# Sinds 4 dagen zwarte diarree/brijige ontlasting, ongeveer 1-2x per dag, geen helderrood bloed. Heeft voorafgaand aan de diarree wat krampende pijn in onderbuik, na ontlasting gehad te hebben zijn de klachten weer verdwenen. Verminderde eetlust, eet 's ochtends twee plakjes worst en 's avonds 1 frikandel. Geeft ongeveer 1x per dag over, enkele uren na het eten, zonder bloed. Zuurbranden+. Sinds vannacht toenemend duizelig/licht in het hoofd en slap in de benen bij opstaan. Waarop de HA gebeld. Heeft gisteren eenmalig ibuprofen gebruikt, bruistablet.
#
# Tr. circ: POB-, palpitaties-, uitstraling-
# Tr. resp: hoesten-, dyspnoe-
# Tr. uro: dysurie-, hematurie-, pollakisurie-
# Sociaal: sinds kort weduwnaar, vader van 11-jarige zoon.
# Intoxicaties: rookt 20 sig/dag, drinkt 1L bier per dag
# -Medicatie: Simvastatine omh 40mg 1d1
# Dipyridamol ret c mga 200mg 2d1
# Acetylsalicylzuur 80mg 1d1
# -A = Allergieën (alleen verpleegkundig): -
# [ Onderzoek ]
# -Lichamelijk onderzoek: Niet acuut zieke, wat bleke patient
#
# A: vrij, nexus-
# B: Symmetrische thoraxexcursies, VAG bdz, geen bijgeluiden. SaO2 100% zonder zuurstof.
# C: 132/89, p 90/min. Stabiele thorax/bekken/femora. Abdomen: spaarzame peristaltiek, wisselende tympanie, geen drukpijn, geen loslaatpijn, geen slagpijn nierloges. Soepele buik. RT: zwarte ontlasting aan handschoen.
# D: E4M6V5, geen lateralisatie. Geen aanwijzingen voor meningisme.
# E: T 37.2. Wat bleke sclerae.
# -Aanvullend onderzoek: Ja
# -Lab: Hb 4.1, Ht 0.20, MCV 82, leuko 12.8, trombo 276, ureum 7.0, glucose 6.6, Na 135, K 3.8, kreat 96, GFR>60, bili tot 3, alk fos 55, ggt 38, asat 24, alat 23, LD 140, lipase 42.
# -Functieonderzoek: ECG: sinusritme 89/min, normale hartas, normale geleidingstijden, negatieve p-toppen in AVR en negatief complex V1, geen ST-elevatie of depressie, negatieve t-toppen in III, AVR, geen Q's. Conclusie: normaal ECG
# [ Conclusie ]
# -Samenvatting: 58-jarige patient met in VG een CVA, komt op SEH met sinds 4 dagen zwarte ontlasting. Is daarbij toenemend licht in het hoofd. Bij LO bleke patient met goede controles: 129/72, p 91/min reg en SaO2 97% zonder zuurstof. In het lab een Hb van 4.1. DD GI-bloeding obv ulcus pepticus/duodeni en alcoholgebruik.
# -(Werk)diagnose: Hb 4.1, melena DD hoge GI-bloeding
# [ Beleid ]
# -Beleid: - Opname AOA voor MDL
# - Erytrocytenconcentraat 2x (bij ASA II patient)
# - Gastroscopie volgt (aanvraag door ass. MDL)
# - Nuchter tot nader order
# - 1.5L NaCl 0.9% gedurende 24 uur
# - Pantoprazol 80mg iv. (op SEH gegeven). Gevolgd door perfusor 8mg/uur.
# - EWS 6dd
# - Hb-controle na 2e erytrocytenconcentraat
# - Volledig beleid, iom patient
# - Continueren thuismedicatie
# [ Opdrachten ]
# [ Opdrachten SEH ]
# -Opdrachten SEH verpleegkundige: pantoprazol 80mg iv bolus (Te accepteren)
# [ Opdrachten verpleegafdeling V2 ]
# -Algemeen: Opname AOA voor MDL (Voltooid)
# -Infuusbeleid: Erytrocytenconcentraat 2x (bij ASA II patient) (Voltooid)
# -Zuurstofbeleid: Gastroscopie volgt (Voltooid)
# -Onderzoeken: Nuchter tot nader order (Voltooid)
# -Observaties: 1.5L NaCl 0.9% gedurende 24 uur (Voltooid)
# -Metingen: Pantoprazol 80mg iv. (op SEH gegeven). Gevolgd door perfusor 8mg/uur. (Voltooid)
# -Voeding: EWS 6dd (Voltooid)
# -ADL: Hb-controle na 2e erytrocytenconcentraat (Voltooid)
# -Algemeen: Volledig beleid, iom patient (Voltooid)
# Continueren thuismedicatie (Voltooid)
# [ NIHSS score ]
# -Toelichting: Voor uitleg scoring, zie stroke protocol, bijlagen
# [ Overig ]
# -Gezien door (naam, functie): [FIRSTNAME] Dibbits anios SEH, E. Smits SEH-arts
# -In overleg met (naam, functie): Boekema MDL-arts
# [ hulplijst sepsis ]
# -Bestaat er op basis van de anamnese een verdenking op een infectie: Nee
# -----

# %%
for i, row in df_specific[df_specific['pseudo_id'] == 'C71B153E9F184C29E8D39654E41C8B54586E3AF4'].iterrows():
    print(f"🩸 Date: {row['date']}")
    print(f"🩸 Match: {row['agib_match']}")
    print(f"📍 Context: {row['agib_context']}")
    print(f"📜 Content: {row['verslagen_report_content']}")
    print("-----")
# Out:
# 🩸 Date: 2020-01-08 12:58:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Reden van komst / Verwijzing:
# Reden van komst (brief): Aanrijding fiets
#
# Anamnese:
# Patiënte is op de fiets aangereden door auto (ongeveer 20km/u). Daarbij met hoofd op vooruit gekomen en daarna op straat gevallen. Geen bewustzijnsverlies.
# Anamnestisch bekend met onregelmatig hartritme, echter geen documentatie hiervan. Niet onder behandeling van een cardioloog.
# Allergie: geen bekend.
# CLOPIDOGREL TABLET   75MG (ORAAL), 1 x per dag 75 milligram
# FERROFUMARAAT TABLET 200MG (ORAAL), 1 x per 2 dagen 1 stuk 7-1-2020 laatste
# FOLIUMZUUR TABLET 0,5MG (ORAAL), 1 x per dag 1 stuk
# LERCANIDIPINE TABLET OMHULD 10MG (ORAAL), 1 x per dag 1 stuk
# ENALAPRIL/HYDROCHLOORTHIAZIDE TABLET 20/12,5MG (ORAAL), 1 x per dag 1 stuk
#
#
#
#
# Lichamelijk onderzoek:
# A: vrij, CWK drukpijnlijk C3-C4
# B: SaO2 98% bij kl.  Pul: VAG bdz. Drukpijn sternum+. Geen uitwendig letsel. Geen drukpijn ribben
# C: Bloeddruk 158/65mmHg, 122/min . Abd: soepel, niet drukpijnlijk. Bekken/femora: stabiel, niet drukpijnlijk.
# D: EMVmax, geen lateralisatie, PEARRL. Georienteerd in triplo.
# E: Temp 36,7 graden Celsius.
# Logroll: wervelkolom: geen hematomen/verwondingen, niet drukpijnlijk.
#
# Secondary survey
# Palpatie aangezicht niet pijnlijk, ossale structuren intact. Kaakocclusie goed. Oogvolgbewegingen normaal. Laceratie 3cm kin
#
# Neurologisch onderzoek:
# Georienteerd in triplo. Geen dysartrie of afasie. Geen imprentingsstoornis.
# HZ: pupillen isocoor lichtreactief, OVB ongestoord, geen nystagmus/diplopie,  sensomotoriek gelaat ongestoord, SCM/trapezius MRC 5/5.
# Coordinatie: VTNP ongestoord.
# Motoriek: barre zakt niet uit. Biceps/triceps/vingerflexoren MRC 5/5. Quadriceps//ileopsoas MRC 5/5. Voetheffers/strekkers MRC 5/5.
# Sensibiliteit: Globaal intact
# Reflex: VZR Plantair bdz. BPR/TPR/RR 0/0
#
# Pols links:
# inspectie; hematoom thv ulna
# palpatie: drukpijn distale ulna+, radius-, tabatiere-
# bew ond: niet beperkt
# nv intact
#
# Extremiteiten:
# Dig III rechter hand: hematoom, zwelling thv proximale phalanx. Drukpijn proximale phalanx. Geen asdrukpijn. Flexie/extensie intact.
#
# Excoriatie R knie en dorsale scheenbeen, kleine laceratie L knie,gehecht.
#
#
#
#
# Aanvullend onderzoek:
# Lab: 025644
# 08-01-2020 13:32
# Hemoglobine	7.3	mmol/L
# Hematocriet	0.34	L/L
# MCV	97	fL
# hs Troponine T	25	ng/l
#
# ECG:  SR met PAC's danwel atriumfiblleren 116/min, IM-as, overig conform eerder ECG.
# (iom dr. Verbunt Cardioloog: medebeoordeling ECG > ook niet met zekerheid te differentieren tussen SR met PAC of AF)
#
# Beeldvorming
# X-thorax: geen aanwijzingen voor pneumonthorax/hemothorax
# CT-cerebrum/CWK: CT-schedel:
# Blanco scan schedel. Reconstructies in botsetting.
# Atrofie passend bij de leeftijd. Klein lacunair defect basale ganglia links. In het hersenparenchym geen gebieden met massawerking. Geen bloeding of hematoom.
# Het neurocranium is intact.
# Conclusie: geen traumatische afwijkingen.
#
# CT-CWK: volumescan CWK in botsetting. Reconstructies vervaardigd. Afbeelding schedelbasis tot en met Th2.
# De corpora staan in lijn en zijn op hoogte. De ossale structuren zijn intact, geen fractuur.
# Versterkte TWR-versmalling met degeneratieve afwijkingen niveau C4/C7.
# Conclusie: degeneratieve afwijkingen CWK. Geen traumatische afwijkingen.
#
# X-pols L: geen fractuur
# X- sternum: geen fractuur.
# X-dig III R: avulsiefractuur palmaire zijde basis middelste falanx
#
#
#
# Conclusie:
# 1. HET fiets tegen auto met trauma capitis ABCD stabiel. Op CT-cerebrum geen traumatische afwijkingen.
# 2. ECG SR met PAC's danwel AF de novo DD corcontusie (Trop T niet verhoogd)
# 3. Wond kin en knie links
#
#
# Beleid:
# Algemeen: Co 6wk controle neurologie, folder LTH meegeven (Voltooid)
# Opname AOA met telemetrie (Voltooid)
# Co 1wk traumapoli (Te accepteren)
#
# Beleid:
# Observaties: EWS 3dd (voltooid)
#
# Beleid:
# Interventies: Mobiliseren (voltooid)
#
# Beleid:
# Voeding: ~Eigen dieet (voltooid)
# Waakinfuus (voltooid)
#
# Beleid:
# In medevisie van dr. Admiraal/dr Jetten (SEH-arts):
# - Spalk dig III rechts.
# - Co 1wk traumapoli
# - Hechting kin en linker knie
#
# I.o.m. dr. Verbunt (dd cardioloog)
# - Opname AOA met telemetrie
# - EWS 3dd
# - Mobiliseren
# - Eigen dieet
# - Waakinfuus
# - Paracetamol 4dd1000mg zn
# - Oxycodon 6dd 5mg zn
#  - Movicolon 1dd1 zn
# I.o.m. vd Hoef (assistent chirurguie)
# - medebehndeling morgen tertiaire survey
#
# I.o.m. dr. van Ginneken (dd neuroloog):
# - Co 6wk controle neurologie, folder LTH meegeven
# -----
# 🩸 Date: 2020-01-08 12:30:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Beloop:
# Verpleegkundige rapportage (naslag): Mw. pijnstilling aangeboden, wil deze niet.
# -----
# 🩸 Date: 2019-10-14 16:51:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Dhr. B. ter Keurst, huisarts
# [STREETNAME] LX  [CITY]
#
#
#
#
#
# datum
# 14-10-2019
# kenmerk
# 0006864707 / [PATIENTID]
# BSN nr.
# [BSN]
# betreft
# mevrouw [INITIALS] [LASTNAME], geb. [BIRTHDATE] (74)
# [STREETNAME], [ZIP]  [CITY]
# tel. [PHONENUMBER]
#
#
# Geachte collega,
#
# Recent zag ik bovengenoemde patiënte op de Polikliniek Maag Darm Leverziekten.
#
# Overweging/differentiaal diagnose
# Ik heb de uitslag van het bloedonderzoek met patiënte en haar echtgenoot besproken:  Hb stabiel.
# Daarom voorgesteld Fe nog wat verder te minderen: naar om de dag.
#
# Beleid
# Ferro-tabletten minderen  naar om de dag
# over 3 maanden weer controle Hb, ik zal haar dan bellen over de uitslag
#
# Relevante voorgeschiedenis
# 2019	opname in verband met ernstige anemie, waarvoor transfusie.
# 	CT colonografie: geen poliepen, geen verklaring voor anemie.
# 	CT enterografie: geen aanwijzingen voor een enterale bloedingsbron.
# Teruggaand tot en met de CT-thorax de dato 01-12-2011, ongewijzigde bilobair vergrote bijnier rechts.
# 2016 	matuur cataract
# 2015 	ijzergebreksanemie: coeliakie.
# Gastroscopie: spoortje hematine in de maag zonder aanwijzingen voor ontsteking. Verder normaal aspect van slokdarm, maag en duodenum.
# PA biopten: subtotale vlokatrofie (Marsh 3b).
# 	Colonoscopie: geen afwijkingen.
# 2012 	Wervel, laminect.1 niveau geen tumor (kanaalstenose)
# 2012 	Gewichtsverlies eci.
# Colonoscopie tot aan de flexura hepatica, in het geïnspecteerde traject geen afwijkingen.
# Gastroscopie: nog voedsel in de maag, geen slijmvliesafwijkingen gezien.
# 2008 	Colonoscopie: sigmoidpoliep verwijderd, geen PA.
# 2005 	Colonoscopie: tubulair adenoom in het rectum.
#
# Samenvatting
# Ferriprieve anemie, meest waarschijnlijk bij coeliakie of verminderde beenmergfunctie.
#
# Beloop
# onveranderd. Geen nieuwe klachten.
#
# Aanvullend onderzoek
#
# Laboratorium
# 07-10-2019
# HEMATOLOGIE: Hemoglobine (L): 7.1 mmol/L (7.5 - 10.0), MCV: 98 fL (80 - 100)
# CHEMIE: Ferritine (H): 340 µg/L (13 - 150), IJzer: 25 µmol/L (9 - 30), Transferrine: 2.0 g/L (2.0 - 3.6), Transferrine verzadiging: 50 % (15 - 50), TF/log FERR: 0.78 (< 1.7)
#
# Actuele medicatie: thuismedicatie
# Lercanidipine tablet omhuld 10mg; oraal; 1 x per dag 1 stuk
# Triamcinolonacetonide zalf 1mg/g; cutaan; zo nodig 1 x per dag aanbrengen
# Atorvastatine tablet 20mg; oraal; 1 x per dag 1 stuk levenslange indicatie
# Clopidogrel tablet   75mg; oraal; 1 x per dag 75 milligram
# Enalapril/hydrochloorthiazide tablet 20/12,5mg; oraal; 1 x per dag 1 stuk
# Foliumzuur tablet 0,5mg; oraal; 1 x per dag 1 stuk
# Ferrofumaraat tablet 200mg; oraal; 1 x per 2 dagen 1 stuk
#
#
# Met vriendelijke groet,
#
# dr. M.L. Verhulst, maag-darm-leverarts
#
#
# Deze brief is elektronisch geaccordeerd en daarom niet ondertekend.
# -----
# 🩸 Date: 2019-10-10 09:20:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Samenvatting:
# Ferriprieve anemie, meest waarschijnlijk bij coeliakie.
#
#
# Beloop:
# onveranderd. Geen nieuwe klachten.
# Goede zomer gehad, moet nu wennen aan de koude.
#
#
# Aanvullend onderzoek:
# bloedonderzoek:  Hb stabiel.
#
#
# Overweging / Differentiaal diagnose:
# Ik heb de uitslag van het onderzoek met patiënte en haar echtgenoot besproken:  Hb stabiel.
# Daarom voorgesteld Fe nog wat verder te minderen: naar om de dag. Patiënte gaf aan dit te begrijpen en gaat akkoord.
#
#
# Beleid:
# Ferro-tabletten minderen  naar om de dag
# over 3 maanden weer controle Hb, ik zal dan bellen over de uitslag
#
#
# Overige acties:
# - Afspraak: 3 maanden
# - Laboratorium: CRP, Ferritine, Hemoglobine, MCV
# -----
# 🩸 Date: 2019-07-09 15:20:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Samenvatting:
# Ferriprieve anemie, meest waarschijnlijk bij coeliakie.
#
#
# Beloop:
# het gaat goed. Heeft momenteel geen klachten.
#
#
# Aanvullend onderzoek:
# bloedonderzoek: Hb stabiel, nu 6,9 mmol/l.  Aantal reticulocyten relatief laag.
#
#
# Conclusie:
# Onveranderd anemie, ondanks suppletie. Geen klachten.
#
#
# Overweging / Differentiaal diagnose:
# Ik heb de uitslag van het bloedonderzoek met patiënt besproken: Hb onveranderd, ondanks 2 ferrofumaraat per dag. De vraag is of er ook sprake kan zijn van beenmerg dat niet optimaal nieuw bloed aanmaakt.
# Het voorstel is Fe-tabletten te minderen naar 1 per dag en over 3 maanden het bloedonderzoek te herhalen, dit met name omdat ze geen klachten heeft. Patiënte gaf aan dit te begrijpen en gaat akkoord.
#
#
# Beleid:
# Fe minderen naar 1 per dag
# over 3 maanden weer bloedonderzoek.
#
#
# Overige acties:
# - Laboratorium: IJzer / Transferrine + % verz. Transferrine, Ferritine, Hemoglobine, MCV
# - Afspraak: 3 maanden
# -----
# 🩸 Date: 2019-05-20 10:10:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Samenvatting:
# Ferriprieve anemie, meest waarschijnlijk bij coeliakie.
#
#
# Beloop:
# Heeft last van rechter been: blijkt een lekkende spatader te zijn. Wordt hieraan einde mei geopereerd.
#
#
# Aanvullend onderzoek:
# bloedonderzoek: Hb 6,8 mmol/l, verder geen afwijkingen.
#
#
# Overweging / Differentiaal diagnose:
# Ik heb de uitslag van het bloedonderzoek met patiënte en haar echtgenoot besproken: Hb nu goed, ook geen tekort aan Fe of foliumzuur. In bloed nu geen aanwijzingen voor coeliakie. Bloedarmoede zou ook kunnen passen bij minder goed functioneren van beenmerg, daaraan niet veel te doen, anders dan zorgen voor voldoende Fe en vitamines.
# Daarom nu niets veranderen.
#
#
# Beleid:
# over 6 weken weer bloedonderzoek, ik bel dan over de uitslag
#
#
# Overige acties:
# - Afspraak: 6 weken
# - Laboratorium: Hemoglobine, MCV, Reticulocyten
# -----
# 🩸 Date: 2019-04-08 10:42:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Samenvatting:
# Ferriprieve anemie, meest waarschijnlijk bij coeliakie.
#
#
# Beloop:
# heeft last van stijve benen, vanaf de heupen. Moeheid lijkt af te nemen.
#
#
# Aanvullend onderzoek:
# Hb gestegen naar 6,5 mmol/l.
# CT enterografie:
# 1: geen aanwijzingen voor een enterale bloedingsbron.
# 2: teruggaand tot en met de CT-thorax de dato 01-12-2011, ongewijzigde bilobair vergrote bijnier rechts.
#
#
# Overweging / Differentiaal diagnose:
# Ik heb de uitslag van het bloedonderzoek en de CT scan met patiënte en haar echtgenoot besproken: in de dunne darm geen afwijkingen. Geen verklaring voor laag Hb. Met patiënte werd tijdens de opname niet gesproken over herhalen van een gastroscopie. Nu wel gedaan, maar daar voelt zij niet voor. Ook voelt zij nog steeds niet voor starten met een glutenvrij dieet. Ik heb haar gezegd dat een dieet ook kan helpen bij de behandeling van bloedarmoede. Informatie via www.mlds.nl meegegeven. Zij gaat dat lezen en we komen er bij volgend consult op terug.
#
#
# Beleid:
# voorlopig doorgaan met Fe en foliumzuur
# over 6 weken weer controle bloed.
#
#
# Overige acties:
# - Laboratorium: IJzer / Transferrine + % verz. Transferrine, CRP, Ferritine, Foliumzuur, Hemoglobine, IgA, MCV, anti-tTG (IgA), Coeliakie diagnostiek, Onderzoek:, Onderzoek: Coeliakie
# - Afspraak: 6 weken
# -----
# 🩸 Date: 2019-03-18 10:29:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Samenvatting:
# Ferriprieve anemie, acute nierinsufficiëntie
# Voorgeschiedenis: coeliakie
# AS: clopidogrel
#
#
# Beloop:
# Vandaag weer bloedtransfusie. Heeft geen specifieke klachten. Houdt geen dieet ivm coeliakie.
#
#
# Aanvullend onderzoek:
# Hb weer gedaald.
# CT colonografie: lang slingerend sigmoïd zonder stenose of divertikels. Geen aanwijzingen voor RIP of poliepen. Goed ontplooiend normaal caecum. Normale ileocaecale overgang.
# Voor zover de extracolonische organen zonder i.v. contrast te beoordelen geen duidelijke afwijkingen. Iliacaal stents beiderzijds in situ.
#
#
# Overweging / Differentiaal diagnose:
# Ik heb met patiënte en haar echtgenoot gesproken over mogelijke verklaring van laag Hb: onvoldoende resorptie van Fe door coeliakie of verlies van bloed ergens in maag of darmen. Op CT colonografie geen poliep of tumor, maar bloedverlies uit kleine vaatjes kan nog altijd. Ook kan er  (bij niet behandelde coeliakie) in de dunne darm afwijking ontstaan, waaruit bloedverlies. Zeker bij gebruik bloedverdunners. Daarom voorgesteld een CT enterografie te verrichten, om dunne darm beter in beeld te brengen. Patiënte wil dit nu wel.
#
#
# Beleid:
# CT enterografie
# vandaag bloedtransfusie, daarna Hb controle over 2 weken
#
#
# Overige acties:
# - Afspraak: 3 weken
# - Radiologie: CT abdomen enteroclyse + iv contrast
# - Laboratorium: Hemoglobine, MCV, Reticulocyten
# -----
# 🩸 Date: 2019-03-15 10:00:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Samenvatting:
# Ferriprieve anemie, acute nierinsufficiëntie
# Voorgeschiedenis: coeliakie
# AS: clopidogrel
#
#
# Beloop:
# Graag recept ivm ijzerinfuus in HIX zetten ovv Dagbeh.
# -----
# 🩸 Date: 2019-03-14 15:16:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Samenvatting:
# Ferriprieve anemie, acute nierinsufficiëntie
# Voorgeschiedenis: coeliakie
# AS: clopidogrel
#
#
# Beloop:
# Opname gemaild voor transfusie en ijzerinfuus, zij gaan inplannen, kruisbloed  labbon naar pte opgestuurd.
# -----
# 🩸 Date: 2019-03-14 14:56:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Samenvatting:
# Ferriprieve anemie, acute nierinsufficiëntie
# Voorgeschiedenis: coeliakie
# AS: clopidogrel
#
#
# Anamnese:
# Is moe. Komt tot weinig.
#
#
# Aanvullend onderzoek:
# 14-03-2019
# Hemoglobine	4.6	mmol/L
# MCV	89	fL
# Ferritine	200	µg/L
# IJzer	12	µmol/L
# Transferrine	2.6	g/L
# Transferrine verzadiging	18	%
# TF/log FERR	1.11
# Foliumzuur	10	nmol/l
# Vitamine B12	310	pmol/L
#
# Ferritine wel gestegen op 500mg ijzer en packed cells. Nu wel weer Hb 4,6
#
#
# Beleid:
# ijzerinfuus 1 gr en 2 packed cells via dagbehandeling.
# PM nog gastroscopie eens gezien eerder hematine aldaar.
#
#
# Overige acties:
# - Aanvraag Opname
#
# Overige acties:
# - Afspraak
# -----
# 🩸 Date: 2019-02-22 15:40:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Dhr. B. ter Keurst, huisarts
# [STREETNAME] LX  [CITY]
#
#
#
#
#
# datum
#   -  -
# kenmerk
# 0006476277 / [PATIENTID]
# BSN nr.
# [BSN]
# betreft
# mevrouw [INITIALS] [LASTNAME], geb. [BIRTHDATE] (73)
# [STREETNAME], [ZIP]  [CITY]
# tel. [PHONENUMBER]
#
#
# Geachte collega,
#
# Bovengenoemde patiënte was opgenomen van 21-02-2019 tot en met 22-02-2019 op de afdeling Maag-, Darm- en Leverziekten in verband met anemie.
#
# Conclusie
# Ferriprieve anemie, mogelijk bij occult gastro-intestinaal bloedverlies
#
# Beleid
# 2PC erytrocytenconcentraat
# 500mg ferrinject, ferrofumaraat 2dd200mg
# Poli afspraak dr. Verhulst 18-3 met lab vooraf
#
# Relevante voorgeschiedenis
# 2016 matuur cataract
# 2015 coeliakie
# 2015 ijzergebreksanemie
# 2015 ijzergebreksanemie
# 2015 Procedurele sedatie analgesie (PSA) buiten de OK
# 2012 Wervel, laminect.1 niveau geen tumor (kanaalstenose)
# 2008 Colonoscopie: follow up colonpoliepen 2005, tubulair adenoom in het rectum. Nu 1 sigmoidpoliep verwijderd
#
# Anamnese
# Sinds enkele maanden vermoeid, dyspneu bij inspanning. tevens duizelig. Heeft last van hartkloppingen sinds enkele weken.
# Heeft in december een grote wond gehad aan het been die veel heeft gebloed. Daarnaast vrijwel dagelijks bloedneuzen die dan de hele ochtend duren.
# Geen zwarte ontlasting of bloed bij ontlasting.
# Eten gaat wel goed, wel iets minder afgelopen tijd.
#
# Lichamelijk onderzoek
# Niet acuut ziek helder en adequaat
# AH 16/min, temp 36.6, HF 110/min, saturatie 100%, tensie 142/63
# H/H: geen klieren voelbaar, bleke sclera. Iets verhoogd CVD links.
# Cor: S1S2, geen bijgeluiden
# Pul: VAG, licht brommen over alle longvelden
# Abd: np, wt,gevoelig rechtsonder, soepele buik, geen loslaatpijn
# Extr: geen oedeem
#
# Aanvullend onderzoek
# Laboratorium
# 21-02-2019
# HEMATOLOGIE: CRP: 0.30 mg/L (< 5), Hemoglobine (L): 3.7 mmol/L (7.5 - 10.0), Hematocriet (L): 0.19 L/L (0.35 - 0.45), Erytrocyten (L): 2.39 x10^12/L (4.00 - 5.00), Reticulocyten: 37 x10^9/L (25 - 120), Ret.Prod.Index (L): 0.3 % (> 2.0), MCV (L): 79 fL (80 - 100), Leukocyten: 5.8 x10^9/L (4.0 - 10.0), Trombocyten: 352 x10^9/L (150 - 400)
# Bloedgroep: Bloedgroep: A pos, IAT: neg. (negatief)
# CHEMIE: Glucose: 6.1 mmol/l (4.0 - 7.8), Natrium (L): 130 mmol/L (135 - 145), Kalium: 4.3 mmol/L (3.5 - 5.0), Ureum (H): 12.6 mmol/L (2.5 - 6.4), Kreatinine (H): 99 µmol/L (49 - 90), eGFR CKD-EPI (L): 48 ml/m/1.73m^2 (> 90), Alkalische Fosfatase (AF) (H): 112 U/L (33 - 98), GGT: 29 U/L (< 38), ALAT: 16 U/L (< 34), LD: 150 U/L (< 247), Haptoglobine: 1.64 g/L (0.37 - 2.21), Ferritine: 14 µg/L (13 - 150), IJzer (L): 7 µmol/L (9 - 30), Transferrine: 3.4 g/L (2.0 - 3.6), Transferrine verzadiging (L): 8 % (15 - 50), TF/log FERR (H): 2.92 (< 1.7), Albumine: 44 g/L (35 - 50)
# Vitaminen: Foliumzuur (L): 4 nmol/l (> 8.0), Vitamine B12: 160 pmol/L (145 - 569)
#
# ECG: sinusritme regulair, HF 92, INT hart-as, iets verbreed QRS-complex 129, andere gleidngstijden normaal. ST-depressie 1 mm in V3 en V4, geen ST-elevatie, inverse T in V1. RBTB. ECG conform eerder.
#
# Beloop
# De bovengenoemde patiënte werd opgenomen i.v.m. vermoeidheid, dyspnoe en duizeligheid. Bloedonderzoek liet een ferriprieve anemie en acute nierinsufficiëntie zien. Er werd gedacht aan occult gastro-intestinaal bloedverlies. De patiënte werd behandeld met 2PCs erytrocytenconcentraat en ijzersuppletie. Hierop verdwenen de klachten. De patiënte gaf aan geen behoefte te hebben aan aanvullend onderzoek, zoals een coloscopie of CT van het colon ter analyse van een mogelijke bloedingsfocus. Ze zal poliklinisch vervolgd worden bij dr. Verhulst op 18-3.
#
# Actuele medicatie: thuismedicatie
# Ferrofumaraat tablet 200mg; oraal; 2 x per dag 1 stuk
# Foliumzuur tablet 0,5mg; oraal; 1 x per dag 1 stuk
# Lercanidipine tablet omhuld 10mg; oraal; 1 x per dag 1 stuk
# Elvitaal calcium magnesium zink tablet; niet ingev.; 1 x per dag 1 stuk
# Pantoprazol tablet msr 20mg; oraal; 1 x per dag 1 stuk
# Paracetamol tablet  500mg; oraal; 4 x per dag 2 stuk
# Triamcinolonacetonide zalf 1mg/g; cutaan; zo nodig 1 x per dag aanbrengen
# Atorvastatine tablet 20mg; oraal; 1 x per dag 1 stuk levenslange indicatie
# Clopidogrel tablet   75mg; oraal; 1 x per dag 75 milligram
#
#
# Met vriendelijke groet,
#
# M.J.M. van Agtmaal, arts assistent
#
# Namens
# dr. M.J. ter Borg, maag-darm-leverarts
#
# Deze brief is elektronisch geaccordeerd en daarom niet ondertekend.
# -----
# 🩸 Date: 2019-02-22 10:30:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Samenvatting:
# Ferriprieve anemie, acute nierinsufficiëntie
# Voorgeschiedenis: coeliakie
# AS: clopidogrel
#
#
# Beloop:
# cp na ct-colonografie 28-2. Graag iom dr. Verhulst te plannen, 18-3 eerste reguliere mogelijkheid. Afspraak mag per post worden verstuurd.
# ed: ct gaat niet door, cp 18-3 is akkoord
# -----
# 🩸 Date: 2019-02-22 08:58:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Samenvatting:
# Ferriprieve anemie, acute nierinsufficiëntie
# Voorgeschiedenis: coeliakie
# AS: clopidogrel
#
#
# Beloop:
# Slecht geslapen, voelt zich fit. Wil graag naar huis. Uitleg gegeven over CT scan met voorbereiding.
# Ziet erg op tegen coloscopie, liever CT colo
#
#
# Lichamelijk onderzoek:
# T37 RR 159/69 p73 Sat 100% AHF 12/min
#
#
# Beleid:
# iom dr ter Borg:
# Poliklinische CT-colo
# Poli afspraak dr. Verhulst met lab en CT-colo vooraf
# Akkoord heden ontslag
#
#
# Overdracht:
# Overdracht: Ferriprieve anemie, acute nierinsufficiëntie
# -----
# 🩸 Date: 2019-02-21 20:42:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Dhr. B. ter Keurst, huisarts
# Kastelenplein 172
# 5653 LX  [CITY]
#
#
#
#
#
# datum
# 21-02-2019
# kenmerk
# 0006474470 / [PATIENTID]
# BSN nr.
# [BSN]
# betreft
# mevrouw [INITIALS] [LASTNAME], geb. [BIRTHDATE] (73)
# [STREETNAME], [ZIP]  [CITY]
# tel. [PHONENUMBER]
#
#
# Geachte collega,
#
# Bovengenoemde patiënt bezocht op 21-02-2019 de spoedeisende hulp.
#
#
# Reden van komst
# Symptomatische anemie
#
#
# Conclusie
# 73-jarige vrouw bekend met COPD en hypertensie en ijzergebreksanemie komt ivm vermoeidheid en duizeligheid en microcytaire anemie
# 1.  microcytaire anemie Hb 3.7 Wd bij ijzerdeficiëntie bij coeliakie dd aanmaakstoornis dd bij nierinsufficiëntie, dd verlies epistaxis dd bij gastro-intestinaal verlies(nu geen aanwijzingen voor) dd bij vit def
# 2. Hyponatriemie dd bij hydrochlootrhiazide dd tea en toast dd SIADH
# 3. Achteruitgang nierfunctie Wd prerenaal bij verminderde intake+ diuretica dd renaal medicamenteus? dd postrenaal niet uitgesloten
#
#
# Beleid
# iom dr Keet;
# - opname
# - enalapril/hydrochloorthiazide stop. tensie vervolgen
# - 2 PC +, 500mg ferr-inject
# -  start ferrofumoraat 200mg 2d
# - foliumzuur suppletie  0,5mg/dag
# - nemen medicatie zo mee
# - advies tot goede vochtintake
# - 2 EWS
#
#  iom Buster: opname MDL gezien bekend bij MDL met coeliakie. PM poli-controle over enkele weken nog inplannen.
#
# Patiente geeft akkoord voor saturnus-studie, bloed is afgenomen en mw heeft de folders gekregen
#
# Anamnese
# Gezien door E.von Scheibler ass. interne
# Voorgeschiedenis:
# COPD
# HT
# Claustrofobie
# 2005 	Tubulair adenoom in het rectum
# 2008 	Colonoscopie 1 sigmoidpoliep verwijderd
# 2011 	Gewichtsdaling eci
# 2012 	Poli neurologie: HNP+ stenose L4/5. Operatieve behandeling
# 2013 	Poli interne geneeskunde (collega Peerdeman): Gewichtsverlies zonder verklaring in longen of tr digestivus. Momenteel stabiel. Anemie zonder bloedingsfocus in de tr digestivus. X maag: gda, slecht te beoordelen. Colonoscopie tot aan de flexura hepatica, in het geïnspecteerde traject geen afwijkingen. Goede reactie op ijzersuppletie.
# 2014 	Poli chirurgie: Claudicatio op basis van occlusie arteria iliaca communis links en stenose arteria iliaca communis rechts
# 2014 	Opname chirurgie: centrale rekanalisatie + stents bdz iliacaal
# 2015 	Poli chirurgie: Concluderend past het beeld niet bij vasculaire insufficiëntie maar eerder bij een artrogeen dan wel myogeen probleem. Mogelijk dat er sprake is van jicht
# 2015	ijzergebreksanemie
#
# Anamnese
# Sinds enkele maanden vermoeid, dyspneu bij inspanning. tevens duizelig. Heeft last van hartkloppingen sinds enkele weken.
# Heeft in december een grote wond gehad aan het been die veel heeft gebloed. Daarnaast vrijwel dagelijks bloedneuzen die dan de hele ochtend duren.
# Geen zwarte ontlasting of bloed bij ontlasting.
# Eten gaat wel goed, wel iets minder afgelopen tijd.
#
# Familie: vader darmkanker overleden op 62jr.
#
# Medicatie
# Grepid
# Enelapril/hydrochloorthiazide
# lercanidipine
#
# Geen medicatielijst mee;
# Gebruikt GEEN ferrofurmoraat (4jr gelden gestopt), maagbeschermer of NSAID's.
#
# Intox
# Roken: 6 sig/dag
# Alcohol: 2 glazen whisky per dag
# Drugs: nee
#
#
# Lichamelijk onderzoek
# Niet acuut ziek helder en adequaat
# AH 16/min, temp 36.6, HF 110/min, saturatie 100%, tensie 142/63
# H/H: geen klieren voelbaar, bleke sclera. Iets verhoogd CVD links.
# Cor: S1S2, geen bijgeluiden
# Pul: VAG, licht brommen over alle longvelden
# Abd: np, wt,gevoelig rechtsonder, soepele buik, geen loslaatpijn
# Extr: geen oedeem
#
# Aanvullend onderzoek
# Lab
# CRP	0.30	mg/L
# Hemoglobine	(3.7)	mmol/L
# Hematocriet	0.19	L/L
# Erytrocyten	2.39	x10^12/L
# Reticulocyten	37	x10^9/L
# Ret.Prod.Index	0.3	%
# MCV	79	fL
# Leukocyten	5.8	x10^9/L
# Trombocyten	352	x10^9/L
# Bloedgroep	A pos
# IAT	neg.
# Glucose	6.1	mmol/l
# Natrium	130	mmol/L
# Kalium	4.3	mmol/L
# Ureum	12.6	mmol/L
# Kreatinine	99	µmol/L
# eGFR CKD-EPI	48	ml/m/1.73m^2
# Alkalische Fosfatase (AF)	112	U/L
# GGT	29	U/L
# ALAT	16	U/L
# LD	150	U/L
# Haptoglobine	1.64	g/L
# Ferritine	14	µg/L
# IJzer	7	µmol/L
# Transferrine	3.4	g/L
# Transferrine verzadiging	8	%
# TF/log FERR	2.92
# Albumine	44	g/L
# Foliumzuur	4	nmol/l
# Vitamine B12	160	pmol/L
# Extra buis	Blauw
#
#
# ECG: sinusritme regulair, HF 92, INT hart-as, iets verbreed QRS-complex 129, andere gleidngstijden normaal. ST-depressie 1 mm in V3 en V4, geen ST-elevatie, inverse T in V1. RBTB. ECG conform eerder.
#
# USED
# Natrium U	52	mmol/L
# Osmolaliteit	333	mOsmol/kg
#
#
# Medicatie actueel
# Clopidogrel tablet   75mg; oraal; 1 x per dag 75 milligram
#
# Atorvastatine tablet 20mg; oraal; 1 x per dag 1 stuk levenslange indicatie
#
# Triamcinolonacetonide zalf 1mg/g; cutaan; zo nodig 1 x per dag aanbrengen
#
# Paracetamol tablet  500mg; oraal; 4 x per dag 2 stuk
#
# Pantoprazol tablet msr 20mg; oraal; 1 x per dag 1 stuk
#
# Elvitaal calcium magnesium zink tablet; niet ingev.; 1 x per dag 1 stuk
#
# Lercanidipine tablet omhuld 10mg; oraal; 1 x per dag 1 stuk
#
# Ferrofumaraat tablet 200mg; oraal; 3 x per dag 1 stuk
#
# Foliumzuur tablet 0,5mg; oraal; 1 x per dag 1 stuk
#
#
#
#
# Met vriendelijke groet,
#
# E. von Scheibler, arts assistent
#
# Namens
# dr. S.W.M. Keet, internist-nefroloog
#
# Deze brief is elektronisch geaccordeerd en daarom niet ondertekend.
# -----
# 🩸 Date: 2019-02-21 16:59:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Reden van komst / Verwijzing:
# Reden van komst (brief): Symptomatische anemie
#
# Anamnese:
# Gezien door E.von Scheibler ass. interne
# Voorgeschiedenis:
# COPD
# HT
# Claustrofobie
# 2005 	Tubulair adenoom in het rectum
# 2008 	Colonoscopie 1 sigmoidpoliep verwijderd
# 2011 	Gewichtsdaling eci
# 2012 	Poli neurologie: HNP+ stenose L4/5. Operatieve behandeling
# 2013 	Poli interne geneeskunde (collega Peerdeman): Gewichtsverlies zonder verklaring in longen of tr digestivus. Momenteel stabiel. Anemie zonder bloedingsfocus in de tr digestivus. X maag: gda, slecht te beoordelen. Colonoscopie tot aan de flexura hepatica, in het geïnspecteerde traject geen afwijkingen. Goede reactie op ijzersuppletie.
# 2014 	Poli chirurgie: Claudicatio op basis van occlusie arteria iliaca communis links en stenose arteria iliaca communis rechts
# 2014 	Opname chirurgie: centrale rekanalisatie + stents bdz iliacaal
# 2015 	Poli chirurgie: Concluderend past het beeld niet bij vasculaire insufficiëntie maar eerder bij een artrogeen dan wel myogeen probleem. Mogelijk dat er sprake is van jicht
# 2015	ijzergebreksanemie
#
# Anamnese
# Sinds enkele maanden vermoeid, dyspneu bij inspanning. tevens duizelig. Heeft last van hartkloppingen sinds enkele weken.
# Heeft in december een grote wond gehad aan het been die veel heeft gebloed. Daarnaast vrijwel dagelijks bloedneuzen die dan de hele ochtend duren.
# Geen zwarte ontlasting of bloed bij ontlasting.
# Eten gaat wel goed, wel iets minder afgelopen tijd.
#
# Familie: vader darmkanker overleden op 62jr.
#
# Medicatie
# Grepid
# Enelapril/hydrochloorthiazide
# lercanidipine
#
# Geen medicatielijst mee;
# Gebruikt GEEN ferrofurmoraat (4jr gelden gestopt), maagbeschermer of NSAID's.
#
# Intox
# Roken: 6 sig/dag
# Alcohol: 2 glazen whisky per dag
# Drugs: nee
#
#
# Tractus anamnese:
# Tractus anamnese: Koorts , afvallen, nachtzweten
# Epistaxis+
# tr. circ: POB-, palpitaties+
# tr. resp: dyspnoe d'effort, hoesten-
# tr. dig: buikpijn-, N-V-, normale bruine def. bloed-
# tr. urogen: dysurie-, hematurie-
#
#
# Lichamelijk onderzoek:
# Niet acuut ziek helder en adequaat
# AH 16/min, temp 36.6, HF 110/min, saturatie 100%, tensie 142/63
# H/H: geen klieren voelbaar, bleke sclera. Iets verhoogd CVD links.
# Cor: S1S2, geen bijgeluiden
# Pul: VAG, licht brommen over alle longvelden
# Abd: np, wt,gevoelig rechtsonder, soepele buik, geen loslaatpijn
# Extr: geen oedeem
#
#
# Aanvullend onderzoek:
# Lab
# CRP	0.30	mg/L
# Hemoglobine	(3.7)	mmol/L
# Hematocriet	0.19	L/L
# Erytrocyten	2.39	x10^12/L
# Reticulocyten	37	x10^9/L
# Ret.Prod.Index	0.3	%
# MCV	79	fL
# Leukocyten	5.8	x10^9/L
# Trombocyten	352	x10^9/L
# Bloedgroep	A pos
# IAT	neg.
# Glucose	6.1	mmol/l
# Natrium	130	mmol/L
# Kalium	4.3	mmol/L
# Ureum	12.6	mmol/L
# Kreatinine	99	µmol/L
# eGFR CKD-EPI	48	ml/m/1.73m^2
# Alkalische Fosfatase (AF)	112	U/L
# GGT	29	U/L
# ALAT	16	U/L
# LD	150	U/L
# Haptoglobine	1.64	g/L
# Ferritine	14	µg/L
# IJzer	7	µmol/L
# Transferrine	3.4	g/L
# Transferrine verzadiging	8	%
# TF/log FERR	2.92
# Albumine	44	g/L
# Foliumzuur	4	nmol/l
# Vitamine B12	160	pmol/L
# Extra buis	Blauw
#
#
# ECG: sinusritme regulair, HF 92, INT hart-as, iets verbreed QRS-complex 129, andere gleidngstijden normaal. ST-depressie 1 mm in V3 en V4, geen ST-elevatie, inverse T in V1. RBTB. ECG conform eerder.
#
# USED
# Natrium U	52	mmol/L
# Osmolaliteit	333	mOsmol/kg
#
#
#
# Conclusie:
# 73-jarige vrouw bekend met COPD en hypertensie en ijzergebreksanemie komt ivm vermoeidheid en duizeligheid en microcytaire anemie
# 1.  microcytaire anemie Hb 3.7 Wd bij ijzerdeficiëntie bij coeliakie dd aanmaakstoornis dd bij nierinsufficiëntie, dd verlies epistaxis dd bij gastro-intestinaal verlies(nu geen aanwijzingen voor) dd bij vit def
# 2. Hyponatriemie dd bij hydrochlootrhiazide dd tea en toast dd SIADH
# 3. Achteruitgang nierfunctie Wd prerenaal bij verminderde intake+ diuretica dd renaal medicamenteus? dd postrenaal niet uitgesloten
#
#
#
# Beleid:
# Algemeen: 2 EWS (Voltooid)
# 2 PC ieder in 3 uur (Voltooid)
# VOD morgen (Voltooid)
# ferr-inject na PC (Te accepteren)
#
# Beleid:
# iom dr Keet;
# - opname
# - enalapril/hydrochloorthiazide stop. tensie vervolgen
# - 2 PC +, 500mg ferr-inject
# -  start ferrofumoraat 200mg 2d
# - foliumzuur suppletie  0,5mg/dag
# - nemen medicatie zo mee
# - advies tot goede vochtintake
# - morgen lab controle
# - 2 EWS
#
#  iom Buster: opname MDL gezien bekend bij MDL met coeliakie. PM poli-controle over enkele weken nog inplannen.
#
# Patiente geeft akkoord voor saturnus-studie, bloed is afgenomen en mw heeft de folders gekregen
# -----
# 🩸 Date: 2018-12-22 21:25:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Reden van komst / Verwijzing:
# Reden van komst (brief): Wond onderbeen
#
# Anamnese:
# Patiente wilde overeind komen uit een stoel en heeft hierbij het linker onderbeen open gehaald aan de stoel.
# Flink bloedende wond.
# Tetanusvaccinatie >10 jaar geleden.
#
# Med: oa plavix
#
#
# Lichamelijk onderzoek:
# In triage 45 minuten met drukverband gezeten ivm fors bloeden. Hierna nagenoeg droog.
#
# Linker onderbeen: pretibiale lapverwonding met distaal hiervan nog een oppervlakkige excoriatie
# Huid van de lap is avitaal.
# Functie voet intact, sensibiliteit intact, CR <2sec
#
#
# Conclusie:
# Pretibiale lapverwonding links
#
#
# Beleid:
# Lokaal anesthesie met lidocaine 1%
# Avitale lap verwijderd
# Wonden gereinigd
#
# Tetanustoxoid
# Drukverband
# Wondcontrole via de huisarts
# -----
# 🩸 Date: 2018-12-22 19:30:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Beloop:
# Verpleegkundige rapportage (naslag): wondverband met mepitel, drukverband
# advies gegeven tot hooghouden
# controle huisarts
# -----
# 🩸 Date: 2016-02-10 14:40:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Samenvatting:
# Opdrachten
# [ poli opdrachten ]
# -Afspraak bij: MDL-arts
# -Aantal: 4
# -Afspraak over: Maand(en)
# -Tijdsduur: TC
# -Opmerking: aub lab bon opsturen, belt zelf voor nieuwe afspraak na bloedprikken
# -----
# 🩸 Date: 2016-02-10 14:35:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Samenvatting:
# Vervolgconsult
# -Type registratie: Verkort
# [ Verkort dossier VV ]
# -Verwijsreden: Overig
# -Toelichting: coeliakie
# -Anamnese: TP: gaat goed. Geen klachten.
# [ Metingen ]
# -Uitslagen: bloedonderzoek: stabiel. Hb bijna normaal, vitamine ongestoord.
# -Samenvatting: coeliakie, geen darmklachten. Wel laag Hb, bij laag fe en foliumzuur.
# -Conclusie: tevreden
# -Beleid: controle over 4 maanden, tevoren weer bloedonderzoek. Indien dan nog stabiel retour HA.
# [ Knoppen 1e consult ]
# [ Knoppen 1e consult sub ]
# -Poli labaanvraag: Poliklinische labaanvraag
# [ Knoppen beleid RVE ]
# -Opdrachten poli-medewerker: poli opdrachten
# - Afspraak bij: MDL-arts; afspraak over: 4; Afspraak over: Maand(en); Tijdsduur: TC; Opmerking: aub lab bon opsturen, belt zelf voor nieuwe afspraak na bloedprikken;
# [ poli opdrachten ]
# -Afspraak bij: MDL-arts
# -Aantal: 4
# -Afspraak over: Maand(en)
# -Tijdsduur: TC
# -Opmerking: aub lab bon opsturen, belt zelf voor nieuwe afspraak na bloedprikken
# -----
# 🩸 Date: 2015-11-09 10:16:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Samenvatting:
# Opdrachten
# [ poli opdrachten ]
# -Afspraak bij: MDL-arts
# -Aantal: 3
# -Afspraak over: Maand(en)
# -Tijdsduur: TC
# -Laboratorium: voor controle
# -Afgewerkt door poli: jp
# -----
# 🩸 Date: 2015-11-09 10:02:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Samenvatting:
# Vervolgconsult
# -Type registratie: Verkort
# [ Verkort dossier VV ]
# -Verwijsreden: Overig
# -Toelichting: coeliakie
# -Anamnese: is gestopt met dieet. Vond het te veel gedoe en ziet er het nut niet van in.
# [ Metingen ]
# -Uitslagen: Hb blijft laag en vitamine D is opnieuw verlaagd.
# -Bespreking: nogmaals gesproken dat er een discrepantie is tussen de klachten en bevindingen. Patiente geeft aan dat zij het echt niet ziet zitten het dieet te volgen. Heeft artikel uit de krant bij zich waarin het nut van Ca-suppletie bij osteoporose wordt betwijfeld. Uitleg gegegevn over coeliakie en verhoogd risico op lymfoom en dunne darmkanker. Patiente  geeft aan dat te begrijpen, maar esondanks te blijven bij haar standpunt. Vindt het wel acceptabel om Fe en vitamine te (blijven) gebruiken, op geleide van spiegels.
# -Samenvatting: coeliakie, geen darmklachten. Wel laag Hb, bij laag fe en foliumzuur.
# -Beleid: controle over 3 maanden, tevoren weer bloedonderzoek.
# [ Knoppen 1e consult ]
# [ Knoppen 1e consult sub ]
# -Poli labaanvraag: Poliklinische labaanvraag
# [ Knoppen beleid RVE ]
# -Opdrachten poli-medewerker: poli opdrachten
# - Afspraak bij: MDL-arts; afspraak over: 3; Afspraak over: Maand(en); Tijdsduur: TC; Laboratorium: voor controle; Afgewerkt door poli: jp;
# [ poli opdrachten ]
# -Afspraak bij: MDL-arts
# -Aantal: 3
# -Afspraak over: Maand(en)
# -Tijdsduur: TC
# -Laboratorium: voor controle
# -Afgewerkt door poli: jp
# -----
# 🩸 Date: 2015-08-25 15:42:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Samenvatting:
# Opdrachten
# [ poli opdrachten ]
# -Afspraak bij: MDL-arts
# -Aantal: 2
# -Afspraak over: Maand(en)
# -Tijdsduur: CP 10
# -Laboratorium: voor controle
# -Opmerking: heeft al lab bon, aub afspraak en recept opsturen; gedaan KH
# -----
# 🩸 Date: 2015-08-25 15:30:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Samenvatting:
# Vervolgconsult
# -Type registratie: Verkort
# [ Verkort dossier VV ]
# -Verwijsreden: Overig
# -Toelichting: coeliakie
# -Anamnese: TP: is begonnen met dieet. Mderkt geen verschil.
# [ Metingen ]
# -Uitslagen: Hb gestegen naar 7,0 mmol/l. anti-tTG negatief ?
# DXA: duidelijk verlaagde botdichtheid in de femurhals.
# -Bespreking: uitgelegd dat gevonden afwijkingen kunnen passen bij coeliakie. Niet altijd zijn antistoffen positief.
# Geadviseerd toch door te gaan met dieet, anders lijkt suppleren "dweilen met de kraan open". Patiente geeft aan erover na te willen denken.
# -Samenvatting: coeliakie, geen darmklachten. Wel laag Hb, bij laag fe en foliumzuur.
# -Beleid: controle over 2 maanden, tevoren weer bloedonderzoek.
# [ Knoppen 1e consult ]
# [ Knoppen 1e consult sub ]
# [ Knoppen beleid RVE ]
# -Opdrachten poli-medewerker: poli opdrachten
# - Afspraak bij: MDL-arts; afspraak over: 2; Afspraak over: Maand(en); Tijdsduur: CP 10; Laboratorium: voor controle; Opmerking: heeft al lab bon, aub afspraak en recept opsturen; gedaan KH;
# [ poli opdrachten ]
# -Afspraak bij: MDL-arts
# -Aantal: 2
# -Afspraak over: Maand(en)
# -Tijdsduur: CP 10
# -Laboratorium: voor controle
# -Opmerking: heeft al lab bon, aub afspraak en recept opsturen; gedaan KH
# -----
# 🩸 Date: 2015-08-13 13:50:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Samenvatting:
# Opdrachten
# [ poli opdrachten ]
# -Afspraak bij: MDL-arts
# -Afspraak over: Na afrondig onderzoeken
# -Tijdsduur: TC
# -Afspraak bij: MDL-arts
# -Aantal: 3
# -Afspraak over: Maand(en)
# -Tijdsduur: CP 10
# -Controle: Röntgen
# -Opmerking: DXA
# -Laboratorium: Nu en voor controle
# -----
# 🩸 Date: 2015-08-13 13:31:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Samenvatting:
# Eerste consult
# -Type 1e consult: Verkort
# [ Verkort dossier ]
# -Verwijzer: Intern
# -Intern: van de Wall Bake
# -Verwijsreden: Overig
# -Toelichting: coeliakie
# -Anamnese: Had geen specifieke klachten, anders dan moeiheid. Geen buikklachten. Ontlasting een maal daags en vast. Gewicht is al langere tijd laag, heeft een periode 48 kg gewogen. Momenteel schommelt het rond 55 kg.
# Bij aanvullend onderzoek werd bloedarmoede gevonden. Geeft aaan al heel het leven een laag Hb te hebben, eerder werd nooit gesproken over of gedacht aan coeliakie.
# Familie: niemand bekend met coeliakie. Wel heeft schoondochter ook coeliakie.
# [ Metingen ]
# -Lengte: 169 cm
# -Gemeten gewicht: 53 kg
# -   gewogen: met kleding
# -BMI: 18,56
# -Bespreking: uitgelegd dat coeliakie ook zonder veel klachten kan bestaan. Maar ook dat tekorten aan Fe en foliumzuur, en mogelijk nog andere vitaminen, gevolg kunnen zijn van coeliakie. Patienten die een dieet agaan volgen kunnen zich dan toch veel beter voelen. patiente geeft aan niet veel te voelen voor een dieet, maar ook niet graag pillen te slikken. Wil daarom wel gaan proberen wat het effect van het dieet voor haar is. Heeft geen behoefte aan een consult bij een dietiste, wil eerst met haar schoondochter overleggen.
# -Samenvatting: coeliakie, geen darmklachten. Wel laag Hb, bij laag fe en foliumzuur.
# -Beleid: starten met glutenvrij dieet
# lab: coeliakie diagnostiek alsnog doen, dan ook Hb en vit D controleren
# DXA
# [ Knoppen 1e consult ]
# [ Knoppen 1e consult sub ]
# [ Knoppen beleid RVE ]
# -Opdrachten poli-medewerker: poli opdrachten
# - Afspraak bij: MDL-arts; Afspraak over: Na afrondig onderzoeken; Tijdsduur: TC; Afspraak bij: MDL-arts; afspraak over: 3; Afspraak over: Maand(en); Tijdsduur: CP 10; Controle: Röntgen; Opmerking: DXA; Laboratorium: Nu en voor controle;
# [ poli opdrachten ]
# -Afspraak bij: MDL-arts
# -Afspraak over: Na afrondig onderzoeken
# -Tijdsduur: TC
# -Afspraak bij: MDL-arts
# -Aantal: 3
# -Afspraak over: Maand(en)
# -Tijdsduur: CP 10
# -Controle: Röntgen
# -Opmerking: DXA
# -Laboratorium: Nu en voor controle
# -----
# 🩸 Date: 2015-07-03 15:48:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Samenvatting:
# Opdrachten medewerker INT
# [ Opdrachten voor medewerker ]
# -Afspraak over: Geen afspraak
# -Laboratorium: Nu
# -Diversen: ICC poli MDL --> afspraak is gemaakt, Christel stuurt bevestiging
# -Afgewerkt door poli INT: Miriam Peters
# -----
# 🩸 Date: 2015-07-03 15:42:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Samenvatting:
# Vervolg consult
# -Type vervolgconsult: Verkort
# [ Anamnese ]
# -Datum: 06-07-2015
# -Tijd: 17:00
# -Voorgeschiedenis interne: COPD
# HT
# Claustrofobie
# 2005 tubulair adenoom in het rectum
# 2008 Colonoscopie 1 sigmoidpoliep verwijderd
# 2011 gewichtsdaling eci
# 2012 poli neurologie: HNP+ stenose L4/5. Operatieve behandeling
# 2013 poli interne geneeskunde (coll. Peerdeman): Gewichtsverlies zonder verklaring in longen of tr digestivus. Momenteel stabiel. Anemie zonder bloedingsfocus in de tr digestivus. X maag: gda, slecht te beoordelen. Colonoscopie tot aan de flexura hepatica, in het geïnspecteerde traject geen afwijkingen. Goede reactie op ijzersuppletie.
# 2014 poli chirurgie: Claudicatio op basis van occlusie arteria iliaca communis links en stenose arteria iliaca communis rechts
# 2014 opname chirurgie: centrale recanalisatie + stents bdz iliacaal
# 2015 poli chirurgie: Concluderend past het beeld niet bij vasculaire insufficiëntie maar eerder bij een artrogeen dan wel myogeen probleem. Mogelijk dat er sprake is van jicht
# 2015 poli interne geneeskunde: Recidief anemie, normocytair. Waarschijnlijk toch ferriprief. Normaal MCV mogelijk tgv forse alcohol gebruik. Tevens foliumzuur deficiëntie. Licht verhoogd AF. Hyponatriëmie, mogelijk tgv thiazide. 1e gr AV block, RBTB
#
# [ Voorgeschiedenis ]
# -Relevante voorgeschiedenis: 07-2015 ijzergebreksanemie
# 06-2015 Procedurele sedatie analgesie (PSA) buiten de OK
# 06-2015 ijzergebreksanemie
# 2012 Wervel, laminect.1 niveau geen tumor (kanaalstenose)
# 2008 Colonoscopie: follow up colonpoliepen 2005, tubulair adenoom in het rectum. Nu 1 sigmoidpoliep verwijderd
# -Samenvatting: anemie, volgens HA normocytair
# in verleden vaker gehad, toen wel reactie op Fe
# in verleden colonpoliepen gehad. Laatste colo 2012, ascendens niet gezien
# Geen gastro bekend
# Voorts: COPD, HT, vaatlijden etc
# Mogelijk jicht??
# -Medicatie: EZIS
# tevens recent nog 1 tab van HA, colchicine
# Heeft ook inhalaties: ipratroprium
# allergie: mogelijk metoprolol? Onzeker. Kreeg er vlekjes van
# -Actuele allergieën: METOPROLOL / BETABLOKKERS /
# -Anamnese: Verdraagt de ferro en FZ goed.
# [ Lichamelijk onderzoek ]
# [ Metingen ]
# -Laatst bekende gewicht: 54,5 (KG)  25-06-2015
# -Laatst bekende lengte: 169 (CM)  25-06-2015
# -Laatst bekende bloeddruk: 145/75 01-01-0101
# -Laatste bekende BMI: 19,08
# [ Conclusie en beleid ]
# -Conclusie: Anemie, iets verbeterd
# gemengde deficientie (Fe, FZ), verbeterd met supplementen
# coloscopie gb
# gastroscopie gda
# PA duodenum toont wel subtotale vlokatrofie: coeliakie
# -Beleid: serologie coeliakie nu inzetten
# PM dietiste: glutenvrij
# poli MDL
# [ Beleid ]
# [ INT extra knoppen ]
# [ INT extra knoppen ]
# -Poli labaanvraag: Poliklinische labaanvraag
# -Opdrachten poli-medewerker: Opdrachten voor medewerker
# - Afspraak over: Geen afspraak; Laboratorium: Nu; Diversen: ICC poli MDL --> afspraak is gemaakt, Christel stuurt bevestiging; Afgewerkt door poli: Miriam Peters;
# [ Opdrachten voor medewerker ]
# -Afspraak over: Geen afspraak
# -Laboratorium: Nu
# -Diversen: ICC poli MDL --> afspraak is gemaakt, Christel stuurt bevestiging
# -Afgewerkt door poli INT: Miriam Peters
# -----
# 🩸 Date: 2015-06-29 17:22:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Samenvatting:
# Endoscopie verslag
# [ 370060030 Endoscopie - Algemeen ]
# -Datum onderzoek: 29-06-2015
# -Aanvrager: Specialist intern
# -Specialist intern: A.W.L. vd Wall Bake
# -Endoscopist: E. Buster
# -Indicatie aanvraag: ijzergebrek eci. In 2013 X maag, ntb. Coloscopie onvolledig
# opa, vader en 2 broers krgen CRC
# -ASA klasse: 2
# -Cumarinederivaat: nvt
# -Acetylsalicylzuur: niet gestopt, omdat
# -Antibiotische profylaxe: nvt
# -Endoscopische verrichting: coloscopie
# -Timeout: Ja
# -Premedicatie: propofol
# -Introductie afstand: het coecum
# -Beleving: niet of nauwelijks belastend
# [ Darmreiniging (BBPS) ]
# -Rechts (coecum en ascendens): 2
# -Transversum (incl. flexura hepatica en lienalis): 3
# -Links (descendens, sigmoïd, rectum): 2
# -Totaal score: 7
# -Beoordeelbaarheid: goed
# -Bevindingen: Rectaal toucher: geen afwijkingen. Lastige introductie van de colonoscoop tot in het coecum door uitbochten. De Valvula Bauhini en appendixopening hebben een normaal aspect. De coecumbodem kan niet geheel worden overzien door de vele pitten. Het lukt niet om in het terminale ileum te kijken. In het gehele colon normaal aspect van het slijmvlies, de vaattekening is normaal. In het rectum geen afwijkingen, er is in retroversie gekeken.
# -Complicatie: Geen. Indien er binnen 30 dagen een complicatie optreedt, verzoeken wij u deze te melden.
# -Conclusie: Normaal aspect van het gehele colon.
# -----
# 🩸 Date: 2015-06-29 17:16:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Samenvatting:
# Endoscopie verslag
# [ 370060030 Endoscopie - Algemeen ]
# -Datum onderzoek: 29-06-2015
# -Aanvrager: Specialist intern
# -Specialist intern: A.W.L. vd Wall Bake
# -Endoscopist: E. Buster
# -Indicatie aanvraag: ijzergebrek eci. In 2013 X maag, ntb. Coloscopie onvolledig
# opa, vader en 2 broers krgen CRC
# -ASA klasse: 2
# -Cumarinederivaat: nvt
# -Acetylsalicylzuur: niet gestopt, omdat
# -Antibiotische profylaxe: nvt
# -Endoscopische verrichting: gastroscopie
# -Timeout: Ja
# -Premedicatie: anders
# -Welke en hoeveelheid medicatie: propofol
# -Introductie: vlot
# -Beleving: niet of nauwelijks belastend
# [ Type Gastroscopie ]
# -Type gastroscopie: algemeen
# -Beoordeelbaarheid: goed
# -Slokdarm: Geen afwijkingen aan de mucosa van de slokdarm. De Z-lijn valt samen met de GE-overgang en diafragma-impressie op 40cm.
# -Maag: Fraaie ontplooiing van de maag en normale maagplooien. Er is geen retentie, kleine spoortjes hematine. De mucosa van het corpus en antrum toont geen afwijkingen, met name geen roodheid of erosies. De pylorus is fraai rond en eenvoudig te passeren. In retroflexie geen afwijkingen aan de angulus en fundus, de hiatus sluit om de scoop.
# -Duodenum: Normaal aspect van de bulbus duodeni en verdere duodenum.
# -Additionele verrichtingen: Random biopten duodenum genomen.
# -Complicaties: Geen. Indien er binnen 30 dagen een complicatie optreedt, verzoeken wij u deze te melden.
# -CLO test: Ja
# -Uitslag CLO test: negatief
# -Conclusie: Spoortje hematine in de maag zonder aanwijzingen voor ontsteking. Verder normaal aspect van slokdarm, maag en duodenum.
# CLO-test negatief.
# Random biopten uit het duodenum genomen, PA volgt.
# -----
# 🩸 Date: 2015-06-25 13:56:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Samenvatting:
# Memo
# -Memo: anesthesie is accoord met propofol op 29-6.
# -----
# 🩸 Date: 2015-06-25 12:41:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Samenvatting:
# Vervolg consult
# -Type vervolgconsult: Verkort
# [ Anamnese ]
# -Datum: 25-06-2015
# -Tijd: 12:41
# -Voorgeschiedenis interne: COPD
# HT
# Claustrofobie
# 2005 tubulair adenoom in het rectum
# 2008 Colonoscopie 1 sigmoidpoliep verwijderd
# 2011 gewichtsdaling eci
# 2012 poli neurologie: HNP+ stenose L4/5. Operatieve behandeling
# 2013 poli interne geneeskunde (coll. Peerdeman): Gewichtsverlies zonder verklaring in longen of tr digestivus. Momenteel stabiel. Anemie zonder bloedingsfocus in de tr digestivus. X maag: gda, slecht te beoordelen. Colonoscopie tot aan de flexura hepatica, in het geïnspecteerde traject geen afwijkingen. Goede reactie op ijzersuppletie.
# 2014 poli chirurgie: Claudicatio op basis van occlusie arteria iliaca communis links en stenose arteria iliaca communis rechts
# 2014 opname chirurgie: centrale recanalisatie + stents bdz iliacaal
# 2015 poli chirurgie: Concluderend past het beeld niet bij vasculaire insufficiëntie maar eerder bij een artrogeen dan wel myogeen probleem. Mogelijk dat er sprake is van jicht
# [ Voorgeschiedenis ]
# -Relevante voorgeschiedenis: 2012 Wervel, laminect.1 niveau geen tumor (kanaalstenose)
# 2008 Colonoscopie: follow up colonpoliepen 2005, tubulair adenoom in het rectum. Nu 1 sigmoidpoliep verwijderd
# -Samenvatting: anemie, volgens HA normocytair
# in verleden vaker gehad, toen wel reactie op Fe
# in verleden colonpoliepen gehad. Laatste colo 2012, ascendens niet gezien
# Geen gastro bekend
# Voorts: COPD, HT, vaatlijden etc
# Mogelijk jicht??
# -Medicatie: EZIS
# tevens recent nog 1 tab van HA, colchicine
# Heeft ook inhalaties: ipratroprium
# allergie: mogelijk metoprolol? Onzeker. Kreeg er vlekjes van
# -Actuele allergieën: METOPROLOL / BETABLOKKERS /
# -Anamnese: zie E-mail:
# Beste,
#
#
#
# Ik heb zojuist Mw [LASTNAME] gezien..
#
# Pat geeft hier een andere familie anamnese als in u brief staat…ik heb dit met pat kortgesloten.
#
# Pat vond het bij u niet meer van belang omdat het met haar broers inmiddels weer goed gaat…mi voor de volledigheid wel van belang.
#
#
#
# Familie anamnese:
#
# opa darmca
#
# vader darmca met 66jr overleden
#
# broer darmca diagnose gesteld ouder dan 50
#
# broer darmca diagnose met 59 jr.
#
#
#
# moeder overleden tgv alvleesklierkanker
#
#
#
# groeten Marieke Bogaerts
#
#
#
# maag darm leververpleegkundige
#
#
# [ Lichamelijk onderzoek ]
# [ Metingen ]
# -Laatst bekende gewicht: 54,4 (KG)  01-06-2015
# -Laatst bekende lengte: 167 (CM)  01-06-2015
# -Laatst bekende bloeddruk: 145/75 01-06-2015
# -Laatste bekende BMI: 19,51
# [ Conclusie en beleid ]
# -----
# 🩸 Date: 2015-06-22 12:03:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Samenvatting:
# Vervolgconsult
# -Type registratie: Uitgebreid
# [ Anamnese ]
# -Verwijzer: Intern
# -Intern: Dr van de wall bake
# -Verwijsreden: Overig
# -Toelichting: Gastro en colonoscopue ivm ijzergebreksanemie eci
# -Anamnese: VG:
# COPD
# HT
# Claustrofobie
# 2005 	Tubulair adenoom in het rectum
# 2008 	Colonoscopie 1 sigmoidpoliep verwijderd
# 2011 	Gewichtsdaling eci
# 2012 	Poli neurologie: HNP+ stenose L4/5. Operatieve behandeling
# 2013 	Poli interne geneeskunde (collega Peerdeman): Gewichtsverlies zonder verklaring in longen of tr digestivus. Momenteel stabiel. Anemie zonder bloedingsfocus in de tr digestivus. X maag: gda, slecht te beoordelen. Colonoscopie tot aan de flexura hepatica, in het geïnspecteerde traject geen afwijkingen. Goede reactie op ijzersuppletie.
# 2014 	Poli chirurgie: Claudicatio
# 2014 	Opname chirurgie: centrale rekanalisatie + stents bdz iliacaal
#
# KOmt binnen met het verhaal geen maagonderzoek te willen erg gespannen. Aangeboden om scopie onder propfol te doen ipv dormicum / fentanyl ( dit werkte voor pat niet voldoende)
# Geen klachten van maag of darmen.
# Geen zwarte def, nu wel tgv ferro.
# Roken:+, Alcohol:3 E/dag
# Medicatie:
# Acetylsalicylzuur  80mg,  Enalapril/hydrochloorthiazide 20/12,5mg 1dd1 , Lercanidipine  10mg  1dd 1,
# Simvastatine 40mg 1 xdd 1 stuk, ipatropium inhalatie,
# Foliumzuur tablet 5mg  1dd1,
# Ferrofumaraat  200mg 3 dd1
# Allergie: metorpolol
# Hart/Long problemen: COPD controle via huisarts
# Familie anamnese:
# opa darmca
# ...
# [ Lichamelijk onderzoek ]
# [ Metingen ]
# -Gemeten gewicht: 51 kg
# [ Conclusie en beleid ]
# -Conclusie: gewichtsverlies eci, ijzergebrek. patiente weigert maagonderzoek. Colo gb.
# -Beleid: Poli half oktober met lab.
# [ Beleid ]
# [ INT extra knoppen ]
# [ INT extra knoppen ]
# -Poli labaanvraag: Poliklinische labaanvraag
# -Opdrachten poli-medewerker: Opdrachten voor medewerker
# - Diversen: Poli half oktober met lab.; Afgewerkt door poli: HtV;
# -----
# 🩸 Date: 2012-07-30 10:01:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Samenvatting:
# Vervolg consult
# -Type vervolgconsult: Verkort
# [ Anamnese ]
# -Datum: 30-07-2012
# -Tijd: 10:01
# -Voorgeschiedenis interne: COPD
# Claustrofobie
# -Samenvatting: Onbegrepen gewichtsverlies bij packyears en mgl afwijking li mamma.
# -Medicatie: enalapril 1dd20.metoprolol
# -Anamnese: TC [PHONENUMBER] gg
# [PHONENUMBER] echtgenoot uitleg dat onderzoek geen afwijkingen laat zien maar niet heel betrouwbaar is in uitsluiten van pathologie
# [ Lichamelijk onderzoek ]
# -Aanvullend onderzoek: X maag:
# Patiënte zegt nuchter te zijn, doch er is een forse maaginhoud zichtbaar voordat het onderzoek begint. Wandafwijkingen kunnen hiermee makkelijk gemist worden. Er is een vlotte passage door de oesophagus. Normale oesophagus-maagovergang. Voor zover coating te bereiken is bij deze maaginhoud worden er geen grove afwijkingen gezien. Subtiele plooi-afwijkingen of ulceraties zijn makkelijk te missen. De passage door de bulbus is normaal.
# [ Conclusie en beleid ]
# -Beleid: ttv poliafspraak in aug bespreken of gastro alsnog geindiceerd is
# poli dr Peerdeman = reeds gepland
# -----
# 🩸 Date: 2012-07-10 13:49:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Samenvatting:
# Opdrachten medewerker INT
# [ Opdrachten voor medewerker ]
# -Diversen: x-maag. TF Vreu/Tick met uitslag. Poli PDM 4-5 wkn met lab.
# -Afgewerkt door poli INT: kd
# -----
# 🩸 Date: 2012-07-10 08:41:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Samenvatting:
# Vervolg consult
# -Type vervolgconsult: Verkort
# [ Anamnese ]
# -Datum: 10-07-2012
# -Tijd: 08:41
# -Voorgeschiedenis interne: COPD
# Claustrofobie
# -Samenvatting: Onbegrepen gewichtsverlies bij packyears en mgl afwijking li mamma.
# -Medicatie: enalapril 1dd20.metoprolol
# -Anamnese: Hb gedaald naar 6,8 en duidelijk ijzergebrek. Nogmaals bespreken indicatie tot gastroscopie. tevens hyponatriaemie bij HCT gebruik. Al gestopt door HA.
# Gaat hetzelfde. Pijn in de onderrug en knieholten. Veel moeite met lopen en staan. Vrijdag naar neuroloog
# Durft geen maagonderzoek,  is bang te stikken ondanks uitleg. Wil pertinent geen maagonderzoek.
# [ Lichamelijk onderzoek ]
# [ Metingen ]
# -Gemeten gewicht: 52 kg
# [ Conclusie en beleid ]
# -Beleid: x-maag.
# [ Beleid ]
# [ INT extra knoppen ]
# [ INT extra knoppen ]
# -Poli labaanvraag: Poliklinische labaanvraag
# -Opdrachten poli-medewerker: Opdrachten voor medewerker
# - Diversen: x-maag. TF Vreu/Tick met uitslag. Poli PDM 4-5 wkn met lab.; Afgewerkt door poli: kd;
# -----
# 🩸 Date: 2012-05-07 12:19:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Samenvatting:
# Opdrachten medewerker INT
# [ Opdrachten voor medewerker ]
# -Diversen: Poli 2 mnd met lab.
# -Afgewerkt door poli INT: MB
# -----
# 🩸 Date: 2012-05-07 07:56:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Samenvatting:
# Vervolg consult
# -Type vervolgconsult: Verkort
# [ Anamnese ]
# -Datum: 07-05-2012
# -Tijd: 07:56
# -Voorgeschiedenis interne: COPD
# -Samenvatting: Onbegrepen gewichtsverlies bij packyears en mgl afwijking li mamma.
# -Medicatie: Hydrochloorthiazide 1dd, enalapril 1dd20.
# -Anamnese: Colonoscopie geen afwijkingen. Gaat goed, geen klachten. Eet vollop, smaakt goed. Echtgenoot vindt dat wel wat meer zou mogen eten. At vroeger wel meer.
# Optie gastroscopie besproken. ziet patiente niks in, geeft aan geen maagklachten, ontkent dat mindre eetlust zou hebben dan paar jaar geleden.
# [ Lichamelijk onderzoek ]
# [ Metingen ]
# -Gemeten gewicht: 51.5 kg
# [ Conclusie en beleid ]
# -Beleid: Lab herhalen ivm anaemie en ijzergebrek. Afsluitend gastro? Poli 2 mnd met lab.
# -Overige aantekeningen:
# [ Beleid ]
# [ INT extra knoppen ]
# [ INT extra knoppen ]
# -Poli labaanvraag: Poliklinische labaanvraag
# -Opdrachten poli-medewerker: Opdrachten voor medewerker
# - Diversen: Poli 2 mnd met lab.; Afgewerkt door poli: MB;
# -----
# 🩸 Date: 2012-03-13 11:12:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Samenvatting:
# Aanvraag Endoscopie
# -Locatie: [CITY] (tel 6350)
# -Datum aanvraag: 13-03-2012
# -Aanvrager: WMJ Menting-Adriaans
# -Arts assistent: peerdeman / straathof
# -Afdeling: //
# [ Aanvraag ]
# -Indicatie aanvraag: poliepfollow-up en
#  gewichtsverlies heeft zij in haar lab een anaemie en een CEA van 8.
# -Sedatie gewenst: ja
# -Let op: Bij poliklinische patiënten eerst afspraak MDL-verpleegkundige
# -Ingelicht volgens WGBO: ja
# -Relevante allergieën: nee
# -Acetylsalicylzuur: nvt
# -Antibiotische profylaxe: nvt
# -Cumarinederivaat: nvt
# -Toelichting: vorige keer toch nog een pijnlijk onderzoek/ geen poli afspraak voor de mdl gemaakt.
# -----
# 🩸 Date: 2012-03-13 11:03:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Samenvatting:
# Vervolgconsult
# -Type registratie: Uitgebreid
# -Voorgeschiedenis: 2008 Colonoscopie: follow up colonpoliepen 2005, tubulair adenoom in het rectum. Nu 1 sigmoidpoliep verwijderd
# [ Anamnese ]
# -Verwijzer: Intern
# -Intern: straathof/ peerdeman
# -Verwijsreden: Overig
# -Toelichting: poliepfollow-up / gewichtsverlies heeft zij in haar lab een anaemie en een CEA van 8.
# -Anamnese: Mevr heeft voirg jaar het onderzoek niet door laten gaan, ziet enorm op tegen het drinken van de colofort
# Is nu onder behandeling van dr. |Peerdeman; gewichtverlies en bloedarmoede. zij heeft opnieuw aangedrongen op een colonoscopie.; geen nieuwe aanvraag
# (overleg via de mail; Naast gewichtsverlies heeft zij in haar lab een anaemie en een CEA van 8.)
# Allergie; onbkend
# Medicatie; geen
#
# Wat zijn uw huidige klachten?
# laag gewicht, bloed armoede, kouwelijk, blauwe vingers en hardstikke moe en veel transpireren
# ontlasting is normaal; 1 perdag gevormde ontlasting
# gewicht stabiel ondanks extra eten.
# Heeft u suikerziekte?; nee
#
# Heeft u hart / longproblemen?; nee
#
# Komen er in uw directe familie kwaadaardige ziekten voor??
# Zo ja, welke en bij wie:
# opa darmca
# vader darmca met 66jr overleden
# broer darmca diagnose gesteld ouder dan 50 jr.
# broer darmca diagnose met 59 jr
# zus borstkanker
# Zijn er in uw directe familie ooit darmpoliepen geconstateerd??
# onbkend
#
# Overige opmerkingen:
#
#
# [ Uitgebreide anamnese ]
# [ Lichamelijk onderzoek ]
# [ Metingen ]
# -Lengte: 170 cm
# -Gemeten gewicht: 51 kg
# -BMI: 17,65
# [ Uitgebreid LO ]
# [ Bevindingen / Bespreking ]
# [ Inzien uitslagen ]
# -Bespreking: Checklist MDL- verpleegkundige
#
# Patiënt is ingelicht over de colonoscopie
# Ja
# Patiënt kiest voor pré-medicatie
# Ja
# Patiënt is op de hoogte van de mogelijke complicaties; bloeding, perforatie en bij pré-medicatie ook aspiratie en ademhalingsdepressie
# Ja /
# Patiënt geeft aan informatie begrepen te hebben en gaat akoord met het onderzoek
# Ja
# picoprep meegegeven.
# [ Conclusie en Beleid ]
# -Samenvatting: poliepfollow-up
# [ Beleid ]
# [ EPB/ DBC ]
# [ Knoppen 1e consult ]
# [ Knoppen 1e consult sub ]
# [ Knoppen beleid RVE ]
# -----
# 🩸 Date: 2012-02-28 12:26:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Samenvatting:
# Opdrachten medewerker INT
# [ Opdrachten voor medewerker ]
# -Diversen: Colonoscopie met roesje korte termijn.
# Afspr. MDL-vpk gemaakt
# -Afgewerkt door poli INT: kd
# -----
# 🩸 Date: 2012-02-27 14:19:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Samenvatting:
# Vervolg consult
# -Type vervolgconsult: Verkort
# [ Anamnese ]
# -Datum: 27-02-2012
# -Tijd: 14:19
# -Voorgeschiedenis interne: COPD
# -Samenvatting: Onbegrepen gewichtsverlies bij packyears en mgl afwijking li mamma.
# -Medicatie: Hydrochloorthiazide 1dd, enalapril 1dd20.
# -Anamnese: Hb 7.2 en CEA 8.7. Had al scopie moeten krijgen in 2011 ivm poliep. Onveranderd. Komt nog steeds niet aan, ondanks veel snoepen en eten.
# [ Lichamelijk onderzoek ]
# [ Metingen ]
# -Gemeten gewicht: 51.4 kg
# [ Conclusie en beleid ]
# -Beleid: Colonoscopie.
# -Overige aantekeningen: PM Zou ook nieuwe colo moeten krijgen in 2011 ivm follow-up poliep. Wil echter niet.
# -Opdrachten poli-medewerker: Opdrachten voor medewerker
# - Diversen: Colonoscopie met roesje korte termijn.
# Afspr. MDL-vpk gemaakt; Afgewerkt door poli: kd;
# -----
# 🩸 Date: 2011-12-06 11:44:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Samenvatting:
# Vervolg consult
# -Type vervolgconsult: Verkort
# [ Anamnese ]
# -Datum: 06-12-2011
# -Tijd: 11:44
# -Voorgeschiedenis interne: COPD
# -Samenvatting: Onbegrepen gewichtsverlies bij packyears en mgl afwijking li mamma.
# -Medicatie: Hydrochloorthiazide 1dd, enalapril 1dd20.
# -Anamnese: CT thorax TF Geen primair longca. in lab wel lichte anaemie en ijzergebrek. scopie?
# Ziet erg op tegen scopie, daarom even expectatief.
# [ Lichamelijk onderzoek ]
# [ Metingen ]
# -Gemeten gewicht: 51 kg
# [ Conclusie en beleid ]
# -Beleid: Poli jan 2012 met lab.
# -Overige aantekeningen: PM Zou ook nieuwe colo moeten krijgen in 2011 ivm follow-up poliep. Wil echter niet.
# [ Beleid ]
# [ INT extra knoppen ]
# [ INT extra knoppen ]
# -Poli labaanvraag: Poliklinische labaanvraag
# -----
# 🩸 Date: 2011-11-29 12:20:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Samenvatting:
# Opdrachten medewerker INT
# [ Opdrachten voor medewerker ]
# -Diversen: heden lab, CT thorax. Poli uitslag CT.
# -Afgewerkt door poli INT: JB
# -----
# 🩸 Date: 2011-11-29 07:51:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Samenvatting:
# Vervolg consult
# -Type vervolgconsult: Verkort
# [ Anamnese ]
# -Datum: 29-11-2011
# -Tijd: 07:51
# -Voorgeschiedenis interne: COPD
# -Samenvatting: Onbegrepen gewichtsverlies bij packyears en mgl afwijking li mamma.
# -Medicatie: Hydrochloorthiazide 1dd.
# -Anamnese: Hb 7.3 normocytair. Mammografie gb. Echo abdomen gb. Toch weer wat afgevallen!
# [ Lichamelijk onderzoek ]
# [ Metingen ]
# -Gemeten gewicht: 51 kg
# [ Conclusie en beleid ]
# -Beleid: Ijzerstatus en Ct thorax.
# [ Beleid ]
# [ INT extra knoppen ]
# [ INT extra knoppen ]
# -Poli labaanvraag: Poliklinische labaanvraag
# -Opdrachten poli-medewerker: Opdrachten voor medewerker
# - Diversen: heden lab, CT thorax. Poli uitslag CT.; Afgewerkt door poli: JB;
# -----
# 🩸 Date: 2011-11-15 10:14:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Samenvatting:
# Opdrachten medewerker INT
# [ Opdrachten voor medewerker ]
# -Diversen: Heden lab, x-mammo en echo abdomen. Poli uitslag.
# -Afgewerkt door poli INT: SvE
# -----
# 🩸 Date: 2011-11-15 07:35:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Samenvatting:
# 1e consult
# -Type 1e consult: Verkort
# [ Anamnese ]
# -Datum consult: 15-11-2011
# -Tijd: 07:35
# -Reden van komst: Gewichtverlies.
# -Verwijzer: Huisarts
# -Huisarts: <ObjectGegevens>
# -Voorgeschiedenis interne: COPD
# -Medicatie: Hydrochloorthiazide 1dd.
# -Anamnese: Afgelopen 4 jaar 14 kg afgevallen. Laatste half jaar  4-5 kg. Lijkt sinds 2 weken te stabiliseren rond 51 kg. Conditie: Moe als een hond al jaren. Gaat wel sporten, maar continu vermoeid, was vroeger niet zo. HA maakte al x-thorax 2 weken geleden zonder afwijkingen.
# Ontzettend  koud en koude acra. Transpireert heel veel, nachtzweten-.
# Eten zelfde. eetlust nooit goed geweest, eet omdat het moet. Passageklachten-, P/R-, miss-, brak-, buikpijn-, ontlasting regelmatig, dagelijks, bloed-, slijm-.
# Hoesten++, verkouden++, sputum soms helder. Dyspnoe+ altijd, niet direct bij inspanning.
# AP -, palp+ wisselend aanwezig, oedeem re enkel sinds paar jaar, nyct -, orthopnoe-.
# Mictie gb.
# Menopauze sinds 1990. Geen vag bloedverlies..
# Allergie: dubieus sommige AB.
# Intox: Alc 4 Eh/dag, roken 16 sig/dag. Meer dan 50 jaar.
# Soc: gehuwd, 2 kinderen, administratief werk gedaan. Hobby: Sportclub 5 dgn/week. Al 11 jaar bij sportclub, niet toegenomen afgelopen 5 jaar.
# PM Doet niet mee aan bevolkingsonderzoek mamma. Vindt vervelend onderzoek.
# [ Lichamelijk onderzoek ]
# -Algemeen LO: WHO 0. Hoofd/hals: pupillen isocoor, geen pathologische lymfadenopathie, thyroid niet vergroot.
# Mammae: bdzdz palpabel klierweefsel, lijkt li hobbeliger en vaster dan re.
# Cor: normale tonen, geen souffles. Pulmones: normaal ademgeruis, geen bijgeluiden.
# Abdomen: normale peristaltiek, soepele buik, lever en milt niet palpabel, geen palpabele weerstanden, geen druk- of loslaatpijn, geen slagpijn in de nierloges. Rectaal toucher niet verricht.
# Extremiteiten: geen pathologische lymfadenopathie axillair of inguinaal, geen oedemen. Veneuze insuff.
# [ Metingen ]
# -Lengte: 170 cm
# -Gemeten gewicht: 51.5 kg
# -BMI: 17,8
# -Lichaamsoppervlakte (m2): 1,56
# [ Conclusie en Beleid ]
# -Samenvatting: Onbegrepen gewichtsverlies bij packyears en mgl afwijking li mamma.
# -Beleid: Heden lab, mammografie en echo-abdomen. (PM CT thorax).
# [ Beleid ]
# [ INT extra knoppen ]
# [ INT extra knoppen ]
# -Poli labaanvraag: Poliklinische labaanvraag
# -Opdrachten poli-medewerker: Opdrachten voor medewerker
# - Diversen: Heden lab, x-mammo en echo abdomen. Poli uitslag.; Afgewerkt door poli: SvE;
# -----
# 🩸 Date: 2011-06-15 11:00:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Samenvatting:
# Aanvraag Endoscopie
# -Datum aanvraag: 15-06-2011
# -Aanvrager: MMA Snellens-Smolders
# -Afdeling: //
# [ Aanvraag ]
# -Soort onderzoek: Colonoscopie
# -Let op: Poliklinisch, na afspraak MDL-verpleegkundige
# -Let op: INR < 1,5
# -Indicatie aanvraag: follow up colonpoliepen 2005, tubulair adenoom in het rectum. In 2008 1 sigmoidpoliep verwijderd
# -----
# 🩸 Date: 2011-06-15 10:58:00
# 🩸 Match: None
# 📍 Context: None
# 📜 Content: Samenvatting:
# Eerste consult
# -Type 1e consult: Uitgebreid
# -Voorgeschiedenis: 2008 Colonoscopie: follow up colonpoliepen 2005, tubulair adenoom in het rectum. Nu 1 sigmoidpoliep verwijderd
# [ Anamnese ]
# -Verwijzer: Overig
# -Datum eerste consult: <ObjectGegevens>
# -  -: Dr. Straathof
# -Verwijsreden: Overig
# -Toelichting: poliepfollow-up
# -Anamnese: Algemene vragen:
# allerie insektenbeten
#
# Medicatie overzicht:
# geen
#
# Wat zijn uw huidige klachten?
# geen
#
# Heeft u iets bijzonders gezien aan uw ontlasting?
# nee
#
# Bent u in de afgelopen 6 maanden aangekomen/ afgevallen
# -1.5 kg
#
# Heeft u suikerziekte?
# nee
#
# Heeft u hart / longproblemen?
# nee
#
# Komen er in uw directe familie kwaadaardige ziekten voor??
# opa darmca
# vader darmca met 66jr overleden
# broer darmca diagnose gesteld ouder dan 50 jr.
# broer darmca diagnose met 59 jr.
#
# Zijn er in uw directe familie ooit darmpoliepen geconstateerd??
# broers
#
# Overige opmerkingen:
# Mw wil geen onderzoek laten doen, ze vindt het vreselijk zoveel te moeten drinken, wil mocht er evt iets gezein worden geen behandeling en vindt verzorgingshuizen verschrikkelijk. Wil hier niet in terechtkomen. Mw geeft ook geen gehoor meer aan longfunctieonderzoek en borstonderzoek.
# Mw noodzaak van onderzoek uitgelegd. Mocht ze zich bedenken kan ze altijd contact met ons opnemen. Dr.Straathof is op de hoogte.
# [ Uitgebreide anamnese ]
# [ Lichamelijk onderzoek ]
# [ Metingen ]
# -BMI: 18,14
# -   gewogen: zonder kleding
# -Gemeten gewicht: 51.2 kg
# -Lengte: 168 cm
# -Tekening:
# -Algemeen LO:
# [ Uitgebreid LO ]
# [ Bevindingen / Bespreking ]
# [ Inzien uitslagen ]
# -Bespreking: Checklist MDL- verpleegkundige
#
# Patiënt is ingelicht over de colonoscopie
# Ja
# Patiënt kiest voor pré-medicatie
# Ja
# Patiënt is op de hoogte van de mogelijke complicaties; bloeding, perforatie en bij pré-medicatie ook aspiratie en ademhalingsdepressie
# Ja
# Patiënt geeft aan informatie begrepen te hebben en gaat akoord met het onderzoek
# Ja
# Patiënt heeft recept voor de voorbereiding ontvangen?
# Ja
# De scopie aanvraag is volledig ingevuld en gescand?
# Ja
# Indien van toepassing: Bed is geregeld op de dagbehandeling
# Ja
#
# Heeft patiënt een pacemaker?
#  Nee
#
# Gebruikt patiënt bloedverdunnende medicatie?
# Nee
#
# Gebruikt patiënt ijzerpreparaten?
# Nee
#
# Is patiënt bekend met diabetes mellitus?
#  Nee
#
# Heeft de patiënt epilepsie? ( geen Anexate gebruiken)
# Nee
#
# MRSA screening, afgelopen 3 maanden> 24 uur in een buitenlandse ziekenhuis gewwest of een behandeling ondergaan. Komt u beroepsmatig in contact met varkens of vleeskalveren.  Nee
# (Indien ja, MRSA-lijst invullen)
#
#
# Overige bijzonderheden:
#
#
# [ Conclusie en Beleid ]
# -Samenvatting: poliepfollow-up
# -Conclusie:
# [ Beleid ]
# [ Knoppen 1e consult ]
# [ Knoppen 1e consult sub ]
# [ Knoppen beleid RVE ]
# [ Opdrachten dagverpleging ]
# -----

# %%
pseudo_ids_with_agib = df_specific[df_specific['agib_mention'] == True]['pseudo_id'].unique()
pseudo_ids_df = pd.DataFrame(pseudo_ids_with_agib, columns=['pseudo_id'])
pseudo_ids_df
# Out:
#                                    pseudo_id
# 0   046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 1   0BC512A65442D0BB4B00FBE05E7EA6283E5C11FD
# 2   0DD73490997F61870C32B3BB7C9CDE4E801FFF7D
# 3   0E041554A0B23505AD762D006AB320CF4AF8F969
# 4   12D65DA1F4CFAC101DE53C050C9037D97F42FC18
# 5   21031C9814F3BD6EFACD9FBC5AF409820CDABAB4
# 6   2562E6AE0D16F0504B50CEE14D0D1F0A37596ED8
# 7   37099C38CFE1055CF6950B3D61CEC774849364D9
# 8   37BFA228DFA04BE0596DCCC63D245B42B3A15727
# 9   395219FA6E57FE6DA93F36F3EB68F4667D325895
# 10  40FF2EE78841C453C1C673E9047BABC03DD6CCEE
# 11  52EE37A2B81CD38A3062B4B7B216EDBB8BE07E6C
# 12  6273B4D1B5AF27A667D048CD06A900C9751F8357
# 13  65F35D3FB57B75161F6854ACD38FBEB77A0394B0
# 14  6CF1734B040468B6802E26DFA5BC6B6FF6869362
# 15  6E3082A914A5A2ACE5B7F0B1F0C1294221BBD9C1
# 16  7087EB7CD49F67A7A8E51203DE7C0F9FFBBFB51B
# 17  7CDC164CC77C52E6E71C9DFB08925F79F8F1176D
# 18  895342BFD0D1C32FFF8F009C0E20CBE97B04677D
# 19  94876C5A2D72759210A854698D5A5E012C2ED946
# 20  9577D4850CAA322401163181BB1A3634F653683A
# 21  96764B9E95688ACB64A6C8E99AC2E6D5828BED12
# 22  A9A2482C557733BFC15A7DEAC217F8766D37FAA1
# 23  BEBEFC726C577A7B40F1A467F4E59746FBC7F76B
# 24  C775682FCB29A890D7B64B211F17DFF3D8867951
# 25  CB30ED9CF2F8BE2FABC260C6990B8305E2C09F37
# 26  CF58B7215ED673FD2AC116C49953A9941E73F597
# 27  D03939761BC11D044530F640971D703055A53552
# 28  D25F6785232C8650378EAE7E1D994F3506AEF6DA
# 29  D5454CFC13F8A58EB3E0B964D1D9B4199C0B0501
# 30  D9CCFA8F9DBD7233A09EB2ED21F53D791D96B92E
# 31  DB713A8F5F17426A57148E54A958A9C2BB241ECC
# 32  EC46C3AA9E8858EBAEFEB2C1A429DBD6BA8783BE
# 33  EC6EED9DCF9A5CD8EDAC5DB8A9C9D339C7FC89DC
# 34  EF04810F281C202634208F2091141C40EBD2BC3A
# 35  F5F86E4F57D98E65D464A42AC325615EFE0D5C31
