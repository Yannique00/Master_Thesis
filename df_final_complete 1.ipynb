# %%
import pandas as pd
import re

# %%
# df_hb = pd.read_csv('a:/bloeding-met-patientenlijst-gedetailleerd/bloeding-met-patientenlijst-10-lab.csv')

# path = 'a:/test-data'
# file = 'bloeding-met-patientenlijst-copy-10-lab'
# df_hb = pd.read_csv(f'{path}/{file}.csv') 

# random_patients = ['1C2103096F6605C14058A50A73B547E7FE3C9979', '0089B0DD461CDF5783EB16B371F0705E886443CE', '13EFEF4EE09106A298D217CCB2A702E18E351202', '02BD6625E37046C9C5E348E4DD6B18AC9C839D6C', '07F1A0C762415CEAE949A1119F7987251C5FE2CF', '031237F020F522F81EBE68FB10530BE5B338E58B', '01C3A3E194149D9C871373E49B8DA614A72428F1', '26B916D3BE2F8D4CBDFB1BA43AA6587D427B00FC', '01283148C27F27F492A54C8E68C1955EBB283FEE', '0087949E507BDA53F03F4E7A357C2057AFED2848', '00B35C907E9385D506DEED0576D5FE6EF731CA54', '062EA6F07818F539F78D0A7F8F014840A9F8D03D', '15979570214B1EC8C3A6C8D20D11B5FF0FC94A49', '016E3D76E797CDC875EA4E25B9E0FE7A4C83F92F', '0F51FAEAB4C84B7422A5149AC88A7D705D0087DA', '01A32746CBC9DC01F3709A3CF1575342A2BD9A32', '00F37BE661C10C9455C5EBA8A1BE0151677F0491', '1C9AE22A1831BDA2151F04E7E8BFFDB8864649CC', '1D31D4032DC6EE7F1C91F189EA63AA05CE3C014D', '0213525586905BCC987028AA073B67E1AFA8BAB0', '00BD2A7D7FC6F8DE98238FD198656DCBF2C33531', '26E7A07AC9783E93018E47B0DF318754DFE1A8D6', '029927802B0C8E2AED196B479D47BF0C5AFEBD1A', '2661C9B2C963DBB1296FF650DB0D3CC46C4F02EB', '017D4585B6D89095AF2C8984AE665FEFD39587BB', '100ED287105C74D5A041F4CC902F01D1FDD1E29F', '0118EAE341EBEDC24C6A4B9FDD284C3163118085', '10B7670CEEDE51D114DB4DA7E21C3216D8934894', '012C55BA94F266AB509051A1437653C242E8C5ED', '0153BBDED30D6F371EEB6C8AF12D87637EE23E0C', '01E1189C36B07093D0AEF612DF62E7C858EF47F3', '052CBBB5FD54B5AAA6EDA5E886CBE2E1096C114B', '063AE1E178E39D883F4A68E07766B5BB55477A3B', '00E85EA33E55AC1295F51BD4D33B5B9BFCC39275', '15DAA38394DBD6084D71950D1B117A172915D5FF', '0F6E03661EEEDD71FF07066C47C11CF2D866DCF5', '013AD0878DCA9DBAC4211791619C40BB605850C4', '2718A80B8CECEFAD740CD68C556218D43CCF3F51', '0149515B704A19A1AAD7FC3E45E5CC461117AFDF', '009A96A66DAEC4B18EF5EF192DB9AE60C7F08C61', '026866B398A38E1A274F49040C43C0ED59B293C0', '006265630EA7C11DD855F5EFB0692DDC53B0A806', '00D18EE08E5E35D4B8173DB636AE8433AAED3EFD', '14C8AD7BB63F16F18ECAFA67DA25BBC4167B336D', '025E6793B0FA3673404231B306B6AD2AB85BE792', '21E819B575C27415E1DF3B42436C4638ED9E9534', '0051CC4BF108BB13B6711C7DF61552DDF7213088', '16311B0009E80A0C219025EFDD6EF068C12DF44F', '1E451E45C59736A86E0C29E3D3D7403A89CA049E', '000F4E47813CFAFB68C7F5170D98A45CAE2DC089', '1D7FA27E648BC9A5EE495A4A4830C4A7BC7B3096', '1F1E6766590E19853F33ECB2ABC57D4A9C508548', '02773D164DA726DCCCE66A339D606DCCA6943255', '00217398C6C1B639C15E9325A32D16D8A26F8706', '1D6593EB75F3E170A46E6675E1452B5320E122DF', '0D10CD05CE13155E8588E69758D859AFA2C78684', '027785AD9B8E4E77FA38DF59D6FF12AD2489E2C0', '00EC7139F5DABAA261DCCAB9995F59B22BC390E2', '017A39E9E91490A153F375B93DB80AA00DFA5AE2', '1D92A3C4BDA0CA6705C4483EA98DA79B22A83BD2', '02A3D28FDA93CC946D2A42D264EBAE251E69A626', '05DA1397AA5F2BFB7ED81F686547924CDDFA707A', '02094DE0CECDF679FA9766A5DA012F88493A5B68', '267B9C791BC05D21D1A0CE67C16B7EFE63B72286', '00A87DF8491F352150D81C963DF598BF1B54C510', '23AFD57C70C4F7F9D712827C9E2F8317F3BAF9CD', '01A33516C4E29B8B112E7C32E7B5D37400D54659', '01DDB1CE2441154664F4C3167C7D2A71C89A29D0', '1905A8FC2F602F25609E3700F856BBBD0A8EA559', '1381FB9BAF1CE63F7BCC312416AE6EE5CDC1DC34', '1ECB42DEDA1AF129BE4924951581D93E80D3799A', '214C546EBB8ADEF131980B088C9400B204BEE7DF', '09F8E0BA1A689027BC8382114DF97997CE578269', '08E19691F05C17DDC2A91D95075EA80F480D37E3', '001436ED41F025354DD54DE404DE1030018CD2F9', '223E94C25E47C2C9ADB0347B53B8FA3EE99201A9', '0FDD10B0057B6B2053B40B36D8FFD1E74B382664', '070D174B144AE268295702454141ED0817B7E472', '1CDB5D51857215C24CEBEC95106396DE40280E3F', '1F08F4152E67F3BF632DEA831549B4365DCAEC23', '02E050F12FB8CE4F7F99DE8443ADB9EBE24426B7', '0085673A4BB2E37EF4FF5FE7AEBE72286FEAF407', '046662B8B04838AF0A07CF6E6CD469A59080B2B6', '002FA54A84E75906E16CA14EDA7F780E1B7897DD', '0BFAE2C5E78A6F4D29B2CE605700586D96BDA547', '0A75CFB93DF2EBCA4D5FE108CA3450FE8A30BC6B', '1C4B3DA762A9475192DCC9F6EC2B00C634740C3C', '002DCB0135B784DA6C311D6361E7634351E4AE5D', '0DFF92E4DBC9E36378A7C8F25B9DE0C2CA3D9FEF', '0F0AF8F66D8CC778F4703920AECD4316AA3C7611', '02E47A9FC26AC14932E9EC75D9813F93DAA70D15', '205E9FEA75FF3EA54B50098FAB43BA0B8D43C186', '0919D3B1EFDF45619262002852D21C13065F93F3', '10128C8B92BD3D63DBDFE350EFD117B47F20B32D', '027C458D96707BD844C5A4E2C8EF9EA7AFF196B0', '131AC0E52C29E3E9291F9A6DB1029D6645E832E2', '00E8B09F43310DF850670A416AF3886807B6C128', '06CB0062D1D9F2EEE4E54AF817BA8BBDCDBC34C0', '0560D0F00547586565EE6C5AAFACFC00E4A5F5DA', '1A8E10CA839EA8A2153CFF90AD7BF3416E7B10E4', '032B0A46846D51BAA0286C0FDC6F56BA65EDCB36', '170362394C66FD84E2F4EA8A186124F35EA96E26', '105CBE3AEA29C17B688B397C8B267758ABA49DA2', '209F6949D1114CD6F10D2FECE58555E20F813865', '19D823683CF3582DACBE6501248805FD78A7A24D']
# print(len(random_patients))

# # Filter the DataFrame to include only the random patients
# df_filtered = df_hb[df_hb['pseudo_id'].isin(random_patients)]
# len(df_filtered['pseudo_id'].unique())

# df_hb = df_filtered.reset_index(drop=True)


# path = 'a:/test-date-past-month'
# file = 'bloeding-test-recentelijk-10-lab'
# df_hb = pd.read_csv(f'{path}/{file}.csv')

path = 'a:/test-date-past-month-copy'
file = 'bloeding-test-recentelijk-copy-10-lab'
df_hb = pd.read_csv(f'{path}/{file}.csv')


df_hb['lab_measurement_start_date'] = pd.to_datetime(df_hb['lab_measurement_start_date'])

df_hb
# Out:
#                                      pseudo_id lab_measurement_description  \
# 0     015D6D678A50A376699EF4D0EF0D291AA12E32E7                  Bloedgroep
# 1     015D6D678A50A376699EF4D0EF0D291AA12E32E7                Calprotect F
# 2     015D6D678A50A376699EF4D0EF0D291AA12E32E7                 Hemoglobine
# 3     015D6D678A50A376699EF4D0EF0D291AA12E32E7                         MCV
# 4     015D6D678A50A376699EF4D0EF0D291AA12E32E7                 Trombocyten
# ...                                        ...                         ...
# 3237  FE14A5DDB54FC7F5C6EB5283B4128401C0998A8C                         NaN
# 3238  FE14A5DDB54FC7F5C6EB5283B4128401C0998A8C                         NaN
# 3239  FE14A5DDB54FC7F5C6EB5283B4128401C0998A8C                         NaN
# 3240  FE14A5DDB54FC7F5C6EB5283B4128401C0998A8C                         NaN
# 3241  FE14A5DDB54FC7F5C6EB5283B4128401C0998A8C                         NaN
#
#      lab_measurement_test_value_string  lab_measurement_test_value_numeric  \
# 0                                B pos                                 NaN
# 1                                  257                              257.00
# 2                                  7.6                                7.60
# 3                                   95                               95.00
# 4                                  159                              159.00
# ...                                ...                                 ...
# 3237                               4.2                                4.20
# 3238                               3.6                                3.60
# 3239                              7.31                                7.31
# 3240                              7.22                                7.22
# 3241                          Zie opm.                                 NaN
#
#      lab_measurement_test_value_unit lab_measurement_start_date
# 0                                NaN        2025-04-04 00:00:00
# 1                              mg/kg        2025-04-02 09:51:00
# 2                             mmol/L        2025-04-02 09:50:00
# 3                                 fL        2025-04-02 09:50:00
# 4                            x10^9/L        2025-04-02 09:50:00
# ...                              ...                        ...
# 3237                             NaN        2000-11-23 00:58:00
# 3238                             NaN        2000-11-22 22:38:00
# 3239                             NaN        2000-11-22 21:43:00
# 3240                             NaN        2000-11-22 21:43:00
# 3241                             NaN        2000-11-22 21:43:00
#
# [3242 rows x 6 columns]

# %%
df_hb['lab_measurement_description'].unique()
# Out:
# array(['Bloedgroep', 'Calprotect F', 'Hemoglobine', 'MCV', 'Trombocyten',
#        'Leucocyten', 'Kreatinine', 'Alkalische Fosfatase (AF)', 'GGT',
#        'ALAT', 'CRP', 'eGFR CKD-EPI', 'Nitriet (ur)',
#        'Plaveisel epitheel (kwantitatief)', 'Bacteriën', 'Materiaal :',
#        'Klin./Medische gegevens', 'Antibiotica', 'Extra onderzoek op',
#        'pH (kwant)  U', 'Urine kweek', 'Leukocyten', 'Erytrocyten',
#        'Uraat', 'Kalium', 'Calcium', 'Albumine', 'Calcium corr',
#        'non-HDL cholest.', 'Hematocriet', 'Natrium', 'Ureum',
#        'Cholesterol', 'HDL Cholesterol', 'Cholesterol-HDL Ratio',
#        'LDL Cholesterol', 'Triglyceriden', 'Glucose', 'Extern lab.',
#        '6-TGN_AZA6MP(*)', '6-MMPR_AZA6MP(*)', 'bepaling :(*)',
#        'TF/log FERR', 'Lactase defi.genotype', 'Bilirubine Totaal',
#        'ASAT', 'Actief B12', 'Foliumzuur', 'IJzer', 'Transferrine',
#        'Transferrineverzadiging', 'Ferritine', 'IgA', 'anti-tTG IgA',
#        'TSH(screen)', 'INR', 'Bacterieel', 'Plaveisel epith.',
#        'Opmerking:', 'Bloedkweek', 'Base Excess', 'Bicarbonaat',
#        'Lactaat (bloedgas)', 'O2-verzadiging', 'pCO2', 'pH', 'pO2',
#        'Materiaal:', 'Irregulaire antistoffen', 'Bloedgroep Rhesus',
#        'Anti-Helicobacter pylori', 'Opm. afname', 'LD', 'Myelocyten',
#        'Metamyelocyten', 'Neutrofielen', 'Lymfocyten', 'Monocyten',
#        'Eosinofielen', 'Toxische korreling', 'Staafkernigen',
#        'Informatie', 'Neutrofielen #', 'Lymfocyten #', 'Monocyten #',
#        'Eosinofielen #', 'Lipase', 'Spijtmateriaal RUMC Liason bepaling',
#        'Totaal eiwit', 'pH (vo)', 'Materiaal =', 'Cytogram',
#        'Hb (bloedgas)', 'aant.lt. O2:', 'Extra buis', nan, 'Glucose POC',
#        'Fosfaat', 'Magnesium', 'Bloedtransfusie', 'eGFR (MDRD)',
#        'Parathormoon (PTH)', 'Vit.D3 25 OH', 'Bezinking',
#        'Chromogranine A(*)', 'FORCE-NEN studie', 'HIAA(5)/24 U', 'Volume',
#        'Bilirubine Direct', 'Glucose 11 u', 'Glucose 16 u',
#        'Glucose 21 u', 'PetCo2', 'SpO2(Hamilton)',
#        'SpO2(Philips, Masimo)', 'Protrombinetijd', 'APTT',
#        'Glucose (bloedgas)', 'Kalium bloedgas', 'Natrium bloedgas', 'TSH',
#        'T4 (vrij)', 'D-dimeer', 'Basofielen', 'Basofielen #',
#        'Thyr. panel', 'Glucose nuchter', 'Microalbumine(u)',
#        'Alb/Kreat R', 'Opmering Klin.Chem.', 'hCG+beta U', 'Slijm',
#        'CA 125', 'Zwangerschapstest', 'Info urine', 'Lactaat',
#        'Kalium gecorrigeerd', 'del.tijd opm', 'CK', 'CK-MB massa',
#        'hs Troponine T', 'M-malonzuur gecorrigeerd', 'Cortisol 8 uur',
#        'M-malonzuur', 'PSA', 'Elek.forese',
#        'Info bij M-proteine onderzoek', 'IgG', 'IgM', 'Reticulocyten',
#        'Haptoglobine', 'Ret.Prod.Index', 'Anem. panel', 'Opmerking',
#        'INR(TD)', 'iFOBT kwant.', 'iFOBT', 'Aspect feces', 'Urinezuur',
#        'Rh. KELL typ.', 'Albumine U', 'Glucose U', 'Eiwit/Kreat R',
#        'HbA1c', 'ANA', 'Alfa-1-antitrypsine', 'Ceruloplasmine',
#        'Mitochondrien antistoffen', 'Spijtserum', 'Hepatitis E (PCR)',
#        'Epstein Barr(*)', 'CMV(*)', 'Hepatitis A(*)', 'Info:',
#        'Klin.Gen.LUMC(*)', 'DNA hemochromatose', 'Eiwit(tot.)U',
#        'Vitamine B1', 'Vitamine B6', 'CRP-POCT', 'Bloedkweek(*)',
#        'Erytroblast.', 'Anti-CCP', 'Reumafactor', 'Klin.Gen.AZM(*)',
#        '25OHVD panel', 'Galzure zouten(*)', 'IgE', 'Vrije T3',
#        'Osmolaliteit', 'hCG+beta U (zwangerschapstest)', 'AFP', 'gewicht',
#        'Antist.Typ.', 'Irr.Antist.', 'CEA', 'NT-proBNP', 'CDT(IFCC)',
#        'CDT (CBR)', 'Borrelia (Lyme) DNA PCR', 'Lues serol.(*)',
#        'Artr. panel', 'Cortisol', 'Chloride', 'Opm.diff.',
#        'Lymfo. Reactief', 'PAMM'], dtype=object)

# %%
relevant_tests = [
    'Hemoglobine',
    # 'Hematocriet',
    # 'INR',
    # 'APTT',
    # 'Protrombinetijd',
    # 'Ureum',
    # 'MCV',
    # 'Trombocyten'
]


df_hb_filtered = df_hb[df_hb['lab_measurement_description'].isin(relevant_tests)]
print(df_hb_filtered['pseudo_id'].nunique())
# Out:
# 35

# %% [markdown]
# Taking treatments/diagnosis into a count

# %%
df_dbc = pd.read_csv('a:/bloeding-met-patientenlijst-gedetailleerd/bloeding-met-patientenlijst-2-diagnose-db-cs.csv')

# path = 'a:/test-data'
# file_dbc = 'bloeding-met-patientenlijst-copy-2-diagnose-db-cs'
# df_dbc = pd.read_csv(f'{path}/{file_dbc}.csv') 
# df_dbc

# random_patients = ['1C2103096F6605C14058A50A73B547E7FE3C9979', '0089B0DD461CDF5783EB16B371F0705E886443CE', '13EFEF4EE09106A298D217CCB2A702E18E351202', '02BD6625E37046C9C5E348E4DD6B18AC9C839D6C', '07F1A0C762415CEAE949A1119F7987251C5FE2CF', '031237F020F522F81EBE68FB10530BE5B338E58B', '01C3A3E194149D9C871373E49B8DA614A72428F1', '26B916D3BE2F8D4CBDFB1BA43AA6587D427B00FC', '01283148C27F27F492A54C8E68C1955EBB283FEE', '0087949E507BDA53F03F4E7A357C2057AFED2848', '00B35C907E9385D506DEED0576D5FE6EF731CA54', '062EA6F07818F539F78D0A7F8F014840A9F8D03D', '15979570214B1EC8C3A6C8D20D11B5FF0FC94A49', '016E3D76E797CDC875EA4E25B9E0FE7A4C83F92F', '0F51FAEAB4C84B7422A5149AC88A7D705D0087DA', '01A32746CBC9DC01F3709A3CF1575342A2BD9A32', '00F37BE661C10C9455C5EBA8A1BE0151677F0491', '1C9AE22A1831BDA2151F04E7E8BFFDB8864649CC', '1D31D4032DC6EE7F1C91F189EA63AA05CE3C014D', '0213525586905BCC987028AA073B67E1AFA8BAB0', '00BD2A7D7FC6F8DE98238FD198656DCBF2C33531', '26E7A07AC9783E93018E47B0DF318754DFE1A8D6', '029927802B0C8E2AED196B479D47BF0C5AFEBD1A', '2661C9B2C963DBB1296FF650DB0D3CC46C4F02EB', '017D4585B6D89095AF2C8984AE665FEFD39587BB', '100ED287105C74D5A041F4CC902F01D1FDD1E29F', '0118EAE341EBEDC24C6A4B9FDD284C3163118085', '10B7670CEEDE51D114DB4DA7E21C3216D8934894', '012C55BA94F266AB509051A1437653C242E8C5ED', '0153BBDED30D6F371EEB6C8AF12D87637EE23E0C', '01E1189C36B07093D0AEF612DF62E7C858EF47F3', '052CBBB5FD54B5AAA6EDA5E886CBE2E1096C114B', '063AE1E178E39D883F4A68E07766B5BB55477A3B', '00E85EA33E55AC1295F51BD4D33B5B9BFCC39275', '15DAA38394DBD6084D71950D1B117A172915D5FF', '0F6E03661EEEDD71FF07066C47C11CF2D866DCF5', '013AD0878DCA9DBAC4211791619C40BB605850C4', '2718A80B8CECEFAD740CD68C556218D43CCF3F51', '0149515B704A19A1AAD7FC3E45E5CC461117AFDF', '009A96A66DAEC4B18EF5EF192DB9AE60C7F08C61', '026866B398A38E1A274F49040C43C0ED59B293C0', '006265630EA7C11DD855F5EFB0692DDC53B0A806', '00D18EE08E5E35D4B8173DB636AE8433AAED3EFD', '14C8AD7BB63F16F18ECAFA67DA25BBC4167B336D', '025E6793B0FA3673404231B306B6AD2AB85BE792', '21E819B575C27415E1DF3B42436C4638ED9E9534', '0051CC4BF108BB13B6711C7DF61552DDF7213088', '16311B0009E80A0C219025EFDD6EF068C12DF44F', '1E451E45C59736A86E0C29E3D3D7403A89CA049E', '000F4E47813CFAFB68C7F5170D98A45CAE2DC089', '1D7FA27E648BC9A5EE495A4A4830C4A7BC7B3096', '1F1E6766590E19853F33ECB2ABC57D4A9C508548', '02773D164DA726DCCCE66A339D606DCCA6943255', '00217398C6C1B639C15E9325A32D16D8A26F8706', '1D6593EB75F3E170A46E6675E1452B5320E122DF', '0D10CD05CE13155E8588E69758D859AFA2C78684', '027785AD9B8E4E77FA38DF59D6FF12AD2489E2C0', '00EC7139F5DABAA261DCCAB9995F59B22BC390E2', '017A39E9E91490A153F375B93DB80AA00DFA5AE2', '1D92A3C4BDA0CA6705C4483EA98DA79B22A83BD2', '02A3D28FDA93CC946D2A42D264EBAE251E69A626', '05DA1397AA5F2BFB7ED81F686547924CDDFA707A', '02094DE0CECDF679FA9766A5DA012F88493A5B68', '267B9C791BC05D21D1A0CE67C16B7EFE63B72286', '00A87DF8491F352150D81C963DF598BF1B54C510', '23AFD57C70C4F7F9D712827C9E2F8317F3BAF9CD', '01A33516C4E29B8B112E7C32E7B5D37400D54659', '01DDB1CE2441154664F4C3167C7D2A71C89A29D0', '1905A8FC2F602F25609E3700F856BBBD0A8EA559', '1381FB9BAF1CE63F7BCC312416AE6EE5CDC1DC34', '1ECB42DEDA1AF129BE4924951581D93E80D3799A', '214C546EBB8ADEF131980B088C9400B204BEE7DF', '09F8E0BA1A689027BC8382114DF97997CE578269', '08E19691F05C17DDC2A91D95075EA80F480D37E3', '001436ED41F025354DD54DE404DE1030018CD2F9', '223E94C25E47C2C9ADB0347B53B8FA3EE99201A9', '0FDD10B0057B6B2053B40B36D8FFD1E74B382664', '070D174B144AE268295702454141ED0817B7E472', '1CDB5D51857215C24CEBEC95106396DE40280E3F', '1F08F4152E67F3BF632DEA831549B4365DCAEC23', '02E050F12FB8CE4F7F99DE8443ADB9EBE24426B7', '0085673A4BB2E37EF4FF5FE7AEBE72286FEAF407', '046662B8B04838AF0A07CF6E6CD469A59080B2B6', '002FA54A84E75906E16CA14EDA7F780E1B7897DD', '0BFAE2C5E78A6F4D29B2CE605700586D96BDA547', '0A75CFB93DF2EBCA4D5FE108CA3450FE8A30BC6B', '1C4B3DA762A9475192DCC9F6EC2B00C634740C3C', '002DCB0135B784DA6C311D6361E7634351E4AE5D', '0DFF92E4DBC9E36378A7C8F25B9DE0C2CA3D9FEF', '0F0AF8F66D8CC778F4703920AECD4316AA3C7611', '02E47A9FC26AC14932E9EC75D9813F93DAA70D15', '205E9FEA75FF3EA54B50098FAB43BA0B8D43C186', '0919D3B1EFDF45619262002852D21C13065F93F3', '10128C8B92BD3D63DBDFE350EFD117B47F20B32D', '027C458D96707BD844C5A4E2C8EF9EA7AFF196B0', '131AC0E52C29E3E9291F9A6DB1029D6645E832E2', '00E8B09F43310DF850670A416AF3886807B6C128', '06CB0062D1D9F2EEE4E54AF817BA8BBDCDBC34C0', '0560D0F00547586565EE6C5AAFACFC00E4A5F5DA', '1A8E10CA839EA8A2153CFF90AD7BF3416E7B10E4', '032B0A46846D51BAA0286C0FDC6F56BA65EDCB36', '170362394C66FD84E2F4EA8A186124F35EA96E26', '105CBE3AEA29C17B688B397C8B267758ABA49DA2', '209F6949D1114CD6F10D2FECE58555E20F813865', '19D823683CF3582DACBE6501248805FD78A7A24D']
# print(len(random_patients))

# # Filter the DataFrame to include only the random patients
# df_filtered_dbc = df_dbc[df_dbc['pseudo_id'].isin(random_patients)]
# len(df_filtered_dbc['pseudo_id'].unique())

# df_dbc = df_filtered_dbc

df_dbc['diagnose_db_cs_dbc_start_date'] = pd.to_datetime(df_dbc['diagnose_db_cs_dbc_start_date'])
df_dbc['diagnose_db_cs_dbc_end_date'] = pd.to_datetime(df_dbc['diagnose_db_cs_dbc_end_date'])
df_dbc.head()


df_dbc['diagnose_db_cs_dbc_start_date'] = pd.to_datetime(df_dbc['diagnose_db_cs_dbc_start_date'])
df_dbc['diagnose_db_cs_dbc_end_date'] = pd.to_datetime(df_dbc['diagnose_db_cs_dbc_end_date'])
df_dbc.head()
# Out:
#                                   pseudo_id  \
# 0  046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 1  046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 2  046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 3  046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 4  046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
#
#    diagnose_db_cs_dbc_specialty_code  \
# 0                                318
# 1                                318
# 2                                318
# 3                                318
# 4                                318
#
#     diagnose_db_cs_dbc_specialty_code_description  \
# 0  Gastro-enterologie (MDL, maag-darm-lever-arts)
# 1  Gastro-enterologie (MDL, maag-darm-lever-arts)
# 2  Gastro-enterologie (MDL, maag-darm-lever-arts)
# 3  Gastro-enterologie (MDL, maag-darm-lever-arts)
# 4  Gastro-enterologie (MDL, maag-darm-lever-arts)
#
#    diagnose_db_cs_dbc_diagnosis_code  \
# 0                                203
# 1                                203
# 2                                203
# 3                                203
# 4                                612
#
#   diagnose_db_cs_dbc_diagnosis_code_description diagnose_db_cs_dbc_start_date  \
# 0        Bloedverlies tractus digestivus e.c.i.                    2021-09-05
# 1        Bloedverlies tractus digestivus e.c.i.                    2021-05-08
# 2        Bloedverlies tractus digestivus e.c.i.                    2021-01-08
# 3        Bloedverlies tractus digestivus e.c.i.                    2020-11-24
# 4    (acute)Bloeding distale tractus digestivus                    2017-06-02
#
#   diagnose_db_cs_dbc_end_date
# 0                  2022-01-02
# 1                  2021-09-04
# 2                  2021-05-07
# 3                  2021-01-07
# 4                  2017-09-29

# %%
df_dbc['diagnosis_window_start'] = df_dbc['diagnose_db_cs_dbc_start_date'] - pd.Timedelta(days=90)
df_dbc['diagnosis_window_end'] = df_dbc['diagnose_db_cs_dbc_end_date'] + pd.Timedelta(days=7)

# Repeat Hb data for possible merging
df_merged = df_hb_filtered.merge(df_dbc, on='pseudo_id', how='inner')

# Keep only those where Hb test is within the diagnosis window
df_merged = df_merged[
    (df_merged['lab_measurement_start_date'] >= df_merged['diagnosis_window_start']) &
    (df_merged['lab_measurement_start_date'] <= df_merged['diagnosis_window_end'])
]

# df_merged = df_merged[
#     (df_merged['lab_measurement_start_date'] >= df_merged['diagnose_db_cs_dbc_start_date']) &
#     (df_merged['lab_measurement_start_date'] <= df_merged['diagnose_db_cs_dbc_end_date'])
# ]

df_merged
# Out:
# Empty DataFrame
# Columns: [pseudo_id, lab_measurement_description, lab_measurement_test_value_string, lab_measurement_test_value_numeric, lab_measurement_test_value_unit, lab_measurement_start_date, diagnose_db_cs_dbc_specialty_code, diagnose_db_cs_dbc_specialty_code_description, diagnose_db_cs_dbc_diagnosis_code, diagnose_db_cs_dbc_diagnosis_code_description, diagnose_db_cs_dbc_start_date, diagnose_db_cs_dbc_end_date, diagnosis_window_start, diagnosis_window_end]
# Index: []

# %%
# Sort by patient and time
df_merged3 = df_merged.sort_values(by=['pseudo_id', 'lab_measurement_start_date'])

# Calculate time difference to the next Hb measurement (in days)
df_merged3['timestamp_next'] = df_merged3.groupby('pseudo_id')['lab_measurement_start_date'].shift(-1)
df_merged3['days_to_next'] = (df_merged3['timestamp_next'] - df_merged['lab_measurement_start_date']).dt.days

# Filter only those within 7 days
df_merged3['within_7_days'] = df_merged3['days_to_next'] <= 7

# Calculate % change in Hb per patient
df_merged3['hb_pct_change'] = df_merged3.groupby('pseudo_id')['lab_measurement_test_value_numeric'].pct_change(periods=-1) * -100  # negative drop

# Flag significant drops (e.g. ≥ 6.85%)
SIGNIFICANT_DROP_THRESHOLD = 6.85

df_merged3['significant_hb_drop_diagnose'] = (
    df_merged3['hb_pct_change'] >= SIGNIFICANT_DROP_THRESHOLD
)

# Flag significant drops (e.g. ≥ 6.85%) within 7 days
# df_merged['significant_hb_drop_diagnose_7_days'] = (
#     df_merged['hb_pct_change'] >= SIGNIFICANT_DROP_THRESHOLD
# ) & df_merged['within_7_days']

# %%
# Filter only significant drops
# significant_drops_7_days_diagnosis = df_merged[df_merged['significant_hb_drop_7_days_diagnosis']]
significant_drops_diagnosis = df_merged3[df_merged3['significant_hb_drop_diagnose']]

# # Optional: one row per patient + diagnosis period
# patients_with_drop = significant_drops_7_days_diagnosis[group_cols].drop_duplicates()
# len(patients_with_drop)

# hb_patient_lst_7_days_diagnosis = significant_drops_7_days_diagnosis['pseudo_id'].unique().tolist()
# print(len(hb_patient_lst_7_days_diagnosis)) # 31 
# hb_patient_lst_7_days_diagnosis

hb_patient_lst_diagnosis = significant_drops_diagnosis['pseudo_id'].unique().tolist()
print(len(hb_patient_lst_diagnosis)) # 31
# Out:
# 0

# %% [markdown]
# With 3 days rescrition

# %%
# Sort by patient and time
df_merged2 = df_merged.sort_values(by=['pseudo_id', 'lab_measurement_start_date'])

# Calculate time difference to the next Hb measurement (in days)
df_merged2['timestamp_next'] = df_merged2.groupby('pseudo_id')['lab_measurement_start_date'].shift(-1)
df_merged2['days_to_next'] = (df_merged2['timestamp_next'] - df_merged2['lab_measurement_start_date']).dt.days

# Filter only those within 7 days
df_merged2['within_7_days'] = df_merged2['days_to_next'] <= 7

# Calculate % change in Hb per patient
df_merged2['hb_pct_change'] = df_merged2.groupby('pseudo_id')['lab_measurement_test_value_numeric'].pct_change(periods=-1) * -100  # negative drop

# Flag significant drops (e.g. ≥ 6.85%)
SIGNIFICANT_DROP_THRESHOLD = 6.85

# df_merged['significant_hb_drop_diagnose'] = (
#     df_merged['hb_pct_change'] >= SIGNIFICANT_DROP_THRESHOLD
# )

# Flag significant drops (e.g. ≥ 6.85%) within 7 days
df_merged2['significant_hb_drop_diagnose_7_days'] = (
    df_merged2['hb_pct_change'] >= SIGNIFICANT_DROP_THRESHOLD
) & df_merged2['within_7_days']



df_merged2
# Out:
# Empty DataFrame
# Columns: [pseudo_id, lab_measurement_description, lab_measurement_test_value_string, lab_measurement_test_value_numeric, lab_measurement_test_value_unit, lab_measurement_start_date, diagnose_db_cs_dbc_specialty_code, diagnose_db_cs_dbc_specialty_code_description, diagnose_db_cs_dbc_diagnosis_code, diagnose_db_cs_dbc_diagnosis_code_description, diagnose_db_cs_dbc_start_date, diagnose_db_cs_dbc_end_date, diagnosis_window_start, diagnosis_window_end, timestamp_next, days_to_next, within_7_days, hb_pct_change, significant_hb_drop_diagnose_7_days]
# Index: []

# %%
# Filter only significant drops
significant_drops = df_merged2[df_merged2['significant_hb_drop_diagnose_7_days']]

# Optional: one row per patient + diagnosis period
patients_with_drop = significant_drops.drop_duplicates()
len(patients_with_drop)

hb_patient_lst_diagnosis_7_days = significant_drops['pseudo_id'].unique().tolist()
print(len(hb_patient_lst_diagnosis_7_days)) # 42  #27 with 3 days
# hb_patient_lst_diagnosis_7_days
# Out:
# 0

# %%
# Sort by patient and time
df_merged2 = df_merged.sort_values(by=['pseudo_id', 'lab_measurement_start_date'])

# Calculate time difference to the next Hb measurement (in days)
df_merged2['timestamp_next'] = df_merged2.groupby('pseudo_id')['lab_measurement_start_date'].shift(-1)
df_merged2['days_to_next'] = (df_merged2['timestamp_next'] - df_merged2['lab_measurement_start_date']).dt.days

# Filter only those within 7 days
df_merged2['within_7_days'] = df_merged2['days_to_next'] <= 7

# Calculate % change in Hb per patient
df_merged2['hb_pct_change'] = df_merged2.groupby('pseudo_id')['lab_measurement_test_value_numeric'].pct_change(periods=-1) * -100  # negative drop

# Flag significant drops (e.g. ≥ 6.85%)
SIGNIFICANT_DROP_THRESHOLD = 6.85

# df_merged['significant_hb_drop_diagnose'] = (
#     df_merged['hb_pct_change'] >= SIGNIFICANT_DROP_THRESHOLD
# )

# Flag significant drops (e.g. ≥ 6.85%) within 7 days
df_merged2['significant_hb_drop_diagnose_7_days'] = (
    df_merged2['hb_pct_change'] >= SIGNIFICANT_DROP_THRESHOLD
) & df_merged2['within_7_days']



df_merged2
# Out:
# Empty DataFrame
# Columns: [pseudo_id, lab_measurement_description, lab_measurement_test_value_string, lab_measurement_test_value_numeric, lab_measurement_test_value_unit, lab_measurement_start_date, diagnose_db_cs_dbc_specialty_code, diagnose_db_cs_dbc_specialty_code_description, diagnose_db_cs_dbc_diagnosis_code, diagnose_db_cs_dbc_diagnosis_code_description, diagnose_db_cs_dbc_start_date, diagnose_db_cs_dbc_end_date, diagnosis_window_start, diagnosis_window_end, timestamp_next, days_to_next, within_7_days, hb_pct_change, significant_hb_drop_diagnose_7_days]
# Index: []

# %%
df_merged['lab_measurement_test_value_numeric'].value_counts()
df_merged['lab_measurement_description'].value_counts()
# Out:
# Series([], Name: lab_measurement_description, dtype: int64)

# %%
df_merged4 = df_merged.sort_values(by=['pseudo_id', 'lab_measurement_start_date'])
df_merged4
# Out:
# Empty DataFrame
# Columns: [pseudo_id, lab_measurement_description, lab_measurement_test_value_string, lab_measurement_test_value_numeric, lab_measurement_test_value_unit, lab_measurement_start_date, diagnose_db_cs_dbc_specialty_code, diagnose_db_cs_dbc_specialty_code_description, diagnose_db_cs_dbc_diagnosis_code, diagnose_db_cs_dbc_diagnosis_code_description, diagnose_db_cs_dbc_start_date, diagnose_db_cs_dbc_end_date, diagnosis_window_start, diagnosis_window_end]
# Index: []

# %%
df_merged4 = df_merged.sort_values(by=['pseudo_id', 'lab_measurement_start_date'])
df_merged4['Hemoglobine'] = None


for i in range(len(df_merged4)):
    if df_merged4['lab_measurement_description'].iloc[i] == 'Hemoglobine':
        df_merged4['Hemoglobine'].iloc[i] = df_merged4['lab_measurement_test_value_numeric'].iloc[i]

print(df_merged4['Hemoglobine'].value_counts())
print(df_merged4['pseudo_id'].nunique())
# Out:
# Series([], Name: Hemoglobine, dtype: int64)
# 0

# %%
df_merged4['Hemoglobine'].value_counts()
# Out:
# Series([], Name: Hemoglobine, dtype: int64)

# %%
import pandas as pd
import numpy as np

# # Assume your dataframe is called df and has these columns: ['Patient_ID', 'Datum', 'Hemoglobine']
# df['Datum'] = pd.to_datetime(df['Datum'])
# df = df.sort_values(['Patient_ID', 'Datum'])



# For each patient, slide a 7-day window and find max/min Hb
result = []

for patient_id, group in df_merged4.groupby('pseudo_id'):
    group = group.sort_values('lab_measurement_start_date').reset_index(drop=True)
    
    for i, row in group.iterrows():
        window_start = row['lab_measurement_start_date'] - pd.Timedelta(days=7)
        window_data = group[(group['lab_measurement_start_date'] >= window_start) & (group['lab_measurement_start_date'] <= row['lab_measurement_start_date'])]
        # print('lab_measurement_start_data', row['lab_measurement_start_date'])
        # print('window_start', window_start)
        
        if len(window_data) >= 2:
            max_hb = window_data['Hemoglobine'].max()
            min_hb = window_data['Hemoglobine'].min()
            drop_pct = ((max_hb - min_hb) / max_hb) * 100
            
            if drop_pct >= 6.85: # and min_hb < 7.5:
                result.append({
                    'pseudo_id': patient_id,
                    'Window_End': row['lab_measurement_start_date'],
                    'lab_measurement_start_date': row['lab_measurement_start_date'],
                    'Hb_Drop_%': drop_pct,
                    'Hb_bool': True if drop_pct >= 6.85 else False,
                    'Max_Hb': max_hb,
                    'Min_Hb': min_hb
                })

df_hb_drops = pd.DataFrame(result)
df_hb_drops.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df_hb_drops
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df_hb_drops['pseudo_id'].nunique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Y.vanMegen\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File c:\Users\Y.vanMegen\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Y.vanMegen\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'pseudo_id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df_hb_drops['pseudo_id'].nunique()
#
# File c:\Users\Y.vanMegen\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File c:\Users\Y.vanMegen\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'pseudo_id'

# %% [markdown]
# IAT Testing

# %%
iat_df = df_hb[df_hb['lab_measurement_description'].str.lower().str.contains('irr|irregulaire', na=False)]
iat_df
# Out:
#                                       pseudo_id lab_measurement_description  \
# 445    0DD73490997F61870C32B3BB7C9CDE4E801FFF7D     Irregulaire antistoffen
# 731    12D65DA1F4CFAC101DE53C050C9037D97F42FC18     Irregulaire antistoffen
# 774    12D65DA1F4CFAC101DE53C050C9037D97F42FC18     Irregulaire antistoffen
# 885    15CF926899FB0141DABA60251D292FCC89C94C1B     Irregulaire antistoffen
# 1457   23E295F4F8F7550C76B6C22ABDA7DFFB3FCF1682     Irregulaire antistoffen
# ...                                         ...                         ...
# 9913   F63683C1B401C1929E4B45EDBCE3E4CE7757EE9F     Irregulaire antistoffen
# 9990   F797097BA39F81B05EEC3F251973743CA03CB9B4     Irregulaire antistoffen
# 10027  F797097BA39F81B05EEC3F251973743CA03CB9B4     Irregulaire antistoffen
# 10131  F8C241E69061BB450778B7A4CC336FF520469A0A     Irregulaire antistoffen
# 10262  FAA79717FF2C725767E9469350ACECF640E5FCBC     Irregulaire antistoffen
#
#       lab_measurement_test_value_string  lab_measurement_test_value_numeric  \
# 445                                NEG.                                 NaN
# 731                                NEG.                                 NaN
# 774                                NEG.                                 NaN
# 885                                NEG.                                 NaN
# 1457                               NEG.                                 NaN
# ...                                 ...                                 ...
# 9913                               NEG.                                 NaN
# 9990                               NEG.                                 NaN
# 10027                              NEG.                                 NaN
# 10131                              NEG.                                 NaN
# 10262                              NEG.                                 NaN
#
#       lab_measurement_test_value_unit lab_measurement_start_date
# 445                               NaN        2021-09-30 09:30:00
# 731                               NaN        2022-07-19 11:50:00
# 774                               NaN        2022-07-04 08:00:00
# 885                               NaN        2024-03-20 15:32:00
# 1457                              NaN        2018-12-02 08:00:00
# ...                               ...                        ...
# 9913                              NaN        2025-02-17 09:37:00
# 9990                              NaN        2024-12-25 14:30:00
# 10027                             NaN        2024-12-22 20:22:00
# 10131                             NaN        2023-03-24 08:00:00
# 10262                             NaN        2020-06-19 11:00:00
#
# [76 rows x 6 columns]

# %%
iat_df['lab_measurement_test_value_string'].value_counts()
# Out:
# NEG.     72
# Pos.      2
# TEKST     2
# Name: lab_measurement_test_value_string, dtype: int64

# %%
iat_df[iat_df['lab_measurement_test_value_string'] != 'NEG.']
# iat_df['lab_measurement_test_value_string                                         '].iloc[0]
# Out:
#                                      pseudo_id lab_measurement_description  \
# 8162  D25F6785232C8650378EAE7E1D994F3506AEF6DA     Irregulaire antistoffen
# 8163  D25F6785232C8650378EAE7E1D994F3506AEF6DA                 Irr.Antist.
# 8234  D25F6785232C8650378EAE7E1D994F3506AEF6DA     Irregulaire antistoffen
# 8235  D25F6785232C8650378EAE7E1D994F3506AEF6DA                 Irr.Antist.
#
#      lab_measurement_test_value_string  lab_measurement_test_value_numeric  \
# 8162                              Pos.                                 NaN
# 8163                             TEKST                                 NaN
# 8234                              Pos.                                 NaN
# 8235                             TEKST                                 NaN
#
#      lab_measurement_test_value_unit lab_measurement_start_date
# 8162                             NaN        2022-09-09 08:00:00
# 8163                             NaN        2022-09-09 08:00:00
# 8234                             NaN        2022-09-05 08:00:00
# 8235                             NaN        2022-09-05 08:00:00

# %%
iat_patiënten = iat_df['pseudo_id'].unique()
len(iat_patiënten) #46  
iat_patiënten_lst = iat_patiënten.tolist()
iat_patiënten
# Out:
# array(['0DD73490997F61870C32B3BB7C9CDE4E801FFF7D',
#        '12D65DA1F4CFAC101DE53C050C9037D97F42FC18',
#        '15CF926899FB0141DABA60251D292FCC89C94C1B',
#        '23E295F4F8F7550C76B6C22ABDA7DFFB3FCF1682',
#        '29B3653AE690547AB14AC7FCD32B21A561D5FF9A',
#        '2E7E9399C8366C94770E35BC822203C1B0BDAB07',
#        '355F07B9B6AF154431F346CBC4A6722294250C43',
#        '3605432FE03B28514E3927DA7E5C53BD177BFD31',
#        '37BFA228DFA04BE0596DCCC63D245B42B3A15727',
#        '3B21EF377C1BA327A67C2C951A6CB78BEAD5B3FE',
#        '40FF2EE78841C453C1C673E9047BABC03DD6CCEE',
#        '4D22E67480A038F4FEA67046F5706560CBB06C27',
#        '52EE37A2B81CD38A3062B4B7B216EDBB8BE07E6C',
#        '5C16934C56472DEB342641D17FB13F9AEFEEFFAB',
#        '618F149E27BFA64EBFEC903D49A75AAF88BD75B2',
#        '65F35D3FB57B75161F6854ACD38FBEB77A0394B0',
#        '6CF1734B040468B6802E26DFA5BC6B6FF6869362',
#        '706C18D256797B3BAFC980C49CA839BB467F6B5F',
#        '7087EB7CD49F67A7A8E51203DE7C0F9FFBBFB51B',
#        '7561B5E32DE738229F2D658FBAACEFFE80B50600',
#        '82513FFD34AAEE0A2C6BD8DBAE3B6E69B3CA21D5',
#        '895342BFD0D1C32FFF8F009C0E20CBE97B04677D',
#        '8D59B35BBF1DD6A47DEE04D5CE8BE848639D9A73',
#        '94876C5A2D72759210A854698D5A5E012C2ED946',
#        '96764B9E95688ACB64A6C8E99AC2E6D5828BED12',
#        '9763CE55BAB3BF537B9309F9A7A6085F86ED878A',
#        '9A5F28B3534569F4F2EF8F9C7CCD12F102A511D3',
#        'A75FEC66C73E482282B5537091BFBD0814458EAA',
#        'A8FA2D94EA62234A97F2D21737D6046198E67B20',
#        'A9A2482C557733BFC15A7DEAC217F8766D37FAA1',
#        'BAE82DBED446134D3759C32B5457D88A06F8F6AD',
#        'C5EE7D6FA25DF773D7EF38E213CDAAA1419C1A7A',
#        'C775682FCB29A890D7B64B211F17DFF3D8867951',
#        'CB30ED9CF2F8BE2FABC260C6990B8305E2C09F37',
#        'CEA4E6D31E5967750EF8E86C4DBC14D892475FFD',
#        'D25F6785232C8650378EAE7E1D994F3506AEF6DA',
#        'D9CCFA8F9DBD7233A09EB2ED21F53D791D96B92E',
#        'DB713A8F5F17426A57148E54A958A9C2BB241ECC',
#        'E506A62C8E7FC7F419C0023940AA65942115CEEC',
#        'E5969D3A741FDA5B3067AD81444CB371178C8486',
#        'EF04810F281C202634208F2091141C40EBD2BC3A',
#        'F5F86E4F57D98E65D464A42AC325615EFE0D5C31',
#        'F63683C1B401C1929E4B45EDBCE3E4CE7757EE9F',
#        'F797097BA39F81B05EEC3F251973743CA03CB9B4',
#        'F8C241E69061BB450778B7A4CC336FF520469A0A',
#        'FAA79717FF2C725767E9469350ACECF640E5FCBC'], dtype=object)

# %%
df_alleen_iat_patiënten = df_hb[df_hb['pseudo_id'].isin(iat_patiënten)]
df_alleen_iat_patiënten
# Out:
#                                       pseudo_id lab_measurement_description  \
# 400    0DD73490997F61870C32B3BB7C9CDE4E801FFF7D                     Natrium
# 401    0DD73490997F61870C32B3BB7C9CDE4E801FFF7D                      Kalium
# 402    0DD73490997F61870C32B3BB7C9CDE4E801FFF7D                       Ureum
# 403    0DD73490997F61870C32B3BB7C9CDE4E801FFF7D                  Kreatinine
# 404    0DD73490997F61870C32B3BB7C9CDE4E801FFF7D                Opm. dialyse
# ...                                         ...                         ...
# 10328  FAA79717FF2C725767E9469350ACECF640E5FCBC                         MCV
# 10329  FAA79717FF2C725767E9469350ACECF640E5FCBC                     Natrium
# 10330  FAA79717FF2C725767E9469350ACECF640E5FCBC                      Kalium
# 10331  FAA79717FF2C725767E9469350ACECF640E5FCBC                       Ureum
# 10332  FAA79717FF2C725767E9469350ACECF640E5FCBC                  Kreatinine
#
#       lab_measurement_test_value_string  lab_measurement_test_value_numeric  \
# 400                                 138                               138.0
# 401                                 2.0                                 2.0
# 402                                <0.8                                 NaN
# 403                                  51                                51.0
# 404                               Edial                                 NaN
# ...                                 ...                                 ...
# 10328                                78                                78.0
# 10329                               124                               124.0
# 10330                               4.2                                 4.2
# 10331                               9.9                                 9.9
# 10332                                92                                92.0
#
#       lab_measurement_test_value_unit lab_measurement_start_date
# 400                            mmol/L        2021-10-11 12:30:00
# 401                            mmol/L        2021-10-11 12:30:00
# 402                            mmol/L        2021-10-11 12:30:00
# 403                            µmol/L        2021-10-11 12:30:00
# 404                               NaN        2021-10-11 12:30:00
# ...                               ...                        ...
# 10328                              fL        2020-06-15 09:25:00
# 10329                          mmol/L        2020-06-15 09:25:00
# 10330                          mmol/L        2020-06-15 09:25:00
# 10331                          mmol/L        2020-06-15 09:25:00
# 10332                          µmol/L        2020-06-15 09:25:00
#
# [4540 rows x 6 columns]

# %%
patients_in_both = []
for i in range(len(hb_patient_lst_diagnosis)):
    for j in range(len(iat_patiënten)):
        # print('lst:', agib_patient_lst[j])
        if hb_patient_lst_diagnosis[i] == iat_patiënten[j]:
            # print('Patient is both:', df_reports_scopie_patient['pseudo_id'][i])
            if hb_patient_lst_diagnosis[i] not in patients_in_both:
                patients_in_both.append(hb_patient_lst_diagnosis[i])
                
len(patients_in_both)
# Out:
# 31

# %%
len(hb_patient_lst_diagnosis)
# Out:
# 45

# %%
bora_metrics = set(hb_patient_lst_diagnosis) | set(iat_patiënten_lst)
len(bora_metrics)
# bora_metrics
# Out:
# 60

# %%
df_hb
# Out:
#                                       pseudo_id lab_measurement_description  \
# 0      046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6                  Bloedgroep
# 1      046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6                  Kreatinine
# 2      046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6                eGFR CKD-EPI
# 3      046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6                   NT-proBNP
# 4      046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6                 Hemoglobine
# ...                                         ...                         ...
# 10428  FD8C682C1F4FDA1E5EC0B760D30875556419BD71   Alkalische Fosfatase (AF)
# 10429  FD8C682C1F4FDA1E5EC0B760D30875556419BD71                         GGT
# 10430  FD8C682C1F4FDA1E5EC0B760D30875556419BD71                        ASAT
# 10431  FD8C682C1F4FDA1E5EC0B760D30875556419BD71                        ALAT
# 10432  FD8C682C1F4FDA1E5EC0B760D30875556419BD71                         CRP
#
#       lab_measurement_test_value_string  lab_measurement_test_value_numeric  \
# 0                                 A neg                                 NaN
# 1                                    83                                83.0
# 2                                    58                                58.0
# 3                                   780                               780.0
# 4                                   6.9                                 6.9
# ...                                 ...                                 ...
# 10428                                88                                88.0
# 10429                                48                                48.0
# 10430                                25                                25.0
# 10431                                19                                19.0
# 10432                               2.8                                 2.8
#
#       lab_measurement_test_value_unit lab_measurement_start_date
# 0                                 NaN        2024-08-05 00:00:00
# 1                              µmol/L        2024-07-31 09:11:00
# 2                    ml/min/{1.73_m2}        2024-07-31 09:11:00
# 3                               pg/ml        2024-07-22 09:29:00
# 4                              mmol/L        2024-07-22 09:29:00
# ...                               ...                        ...
# 10428                             U/L        2018-10-17 11:11:00
# 10429                             U/L        2018-10-17 11:11:00
# 10430                             U/L        2018-10-17 11:11:00
# 10431                             U/L        2018-10-17 11:11:00
# 10432                            mg/L        2018-10-17 11:11:00
#
# [10433 rows x 6 columns]

# %% [markdown]
# Add sign drop hb to data

# %%
df_hb['signficant_hb_drop_7_days'] = False


for i in range(len(df_hb)):
    for j in range(len(df_merged2)):
        # if df_hb['pseudo_id'].iloc[i] == df_merged[j] and df_hb['lab_measurement_start_date'].iloc[i] == df_merged['lab_measurement_start_date'].iloc[j]:
        if df_hb['pseudo_id'].iloc[i] == df_merged2['pseudo_id'].iloc[j] and df_hb['lab_measurement_start_date'].iloc[i] == df_merged2['lab_measurement_start_date'].iloc[j]:
            df_hb['signficant_hb_drop_7_days'].iloc[i] = df_merged2['significant_hb_drop_diagnose_7_days'].iloc[j]

df_hb['signficant_hb_drop_7_days'].value_counts()
# Out:
# C:\Users\Y.vanMegen\AppData\Local\Temp\ipykernel_13200\1935552907.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_hb['signficant_hb_drop_7_days'].iloc[i] = df_merged2['significant_hb_drop_diagnose_7_days'].iloc[j]
# False    9961
# True      472
# Name: signficant_hb_drop_7_days, dtype: int64

# %%
df_hb['signficant_hb_drop_7_days_max_min'] = False

for i in range(len(df_hb)):
    for j in range(len(df_hb_drops)):
        # if df_hb['pseudo_id'].iloc[i] == df_merged[j] and df_hb['lab_measurement_start_date'].iloc[i] == df_merged['lab_measurement_start_date'].iloc[j]:
        if df_hb['pseudo_id'].iloc[i] == df_hb_drops['pseudo_id'].iloc[j] and df_hb['lab_measurement_start_date'].iloc[i] == df_hb_drops['lab_measurement_start_date'].iloc[j]:
            df_hb['signficant_hb_drop_7_days_max_min'].iloc[i] = df_hb_drops['Hb_bool'].iloc[j]

df_hb['signficant_hb_drop_7_days_max_min'].value_counts()
# Out:
# C:\Users\Y.vanMegen\AppData\Local\Temp\ipykernel_13200\2636995334.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_hb['signficant_hb_drop_7_days_max_min'].iloc[i] = df_hb_drops['Hb_bool'].iloc[j]
# False    9587
# True      846
# Name: signficant_hb_drop_7_days_max_min, dtype: int64

# %%
df_hb
# Out:
#                                       pseudo_id lab_measurement_description  \
# 0      046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6                  Bloedgroep
# 1      046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6                  Kreatinine
# 2      046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6                eGFR CKD-EPI
# 3      046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6                   NT-proBNP
# 4      046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6                 Hemoglobine
# ...                                         ...                         ...
# 10428  FD8C682C1F4FDA1E5EC0B760D30875556419BD71   Alkalische Fosfatase (AF)
# 10429  FD8C682C1F4FDA1E5EC0B760D30875556419BD71                         GGT
# 10430  FD8C682C1F4FDA1E5EC0B760D30875556419BD71                        ASAT
# 10431  FD8C682C1F4FDA1E5EC0B760D30875556419BD71                        ALAT
# 10432  FD8C682C1F4FDA1E5EC0B760D30875556419BD71                         CRP
#
#       lab_measurement_test_value_string  lab_measurement_test_value_numeric  \
# 0                                 A neg                                 NaN
# 1                                    83                                83.0
# 2                                    58                                58.0
# 3                                   780                               780.0
# 4                                   6.9                                 6.9
# ...                                 ...                                 ...
# 10428                                88                                88.0
# 10429                                48                                48.0
# 10430                                25                                25.0
# 10431                                19                                19.0
# 10432                               2.8                                 2.8
#
#       lab_measurement_test_value_unit lab_measurement_start_date  \
# 0                                 NaN        2024-08-05 00:00:00
# 1                              µmol/L        2024-07-31 09:11:00
# 2                    ml/min/{1.73_m2}        2024-07-31 09:11:00
# 3                               pg/ml        2024-07-22 09:29:00
# 4                              mmol/L        2024-07-22 09:29:00
# ...                               ...                        ...
# 10428                             U/L        2018-10-17 11:11:00
# 10429                             U/L        2018-10-17 11:11:00
# 10430                             U/L        2018-10-17 11:11:00
# 10431                             U/L        2018-10-17 11:11:00
# 10432                            mg/L        2018-10-17 11:11:00
#
#        signficant_hb_drop_7_days  signficant_hb_drop_7_days_max_min
# 0                          False                              False
# 1                          False                              False
# 2                          False                              False
# 3                          False                              False
# 4                          False                              False
# ...                          ...                                ...
# 10428                      False                              False
# 10429                      False                              False
# 10430                      False                              False
# 10431                      False                              False
# 10432                      False                              False
#
# [10433 rows x 8 columns]

# %%
relevant_tests = [
    'Hemoglobine',
    'Hematocriet',
    'INR',
    'APTT',
    'Protrombinetijd',
    'Ureum',
    'MCV',
    'Trombocyten'
]

df_tests_filtered = df_hb[df_hb['lab_measurement_description'].isin(relevant_tests)]
df_tests_filtered['pseudo_id'].nunique()
# Out:
# 105

# %%
# df_tests_filtered['Hb'] = None
# df_tests_filtered['Hematocriet'] = None
# df_tests_filtered['MCV'] = None
# df_tests_filtered['INR'] = None
# df_tests_filtered['APTT'] = None
# df_tests_filtered['Protrombinetijd'] = None
# df_tests_filtered['Ureum'] = None
# df_tests_filtered['Trombocyten'] = None
# df_tests_filtered['Bilirubine Totaal'] = None
# df_tests_filtered['ALAT'] = None
# df_tests_filtered['ASAT'] = None
# df_tests_filtered['Alkalische Fosfatase (AF)'] = None
# df_tests_filtered['GGT'] = None

# # for i in range(len(df_tests_filtered)):
# #     if df_tests_filtered['lab_measurement_description'].iloc[i] == 'Hemoglobine':
# #         if df_tests_filtered['lab_measurement_test_value_numeric'].iloc[i] < 7.5:
# #             df_tests_filtered['Hb'].iloc[i] = 'low'
# #         elif df_tests_filtered['lab_measurement_test_value_numeric'].iloc[i] > 7.5:
# #             df_tests_filtered['Hb'].iloc[i] = 'normal'

# #     if df_tests_filtered['lab_measurement_description'].iloc[i] == 'Hematocriet':
# #         if df_tests_filtered['lab_measurement_test_value_numeric'].iloc[i] < 0.35:
# #             df_tests_filtered['Hematocriet'].iloc[i] = 'low'
# #         elif df_tests_filtered['lab_measurement_test_value_numeric'].iloc[i] > 0.35:
# #             df_tests_filtered['Hematocriet'].iloc[i] = 'normal'

# #     if df_tests_filtered['lab_measurement_description'].iloc[i] == 'MCV':
# #         if df_tests_filtered['lab_measurement_test_value_numeric'].iloc[i] < 80:
# #             df_tests_filtered['MCV'].iloc[i] = 'low'
# #         elif df_tests_filtered['lab_measurement_test_value_numeric'].iloc[i] > 80:
# #             df_tests_filtered['MCV'].iloc[i] = 'normal'

# #     if df_tests_filtered['lab_measurement_description'].iloc[i] == 'INR':
# #         if df_tests_filtered['lab_measurement_test_value_numeric'].iloc[i] < 1.5:
# #             df_tests_filtered['INR'].iloc[i] = 'normal'
# #         elif df_tests_filtered['lab_measurement_test_value_numeric'].iloc[i] > 1.5:
# #             df_tests_filtered['INR'].iloc[i] = 'high'

# #     if df_tests_filtered['lab_measurement_description'].iloc[i] == 'APTT':
# #         if df_tests_filtered['lab_measurement_test_value_numeric'].iloc[i] < 35:
# #             df_tests_filtered['APTT'].iloc[i] = 'normal'
# #         elif df_tests_filtered['lab_measurement_test_value_numeric'].iloc[i] > 35:
# #             df_tests_filtered['APTT'].iloc[i] = 'high'
    
# #     if df_tests_filtered['lab_measurement_description'].iloc[i] == 'Protrombinetijd':
# #         if df_tests_filtered['lab_measurement_test_value_numeric'].iloc[i] < 15:
# #             df_tests_filtered['Protrombinetijd'].iloc[i] = 'normal'
# #         elif df_tests_filtered['lab_measurement_test_value_numeric'].iloc[i] > 15:
# #             df_tests_filtered['Protrombinetijd'].iloc[i] = 'high'
    
# #     if df_tests_filtered['lab_measurement_description'].iloc[i] == 'Ureum':
# #         if df_tests_filtered['lab_measurement_test_value_numeric'].iloc[i] < 7.5:
# #             df_tests_filtered['Ureum'].iloc[i] = 'normal'
# #         elif df_tests_filtered['lab_measurement_test_value_numeric'].iloc[i] > 7.5:
# #             df_tests_filtered['Ureum'].iloc[i] = 'high'

# #     if df_tests_filtered['lab_measurement_description'].iloc[i] == 'Trombocyten':
# #         if df_tests_filtered['lab_measurement_test_value_numeric'].iloc[i] < 150:
# #             df_tests_filtered['Trombocyten'].iloc[i] = 'low'
# #         elif df_tests_filtered['lab_measurement_test_value_numeric'].iloc[i] > 150:
# #             df_tests_filtered['Trombocyten'].iloc[i] = 'normal'


    
# # df_tests_filtered

# %%
df_tests_wide = df_tests_filtered.pivot_table(
    index=['pseudo_id', 'lab_measurement_start_date'],
    columns='lab_measurement_description',
    values='lab_measurement_test_value_numeric',
    aggfunc='first'
).reset_index()

print(df_tests_wide['pseudo_id'].nunique())
df_tests_wide
# Out:
# 105
# lab_measurement_description                                 pseudo_id  \
# 0                            046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 1                            046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 2                            046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 3                            046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 4                            046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# ..                                                                ...
# 801                          FD8C682C1F4FDA1E5EC0B760D30875556419BD71
# 802                          FD8C682C1F4FDA1E5EC0B760D30875556419BD71
# 803                          FD8C682C1F4FDA1E5EC0B760D30875556419BD71
# 804                          FD8C682C1F4FDA1E5EC0B760D30875556419BD71
# 805                          FD8C682C1F4FDA1E5EC0B760D30875556419BD71
#
# lab_measurement_description lab_measurement_start_date  APTT  Hematocriet  \
# 0                                  2024-07-03 08:00:00   NaN          NaN
# 1                                  2024-07-05 08:01:00   NaN          NaN
# 2                                  2024-07-08 08:00:00   NaN          NaN
# 3                                  2024-07-11 08:00:00   NaN          NaN
# 4                                  2024-07-15 08:38:00   NaN          NaN
# ..                                                 ...   ...          ...
# 801                                2021-03-03 08:00:00   NaN          NaN
# 802                                2021-03-05 08:00:00   NaN          NaN
# 803                                2021-03-08 08:00:00   NaN          NaN
# 804                                2021-03-09 12:25:00   NaN          NaN
# 805                                2021-03-10 09:30:00   NaN          NaN
#
# lab_measurement_description  Hemoglobine  INR   MCV  Protrombinetijd  \
# 0                                    NaN  1.8   NaN              NaN
# 1                                    NaN  3.4   NaN              NaN
# 2                                    NaN  1.2   NaN              NaN
# 3                                    NaN  2.3   NaN              NaN
# 4                                    6.2  NaN  96.0              NaN
# ..                                   ...  ...   ...              ...
# 801                                  NaN  5.6   NaN              NaN
# 802                                  NaN  1.6   NaN              NaN
# 803                                  NaN  4.1   NaN              NaN
# 804                                  8.7  2.1  88.0              NaN
# 805                                  8.9  2.1  86.0              NaN
#
# lab_measurement_description  Trombocyten  Ureum
# 0                                    NaN    NaN
# 1                                  356.0    NaN
# 2                                    NaN    NaN
# 3                                    NaN    NaN
# 4                                  402.0    5.8
# ..                                   ...    ...
# 801                                  NaN    NaN
# 802                                  NaN    NaN
# 803                                  NaN    NaN
# 804                                  NaN    NaN
# 805                                371.0    NaN
#
# [806 rows x 10 columns]

# %%
## algemeen
df_tests_wide['low_hb'] = df_tests_wide['Hemoglobine'] < 7.5
df_tests_wide['low_hematocriet'] = df_tests_wide['Hematocriet'] < 0.35
#bloedgroep
df_tests_wide['high_ureum'] = df_tests_wide['Ureum'] > 7.5 # voor hoge bloeding 

df_tests_wide['low_mcv'] = df_tests_wide['MCV'] < 80 # voor chronische anemie
df_tests_wide['high_mcv'] = df_tests_wide['MCV'] > 80 # voor eventueel acuut bloedverlies (aangezien waarde dan vaak nog normaal is)


df_tests_wide['high_inr'] = df_tests_wide['INR'] > 1.5 # in geval van coumaringegebruik
df_tests_wide['high_aptt'] = df_tests_wide['APTT'] > 35 # bij leverlijden

df_tests_wide['high_pt'] = df_tests_wide['Protrombinetijd'] > 15
df_tests_wide['high_ureum'] = df_tests_wide['Ureum'] > 7.5
df_tests_wide['low_plt'] = df_tests_wide['Trombocyten'] < 150

# df_tests_wide['high_bilirubine'] = df_tests_wide['Bilirubine totaal'] >= 17
print(df_tests_wide['pseudo_id'].nunique())
df_tests_wide
# Out:
# 105
# lab_measurement_description                                 pseudo_id  \
# 0                            046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 1                            046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 2                            046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 3                            046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 4                            046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# ..                                                                ...
# 801                          FD8C682C1F4FDA1E5EC0B760D30875556419BD71
# 802                          FD8C682C1F4FDA1E5EC0B760D30875556419BD71
# 803                          FD8C682C1F4FDA1E5EC0B760D30875556419BD71
# 804                          FD8C682C1F4FDA1E5EC0B760D30875556419BD71
# 805                          FD8C682C1F4FDA1E5EC0B760D30875556419BD71
#
# lab_measurement_description lab_measurement_start_date  APTT  Hematocriet  \
# 0                                  2024-07-03 08:00:00   NaN          NaN
# 1                                  2024-07-05 08:01:00   NaN          NaN
# 2                                  2024-07-08 08:00:00   NaN          NaN
# 3                                  2024-07-11 08:00:00   NaN          NaN
# 4                                  2024-07-15 08:38:00   NaN          NaN
# ..                                                 ...   ...          ...
# 801                                2021-03-03 08:00:00   NaN          NaN
# 802                                2021-03-05 08:00:00   NaN          NaN
# 803                                2021-03-08 08:00:00   NaN          NaN
# 804                                2021-03-09 12:25:00   NaN          NaN
# 805                                2021-03-10 09:30:00   NaN          NaN
#
# lab_measurement_description  Hemoglobine  INR   MCV  Protrombinetijd  \
# 0                                    NaN  1.8   NaN              NaN
# 1                                    NaN  3.4   NaN              NaN
# 2                                    NaN  1.2   NaN              NaN
# 3                                    NaN  2.3   NaN              NaN
# 4                                    6.2  NaN  96.0              NaN
# ..                                   ...  ...   ...              ...
# 801                                  NaN  5.6   NaN              NaN
# 802                                  NaN  1.6   NaN              NaN
# 803                                  NaN  4.1   NaN              NaN
# 804                                  8.7  2.1  88.0              NaN
# 805                                  8.9  2.1  86.0              NaN
#
# lab_measurement_description  Trombocyten  Ureum  low_hb  low_hematocriet  \
# 0                                    NaN    NaN   False            False
# 1                                  356.0    NaN   False            False
# 2                                    NaN    NaN   False            False
# 3                                    NaN    NaN   False            False
# 4                                  402.0    5.8    True            False
# ..                                   ...    ...     ...              ...
# 801                                  NaN    NaN   False            False
# 802                                  NaN    NaN   False            False
# 803                                  NaN    NaN   False            False
# 804                                  NaN    NaN   False            False
# 805                                371.0    NaN   False            False
#
# lab_measurement_description  high_ureum  low_mcv  high_mcv  high_inr  \
# 0                                 False    False     False      True
# 1                                 False    False     False      True
# 2                                 False    False     False     False
# 3                                 False    False     False      True
# 4                                 False    False      True     False
# ..                                  ...      ...       ...       ...
# 801                               False    False     False      True
# 802                               False    False     False      True
# 803                               False    False     False      True
# 804                               False    False      True      True
# 805                               False    False      True      True
#
# lab_measurement_description  high_aptt  high_pt  low_plt
# 0                                False    False    False
# 1                                False    False    False
# 2                                False    False    False
# 3                                False    False    False
# 4                                False    False    False
# ..                                 ...      ...      ...
# 801                              False    False    False
# 802                              False    False    False
# 803                              False    False    False
# 804                              False    False    False
# 805                              False    False    False
#
# [806 rows x 19 columns]

# %%
# # Combine features: 1) Hb + Urea  OR  2 or more coagulopathy markers
# df_tests_wide['likely_GIB'] = (
#     (df_tests_wide['low_hb'] & df_tests_wide['high_ureum']) |
#     (df_tests_wide[['low_hb', 'high_inr', 'low_plt', 'high_aptt', 'high_pt']].sum(axis=1) >= 2)
# )

# print(df_tests_wide.value_counts('likely_GIB'))
# df_tests_wide

# df_tests_wide['likely_gib'] = (
#     df_tests_wide[['low_hb', 'low_hematocriet', 'high_ureum', 'high_inr', 'high_aptt', 'high_pt', 'low_plt']]
#     .sum(axis=1) >= 2
# )

# df_tests_wide['likely_gib'].value_counts()

# %%
# df_tests_wide['likely_agib'] = (
#     df_tests_wide['low_hb'] &
#     df_tests_wide['high_ureum'] &
#     (df_tests_wide['low_mcv'] == False)  # dus MCV normaal of hoog
# )

# df_tests_wide['likely_agib'].value_counts()

# %% [markdown]
# Combining datasets

# %%
df_scopie = pd.read_csv('a:/bloeding-met-patientenlijst-gedetailleerd/df_scopie.csv')
df_regex = pd.read_csv('a:/bloeding-met-patientenlijst-gedetailleerd/df_regex2.csv')

# file_scopie = 'df_scopie'
# df_scopie = pd.read_csv(f'{path}/{file_scopie}.csv') 

# file_regex = 'df_regex'
# df_regex = pd.read_csv(f'{path}/{file_regex}.csv') 


# file_scopie = 'df_scopie3'
# df_scopie = pd.read_csv(f'{path}/{file_scopie}.csv') 

# file_regex = 'df_regex3'
# df_regex = pd.read_csv(f'{path}/{file_regex}.csv') 


# # Ensure date columns are in datetime format
df_scopie['verslagen_report_start_date'] = pd.to_datetime(df_scopie['verslagen_report_start_date'])
df_regex['verslagen_report_start_date'] = pd.to_datetime(df_regex['verslagen_report_start_date'])

# Merge both DataFrames on pseudo_id and report date
df_combined = pd.merge(
    df_regex,
    df_scopie,	
    on=['pseudo_id', 'verslagen_report_start_date', 'verslagen_report_content'],
    how='inner'  # or 'inner' if you only want overlapping rows
)

len(df_combined)
df_combined.head()
# Out:
#                                   pseudo_id verslagen_report_start_date  \
# 0  046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6         2020-11-26 15:06:00
# 1  046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6         2020-11-26 09:53:00
# 2  046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6         2020-11-25 14:13:00
# 3  046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6         2020-11-25 13:48:00
# 4  046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6         2020-11-25 08:47:00
#
#     verslagen_report_specialism  \
# 0  Maag-, Darm- en Leverziekten
# 1  Maag-, Darm- en Leverziekten
# 2  Maag-, Darm- en Leverziekten
# 3  Maag-, Darm- en Leverziekten
# 4  Maag-, Darm- en Leverziekten
#
#                             verslagen_report_content  agib_final  gib_final  \
# 0  Dhr. A.J. Dingemans, huisarts\r\n[STREETNAME] ...       False       True
# 1  Samenvatting: \nRectaal bloedverlies obv diver...       False       True
# 2  COLOSCOPIE\r\n\r\nBetreft\r\nMw. [INITIALS] [L...       False       True
# 3  GASTROSCOPIE\r\n\r\nBetreft\r\nMw. [INITIALS] ...       False       True
# 4  Samenvatting: \nRectaal bloedverlies ; eenmali...       False       True
#
#    scopie_final  treatment_final diagnose_db_cs_dbc_start_date  \
# 0          True             True                    2020-11-24
# 1          True             True                    2020-11-24
# 2          True            False                    2020-11-24
# 3          True            False                    2020-11-24
# 4          True            False                    2020-11-24
#
#   diagnose_db_cs_dbc_end_date  is_seh  is_scopie scopie_after_seh
# 0                  2021-01-07   False      False            False
# 1                  2021-01-07   False      False            False
# 2                  2021-01-07   False       True            False
# 3                  2021-01-07   False       True            False
# 4                  2021-01-07   False       True            False

# %%
df_combined = df_combined.drop_duplicates(subset=['pseudo_id', 'verslagen_report_start_date', 'verslagen_report_content'])

len(df_combined)
# Out:
# 11047

# %%
print(len(df_scopie), len(df_regex))
print(len(df_scopie.drop_duplicates(subset=['pseudo_id', 'verslagen_report_start_date', 'verslagen_report_content', 'is_seh', 'is_scopie', 'scopie_after_seh'])))
print(len(df_regex.drop_duplicates(subset=['pseudo_id', 'verslagen_report_start_date', 'verslagen_report_content', 'agib_final'])))

print(df_scopie['verslagen_report_start_date'].dtype)
print(df_regex['verslagen_report_start_date'].dtype)
# Out:
# 11090 11090
# 11047
# 11047
# datetime64[ns]
# datetime64[ns]

# %%
df_combined['verslagen_report_start_date'] = pd.to_datetime(df_combined['verslagen_report_start_date'])
df_hb['lab_measurement_start_date'] = pd.to_datetime(df_hb['lab_measurement_start_date'])

df_combined['report_date'] = df_combined['verslagen_report_start_date'].dt.date
df_hb['lab_date'] = df_hb['lab_measurement_start_date'].dt.date

print(df_combined['pseudo_id'].nunique())
print(df_hb['pseudo_id'].nunique())
# Out:
# 105
# 105

# %%
df_merged = pd.merge(
    df_combined,
    df_hb[['pseudo_id', 'lab_date', 'lab_measurement_start_date', 'lab_measurement_description', 'lab_measurement_test_value_numeric', 'signficant_hb_drop_7_days', 'signficant_hb_drop_7_days_max_min']],
    left_on=['pseudo_id', 'report_date'],
    right_on=['pseudo_id', 'lab_date'],
    how='left'  # <-- keeps all rows from df_combined
)

print(df_merged['pseudo_id'].nunique())
df_merged
# Out:
# 105
#                                       pseudo_id verslagen_report_start_date  \
# 0      046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6         2020-11-26 15:06:00
# 1      046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6         2020-11-26 09:53:00
# 2      046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6         2020-11-25 14:13:00
# 3      046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6         2020-11-25 13:48:00
# 4      046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6         2020-11-25 08:47:00
# ...                                         ...                         ...
# 19306  FD8C682C1F4FDA1E5EC0B760D30875556419BD71         2015-03-20 08:13:00
# 19307  FD8C682C1F4FDA1E5EC0B760D30875556419BD71         2015-01-14 15:39:00
# 19308  FD8C682C1F4FDA1E5EC0B760D30875556419BD71         2014-12-21 09:31:00
# 19309  FD8C682C1F4FDA1E5EC0B760D30875556419BD71         2010-11-10 21:03:00
# 19310  FD8C682C1F4FDA1E5EC0B760D30875556419BD71         2010-11-10 20:29:00
#
#         verslagen_report_specialism  \
# 0      Maag-, Darm- en Leverziekten
# 1      Maag-, Darm- en Leverziekten
# 2      Maag-, Darm- en Leverziekten
# 3      Maag-, Darm- en Leverziekten
# 4      Maag-, Darm- en Leverziekten
# ...                             ...
# 19306           Interne Geneeskunde
# 19307           Interne Geneeskunde
# 19308             Spoedeisende Hulp
# 19309             Spoedeisende Hulp
# 19310             Spoedeisende Hulp
#
#                                 verslagen_report_content  agib_final  \
# 0      Dhr. A.J. Dingemans, huisarts\r\n[STREETNAME] ...       False
# 1      Samenvatting: \nRectaal bloedverlies obv diver...       False
# 2      COLOSCOPIE\r\n\r\nBetreft\r\nMw. [INITIALS] [L...       False
# 3      GASTROSCOPIE\r\n\r\nBetreft\r\nMw. [INITIALS] ...       False
# 4      Samenvatting: \nRectaal bloedverlies ; eenmali...       False
# ...                                                  ...         ...
# 19306  Samenvatting: \n1e consult\r\n-Type 1e consult...       False
# 19307  Samenvatting: \nDecursus\r\n-Type decursus: De...       False
# 19308  Samenvatting: \nVerpleegkundige verslaglegging...       False
# 19309  Samenvatting: \nMedisch Dossier\r\n[ Vk Sputov...       False
# 19310  Samenvatting: \nVerpleegkundige verslaglegging...       False
#
#        gib_final  scopie_final  treatment_final diagnose_db_cs_dbc_start_date  \
# 0           True          True             True                    2020-11-24
# 1           True          True             True                    2020-11-24
# 2           True          True            False                    2020-11-24
# 3           True          True            False                    2020-11-24
# 4           True          True            False                    2020-11-24
# ...          ...           ...              ...                           ...
# 19306      False          True            False                           NaN
# 19307      False          True            False                           NaN
# 19308      False         False            False                           NaN
# 19309      False         False            False                           NaN
# 19310      False         False            False                           NaN
#
#       diagnose_db_cs_dbc_end_date  is_seh  is_scopie scopie_after_seh  \
# 0                      2021-01-07   False      False            False
# 1                      2021-01-07   False      False            False
# 2                      2021-01-07   False       True            False
# 3                      2021-01-07   False       True            False
# 4                      2021-01-07   False       True            False
# ...                           ...     ...        ...              ...
# 19306                         NaN   False      False            False
# 19307                         NaN   False      False            False
# 19308                         NaN    True      False            False
# 19309                         NaN    True      False            False
# 19310                         NaN    True      False            False
#
#       report_date lab_date lab_measurement_start_date  \
# 0      2020-11-26      NaN                        NaT
# 1      2020-11-26      NaN                        NaT
# 2      2020-11-25      NaN                        NaT
# 3      2020-11-25      NaN                        NaT
# 4      2020-11-25      NaN                        NaT
# ...           ...      ...                        ...
# 19306  2015-03-20      NaN                        NaT
# 19307  2015-01-14      NaN                        NaT
# 19308  2014-12-21      NaN                        NaT
# 19309  2010-11-10      NaN                        NaT
# 19310  2010-11-10      NaN                        NaT
#
#       lab_measurement_description  lab_measurement_test_value_numeric  \
# 0                             NaN                                 NaN
# 1                             NaN                                 NaN
# 2                             NaN                                 NaN
# 3                             NaN                                 NaN
# 4                             NaN                                 NaN
# ...                           ...                                 ...
# 19306                         NaN                                 NaN
# 19307                         NaN                                 NaN
# 19308                         NaN                                 NaN
# 19309                         NaN                                 NaN
# 19310                         NaN                                 NaN
#
#       signficant_hb_drop_7_days signficant_hb_drop_7_days_max_min
# 0                           NaN                               NaN
# 1                           NaN                               NaN
# 2                           NaN                               NaN
# 3                           NaN                               NaN
# 4                           NaN                               NaN
# ...                         ...                               ...
# 19306                       NaN                               NaN
# 19307                       NaN                               NaN
# 19308                       NaN                               NaN
# 19309                       NaN                               NaN
# 19310                       NaN                               NaN
#
# [19311 rows x 20 columns]

# %%
df_merged['signficant_hb_drop_7_days'].value_counts()
# Out:
# False    7477
# True     1518
# Name: signficant_hb_drop_7_days, dtype: int64

# %% [markdown]
# Hb drop from text

# %%
import pandas as pd
from datetime import datetime, timedelta
import re

df_merged['sigh_hb_drop_text'] = None

def extract_hb_with_timestamps(text, base_date=None):
    results = []
    current_timestamp = None

    time_or_date_pattern = re.compile(
        r'(Lab\s+(\d{1,2}:\d{2})|Laboratorium\s+(\d{2}-\d{2}-\d{4}))',
        re.IGNORECASE
    )

    hb_pattern = re.compile(
        r'\b(?:Hb|Hemoglobine)\b(?:\s*\([^\)]*\))?\s*[:=]?\s*([\d.,]+)',
        re.IGNORECASE
    )

    lines = text.splitlines()
    for line in lines:
        time_date_match = time_or_date_pattern.search(line)
        if time_date_match != None:
            print('time_date_match', time_date_match)
        if time_date_match:
            time_str = time_date_match.group(2)
            date_str = time_date_match.group(3)

            if time_str and base_date:
                try:
                    parsed_time = datetime.strptime(time_str, "%H:%M").time()
                    current_timestamp = datetime.combine(base_date.date(), parsed_time)
                except:
                    pass
            elif date_str:
                try:
                    current_timestamp = datetime.strptime(date_str, "%d-%m-%Y")
                except:
                    pass

        for hb_match in hb_pattern.finditer(line):
            value_str = hb_match.group(1).replace(',', '.')
            try:
                value = float(value_str)
                results.append({
                    'timestamp': current_timestamp or base_date,
                    'hb': value
                })
            except ValueError:
                continue

    return results

# def has_significant_hb_drop(hb_data, ref_date, threshold=1.0, window_days=7):
#     if not hb_data or len(hb_data) < 2:
#         return False
    
#     # Sort by timestamp
#     hb_data = sorted(hb_data, key=lambda x: x['timestamp'])
    
#     for i in range(len(hb_data)):
#         for j in range(i + 1, len(hb_data)):
#             t1 = hb_data[i]['timestamp']
#             t2 = hb_data[j]['timestamp']
#             hb1 = hb_data[i]['hb']
#             hb2 = hb_data[j]['hb']

#             # Ensure both timestamps are valid and within the window
#             if t1 and t2:
#                 if abs((t2 - t1).days) <= window_days and abs((t1 - ref_date).days) <= window_days and abs((t2 - ref_date).days) <= window_days:
#                     if hb1 - hb2 >= threshold:
#                         return True
#     return False

def has_significant_hb_drop(hb_data, ref_date, drop_pct_threshold=6.85, window_days=7):
    if not hb_data or len(hb_data) < 2:
        return False

    # Keep only results within the window of interest
    window_data = [
        entry for entry in hb_data
        if abs((entry['timestamp'] - ref_date).days) <= window_days
    ]
    
    if len(window_data) < 2:
        return False

    max_hb = max(entry['hb'] for entry in window_data)
    min_hb = min(entry['hb'] for entry in window_data)

    if max_hb == 0:
        return False  # Avoid division by zero

    drop_pct = ((max_hb - min_hb) / max_hb) * 100
    print(f"Drop percentage: {drop_pct:.2f}% (Threshold: {drop_pct_threshold}%)")
    return drop_pct >= drop_pct_threshold and min_hb < 7.5


# Apply to your dataframe
def analyze_df(df):
    results = []
    for _, row in df.iterrows():
        report_text = str(row['verslagen_report_content']) if pd.notnull(row['verslagen_report_content']) else ""
        report_date = pd.to_datetime(row['verslagen_report_start_date'])

        hb_data = extract_hb_with_timestamps(report_text, base_date=report_date)
        print(f"Processing report for patient {row['pseudo_id']} on {report_date.date()}")
        print(f"Extracted Hb data: {hb_data}")
        drop_found = has_significant_hb_drop(hb_data, report_date)
        results.append(drop_found)

    df['sigh_hb_drop_text'] = results
    return df


df_merged = analyze_df(df_merged)
df_merged
# Out:
# time_date_match <re.Match object; span=(0, 23), match='Laboratorium 24-11-2020'>
# time_date_match <re.Match object; span=(0, 23), match='Laboratorium 26-11-2020'>
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2020-11-26
# Extracted Hb data: [{'timestamp': datetime.datetime(2020, 11, 24, 0, 0), 'hb': 7.8}, {'timestamp': datetime.datetime(2020, 11, 26, 0, 0), 'hb': 6.8}]
# Drop percentage: 12.82% (Threshold: 6.85%)
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2020-11-26
# Extracted Hb data: []
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2020-11-25
# Extracted Hb data: []
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2020-11-25
# Extracted Hb data: []
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2020-11-25
# Extracted Hb data: [{'timestamp': Timestamp('2020-11-25 08:47:00'), 'hb': 6.4}]
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2020-11-25
# Extracted Hb data: []
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2020-11-24
# Extracted Hb data: [{'timestamp': Timestamp('2020-11-24 20:53:00'), 'hb': 8.2}]
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2020-11-24
# Extracted Hb data: [{'timestamp': Timestamp('2020-11-24 17:50:00'), 'hb': 7.8}]
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2020-11-24
# Extracted Hb data: [{'timestamp': Timestamp('2020-11-24 15:20:00'), 'hb': 7.8}]
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2016-08-23
# Extracted Hb data: [{'timestamp': Timestamp('2016-08-23 17:17:00'), 'hb': 7.8}]
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2016-08-23
# Extracted Hb data: []
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2016-08-23
# Extracted Hb data: []
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2016-08-23
# Extracted Hb data: []
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2016-08-23
# Extracted Hb data: []
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2016-08-23
# Extracted Hb data: []
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2016-08-23
# Extracted Hb data: []
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2016-08-22
# Extracted Hb data: [{'timestamp': Timestamp('2016-08-22 18:26:00'), 'hb': 7.8}, {'timestamp': Timestamp('2016-08-22 18:26:00'), 'hb': 9.1}, {'timestamp': Timestamp('2016-08-22 18:26:00'), 'hb': 7.8}]
# Drop percentage: 14.29% (Threshold: 6.85%)
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2016-08-22
# Extracted Hb data: []
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2016-08-22
# Extracted Hb data: []
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2016-08-22
# Extracted Hb data: []
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2016-08-22
# Extracted Hb data: [{'timestamp': Timestamp('2016-08-22 17:21:00'), 'hb': 7.8}, {'timestamp': Timestamp('2016-08-22 17:21:00'), 'hb': 9.1}, {'timestamp': Timestamp('2016-08-22 17:21:00'), 'hb': 7.8}]
# Drop percentage: 14.29% (Threshold: 6.85%)
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2016-08-22
# Extracted Hb data: [{'timestamp': Timestamp('2016-08-22 15:17:00'), 'hb': 7.8}, {'timestamp': Timestamp('2016-08-22 15:17:00'), 'hb': 9.1}, {'timestamp': Timestamp('2016-08-22 15:17:00'), 'hb': 7.8}]
# Drop percentage: 14.29% (Threshold: 6.85%)
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2016-08-22
# Extracted Hb data: []
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2016-08-22
# Extracted Hb data: []
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2016-06-07
# Extracted Hb data: []
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2015-07-29
# Extracted Hb data: []
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2015-07-16
# Extracted Hb data: []
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2015-06-03
# Extracted Hb data: []
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2015-06-03
# Extracted Hb data: []
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2015-03-05
# Extracted Hb data: []
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2015-03-05
# Extracted Hb data: []
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2015-03-05
# Extracted Hb data: []
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2015-02-27
# Extracted Hb data: []
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2015-02-26
# Extracted Hb data: []
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2015-02-26
# Extracted Hb data: []
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2015-02-24
# Extracted Hb data: []
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2015-02-24
# Extracted Hb data: []
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2015-02-20
# Extracted Hb data: []
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2015-02-19
# Extracted Hb data: []
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2013-10-22
# Extracted Hb data: []
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2013-10-22
# Extracted Hb data: []
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2013-10-22
# Extracted Hb data: [{'timestamp': Timestamp('2013-10-22 21:23:00'), 'hb': 8.9}]
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2013-10-22
# Extracted Hb data: []
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2013-10-21
# Extracted Hb data: []
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2013-10-21
# Extracted Hb data: []
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2013-10-21
# Extracted Hb data: []
# Processing report for patient 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6 on 2013-10-21
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2025-03-15
# Extracted Hb data: [{'timestamp': Timestamp('2025-03-15 23:47:00'), 'hb': 9.1}, {'timestamp': Timestamp('2025-03-15 23:47:00'), 'hb': 8.3}]
# Drop percentage: 8.79% (Threshold: 6.85%)
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2025-03-10
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2025-02-26
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2025-02-26
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2025-02-10
# Extracted Hb data: [{'timestamp': Timestamp('2025-02-10 17:00:00'), 'hb': 9.2}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2025-02-05
# Extracted Hb data: [{'timestamp': Timestamp('2025-02-05 14:10:00'), 'hb': 9.1}, {'timestamp': Timestamp('2025-02-05 14:10:00'), 'hb': 8.3}]
# Drop percentage: 8.79% (Threshold: 6.85%)
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2025-01-30
# Extracted Hb data: [{'timestamp': Timestamp('2025-01-30 17:05:00'), 'hb': 8.3}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2025-01-30
# Extracted Hb data: [{'timestamp': Timestamp('2025-01-30 17:05:00'), 'hb': 8.3}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2025-01-30
# Extracted Hb data: [{'timestamp': Timestamp('2025-01-30 17:05:00'), 'hb': 8.3}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2025-01-30
# Extracted Hb data: [{'timestamp': Timestamp('2025-01-30 17:05:00'), 'hb': 8.3}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2025-01-30
# Extracted Hb data: [{'timestamp': Timestamp('2025-01-30 17:05:00'), 'hb': 8.3}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2025-01-30
# Extracted Hb data: [{'timestamp': Timestamp('2025-01-30 17:05:00'), 'hb': 8.3}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2025-01-30
# Extracted Hb data: [{'timestamp': Timestamp('2025-01-30 17:05:00'), 'hb': 8.3}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2025-01-30
# Extracted Hb data: [{'timestamp': Timestamp('2025-01-30 17:05:00'), 'hb': 8.3}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2025-01-30
# Extracted Hb data: [{'timestamp': Timestamp('2025-01-30 17:05:00'), 'hb': 8.3}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2025-01-30
# Extracted Hb data: [{'timestamp': Timestamp('2025-01-30 17:05:00'), 'hb': 8.3}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2025-01-30
# Extracted Hb data: [{'timestamp': Timestamp('2025-01-30 17:05:00'), 'hb': 8.3}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2025-01-30
# Extracted Hb data: [{'timestamp': Timestamp('2025-01-30 15:22:00'), 'hb': 8.3}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2025-01-30
# Extracted Hb data: [{'timestamp': Timestamp('2025-01-30 15:22:00'), 'hb': 8.3}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2025-01-30
# Extracted Hb data: [{'timestamp': Timestamp('2025-01-30 15:22:00'), 'hb': 8.3}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2025-01-30
# Extracted Hb data: [{'timestamp': Timestamp('2025-01-30 15:22:00'), 'hb': 8.3}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2025-01-30
# Extracted Hb data: [{'timestamp': Timestamp('2025-01-30 15:22:00'), 'hb': 8.3}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2025-01-30
# Extracted Hb data: [{'timestamp': Timestamp('2025-01-30 15:22:00'), 'hb': 8.3}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2025-01-30
# Extracted Hb data: [{'timestamp': Timestamp('2025-01-30 15:22:00'), 'hb': 8.3}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2025-01-30
# Extracted Hb data: [{'timestamp': Timestamp('2025-01-30 15:22:00'), 'hb': 8.3}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2025-01-30
# Extracted Hb data: [{'timestamp': Timestamp('2025-01-30 15:22:00'), 'hb': 8.3}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2025-01-30
# Extracted Hb data: [{'timestamp': Timestamp('2025-01-30 15:22:00'), 'hb': 8.3}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2025-01-30
# Extracted Hb data: [{'timestamp': Timestamp('2025-01-30 15:22:00'), 'hb': 8.3}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2025-01-30
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2025-01-30
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2025-01-30
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2025-01-30
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2025-01-30
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2025-01-30
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2025-01-30
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2025-01-30
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2025-01-30
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2025-01-30
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2025-01-30
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2024-11-04
# Extracted Hb data: [{'timestamp': Timestamp('2024-11-04 09:44:00'), 'hb': 8.0}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2024-11-04
# Extracted Hb data: [{'timestamp': Timestamp('2024-11-04 07:11:00'), 'hb': 8.0}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2024-10-30
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2024-08-19
# Extracted Hb data: [{'timestamp': Timestamp('2024-08-19 16:32:00'), 'hb': 8.4}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2024-06-25
# Extracted Hb data: [{'timestamp': Timestamp('2024-06-25 15:10:00'), 'hb': 9.4}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2024-04-17
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2024-04-16
# Extracted Hb data: [{'timestamp': Timestamp('2024-04-16 15:49:00'), 'hb': 9.1}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2024-04-16
# Extracted Hb data: [{'timestamp': Timestamp('2024-04-16 11:59:00'), 'hb': 9.1}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2024-04-16
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2024-03-25
# Extracted Hb data: [{'timestamp': Timestamp('2024-03-25 09:15:00'), 'hb': 8.0}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2024-03-25
# Extracted Hb data: [{'timestamp': Timestamp('2024-03-25 07:12:00'), 'hb': 8.0}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2024-03-04
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2023-12-10
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2023-11-19
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2023-11-14
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2023-11-12
# Extracted Hb data: [{'timestamp': Timestamp('2023-11-12 10:12:00'), 'hb': 8.2}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2023-06-17
# Extracted Hb data: [{'timestamp': Timestamp('2023-06-17 23:36:00'), 'hb': 8.7}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2023-06-13
# Extracted Hb data: [{'timestamp': Timestamp('2023-06-13 08:01:00'), 'hb': 8.7}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2023-06-09
# Extracted Hb data: [{'timestamp': Timestamp('2023-06-09 15:50:00'), 'hb': 8.7}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2023-05-23
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2023-05-23
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2023-05-23
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2023-05-16
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2023-05-15
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2023-05-14
# Extracted Hb data: [{'timestamp': Timestamp('2023-05-14 09:48:00'), 'hb': 8.3}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2023-03-13
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2023-02-27
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2023-02-13
# Extracted Hb data: [{'timestamp': Timestamp('2023-02-13 15:50:00'), 'hb': 3.0}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2023-01-29
# Extracted Hb data: [{'timestamp': Timestamp('2023-01-29 12:08:00'), 'hb': 7.8}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2023-01-27
# Extracted Hb data: [{'timestamp': Timestamp('2023-01-27 21:18:00'), 'hb': 7.8}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2023-01-27
# Extracted Hb data: [{'timestamp': Timestamp('2023-01-27 18:28:00'), 'hb': 7.8}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2023-01-27
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2023-01-27
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2023-01-23
# Extracted Hb data: [{'timestamp': Timestamp('2023-01-23 10:05:00'), 'hb': 8.0}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2023-01-23
# Extracted Hb data: [{'timestamp': Timestamp('2023-01-23 07:33:00'), 'hb': 8.0}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2023-01-20
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2023-01-20
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2023-01-19
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2023-01-18
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2023-01-17
# Extracted Hb data: [{'timestamp': Timestamp('2023-01-17 08:16:00'), 'hb': 8.0}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2023-01-16
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2023-01-15
# Extracted Hb data: [{'timestamp': Timestamp('2023-01-15 22:39:00'), 'hb': 7.9}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2023-01-15
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2023-01-15
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2023-01-15
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2023-01-14
# Extracted Hb data: [{'timestamp': Timestamp('2023-01-14 18:44:00'), 'hb': 8.4}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2023-01-14
# Extracted Hb data: [{'timestamp': Timestamp('2023-01-14 15:44:00'), 'hb': 8.4}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2023-01-14
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2023-01-14
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2022-12-28
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2022-12-23
# Extracted Hb data: [{'timestamp': Timestamp('2022-12-23 10:47:00'), 'hb': 9.3}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2022-12-23
# Extracted Hb data: [{'timestamp': Timestamp('2022-12-23 08:12:00'), 'hb': 9.3}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2022-12-21
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2022-12-21
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2022-12-12
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2022-12-12
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2022-11-21
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2022-09-30
# Extracted Hb data: [{'timestamp': Timestamp('2022-09-30 13:28:00'), 'hb': 10.8}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2022-03-28
# Extracted Hb data: [{'timestamp': Timestamp('2022-03-28 14:20:00'), 'hb': 10.0}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2022-03-27
# Extracted Hb data: [{'timestamp': Timestamp('2022-03-27 09:40:00'), 'hb': 10.0}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2021-09-27
# Extracted Hb data: [{'timestamp': Timestamp('2021-09-27 11:32:00'), 'hb': 10.0}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2021-06-24
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2021-06-14
# Extracted Hb data: [{'timestamp': Timestamp('2021-06-14 14:13:00'), 'hb': 10.1}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2021-06-14
# Extracted Hb data: [{'timestamp': Timestamp('2021-06-14 08:19:00'), 'hb': 10.1}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2021-02-08
# Extracted Hb data: [{'timestamp': Timestamp('2021-02-08 08:33:00'), 'hb': 9.7}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2020-11-02
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2020-08-24
# Extracted Hb data: [{'timestamp': Timestamp('2020-08-24 12:36:00'), 'hb': 9.6}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2020-03-12
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2020-03-09
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2020-02-17
# Extracted Hb data: [{'timestamp': Timestamp('2020-02-17 10:10:00'), 'hb': 9.0}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2020-02-17
# Extracted Hb data: [{'timestamp': Timestamp('2020-02-17 07:48:00'), 'hb': 9.0}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2019-10-11
# Extracted Hb data: [{'timestamp': Timestamp('2019-10-11 14:17:00'), 'hb': 9.4}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2019-07-13
# Extracted Hb data: [{'timestamp': Timestamp('2019-07-13 12:25:00'), 'hb': 9.0}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2019-04-04
# Extracted Hb data: [{'timestamp': Timestamp('2019-04-04 12:40:00'), 'hb': 9.0}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2019-04-04
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2019-03-29
# Extracted Hb data: [{'timestamp': Timestamp('2019-03-29 11:05:00'), 'hb': 9.0}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2019-03-14
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2018-11-23
# Extracted Hb data: [{'timestamp': Timestamp('2018-11-23 14:17:00'), 'hb': 8.9}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2018-09-10
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2018-09-10
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2018-07-09
# Extracted Hb data: [{'timestamp': Timestamp('2018-07-09 13:19:00'), 'hb': 7.5}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2018-06-14
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2018-06-13
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2018-06-08
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2018-05-28
# Extracted Hb data: [{'timestamp': Timestamp('2018-05-28 11:32:00'), 'hb': 7.9}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2018-04-30
# Extracted Hb data: [{'timestamp': Timestamp('2018-04-30 07:47:00'), 'hb': 7.9}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2018-04-09
# Extracted Hb data: [{'timestamp': Timestamp('2018-04-09 08:17:00'), 'hb': 8.0}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2018-03-01
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2018-02-26
# Extracted Hb data: [{'timestamp': Timestamp('2018-02-26 08:32:00'), 'hb': 8.7}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2018-01-29
# Extracted Hb data: [{'timestamp': Timestamp('2018-01-29 07:39:00'), 'hb': 7.5}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2018-01-16
# Extracted Hb data: [{'timestamp': Timestamp('2018-01-16 11:47:00'), 'hb': 7.2}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2018-01-16
# Extracted Hb data: [{'timestamp': Timestamp('2018-01-16 11:41:00'), 'hb': 7.2}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-12-21
# Extracted Hb data: [{'timestamp': Timestamp('2017-12-21 09:11:00'), 'hb': 6.4}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-12-21
# Extracted Hb data: [{'timestamp': Timestamp('2017-12-21 07:15:00'), 'hb': 6.4}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-12-14
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-12-04
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-12-04
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-12-01
# Extracted Hb data: [{'timestamp': Timestamp('2017-12-01 14:35:00'), 'hb': 6.0}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-11-20
# Extracted Hb data: [{'timestamp': Timestamp('2017-11-20 08:51:00'), 'hb': 6.0}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-11-20
# Extracted Hb data: [{'timestamp': Timestamp('2017-11-20 07:35:00'), 'hb': 6.0}]
# time_date_match <re.Match object; span=(0, 23), match='Laboratorium 10-11-2017'>
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-11-13
# Extracted Hb data: [{'timestamp': datetime.datetime(2017, 11, 10, 0, 0), 'hb': 4.2}, {'timestamp': datetime.datetime(2017, 11, 10, 0, 0), 'hb': 6.1}]
# Drop percentage: 31.15% (Threshold: 6.85%)
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-11-13
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-11-13
# Extracted Hb data: [{'timestamp': Timestamp('2017-11-13 08:50:00'), 'hb': 6.1}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-11-12
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-11-11
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-11-11
# Extracted Hb data: [{'timestamp': Timestamp('2017-11-11 10:54:00'), 'hb': 4.7}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-11-10
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-11-10
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-11-10
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-11-10
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-11-10
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-11-10
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-11-03
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-11-02
# Extracted Hb data: []
# time_date_match <re.Match object; span=(0, 23), match='Laboratorium 31-10-2017'>
# time_date_match <re.Match object; span=(0, 23), match='Laboratorium 02-11-2017'>
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-11-02
# Extracted Hb data: [{'timestamp': datetime.datetime(2017, 10, 31, 0, 0), 'hb': 4.5}, {'timestamp': datetime.datetime(2017, 11, 2, 0, 0), 'hb': 5.8}]
# Drop percentage: 22.41% (Threshold: 6.85%)
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-11-02
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-11-02
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-11-01
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-11-01
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-11-01
# Extracted Hb data: [{'timestamp': Timestamp('2017-11-01 07:42:00'), 'hb': 4.5}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-10-31
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-10-31
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-10-31
# Extracted Hb data: [{'timestamp': Timestamp('2017-10-31 13:44:00'), 'hb': 4.5}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-10-31
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-10-31
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-10-31
# Extracted Hb data: [{'timestamp': Timestamp('2017-10-31 11:16:00'), 'hb': 4.5}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-10-31
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-10-29
# Extracted Hb data: [{'timestamp': Timestamp('2017-10-29 19:08:00'), 'hb': 4.3}, {'timestamp': Timestamp('2017-10-29 19:08:00'), 'hb': 5.5}]
# Drop percentage: 21.82% (Threshold: 6.85%)
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-10-28
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-10-28
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-10-27
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-10-27
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-10-27
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-10-27
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-10-27
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-10-23
# Extracted Hb data: [{'timestamp': Timestamp('2017-10-23 09:54:00'), 'hb': 5.9}, {'timestamp': Timestamp('2017-10-23 09:54:00'), 'hb': 5.4}, {'timestamp': Timestamp('2017-10-23 09:54:00'), 'hb': 5.6}]
# Drop percentage: 8.47% (Threshold: 6.85%)
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-10-23
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-10-23
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-10-16
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-10-09
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-10-09
# Extracted Hb data: []
# time_date_match <re.Match object; span=(0, 23), match='Laboratorium 15-08-2017'>
# time_date_match <re.Match object; span=(0, 23), match='Laboratorium 14-09-2017'>
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-09-30
# Extracted Hb data: [{'timestamp': datetime.datetime(2017, 8, 15, 0, 0), 'hb': 6.7}, {'timestamp': datetime.datetime(2017, 9, 14, 0, 0), 'hb': 5.4}]
# time_date_match <re.Match object; span=(0, 23), match='Laboratorium 15-08-2017'>
# time_date_match <re.Match object; span=(0, 23), match='Laboratorium 14-09-2017'>
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-09-27
# Extracted Hb data: [{'timestamp': datetime.datetime(2017, 8, 15, 0, 0), 'hb': 6.7}, {'timestamp': datetime.datetime(2017, 9, 14, 0, 0), 'hb': 5.4}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-09-27
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-09-26
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-09-25
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-09-22
# Extracted Hb data: [{'timestamp': Timestamp('2017-09-22 08:50:00'), 'hb': 6.0}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-09-21
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-09-20
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-09-19
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-09-18
# Extracted Hb data: [{'timestamp': Timestamp('2017-09-18 09:45:00'), 'hb': 5.8}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-09-15
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-09-14
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-09-14
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-09-13
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-09-12
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-09-11
# Extracted Hb data: [{'timestamp': Timestamp('2017-09-11 09:14:00'), 'hb': 5.6}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-09-10
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-09-09
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-09-08
# Extracted Hb data: [{'timestamp': Timestamp('2017-09-08 09:15:00'), 'hb': 6.0}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-09-07
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-09-07
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-09-06
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-09-06
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-09-05
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-09-05
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-09-04
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-09-03
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-09-01
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-08-31
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-08-30
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-08-29
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-08-28
# Extracted Hb data: [{'timestamp': Timestamp('2017-08-28 09:02:00'), 'hb': 5.1}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-08-27
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-08-26
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-08-25
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-08-24
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-08-24
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-08-23
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-08-22
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-08-21
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-08-21
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-08-18
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-08-18
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-08-17
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-08-16
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-08-16
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-08-15
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-08-15
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2017-08-15
# Extracted Hb data: [{'timestamp': Timestamp('2017-08-15 03:13:00'), 'hb': 6.7}]
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2005-05-02
# Extracted Hb data: []
# Processing report for patient 088C9FD98B8B2CBCB597C17C07AC1845B21F0849 on 2005-02-02
# Extracted Hb data: [{'timestamp': Timestamp('2005-02-02 14:20:00'), 'hb': 9.4}, {'timestamp': Timestamp('2005-02-02 14:20:00'), 'hb': 5.6}]
# Drop percentage: 40.43% (Threshold: 6.85%)
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2022-03-14
# Extracted Hb data: []
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2022-02-22
# Extracted Hb data: []
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2022-01-31
# Extracted Hb data: [{'timestamp': Timestamp('2022-01-31 15:23:00'), 'hb': 8.1}]
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2022-01-31
# Extracted Hb data: []
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2021-11-24
# Extracted Hb data: []
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2021-09-24
# Extracted Hb data: []
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2021-08-09
# Extracted Hb data: []
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2021-07-27
# Extracted Hb data: [{'timestamp': Timestamp('2021-07-27 16:45:00'), 'hb': 7.2}]
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2021-07-27
# Extracted Hb data: []
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2021-07-26
# Extracted Hb data: []
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2021-07-01
# Extracted Hb data: []
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2021-06-15
# Extracted Hb data: []
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2021-05-25
# Extracted Hb data: []
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2021-05-03
# Extracted Hb data: []
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2021-04-26
# Extracted Hb data: []
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2021-04-01
# Extracted Hb data: []
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2021-03-16
# Extracted Hb data: [{'timestamp': Timestamp('2021-03-16 13:06:00'), 'hb': 6.9}]
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2021-03-15
# Extracted Hb data: []
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2021-03-11
# Extracted Hb data: []
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2021-03-05
# Extracted Hb data: []
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2021-02-04
# Extracted Hb data: [{'timestamp': Timestamp('2021-02-04 14:00:00'), 'hb': 4.0}]
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2021-02-04
# Extracted Hb data: [{'timestamp': Timestamp('2021-02-04 12:49:00'), 'hb': 4.0}]
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2021-02-03
# Extracted Hb data: []
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2021-01-28
# Extracted Hb data: [{'timestamp': Timestamp('2021-01-28 16:21:00'), 'hb': 5.3}]
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2021-01-28
# Extracted Hb data: [{'timestamp': Timestamp('2021-01-28 09:13:00'), 'hb': 5.3}]
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2021-01-27
# Extracted Hb data: []
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2021-01-21
# Extracted Hb data: [{'timestamp': Timestamp('2021-01-21 18:32:00'), 'hb': 4.3}, {'timestamp': Timestamp('2021-01-21 18:32:00'), 'hb': 4.3}]
# Drop percentage: 0.00% (Threshold: 6.85%)
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2021-01-21
# Extracted Hb data: [{'timestamp': Timestamp('2021-01-21 17:12:00'), 'hb': 4.3}, {'timestamp': Timestamp('2021-01-21 17:12:00'), 'hb': 4.3}]
# Drop percentage: 0.00% (Threshold: 6.85%)
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2021-01-21
# Extracted Hb data: []
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2021-01-21
# Extracted Hb data: []
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2021-01-20
# Extracted Hb data: []
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2021-01-20
# Extracted Hb data: [{'timestamp': Timestamp('2021-01-20 15:25:00'), 'hb': 5.3}]
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2021-01-20
# Extracted Hb data: []
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2021-01-20
# Extracted Hb data: [{'timestamp': Timestamp('2021-01-20 11:00:00'), 'hb': 5.3}]
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2021-01-20
# Extracted Hb data: [{'timestamp': Timestamp('2021-01-20 09:26:00'), 'hb': 5.3}]
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2021-01-20
# Extracted Hb data: []
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2021-01-20
# Extracted Hb data: []
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2021-01-20
# Extracted Hb data: []
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2021-01-19
# Extracted Hb data: []
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2021-01-19
# Extracted Hb data: []
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2021-01-19
# Extracted Hb data: [{'timestamp': Timestamp('2021-01-19 09:27:00'), 'hb': 5.2}]
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2021-01-19
# Extracted Hb data: []
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2021-01-18
# Extracted Hb data: []
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2021-01-18
# Extracted Hb data: []
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2021-01-18
# Extracted Hb data: []
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2018-10-17
# Extracted Hb data: []
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2018-10-17
# Extracted Hb data: []
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2018-10-16
# Extracted Hb data: [{'timestamp': Timestamp('2018-10-16 15:21:00'), 'hb': 7.3}, {'timestamp': Timestamp('2018-10-16 15:21:00'), 'hb': 8.6}]
# Drop percentage: 15.12% (Threshold: 6.85%)
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2018-10-16
# Extracted Hb data: []
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2018-10-15
# Extracted Hb data: [{'timestamp': Timestamp('2018-10-15 12:52:00'), 'hb': 7.3}]
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2018-10-12
# Extracted Hb data: [{'timestamp': Timestamp('2018-10-12 13:12:00'), 'hb': 8.1}]
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2018-10-11
# Extracted Hb data: [{'timestamp': Timestamp('2018-10-11 09:01:00'), 'hb': 7.8}]
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2018-10-10
# Extracted Hb data: [{'timestamp': Timestamp('2018-10-10 12:13:00'), 'hb': 8.2}]
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2018-10-10
# Extracted Hb data: []
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2018-10-09
# Extracted Hb data: []
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2018-10-09
# Extracted Hb data: []
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2018-10-08
# Extracted Hb data: []
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2018-10-08
# Extracted Hb data: []
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2018-10-07
# Extracted Hb data: [{'timestamp': Timestamp('2018-10-07 17:10:00'), 'hb': 8.6}]
# Processing report for patient 0A5645E02FA818D1629926B6BEFA81CF91C25A46 on 2018-10-07
# Extracted Hb data: [{'timestamp': Timestamp('2018-10-07 14:33:00'), 'hb': 8.6}]
# Processing report for patient 0BC512A65442D0BB4B00FBE05E7EA6283E5C11FD on 2019-03-07
# Extracted Hb data: []
# Processing report for patient 0BC512A65442D0BB4B00FBE05E7EA6283E5C11FD on 2019-03-07
# Extracted Hb data: []
# Processing report for patient 0BC512A65442D0BB4B00FBE05E7EA6283E5C11FD on 2018-12-09
# Extracted Hb data: []
# Processing report for patient 0BC512A65442D0BB4B00FBE05E7EA6283E5C11FD on 2018-12-09
# Extracted Hb data: []
# Processing report for patient 0BC512A65442D0BB4B00FBE05E7EA6283E5C11FD on 2018-09-09
# Extracted Hb data: []
# Processing report for patient 0BC512A65442D0BB4B00FBE05E7EA6283E5C11FD on 2018-09-09
# Extracted Hb data: []
# Processing report for patient 0BC512A65442D0BB4B00FBE05E7EA6283E5C11FD on 2018-02-22
# Extracted Hb data: []
# Processing report for patient 0BC512A65442D0BB4B00FBE05E7EA6283E5C11FD on 2018-02-10
# Extracted Hb data: [{'timestamp': Timestamp('2018-02-10 17:08:00'), 'hb': 7.3}]
# Processing report for patient 0BC512A65442D0BB4B00FBE05E7EA6283E5C11FD on 2018-01-23
# Extracted Hb data: [{'timestamp': Timestamp('2018-01-23 11:15:00'), 'hb': 7.3}]
# Processing report for patient 0BC512A65442D0BB4B00FBE05E7EA6283E5C11FD on 2017-12-17
# Extracted Hb data: []
# Processing report for patient 0BC512A65442D0BB4B00FBE05E7EA6283E5C11FD on 2017-12-16
# Extracted Hb data: []
# Processing report for patient 0BC512A65442D0BB4B00FBE05E7EA6283E5C11FD on 2017-12-16
# Extracted Hb data: []
# Processing report for patient 0BC512A65442D0BB4B00FBE05E7EA6283E5C11FD on 2017-12-15
# Extracted Hb data: []
# Processing report for patient 0BC512A65442D0BB4B00FBE05E7EA6283E5C11FD on 2017-12-15
# Extracted Hb data: []
# Processing report for patient 0BC512A65442D0BB4B00FBE05E7EA6283E5C11FD on 2017-11-29
# Extracted Hb data: []
# Processing report for patient 0BC512A65442D0BB4B00FBE05E7EA6283E5C11FD on 2017-11-22
# Extracted Hb data: []
# Processing report for patient 0BC512A65442D0BB4B00FBE05E7EA6283E5C11FD on 2017-11-20
# ...
# Extracted Hb data: [{'timestamp': Timestamp('2018-10-17 12:35:00'), 'hb': 7.3}]
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2018-10-17
# Extracted Hb data: [{'timestamp': Timestamp('2018-10-17 12:35:00'), 'hb': 7.3}]
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2017-06-15
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2017-03-21
# Extracted Hb data: [{'timestamp': Timestamp('2017-03-21 17:18:00'), 'hb': 5.7}]
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2017-03-21
# Extracted Hb data: [{'timestamp': Timestamp('2017-03-21 09:37:00'), 'hb': 6.5}]
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2017-03-21
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2017-03-20
# Extracted Hb data: [{'timestamp': Timestamp('2017-03-20 08:34:00'), 'hb': 6.8}]
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2017-03-20
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2017-03-19
# Extracted Hb data: [{'timestamp': Timestamp('2017-03-19 13:29:00'), 'hb': 5.7}]
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2017-03-19
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2017-03-19
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2017-03-19
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2017-02-27
# Extracted Hb data: [{'timestamp': Timestamp('2017-02-27 07:43:00'), 'hb': 6.4}]
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2017-02-27
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2017-02-26
# Extracted Hb data: [{'timestamp': Timestamp('2017-02-26 11:28:00'), 'hb': 6.6}]
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2017-02-26
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2017-02-25
# Extracted Hb data: [{'timestamp': Timestamp('2017-02-25 10:56:00'), 'hb': 6.2}]
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2017-02-25
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2017-02-24
# Extracted Hb data: [{'timestamp': Timestamp('2017-02-24 16:08:00'), 'hb': 7.4}, {'timestamp': Timestamp('2017-02-24 16:08:00'), 'hb': 6.4}]
# Drop percentage: 13.51% (Threshold: 6.85%)
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2017-02-24
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2017-02-24
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2017-02-24
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2017-02-24
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2017-02-24
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2017-02-24
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2017-02-24
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2017-02-24
# Extracted Hb data: [{'timestamp': Timestamp('2017-02-24 07:28:00'), 'hb': 7.4}]
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2017-02-23
# Extracted Hb data: [{'timestamp': Timestamp('2017-02-23 22:38:00'), 'hb': 7.5}]
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2017-02-23
# Extracted Hb data: [{'timestamp': Timestamp('2017-02-23 22:38:00'), 'hb': 7.5}]
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2017-02-23
# Extracted Hb data: [{'timestamp': Timestamp('2017-02-23 17:54:00'), 'hb': 7.4}]
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2017-02-23
# Extracted Hb data: [{'timestamp': Timestamp('2017-02-23 16:42:00'), 'hb': 7.4}]
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2017-02-23
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2016-03-01
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2016-03-01
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2016-02-29
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2016-02-29
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2016-02-28
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2016-02-28
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2016-02-27
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2016-02-27
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2016-02-26
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2016-02-26
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2016-02-25
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2016-02-25
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2016-02-24
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2016-02-24
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2016-02-23
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2016-02-23
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2016-02-22
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2016-02-22
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2016-02-22
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2016-02-21
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2016-02-21
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2016-02-20
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2016-02-20
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2016-02-19
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2016-02-19
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2016-02-18
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2016-02-18
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2016-02-18
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2016-02-17
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2016-02-17
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2016-02-16
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2016-02-16
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2016-02-15
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2016-02-15
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2016-02-15
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2016-02-15
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2016-02-15
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2016-02-15
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2016-02-15
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2015-03-20
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2015-03-20
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2015-01-14
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2014-12-21
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2010-11-10
# Extracted Hb data: []
# Processing report for patient FD8C682C1F4FDA1E5EC0B760D30875556419BD71 on 2010-11-10
# Extracted Hb data: []
#                                       pseudo_id verslagen_report_start_date  \
# 0      046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6         2020-11-26 15:06:00
# 1      046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6         2020-11-26 09:53:00
# 2      046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6         2020-11-25 14:13:00
# 3      046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6         2020-11-25 13:48:00
# 4      046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6         2020-11-25 08:47:00
# ...                                         ...                         ...
# 19306  FD8C682C1F4FDA1E5EC0B760D30875556419BD71         2015-03-20 08:13:00
# 19307  FD8C682C1F4FDA1E5EC0B760D30875556419BD71         2015-01-14 15:39:00
# 19308  FD8C682C1F4FDA1E5EC0B760D30875556419BD71         2014-12-21 09:31:00
# 19309  FD8C682C1F4FDA1E5EC0B760D30875556419BD71         2010-11-10 21:03:00
# 19310  FD8C682C1F4FDA1E5EC0B760D30875556419BD71         2010-11-10 20:29:00
#
#         verslagen_report_specialism  \
# 0      Maag-, Darm- en Leverziekten
# 1      Maag-, Darm- en Leverziekten
# 2      Maag-, Darm- en Leverziekten
# 3      Maag-, Darm- en Leverziekten
# 4      Maag-, Darm- en Leverziekten
# ...                             ...
# 19306           Interne Geneeskunde
# 19307           Interne Geneeskunde
# 19308             Spoedeisende Hulp
# 19309             Spoedeisende Hulp
# 19310             Spoedeisende Hulp
#
#                                 verslagen_report_content  agib_final  \
# 0      Dhr. A.J. Dingemans, huisarts\r\n[STREETNAME] ...       False
# 1      Samenvatting: \nRectaal bloedverlies obv diver...       False
# 2      COLOSCOPIE\r\n\r\nBetreft\r\nMw. [INITIALS] [L...       False
# 3      GASTROSCOPIE\r\n\r\nBetreft\r\nMw. [INITIALS] ...       False
# 4      Samenvatting: \nRectaal bloedverlies ; eenmali...       False
# ...                                                  ...         ...
# 19306  Samenvatting: \n1e consult\r\n-Type 1e consult...       False
# 19307  Samenvatting: \nDecursus\r\n-Type decursus: De...       False
# 19308  Samenvatting: \nVerpleegkundige verslaglegging...       False
# 19309  Samenvatting: \nMedisch Dossier\r\n[ Vk Sputov...       False
# 19310  Samenvatting: \nVerpleegkundige verslaglegging...       False
#
#        gib_final  scopie_final  treatment_final diagnose_db_cs_dbc_start_date  \
# 0           True          True             True                    2020-11-24
# 1           True          True             True                    2020-11-24
# 2           True          True            False                    2020-11-24
# 3           True          True            False                    2020-11-24
# 4           True          True            False                    2020-11-24
# ...          ...           ...              ...                           ...
# 19306      False          True            False                           NaN
# 19307      False          True            False                           NaN
# 19308      False         False            False                           NaN
# 19309      False         False            False                           NaN
# 19310      False         False            False                           NaN
#
#       diagnose_db_cs_dbc_end_date  ...  is_scopie  scopie_after_seh  \
# 0                      2021-01-07  ...      False             False
# 1                      2021-01-07  ...      False             False
# 2                      2021-01-07  ...       True             False
# 3                      2021-01-07  ...       True             False
# 4                      2021-01-07  ...       True             False
# ...                           ...  ...        ...               ...
# 19306                         NaN  ...      False             False
# 19307                         NaN  ...      False             False
# 19308                         NaN  ...      False             False
# 19309                         NaN  ...      False             False
# 19310                         NaN  ...      False             False
#
#       report_date lab_date lab_measurement_start_date  \
# 0      2020-11-26      NaN                        NaT
# 1      2020-11-26      NaN                        NaT
# 2      2020-11-25      NaN                        NaT
# 3      2020-11-25      NaN                        NaT
# 4      2020-11-25      NaN                        NaT
# ...           ...      ...                        ...
# 19306  2015-03-20      NaN                        NaT
# 19307  2015-01-14      NaN                        NaT
# 19308  2014-12-21      NaN                        NaT
# 19309  2010-11-10      NaN                        NaT
# 19310  2010-11-10      NaN                        NaT
#
#       lab_measurement_description lab_measurement_test_value_numeric  \
# 0                             NaN                                NaN
# 1                             NaN                                NaN
# 2                             NaN                                NaN
# 3                             NaN                                NaN
# 4                             NaN                                NaN
# ...                           ...                                ...
# 19306                         NaN                                NaN
# 19307                         NaN                                NaN
# 19308                         NaN                                NaN
# 19309                         NaN                                NaN
# 19310                         NaN                                NaN
#
#        signficant_hb_drop_7_days signficant_hb_drop_7_days_max_min  \
# 0                            NaN                               NaN
# 1                            NaN                               NaN
# 2                            NaN                               NaN
# 3                            NaN                               NaN
# 4                            NaN                               NaN
# ...                          ...                               ...
# 19306                        NaN                               NaN
# 19307                        NaN                               NaN
# 19308                        NaN                               NaN
# 19309                        NaN                               NaN
# 19310                        NaN                               NaN
#
#       sigh_hb_drop_text
# 0                  True
# 1                 False
# 2                 False
# 3                 False
# 4                 False
# ...                 ...
# 19306             False
# 19307             False
# 19308             False
# 19309             False
# 19310             False
#
# [19311 rows x 21 columns]

# %%
df_hb2 = df_hb.copy()

# %%
# df_hb['sigh_hb_drop_text'] = False


# for i in range(len(df_hb)):
#     for j in range(len(df_merged)):
#         # if df_hb['pseudo_id'].iloc[i] == df_merged[j] and df_hb['lab_measurement_start_date'].iloc[i] == df_merged['lab_measurement_start_date'].iloc[j]:
#         if df_hb['pseudo_id'].iloc[i] == df_merged['pseudo_id'].iloc[j] and df_hb['lab_measurement_start_date'].iloc[i] == df_merged['lab_measurement_start_date'].iloc[j]:
#             df_hb['sigh_hb_drop_text'].iloc[i] = df_merged['sigh_hb_drop_text'].iloc[j]

# df_hb['sigh_hb_drop_text'].value_counts()


# # Merge the sigh_hb_drop_text column from df_merged into df_hb using the shared keys
# df_hb = df_hb.merge(
#     df_merged[['pseudo_id', 'lab_measurement_start_date', 'sigh_hb_drop_text']],
#     on=['pseudo_id', 'lab_measurement_start_date'],
#     how='left'
# )

# # Fill NaNs with False if there's no match
# df_hb['sigh_hb_drop_text'] = df_hb['sigh_hb_drop_text'].fillna(False)

# # Check value counts
# df_hb['sigh_hb_drop_text'].value_counts()

# # Create a Series with a MultiIndex
# hb_map = df_merged.set_index(['pseudo_id', 'lab_measurement_start_date'])['sigh_hb_drop_text']

# # Map to df_hb using the same MultiIndex
# df_hb['sigh_hb_drop_text'] = df_hb.set_index(['pseudo_id', 'lab_measurement_start_date']).index.map(hb_map)

# # Replace NaN with False
# df_hb['sigh_hb_drop_text'] = df_hb['sigh_hb_drop_text'].fillna(False)

# Aggregate report-level sigh_hb_drop_text to a single value per patient-date
df_merged_agg = (
    df_merged
    .groupby(['pseudo_id', 'lab_measurement_start_date'])['sigh_hb_drop_text']
    .max()
    .reset_index()
)

# Merge the aggregated result into df_hb
df_hb2 = df_hb2.merge(
    df_merged_agg,
    on=['pseudo_id', 'lab_measurement_start_date'],
    how='left'
)

# Replace missing values with False
df_hb2['sigh_hb_drop_text2'] = df_hb2['sigh_hb_drop_text'].fillna(False)


df_hb2
# Out:
# C:\Users\Y.vanMegen\AppData\Roaming\Python\Python311\site-packages\IPython\lib\pretty.py:794: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   output = repr(obj)
# C:\Users\Y.vanMegen\AppData\Roaming\Python\Python311\site-packages\IPython\core\formatters.py:406: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   return method()
#                                       pseudo_id lab_measurement_description  \
# 0      046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6                  Bloedgroep
# 1      046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6                  Kreatinine
# 2      046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6                eGFR CKD-EPI
# 3      046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6                   NT-proBNP
# 4      046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6                 Hemoglobine
# ...                                         ...                         ...
# 10428  FD8C682C1F4FDA1E5EC0B760D30875556419BD71   Alkalische Fosfatase (AF)
# 10429  FD8C682C1F4FDA1E5EC0B760D30875556419BD71                         GGT
# 10430  FD8C682C1F4FDA1E5EC0B760D30875556419BD71                        ASAT
# 10431  FD8C682C1F4FDA1E5EC0B760D30875556419BD71                        ALAT
# 10432  FD8C682C1F4FDA1E5EC0B760D30875556419BD71                         CRP
#
#       lab_measurement_test_value_string  lab_measurement_test_value_numeric  \
# 0                                 A neg                                 NaN
# 1                                    83                                83.0
# 2                                    58                                58.0
# 3                                   780                               780.0
# 4                                   6.9                                 6.9
# ...                                 ...                                 ...
# 10428                                88                                88.0
# 10429                                48                                48.0
# 10430                                25                                25.0
# 10431                                19                                19.0
# 10432                               2.8                                 2.8
#
#       lab_measurement_test_value_unit lab_measurement_start_date  \
# 0                                 NaN        2024-08-05 00:00:00
# 1                              µmol/L        2024-07-31 09:11:00
# 2                    ml/min/{1.73_m2}        2024-07-31 09:11:00
# 3                               pg/ml        2024-07-22 09:29:00
# 4                              mmol/L        2024-07-22 09:29:00
# ...                               ...                        ...
# 10428                             U/L        2018-10-17 11:11:00
# 10429                             U/L        2018-10-17 11:11:00
# 10430                             U/L        2018-10-17 11:11:00
# 10431                             U/L        2018-10-17 11:11:00
# 10432                            mg/L        2018-10-17 11:11:00
#
#        signficant_hb_drop_7_days  signficant_hb_drop_7_days_max_min  \
# 0                          False                              False
# 1                          False                              False
# 2                          False                              False
# 3                          False                              False
# 4                          False                              False
# ...                          ...                                ...
# 10428                      False                              False
# 10429                      False                              False
# 10430                      False                              False
# 10431                      False                              False
# 10432                      False                              False
#
#          lab_date sigh_hb_drop_text  sigh_hb_drop_text2
# 0      2024-08-05               NaN               False
# 1      2024-07-31               NaN               False
# 2      2024-07-31               NaN               False
# 3      2024-07-22               NaN               False
# 4      2024-07-22               NaN               False
# ...           ...               ...                 ...
# 10428  2018-10-17             False               False
# 10429  2018-10-17             False               False
# 10430  2018-10-17             False               False
# 10431  2018-10-17             False               False
# 10432  2018-10-17             False               False
#
# [10433 rows x 11 columns]

# %%
df_hb = df_hb2.copy()

# %%
relevant_tests = [
    'Hemoglobine',
    'Hematocriet',
    'INR',
    'APTT',
    'Protrombinetijd',
    'Ureum',
    'MCV',
    'Trombocyten'
]

df_merged_tests_filtered = df_merged[df_merged['lab_measurement_description'].isin(relevant_tests)]
print(df_merged_tests_filtered['pseudo_id'].nunique())
df_merged_tests_filtered
# Out:
# 59
#                                       pseudo_id verslagen_report_start_date  \
# 54     088C9FD98B8B2CBCB597C17C07AC1845B21F0849         2025-01-30 17:05:00
# 55     088C9FD98B8B2CBCB597C17C07AC1845B21F0849         2025-01-30 17:05:00
# 56     088C9FD98B8B2CBCB597C17C07AC1845B21F0849         2025-01-30 17:05:00
# 59     088C9FD98B8B2CBCB597C17C07AC1845B21F0849         2025-01-30 17:05:00
# 65     088C9FD98B8B2CBCB597C17C07AC1845B21F0849         2025-01-30 15:22:00
# ...                                         ...                         ...
# 19220  FD8C682C1F4FDA1E5EC0B760D30875556419BD71         2018-10-17 12:35:00
# 19221  FD8C682C1F4FDA1E5EC0B760D30875556419BD71         2018-10-17 12:35:00
# 19222  FD8C682C1F4FDA1E5EC0B760D30875556419BD71         2018-10-17 12:35:00
# 19223  FD8C682C1F4FDA1E5EC0B760D30875556419BD71         2018-10-17 12:35:00
# 19227  FD8C682C1F4FDA1E5EC0B760D30875556419BD71         2018-10-17 12:35:00
#
#       verslagen_report_specialism  \
# 54              Spoedeisende Hulp
# 55              Spoedeisende Hulp
# 56              Spoedeisende Hulp
# 59              Spoedeisende Hulp
# 65              Spoedeisende Hulp
# ...                           ...
# 19220           Spoedeisende Hulp
# 19221           Spoedeisende Hulp
# 19222           Spoedeisende Hulp
# 19223           Spoedeisende Hulp
# 19227           Spoedeisende Hulp
#
#                                 verslagen_report_content  agib_final  \
# 54     Huisartsen Achtse Barrier\r\nT.a.v. mevr. C.M....       False
# 55     Huisartsen Achtse Barrier\r\nT.a.v. mevr. C.M....       False
# 56     Huisartsen Achtse Barrier\r\nT.a.v. mevr. C.M....       False
# 59     Huisartsen Achtse Barrier\r\nT.a.v. mevr. C.M....       False
# 65     Reden van komst / Verwijzing: \nTrauma capitis...       False
# ...                                                  ...         ...
# 19220  Reden van komst / Verwijzing: \nReden van koms...       False
# 19221  Reden van komst / Verwijzing: \nReden van koms...       False
# 19222  Reden van komst / Verwijzing: \nReden van koms...       False
# 19223  Reden van komst / Verwijzing: \nReden van koms...       False
# 19227  Reden van komst / Verwijzing: \nReden van koms...       False
#
#        gib_final  scopie_final  treatment_final diagnose_db_cs_dbc_start_date  \
# 54          True         False            False                    2024-10-24
# 55          True         False            False                    2024-10-24
# 56          True         False            False                    2024-10-24
# 59          True         False            False                    2024-10-24
# 65          True         False            False                    2024-10-24
# ...          ...           ...              ...                           ...
# 19220       True         False            False                    2018-10-17
# 19221       True         False            False                    2018-10-17
# 19222       True         False            False                    2018-10-17
# 19223       True         False            False                    2018-10-17
# 19227       True         False            False                    2018-10-17
#
#       diagnose_db_cs_dbc_end_date  ...  is_scopie  scopie_after_seh  \
# 54                     2025-02-20  ...      False               NaN
# 55                     2025-02-20  ...      False               NaN
# 56                     2025-02-20  ...      False               NaN
# 59                     2025-02-20  ...      False               NaN
# 65                     2025-02-20  ...      False               NaN
# ...                           ...  ...        ...               ...
# 19220                  2019-01-14  ...      False             False
# 19221                  2019-01-14  ...      False             False
# 19222                  2019-01-14  ...      False             False
# 19223                  2019-01-14  ...      False             False
# 19227                  2019-01-14  ...      False             False
#
#       report_date    lab_date lab_measurement_start_date  \
# 54     2025-01-30  2025-01-30        2025-01-30 15:32:00
# 55     2025-01-30  2025-01-30        2025-01-30 15:32:00
# 56     2025-01-30  2025-01-30        2025-01-30 15:32:00
# 59     2025-01-30  2025-01-30        2025-01-30 15:32:00
# 65     2025-01-30  2025-01-30        2025-01-30 15:32:00
# ...           ...         ...                        ...
# 19220  2018-10-17  2018-10-17        2018-10-17 11:11:00
# 19221  2018-10-17  2018-10-17        2018-10-17 11:11:00
# 19222  2018-10-17  2018-10-17        2018-10-17 11:11:00
# 19223  2018-10-17  2018-10-17        2018-10-17 11:11:00
# 19227  2018-10-17  2018-10-17        2018-10-17 11:11:00
#
#       lab_measurement_description lab_measurement_test_value_numeric  \
# 54                    Hemoglobine                               8.30
# 55                    Hematocriet                               0.41
# 56                            MCV                              89.00
# 59                          Ureum                              11.00
# 65                    Hemoglobine                               8.30
# ...                           ...                                ...
# 19220                 Hemoglobine                               7.30
# 19221                 Hematocriet                               0.36
# 19222                         MCV                              87.00
# 19223                 Trombocyten                             261.00
# 19227                       Ureum                              10.40
#
#        signficant_hb_drop_7_days signficant_hb_drop_7_days_max_min  \
# 54                         False                              True
# 55                         False                              True
# 56                         False                              True
# 59                         False                              True
# 65                         False                              True
# ...                          ...                               ...
# 19220                      False                             False
# 19221                      False                             False
# 19222                      False                             False
# 19223                      False                             False
# 19227                      False                             False
#
#       sigh_hb_drop_text
# 54                False
# 55                False
# 56                False
# 59                False
# 65                False
# ...                 ...
# 19220             False
# 19221             False
# 19222             False
# 19223             False
# 19227             False
#
# [2598 rows x 21 columns]

# %%
df_tests_filtered = df_merged_tests_filtered.copy()
print(df_tests_wide['pseudo_id'].nunique())
# Out:
# 105

# %%
df_tests_filtered['Hb'] = None
df_tests_filtered['Hematocriet'] = None
df_tests_filtered['MCV'] = None
df_tests_filtered['INR'] = None
df_tests_filtered['APTT'] = None
df_tests_filtered['Protrombinetijd'] = None
df_tests_filtered['Ureum'] = None
df_tests_filtered['Trombocyten'] = None

# for i in range(len(df_tests_filtered)):
#     if df_tests_filtered['lab_measurement_description'].iloc[i] == 'Hemoglobine':
#         if df_tests_filtered['lab_measurement_test_value_numeric'].iloc[i] < 7.5:
#             df_tests_filtered['Hb'].iloc[i] = 'low'
#         elif df_tests_filtered['lab_measurement_test_value_numeric'].iloc[i] > 7.5:
#             df_tests_filtered['Hb'].iloc[i] = 'normal'

#     if df_tests_filtered['lab_measurement_description'].iloc[i] == 'Hematocriet':
#         if df_tests_filtered['lab_measurement_test_value_numeric'].iloc[i] < 0.35:
#             df_tests_filtered['Hematocriet'].iloc[i] = 'low'
#         elif df_tests_filtered['lab_measurement_test_value_numeric'].iloc[i] > 0.35:
#             df_tests_filtered['Hematocriet'].iloc[i] = 'normal'

#     if df_tests_filtered['lab_measurement_description'].iloc[i] == 'MCV':
#         if df_tests_filtered['lab_measurement_test_value_numeric'].iloc[i] < 80:
#             df_tests_filtered['MCV'].iloc[i] = 'low'
#         elif df_tests_filtered['lab_measurement_test_value_numeric'].iloc[i] > 80:
#             df_tests_filtered['MCV'].iloc[i] = 'normal'

#     if df_tests_filtered['lab_measurement_description'].iloc[i] == 'INR':
#         if df_tests_filtered['lab_measurement_test_value_numeric'].iloc[i] < 1.5:
#             df_tests_filtered['INR'].iloc[i] = 'normal'
#         elif df_tests_filtered['lab_measurement_test_value_numeric'].iloc[i] > 1.5:
#             df_tests_filtered['INR'].iloc[i] = 'high'

#     if df_tests_filtered['lab_measurement_description'].iloc[i] == 'APTT':
#         if df_tests_filtered['lab_measurement_test_value_numeric'].iloc[i] < 35:
#             df_tests_filtered['APTT'].iloc[i] = 'normal'
#         elif df_tests_filtered['lab_measurement_test_value_numeric'].iloc[i] > 35:
#             df_tests_filtered['APTT'].iloc[i] = 'high'
    
#     if df_tests_filtered['lab_measurement_description'].iloc[i] == 'Protrombinetijd':
#         if df_tests_filtered['lab_measurement_test_value_numeric'].iloc[i] < 15:
#             df_tests_filtered['Protrombinetijd'].iloc[i] = 'normal'
#         elif df_tests_filtered['lab_measurement_test_value_numeric'].iloc[i] > 15:
#             df_tests_filtered['Protrombinetijd'].iloc[i] = 'high'
    
#     if df_tests_filtered['lab_measurement_description'].iloc[i] == 'Ureum':
#         if df_tests_filtered['lab_measurement_test_value_numeric'].iloc[i] < 7.5:
#             df_tests_filtered['Ureum'].iloc[i] = 'normal'
#         elif df_tests_filtered['lab_measurement_test_value_numeric'].iloc[i] > 7.5:
#             df_tests_filtered['Ureum'].iloc[i] = 'high'

#     if df_tests_filtered['lab_measurement_description'].iloc[i] == 'Trombocyten':
#         if df_tests_filtered['lab_measurement_test_value_numeric'].iloc[i] < 150:
#             df_tests_filtered['Trombocyten'].iloc[i] = 'low'
#         elif df_tests_filtered['lab_measurement_test_value_numeric'].iloc[i] > 150:
#             df_tests_filtered['Trombocyten'].iloc[i] = 'normal'


    
# df_tests_filtered

# %%
df_tests_wide = df_merged_tests_filtered.pivot_table(
    index=['pseudo_id', 'lab_measurement_start_date', 'verslagen_report_content', 'agib_final', 'gib_final', 'scopie_final', 'treatment_final', 'scopie_after_seh', 'signficant_hb_drop_7_days', 'signficant_hb_drop_7_days_max_min', 'sigh_hb_drop_text'],
    columns='lab_measurement_description',	#	is_seh	is_scopie	scopie_after_seh	report_date	lab_measurement_description	lab_measurement_test_value_string	lab_measurement_test_value_numeric	lab_measurement_test_value_unit	lab_measurement_start_date	
    values='lab_measurement_test_value_numeric',
    aggfunc='first'
).reset_index()

print(df_tests_wide['pseudo_id'].nunique())
df_tests_wide
# Out:
# 32
# lab_measurement_description                                 pseudo_id  \
# 0                            0E93D98E82D272810A15FDE70270EE41E9C6DB71
# 1                            0E93D98E82D272810A15FDE70270EE41E9C6DB71
# 2                            0E93D98E82D272810A15FDE70270EE41E9C6DB71
# 3                            0E93D98E82D272810A15FDE70270EE41E9C6DB71
# 4                            0E93D98E82D272810A15FDE70270EE41E9C6DB71
# ..                                                                ...
# 471                          F8D116F01EE0039678998F393FA337C10AD4F4E2
# 472                          F8D116F01EE0039678998F393FA337C10AD4F4E2
# 473                          F8D116F01EE0039678998F393FA337C10AD4F4E2
# 474                          FD8C682C1F4FDA1E5EC0B760D30875556419BD71
# 475                          FD8C682C1F4FDA1E5EC0B760D30875556419BD71
#
# lab_measurement_description lab_measurement_start_date  \
# 0                                  2019-11-24 11:50:00
# 1                                  2019-11-24 11:50:00
# 2                                  2019-11-24 11:50:00
# 3                                  2019-11-24 20:00:00
# 4                                  2019-11-24 20:00:00
# ..                                                 ...
# 471                                2020-09-23 17:23:00
# 472                                2020-09-23 17:23:00
# 473                                2020-09-25 08:00:00
# 474                                2018-10-17 11:11:00
# 475                                2018-10-17 11:11:00
#
# lab_measurement_description                           verslagen_report_content  \
# 0                            Reden van komst / Verwijzing: \nReden van koms...
# 1                            Samenvatting: \nBloedverlies per anum onder AS...
# 2                            Samenvatting: \nBloedverlies per anum onder AS...
# 3                            Reden van komst / Verwijzing: \nReden van koms...
# 4                            Samenvatting: \nBloedverlies per anum onder AS...
# ..                                                                         ...
# 471                          Samenvatting: \nVoorgeschiedenis: \nJicht\nHyp...
# 472                          Samenvatting: \nVoorgeschiedenis: \nJicht\nHyp...
# 473                          Samenvatting: \nVoorgeschiedenis: \nJicht\nHyp...
# 474                          Aan de weledelgeleerde heer\r\ndrs. F.J.G.M. V...
# 475                          Reden van komst / Verwijzing: \nReden van koms...
#
# lab_measurement_description  agib_final  gib_final  scopie_final  \
# 0                                 False       True          True
# 1                                 False       True         False
# 2                                 False       True          True
# 3                                 False       True          True
# 4                                 False       True         False
# ..                                  ...        ...           ...
# 471                               False       True         False
# 472                               False       True         False
# 473                               False       True         False
# 474                               False       True         False
# 475                               False       True         False
#
# lab_measurement_description  treatment_final  scopie_after_seh  \
# 0                                      False              True
# 1                                      False             False
# 2                                      False             False
# 3                                      False              True
# 4                                      False             False
# ..                                       ...               ...
# 471                                    False             False
# 472                                    False             False
# 473                                    False             False
# 474                                    False             False
# 475                                    False             False
#
# lab_measurement_description  signficant_hb_drop_7_days  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ..                                                 ...
# 471                                              False
# 472                                              False
# 473                                              False
# 474                                              False
# 475                                              False
#
# lab_measurement_description  signficant_hb_drop_7_days_max_min  \
# 0                                                        False
# 1                                                        False
# 2                                                        False
# 3                                                        False
# 4                                                        False
# ..                                                         ...
# 471                                                      False
# 472                                                      False
# 473                                                      False
# 474                                                      False
# 475                                                      False
#
# lab_measurement_description  sigh_hb_drop_text  APTT  Hematocriet  \
# 0                                        False   NaN         0.28
# 1                                        False   NaN         0.28
# 2                                        False   NaN         0.28
# 3                                        False   NaN          NaN
# 4                                        False   NaN          NaN
# ..                                         ...   ...          ...
# 471                                      False   NaN          NaN
# 472                                      False   NaN          NaN
# 473                                      False   NaN          NaN
# 474                                      False   NaN         0.36
# 475                                      False   NaN         0.36
#
# lab_measurement_description  Hemoglobine  INR   MCV  Protrombinetijd  \
# 0                                    5.9  NaN  92.0              NaN
# 1                                    5.9  NaN  92.0              NaN
# 2                                    5.9  NaN  92.0              NaN
# 3                                    5.5  NaN  92.0              NaN
# 4                                    5.5  NaN  92.0              NaN
# ..                                   ...  ...   ...              ...
# 471                                  NaN  1.0   NaN              NaN
# 472                                  NaN  1.0   NaN              NaN
# 473                                  8.2  NaN  98.0              NaN
# 474                                  7.3  NaN  87.0              NaN
# 475                                  7.3  NaN  87.0              NaN
#
# lab_measurement_description  Trombocyten  Ureum
# 0                                  305.0    NaN
# 1                                  305.0    NaN
# 2                                  305.0    NaN
# 3                                    NaN    NaN
# 4                                    NaN    NaN
# ..                                   ...    ...
# 471                                  NaN    NaN
# 472                                  NaN    NaN
# 473                                205.0    NaN
# 474                                261.0   10.4
# 475                                261.0   10.4
#
# [476 rows x 19 columns]

# %%
# df_tests_wide['low_hb'] = df_tests_wide['Hemoglobine'] < 7.5
# df_tests_wide['low_hematocriet'] = df_tests_wide['Hematocriet'] < 0.35
# df_tests_wide['low_mcv'] = df_tests_wide['MCV'] < 80
# df_tests_wide['high_inr'] = df_tests_wide['INR'] > 1.5
# df_tests_wide['high_aptt'] = df_tests_wide['APTT'] > 35
# df_tests_wide['high_pt'] = df_tests_wide['Protrombinetijd'] > 15
# df_tests_wide['high_urea'] = df_tests_wide['Ureum'] > 7.5
# df_tests_wide['low_plt'] = df_tests_wide['Trombocyten'] < 150

if df_dbc.empty:
    print("DataFrame is empty")
    df_tests_wide['low_hb'] = None
    df_tests_wide['low_hematocriet'] = None
    df_tests_wide['low_mcv'] = None
    df_tests_wide['high_inr'] = None
    df_tests_wide['high_aptt'] = None
    df_tests_wide['high_pt'] = None
    df_tests_wide['high_urea'] = None
    df_tests_wide['low_plt'] = None
else:
## algemeen
    df_tests_wide['low_hb'] = df_tests_wide['Hemoglobine'] < 7.5
    df_tests_wide['low_hematocriet'] = df_tests_wide['Hematocriet'] < 0.35
    #bloedgroep
    df_tests_wide['high_ureum'] = df_tests_wide['Ureum'] > 7.5 # voor hoge bloeding 

    df_tests_wide['low_mcv'] = df_tests_wide['MCV'] < 80 # voor chronische anemie
    df_tests_wide['high_mcv'] = df_tests_wide['MCV'] > 80 # voor eventueel acuut bloedverlies (aangezien waarde dan vaak nog normaal is)


    df_tests_wide['high_inr'] = df_tests_wide['INR'] > 1.5 # in geval van coumaringegebruik
    df_tests_wide['high_aptt'] = df_tests_wide['APTT'] > 35 # bij leverlijden

    df_tests_wide['high_pt'] = df_tests_wide['Protrombinetijd'] > 15
    df_tests_wide['high_ureum'] = df_tests_wide['Ureum'] > 7.5
    df_tests_wide['low_plt'] = df_tests_wide['Trombocyten'] < 150

df_tests_wide
# Out:
# lab_measurement_description                                 pseudo_id  \
# 0                            0E93D98E82D272810A15FDE70270EE41E9C6DB71
# 1                            0E93D98E82D272810A15FDE70270EE41E9C6DB71
# 2                            0E93D98E82D272810A15FDE70270EE41E9C6DB71
# 3                            0E93D98E82D272810A15FDE70270EE41E9C6DB71
# 4                            0E93D98E82D272810A15FDE70270EE41E9C6DB71
# ..                                                                ...
# 471                          F8D116F01EE0039678998F393FA337C10AD4F4E2
# 472                          F8D116F01EE0039678998F393FA337C10AD4F4E2
# 473                          F8D116F01EE0039678998F393FA337C10AD4F4E2
# 474                          FD8C682C1F4FDA1E5EC0B760D30875556419BD71
# 475                          FD8C682C1F4FDA1E5EC0B760D30875556419BD71
#
# lab_measurement_description lab_measurement_start_date  \
# 0                                  2019-11-24 11:50:00
# 1                                  2019-11-24 11:50:00
# 2                                  2019-11-24 11:50:00
# 3                                  2019-11-24 20:00:00
# 4                                  2019-11-24 20:00:00
# ..                                                 ...
# 471                                2020-09-23 17:23:00
# 472                                2020-09-23 17:23:00
# 473                                2020-09-25 08:00:00
# 474                                2018-10-17 11:11:00
# 475                                2018-10-17 11:11:00
#
# lab_measurement_description                           verslagen_report_content  \
# 0                            Reden van komst / Verwijzing: \nReden van koms...
# 1                            Samenvatting: \nBloedverlies per anum onder AS...
# 2                            Samenvatting: \nBloedverlies per anum onder AS...
# 3                            Reden van komst / Verwijzing: \nReden van koms...
# 4                            Samenvatting: \nBloedverlies per anum onder AS...
# ..                                                                         ...
# 471                          Samenvatting: \nVoorgeschiedenis: \nJicht\nHyp...
# 472                          Samenvatting: \nVoorgeschiedenis: \nJicht\nHyp...
# 473                          Samenvatting: \nVoorgeschiedenis: \nJicht\nHyp...
# 474                          Aan de weledelgeleerde heer\r\ndrs. F.J.G.M. V...
# 475                          Reden van komst / Verwijzing: \nReden van koms...
#
# lab_measurement_description  agib_final  gib_final  scopie_final  \
# 0                                 False       True          True
# 1                                 False       True         False
# 2                                 False       True          True
# 3                                 False       True          True
# 4                                 False       True         False
# ..                                  ...        ...           ...
# 471                               False       True         False
# 472                               False       True         False
# 473                               False       True         False
# 474                               False       True         False
# 475                               False       True         False
#
# lab_measurement_description  treatment_final  scopie_after_seh  \
# 0                                      False              True
# 1                                      False             False
# 2                                      False             False
# 3                                      False              True
# 4                                      False             False
# ..                                       ...               ...
# 471                                    False             False
# 472                                    False             False
# 473                                    False             False
# 474                                    False             False
# 475                                    False             False
#
# lab_measurement_description  signficant_hb_drop_7_days  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ..                                                 ...
# 471                                              False
# 472                                              False
# 473                                              False
# 474                                              False
# 475                                              False
#
# lab_measurement_description  signficant_hb_drop_7_days_max_min  ...  Ureum  \
# 0                                                        False  ...    NaN
# 1                                                        False  ...    NaN
# 2                                                        False  ...    NaN
# 3                                                        False  ...    NaN
# 4                                                        False  ...    NaN
# ..                                                         ...  ...    ...
# 471                                                      False  ...    NaN
# 472                                                      False  ...    NaN
# 473                                                      False  ...    NaN
# 474                                                      False  ...   10.4
# 475                                                      False  ...   10.4
#
# lab_measurement_description  low_hb  low_hematocriet  high_ureum  low_mcv  \
# 0                              True             True       False    False
# 1                              True             True       False    False
# 2                              True             True       False    False
# 3                              True            False       False    False
# 4                              True            False       False    False
# ..                              ...              ...         ...      ...
# 471                           False            False       False    False
# 472                           False            False       False    False
# 473                           False            False       False    False
# 474                            True            False        True    False
# 475                            True            False        True    False
#
# lab_measurement_description  high_mcv  high_inr  high_aptt  high_pt  low_plt
# 0                                True     False      False    False    False
# 1                                True     False      False    False    False
# 2                                True     False      False    False    False
# 3                                True     False      False    False    False
# 4                                True     False      False    False    False
# ..                                ...       ...        ...      ...      ...
# 471                             False     False      False    False    False
# 472                             False     False      False    False    False
# 473                              True     False      False    False    False
# 474                              True     False      False    False    False
# 475                              True     False      False    False    False
#
# [476 rows x 28 columns]

# %%
# # Combine features: 1) Hb + Urea  OR  2 or more coagulopathy markers
# df_tests_wide['likely_GIB'] = (
#     df_tests_wide['gib_final'] |
#     (df_tests_wide['low_hb'] & df_tests_wide['high_urea']) |
#     (df_tests_wide[['low_hb', 'high_inr', 'low_plt', 'high_aptt', 'high_pt']].sum(axis=1) >= 2)
# )

# df_tests_wide.value_counts('likely_GIB')
# df_tests_wide


df_tests_wide['likely_gib'] = (
    df_tests_wide[['low_hb', 'low_hematocriet', 'high_ureum', 'high_inr', 'high_aptt', 'high_pt', 'low_plt']]
    .sum(axis=1) >= 2
)
print(df_tests_wide.value_counts('likely_gib'))
print(df_tests_wide[df_tests_wide['likely_gib']]['pseudo_id'].nunique())
# Out:
# likely_gib
# False    249
# True     227
# dtype: int64
# 25

# %%
df_tests_wide['likely_agib'] = (
    df_tests_wide['low_hb'] &
    df_tests_wide['high_ureum'] &
    (df_tests_wide['low_mcv'] == False)  # dus MCV normaal of hoog
)

print(df_tests_wide.value_counts('likely_agib'))
print(df_tests_wide[df_tests_wide['likely_agib']]['pseudo_id'].nunique())
# Out:
# likely_agib
# False    403
# True      73
# dtype: int64
# 18

# %%
df_tests_wide['likely_agib2'] = (
    df_tests_wide['low_hb'] &
    df_tests_wide['high_ureum'] &
    (df_tests_wide['low_mcv'] == False)
    # eventueel ook:
    # & df_tests_wide['scopie_after_seh']
    # & df_tests_wide['agib_final']
    & df_tests_wide['signficant_hb_drop_7_days']
    
)

print(df_tests_wide.value_counts('likely_agib2'))
print(df_tests_wide[df_tests_wide['likely_agib2']]['pseudo_id'].nunique())
# Out:
# likely_agib2
# False    446
# True      30
# dtype: int64
# 6

# %%
df_tests_wide
# Out:
# lab_measurement_description                                 pseudo_id  \
# 0                            0E93D98E82D272810A15FDE70270EE41E9C6DB71
# 1                            0E93D98E82D272810A15FDE70270EE41E9C6DB71
# 2                            0E93D98E82D272810A15FDE70270EE41E9C6DB71
# 3                            0E93D98E82D272810A15FDE70270EE41E9C6DB71
# 4                            0E93D98E82D272810A15FDE70270EE41E9C6DB71
# ..                                                                ...
# 471                          F8D116F01EE0039678998F393FA337C10AD4F4E2
# 472                          F8D116F01EE0039678998F393FA337C10AD4F4E2
# 473                          F8D116F01EE0039678998F393FA337C10AD4F4E2
# 474                          FD8C682C1F4FDA1E5EC0B760D30875556419BD71
# 475                          FD8C682C1F4FDA1E5EC0B760D30875556419BD71
#
# lab_measurement_description lab_measurement_start_date  \
# 0                                  2019-11-24 11:50:00
# 1                                  2019-11-24 11:50:00
# 2                                  2019-11-24 11:50:00
# 3                                  2019-11-24 20:00:00
# 4                                  2019-11-24 20:00:00
# ..                                                 ...
# 471                                2020-09-23 17:23:00
# 472                                2020-09-23 17:23:00
# 473                                2020-09-25 08:00:00
# 474                                2018-10-17 11:11:00
# 475                                2018-10-17 11:11:00
#
# lab_measurement_description                           verslagen_report_content  \
# 0                            Reden van komst / Verwijzing: \nReden van koms...
# 1                            Samenvatting: \nBloedverlies per anum onder AS...
# 2                            Samenvatting: \nBloedverlies per anum onder AS...
# 3                            Reden van komst / Verwijzing: \nReden van koms...
# 4                            Samenvatting: \nBloedverlies per anum onder AS...
# ..                                                                         ...
# 471                          Samenvatting: \nVoorgeschiedenis: \nJicht\nHyp...
# 472                          Samenvatting: \nVoorgeschiedenis: \nJicht\nHyp...
# 473                          Samenvatting: \nVoorgeschiedenis: \nJicht\nHyp...
# 474                          Aan de weledelgeleerde heer\r\ndrs. F.J.G.M. V...
# 475                          Reden van komst / Verwijzing: \nReden van koms...
#
# lab_measurement_description  agib_final  gib_final  scopie_final  \
# 0                                 False       True          True
# 1                                 False       True         False
# 2                                 False       True          True
# 3                                 False       True          True
# 4                                 False       True         False
# ..                                  ...        ...           ...
# 471                               False       True         False
# 472                               False       True         False
# 473                               False       True         False
# 474                               False       True         False
# 475                               False       True         False
#
# lab_measurement_description  treatment_final  scopie_after_seh  \
# 0                                      False              True
# 1                                      False             False
# 2                                      False             False
# 3                                      False              True
# 4                                      False             False
# ..                                       ...               ...
# 471                                    False             False
# 472                                    False             False
# 473                                    False             False
# 474                                    False             False
# 475                                    False             False
#
# lab_measurement_description  signficant_hb_drop_7_days  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ..                                                 ...
# 471                                              False
# 472                                              False
# 473                                              False
# 474                                              False
# 475                                              False
#
# lab_measurement_description  signficant_hb_drop_7_days_max_min  ...  \
# 0                                                        False  ...
# 1                                                        False  ...
# 2                                                        False  ...
# 3                                                        False  ...
# 4                                                        False  ...
# ..                                                         ...  ...
# 471                                                      False  ...
# 472                                                      False  ...
# 473                                                      False  ...
# 474                                                      False  ...
# 475                                                      False  ...
#
# lab_measurement_description  high_ureum  low_mcv  high_mcv  high_inr  \
# 0                                 False    False      True     False
# 1                                 False    False      True     False
# 2                                 False    False      True     False
# 3                                 False    False      True     False
# 4                                 False    False      True     False
# ..                                  ...      ...       ...       ...
# 471                               False    False     False     False
# 472                               False    False     False     False
# 473                               False    False      True     False
# 474                                True    False      True     False
# 475                                True    False      True     False
#
# lab_measurement_description  high_aptt  high_pt  low_plt  likely_gib  \
# 0                                False    False    False        True
# 1                                False    False    False        True
# 2                                False    False    False        True
# 3                                False    False    False       False
# 4                                False    False    False       False
# ..                                 ...      ...      ...         ...
# 471                              False    False    False       False
# 472                              False    False    False       False
# 473                              False    False    False       False
# 474                              False    False    False        True
# 475                              False    False    False        True
#
# lab_measurement_description  likely_agib  likely_agib2
# 0                                  False         False
# 1                                  False         False
# 2                                  False         False
# 3                                  False         False
# 4                                  False         False
# ..                                   ...           ...
# 471                                False         False
# 472                                False         False
# 473                                False         False
# 474                                 True         False
# 475                                 True         False
#
# [476 rows x 31 columns]

# %%
# print(df_tests_wide['likely_GIB'].value_counts())
# print(df_tests_wide[df_tests_wide['likely_GIB'] == True]['pseudo_id'].unique())
# print(len(df_tests_wide[df_tests_wide['likely_GIB'] == True]['pseudo_id'].unique()))

# %%
# Start with GIB-positive patients
df_tests_wide['likely_AGIB'] = df_tests_wide['gib_final']

df = df_tests_wide.copy()

# %%
df['likely_AGIB'] = (
    df['gib_final'] &
    (
        df['scopie_after_seh'] |                 # urgent scoped
        df['high_ureum'] |                        # upper source suggested by urea
        df['agib_final']                         # not negated and matched AGIB
        # df['gib_match'].str.contains("melena|hematemesis", case=False, na=False)
    )
)

df
# Out:
# lab_measurement_description                                 pseudo_id  \
# 0                            0E93D98E82D272810A15FDE70270EE41E9C6DB71
# 1                            0E93D98E82D272810A15FDE70270EE41E9C6DB71
# 2                            0E93D98E82D272810A15FDE70270EE41E9C6DB71
# 3                            0E93D98E82D272810A15FDE70270EE41E9C6DB71
# 4                            0E93D98E82D272810A15FDE70270EE41E9C6DB71
# ..                                                                ...
# 471                          F8D116F01EE0039678998F393FA337C10AD4F4E2
# 472                          F8D116F01EE0039678998F393FA337C10AD4F4E2
# 473                          F8D116F01EE0039678998F393FA337C10AD4F4E2
# 474                          FD8C682C1F4FDA1E5EC0B760D30875556419BD71
# 475                          FD8C682C1F4FDA1E5EC0B760D30875556419BD71
#
# lab_measurement_description lab_measurement_start_date  \
# 0                                  2019-11-24 11:50:00
# 1                                  2019-11-24 11:50:00
# 2                                  2019-11-24 11:50:00
# 3                                  2019-11-24 20:00:00
# 4                                  2019-11-24 20:00:00
# ..                                                 ...
# 471                                2020-09-23 17:23:00
# 472                                2020-09-23 17:23:00
# 473                                2020-09-25 08:00:00
# 474                                2018-10-17 11:11:00
# 475                                2018-10-17 11:11:00
#
# lab_measurement_description                           verslagen_report_content  \
# 0                            Reden van komst / Verwijzing: \nReden van koms...
# 1                            Samenvatting: \nBloedverlies per anum onder AS...
# 2                            Samenvatting: \nBloedverlies per anum onder AS...
# 3                            Reden van komst / Verwijzing: \nReden van koms...
# 4                            Samenvatting: \nBloedverlies per anum onder AS...
# ..                                                                         ...
# 471                          Samenvatting: \nVoorgeschiedenis: \nJicht\nHyp...
# 472                          Samenvatting: \nVoorgeschiedenis: \nJicht\nHyp...
# 473                          Samenvatting: \nVoorgeschiedenis: \nJicht\nHyp...
# 474                          Aan de weledelgeleerde heer\r\ndrs. F.J.G.M. V...
# 475                          Reden van komst / Verwijzing: \nReden van koms...
#
# lab_measurement_description  agib_final  gib_final  scopie_final  \
# 0                                 False       True          True
# 1                                 False       True         False
# 2                                 False       True          True
# 3                                 False       True          True
# 4                                 False       True         False
# ..                                  ...        ...           ...
# 471                               False       True         False
# 472                               False       True         False
# 473                               False       True         False
# 474                               False       True         False
# 475                               False       True         False
#
# lab_measurement_description  treatment_final  scopie_after_seh  \
# 0                                      False              True
# 1                                      False             False
# 2                                      False             False
# 3                                      False              True
# 4                                      False             False
# ..                                       ...               ...
# 471                                    False             False
# 472                                    False             False
# 473                                    False             False
# 474                                    False             False
# 475                                    False             False
#
# lab_measurement_description  signficant_hb_drop_7_days  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ..                                                 ...
# 471                                              False
# 472                                              False
# 473                                              False
# 474                                              False
# 475                                              False
#
# lab_measurement_description  signficant_hb_drop_7_days_max_min  ...  low_mcv  \
# 0                                                        False  ...    False
# 1                                                        False  ...    False
# 2                                                        False  ...    False
# 3                                                        False  ...    False
# 4                                                        False  ...    False
# ..                                                         ...  ...      ...
# 471                                                      False  ...    False
# 472                                                      False  ...    False
# 473                                                      False  ...    False
# 474                                                      False  ...    False
# 475                                                      False  ...    False
#
# lab_measurement_description  high_mcv  high_inr  high_aptt  high_pt  low_plt  \
# 0                                True     False      False    False    False
# 1                                True     False      False    False    False
# 2                                True     False      False    False    False
# 3                                True     False      False    False    False
# 4                                True     False      False    False    False
# ..                                ...       ...        ...      ...      ...
# 471                             False     False      False    False    False
# 472                             False     False      False    False    False
# 473                              True     False      False    False    False
# 474                              True     False      False    False    False
# 475                              True     False      False    False    False
#
# lab_measurement_description  likely_gib  likely_agib  likely_agib2  \
# 0                                  True        False         False
# 1                                  True        False         False
# 2                                  True        False         False
# 3                                 False        False         False
# 4                                 False        False         False
# ..                                  ...          ...           ...
# 471                               False        False         False
# 472                               False        False         False
# 473                               False        False         False
# 474                                True         True         False
# 475                                True         True         False
#
# lab_measurement_description  likely_AGIB
# 0                                   True
# 1                                  False
# 2                                  False
# 3                                   True
# 4                                  False
# ..                                   ...
# 471                                False
# 472                                False
# 473                                False
# 474                                 True
# 475                                 True
#
# [476 rows x 32 columns]

# %%
print(df_tests_wide['likely_AGIB'].value_counts())
print(df_tests_wide[df_tests_wide['likely_AGIB'] == True]['pseudo_id'].unique())
print(len(df_tests_wide[df_tests_wide['likely_AGIB'] == True]['pseudo_id'].unique()))
# Out:
# True     337
# False    139
# Name: likely_AGIB, dtype: int64
# ['0E93D98E82D272810A15FDE70270EE41E9C6DB71'
#  '15CF926899FB0141DABA60251D292FCC89C94C1B'
#  '20AAD8E38E7C9D75E44F9EA52336B7003ED239BD'
#  '23E295F4F8F7550C76B6C22ABDA7DFFB3FCF1682'
#  '29B3653AE690547AB14AC7FCD32B21A561D5FF9A'
#  '395219FA6E57FE6DA93F36F3EB68F4667D325895'
#  '3B21EF377C1BA327A67C2C951A6CB78BEAD5B3FE'
#  '40FF2EE78841C453C1C673E9047BABC03DD6CCEE'
#  '52EE37A2B81CD38A3062B4B7B216EDBB8BE07E6C'
#  '6CF1734B040468B6802E26DFA5BC6B6FF6869362'
#  '7087EB7CD49F67A7A8E51203DE7C0F9FFBBFB51B'
#  '7561B5E32DE738229F2D658FBAACEFFE80B50600'
#  '895342BFD0D1C32FFF8F009C0E20CBE97B04677D'
#  '96764B9E95688ACB64A6C8E99AC2E6D5828BED12'
#  '9763CE55BAB3BF537B9309F9A7A6085F86ED878A'
#  '9A5F28B3534569F4F2EF8F9C7CCD12F102A511D3'
#  'A8FA2D94EA62234A97F2D21737D6046198E67B20'
#  'BAE82DBED446134D3759C32B5457D88A06F8F6AD'
#  'BEBEFC726C577A7B40F1A467F4E59746FBC7F76B'
#  'C775682FCB29A890D7B64B211F17DFF3D8867951'
#  'C7C86E1AA957D3F18CD7803ABCBE9D63C07AFCCA'
#  'CB30ED9CF2F8BE2FABC260C6990B8305E2C09F37'
#  'D25F6785232C8650378EAE7E1D994F3506AEF6DA'
#  'DD14A8EB729CA98BF5840DA7373992442B0B13CA'
#  'E30405A5247BE2EFBEE529FD3FD26EB70B03594D'
#  'EC46C3AA9E8858EBAEFEB2C1A429DBD6BA8783BE'
#  'EC6EED9DCF9A5CD8EDAC5DB8A9C9D339C7FC89DC'
#  'F5F86E4F57D98E65D464A42AC325615EFE0D5C31'
#  'F8D116F01EE0039678998F393FA337C10AD4F4E2'
#  'FD8C682C1F4FDA1E5EC0B760D30875556419BD71']
# 30

# %%
df_tests_wide['likely_agib'] = (
    df_tests_wide['low_hb'] &
    df_tests_wide['high_ureum'] &
    (df_tests_wide['low_mcv'] == False)
    # eventueel ook:
    & df_combined['scopie_after_seh']
)

# %% [markdown]
# Final

# %%
df_merged
# Out:
#                                       pseudo_id verslagen_report_start_date  \
# 0      046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6         2020-11-26 15:06:00
# 1      046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6         2020-11-26 09:53:00
# 2      046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6         2020-11-25 14:13:00
# 3      046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6         2020-11-25 13:48:00
# 4      046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6         2020-11-25 08:47:00
# ...                                         ...                         ...
# 19306  FD8C682C1F4FDA1E5EC0B760D30875556419BD71         2015-03-20 08:13:00
# 19307  FD8C682C1F4FDA1E5EC0B760D30875556419BD71         2015-01-14 15:39:00
# 19308  FD8C682C1F4FDA1E5EC0B760D30875556419BD71         2014-12-21 09:31:00
# 19309  FD8C682C1F4FDA1E5EC0B760D30875556419BD71         2010-11-10 21:03:00
# 19310  FD8C682C1F4FDA1E5EC0B760D30875556419BD71         2010-11-10 20:29:00
#
#         verslagen_report_specialism  \
# 0      Maag-, Darm- en Leverziekten
# 1      Maag-, Darm- en Leverziekten
# 2      Maag-, Darm- en Leverziekten
# 3      Maag-, Darm- en Leverziekten
# 4      Maag-, Darm- en Leverziekten
# ...                             ...
# 19306           Interne Geneeskunde
# 19307           Interne Geneeskunde
# 19308             Spoedeisende Hulp
# 19309             Spoedeisende Hulp
# 19310             Spoedeisende Hulp
#
#                                 verslagen_report_content  agib_final  \
# 0      Dhr. A.J. Dingemans, huisarts\r\n[STREETNAME] ...       False
# 1      Samenvatting: \nRectaal bloedverlies obv diver...       False
# 2      COLOSCOPIE\r\n\r\nBetreft\r\nMw. [INITIALS] [L...       False
# 3      GASTROSCOPIE\r\n\r\nBetreft\r\nMw. [INITIALS] ...       False
# 4      Samenvatting: \nRectaal bloedverlies ; eenmali...       False
# ...                                                  ...         ...
# 19306  Samenvatting: \n1e consult\r\n-Type 1e consult...       False
# 19307  Samenvatting: \nDecursus\r\n-Type decursus: De...       False
# 19308  Samenvatting: \nVerpleegkundige verslaglegging...       False
# 19309  Samenvatting: \nMedisch Dossier\r\n[ Vk Sputov...       False
# 19310  Samenvatting: \nVerpleegkundige verslaglegging...       False
#
#        gib_final  scopie_final  treatment_final diagnose_db_cs_dbc_start_date  \
# 0           True          True             True                    2020-11-24
# 1           True          True             True                    2020-11-24
# 2           True          True            False                    2020-11-24
# 3           True          True            False                    2020-11-24
# 4           True          True            False                    2020-11-24
# ...          ...           ...              ...                           ...
# 19306      False          True            False                           NaN
# 19307      False          True            False                           NaN
# 19308      False         False            False                           NaN
# 19309      False         False            False                           NaN
# 19310      False         False            False                           NaN
#
#       diagnose_db_cs_dbc_end_date  ...  is_scopie  scopie_after_seh  \
# 0                      2021-01-07  ...      False             False
# 1                      2021-01-07  ...      False             False
# 2                      2021-01-07  ...       True             False
# 3                      2021-01-07  ...       True             False
# 4                      2021-01-07  ...       True             False
# ...                           ...  ...        ...               ...
# 19306                         NaN  ...      False             False
# 19307                         NaN  ...      False             False
# 19308                         NaN  ...      False             False
# 19309                         NaN  ...      False             False
# 19310                         NaN  ...      False             False
#
#       report_date lab_date lab_measurement_start_date  \
# 0      2020-11-26      NaN                        NaT
# 1      2020-11-26      NaN                        NaT
# 2      2020-11-25      NaN                        NaT
# 3      2020-11-25      NaN                        NaT
# 4      2020-11-25      NaN                        NaT
# ...           ...      ...                        ...
# 19306  2015-03-20      NaN                        NaT
# 19307  2015-01-14      NaN                        NaT
# 19308  2014-12-21      NaN                        NaT
# 19309  2010-11-10      NaN                        NaT
# 19310  2010-11-10      NaN                        NaT
#
#       lab_measurement_description lab_measurement_test_value_numeric  \
# 0                             NaN                                NaN
# 1                             NaN                                NaN
# 2                             NaN                                NaN
# 3                             NaN                                NaN
# 4                             NaN                                NaN
# ...                           ...                                ...
# 19306                         NaN                                NaN
# 19307                         NaN                                NaN
# 19308                         NaN                                NaN
# 19309                         NaN                                NaN
# 19310                         NaN                                NaN
#
#        signficant_hb_drop_7_days signficant_hb_drop_7_days_max_min  \
# 0                            NaN                               NaN
# 1                            NaN                               NaN
# 2                            NaN                               NaN
# 3                            NaN                               NaN
# 4                            NaN                               NaN
# ...                          ...                               ...
# 19306                        NaN                               NaN
# 19307                        NaN                               NaN
# 19308                        NaN                               NaN
# 19309                        NaN                               NaN
# 19310                        NaN                               NaN
#
#       sigh_hb_drop_text
# 0                  True
# 1                 False
# 2                 False
# 3                 False
# 4                 False
# ...                 ...
# 19306             False
# 19307             False
# 19308             False
# 19309             False
# 19310             False
#
# [19311 rows x 21 columns]

# %%
# Columns you want to preserve and collapse using 'any'
bool_columns = [
    'agib_final', 'gib_final', 'scopie_final', 'treatment_final',
    'is_seh', 'is_scopie', 'scopie_after_seh', 'signficant_hb_drop_7_days',
    'signficant_hb_drop_7_days_max_min', 'sigh_hb_drop_text'
]

# Group by pseudo_id and apply 'any' to get True if any of the values was True
df_simplified = df_merged.groupby('pseudo_id')[bool_columns].any().reset_index()

# Optional: If you want to add back patient-level metadata like first report date or diagnosis period:
metadata_cols = ['diagnose_db_cs_dbc_start_date', 'diagnose_db_cs_dbc_end_date']
df_metadata = df_merged.groupby('pseudo_id')[metadata_cols].first().reset_index()

# Merge back metadata (optional)
df_final = pd.merge(df_simplified, df_metadata, on='pseudo_id', how='left')

# %%
df_simplified['scopie_after_seh'].value_counts()
# Out:
# False    54
# True     51
# Name: scopie_after_seh, dtype: int64

# %%
# List of the boolean columns you're interested in
criteria_cols = [
    'agib_final', 'gib_final', 'scopie_final', 'treatment_final',
    'is_seh', 'is_scopie', 'scopie_after_seh', 'signficant_hb_drop_7_days',
    'signficant_hb_drop_7_days_max_min', 'sigh_hb_drop_text'
]

# Count how many patients meet each criterion
for col in criteria_cols:
    print(f"\n📊 Value counts for '{col}':")
    print(df_final[col].value_counts())
# Out:
# 📊 Value counts for 'agib_final':
# False    102
# True       3
# Name: agib_final, dtype: int64
#
# 📊 Value counts for 'gib_final':
# True     104
# False      1
# Name: gib_final, dtype: int64
#
# 📊 Value counts for 'scopie_final':
# True     104
# False      1
# Name: scopie_final, dtype: int64
#
# 📊 Value counts for 'treatment_final':
# True     91
# False    14
# Name: treatment_final, dtype: int64
#
# 📊 Value counts for 'is_seh':
# True    105
# Name: is_seh, dtype: int64
#
# 📊 Value counts for 'is_scopie':
# True     89
# False    16
# Name: is_scopie, dtype: int64
#
# 📊 Value counts for 'scopie_after_seh':
# False    54
# True     51
# Name: scopie_after_seh, dtype: int64
#
# 📊 Value counts for 'signficant_hb_drop_7_days':
# False    77
# True     28
# Name: signficant_hb_drop_7_days, dtype: int64
#
# 📊 Value counts for 'signficant_hb_drop_7_days_max_min':
# False    65
# True     40
# Name: signficant_hb_drop_7_days_max_min, dtype: int64
#
# 📊 Value counts for 'sigh_hb_drop_text':
# True     83
# False    22
# Name: sigh_hb_drop_text, dtype: int64

# %%
# Summary: How many patients have each signal = True
true_counts = df_final[criteria_cols].sum()
print("\n✅ Number of patients per criterion (True):")
print(true_counts)
# Out:
# ✅ Number of patients per criterion (True):
# agib_final                             3
# gib_final                            104
# scopie_final                         104
# treatment_final                       91
# is_seh                               105
# is_scopie                             89
# scopie_after_seh                      51
# signficant_hb_drop_7_days             28
# signficant_hb_drop_7_days_max_min     40
# sigh_hb_drop_text                     83
# dtype: int64

# %%
def label_lab_values(row):
    label = {}

    if row['lab_measurement_description'] == 'Hemoglobine':
        label['low_hb'] = row['lab_measurement_test_value_numeric'] < 7.5
    elif row['lab_measurement_description'] == 'Hematocriet':
        label['low_hematocriet'] = row['lab_measurement_test_value_numeric'] < 0.35
    elif row['lab_measurement_description'] == 'MCV':
        label['low_mcv'] = row['lab_measurement_test_value_numeric'] < 80
        label['high_mcv'] = row['lab_measurement_test_value_numeric'] > 100
    elif row['lab_measurement_description'] == 'INR':
        label['high_inr'] = row['lab_measurement_test_value_numeric'] > 1.5
    elif row['lab_measurement_description'] == 'APTT':
        label['high_aptt'] = row['lab_measurement_test_value_numeric'] > 35
    elif row['lab_measurement_description'] == 'Protrombinetijd':
        label['high_pt'] = row['lab_measurement_test_value_numeric'] > 15
    elif row['lab_measurement_description'] == 'Ureum':
        label['high_ureum'] = row['lab_measurement_test_value_numeric'] > 7.5
    elif row['lab_measurement_description'] == 'Trombocyten':
        label['low_plt'] = row['lab_measurement_test_value_numeric'] < 150

    return pd.Series(label)

# %%
# Only keep relevant tests
relevant_tests = [
    'Hemoglobine', 'Hematocriet', 'MCV', 'INR',
    'APTT', 'Protrombinetijd', 'Ureum', 'Trombocyten'
]

df_relevant = df_hb[df_hb['lab_measurement_description'].isin(relevant_tests)].copy()

# Apply the flag function
flagged = df_relevant.apply(label_lab_values, axis=1)

# Combine with pseudo_id
flagged['pseudo_id'] = df_relevant['pseudo_id']

# %%
df_patient_flags = (
    flagged.groupby('pseudo_id')
           .max(numeric_only=False)  # True if any row per patient is True
           .reset_index()
)

df_patient_flags
# Out:
#                                     pseudo_id high_aptt high_inr  high_mcv  \
# 0    046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6       NaN     True     False
# 1    088C9FD98B8B2CBCB597C17C07AC1845B21F0849       NaN      NaN     False
# 2    0A5645E02FA818D1629926B6BEFA81CF91C25A46       NaN      NaN     False
# 3    0BC512A65442D0BB4B00FBE05E7EA6283E5C11FD       NaN      NaN     False
# 4    0DD73490997F61870C32B3BB7C9CDE4E801FFF7D     False    False      True
# ..                                        ...       ...      ...       ...
# 100  F797097BA39F81B05EEC3F251973743CA03CB9B4     False      NaN      True
# 101  F8C241E69061BB450778B7A4CC336FF520469A0A       NaN      NaN     False
# 102  F8D116F01EE0039678998F393FA337C10AD4F4E2       NaN    False     False
# 103  FAA79717FF2C725767E9469350ACECF640E5FCBC     False     True     False
# 104  FD8C682C1F4FDA1E5EC0B760D30875556419BD71       NaN     True     False
#
#     high_pt high_ureum  low_hb low_hematocriet  low_mcv low_plt
# 0       NaN      False    True             NaN    False   False
# 1       NaN       True   False           False    False   False
# 2       NaN      False    True            True     True    True
# 3       NaN       True    True            True     True    True
# 4     False       True    True            True    False   False
# ..      ...        ...     ...             ...      ...     ...
# 100    True      False    True            True    False    True
# 101     NaN       True    True            True    False    True
# 102     NaN       True   False           False    False   False
# 103    True       True    True            True     True   False
# 104     NaN       True    True           False    False    True
#
# [105 rows x 10 columns]

# %%
criteria_cols_lab = [
    'low_hb', 'high_ureum', 'low_hematocriet', 
    'low_mcv', 'high_mcv', 'low_plt', 'high_aptt',
    'high_inr', 'high_pt'
]

# Summary: How many patients have each signal = True
true_counts = df_patient_flags[criteria_cols_lab].sum()
print("\n✅ Number of patients per criterion (True):")
print(true_counts)
# Out:
# ✅ Number of patients per criterion (True):
# low_hb             87
# high_ureum         69
# low_hematocriet    63
# low_mcv            10
# high_mcv           21
# low_plt            24
# high_aptt           8
# high_inr           14
# high_pt            13
# dtype: object

# %%
df_final_complete = pd.merge(
    df_simplified,
    df_patient_flags,
    on='pseudo_id',
    how='left'
)

df_final_complete
# Out:
#                                     pseudo_id  agib_final  gib_final  \
# 0    046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6       False       True
# 1    088C9FD98B8B2CBCB597C17C07AC1845B21F0849       False       True
# 2    0A5645E02FA818D1629926B6BEFA81CF91C25A46       False       True
# 3    0BC512A65442D0BB4B00FBE05E7EA6283E5C11FD       False       True
# 4    0DD73490997F61870C32B3BB7C9CDE4E801FFF7D       False       True
# ..                                        ...         ...        ...
# 100  F797097BA39F81B05EEC3F251973743CA03CB9B4       False       True
# 101  F8C241E69061BB450778B7A4CC336FF520469A0A       False       True
# 102  F8D116F01EE0039678998F393FA337C10AD4F4E2       False       True
# 103  FAA79717FF2C725767E9469350ACECF640E5FCBC       False       True
# 104  FD8C682C1F4FDA1E5EC0B760D30875556419BD71        True       True
#
#      scopie_final  treatment_final  is_seh  is_scopie  scopie_after_seh  \
# 0            True             True    True       True              True
# 1            True             True    True       True             False
# 2            True             True    True       True              True
# 3            True             True    True       True              True
# 4            True             True    True       True              True
# ..            ...              ...     ...        ...               ...
# 100          True             True    True       True              True
# 101          True            False    True      False             False
# 102          True             True    True       True              True
# 103          True             True    True      False             False
# 104          True             True    True       True              True
#
#      signficant_hb_drop_7_days  signficant_hb_drop_7_days_max_min  \
# 0                        False                              False
# 1                        False                               True
# 2                        False                              False
# 3                        False                              False
# 4                        False                              False
# ..                         ...                                ...
# 100                      False                              False
# 101                      False                              False
# 102                      False                              False
# 103                       True                               True
# 104                      False                              False
#
#      sigh_hb_drop_text high_aptt high_inr  high_mcv high_pt high_ureum  \
# 0                 True       NaN     True     False     NaN      False
# 1                 True       NaN      NaN     False     NaN       True
# 2                 True       NaN      NaN     False     NaN      False
# 3                 True       NaN      NaN     False     NaN       True
# 4                 True     False    False      True   False       True
# ..                 ...       ...      ...       ...     ...        ...
# 100               True     False      NaN      True    True      False
# 101               True       NaN      NaN     False     NaN       True
# 102               True       NaN    False     False     NaN       True
# 103               True     False     True     False    True       True
# 104               True       NaN     True     False     NaN       True
#
#      low_hb low_hematocriet  low_mcv low_plt
# 0      True             NaN    False   False
# 1     False           False    False   False
# 2      True            True     True    True
# 3      True            True     True    True
# 4      True            True    False   False
# ..      ...             ...      ...     ...
# 100    True            True    False    True
# 101    True            True    False    True
# 102   False           False    False   False
# 103    True            True     True   False
# 104    True           False    False    True
#
# [105 rows x 20 columns]

# %%
# Add the new column 'bora_hb_ait' to df_final_complete
df_final_complete['bora_hb_ait'] = df_final_complete['pseudo_id'].isin(bora_metrics)

# Verify the result
df_final_complete
# Out:
#                                     pseudo_id  agib_final  gib_final  \
# 0    046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6       False       True
# 1    088C9FD98B8B2CBCB597C17C07AC1845B21F0849       False       True
# 2    0A5645E02FA818D1629926B6BEFA81CF91C25A46       False       True
# 3    0BC512A65442D0BB4B00FBE05E7EA6283E5C11FD       False       True
# 4    0DD73490997F61870C32B3BB7C9CDE4E801FFF7D       False       True
# ..                                        ...         ...        ...
# 100  F797097BA39F81B05EEC3F251973743CA03CB9B4       False       True
# 101  F8C241E69061BB450778B7A4CC336FF520469A0A       False       True
# 102  F8D116F01EE0039678998F393FA337C10AD4F4E2       False       True
# 103  FAA79717FF2C725767E9469350ACECF640E5FCBC       False       True
# 104  FD8C682C1F4FDA1E5EC0B760D30875556419BD71        True       True
#
#      scopie_final  treatment_final  is_seh  is_scopie  scopie_after_seh  \
# 0            True             True    True       True              True
# 1            True             True    True       True             False
# 2            True             True    True       True              True
# 3            True             True    True       True              True
# 4            True             True    True       True              True
# ..            ...              ...     ...        ...               ...
# 100          True             True    True       True              True
# 101          True            False    True      False             False
# 102          True             True    True       True              True
# 103          True             True    True      False             False
# 104          True             True    True       True              True
#
#      signficant_hb_drop_7_days  signficant_hb_drop_7_days_max_min  ...  \
# 0                        False                              False  ...
# 1                        False                               True  ...
# 2                        False                              False  ...
# 3                        False                              False  ...
# 4                        False                              False  ...
# ..                         ...                                ...  ...
# 100                      False                              False  ...
# 101                      False                              False  ...
# 102                      False                              False  ...
# 103                       True                               True  ...
# 104                      False                              False  ...
#
#      high_aptt high_inr high_mcv  high_pt high_ureum low_hb  low_hematocriet  \
# 0          NaN     True    False      NaN      False   True              NaN
# 1          NaN      NaN    False      NaN       True  False            False
# 2          NaN      NaN    False      NaN      False   True             True
# 3          NaN      NaN    False      NaN       True   True             True
# 4        False    False     True    False       True   True             True
# ..         ...      ...      ...      ...        ...    ...              ...
# 100      False      NaN     True     True      False   True             True
# 101        NaN      NaN    False      NaN       True   True             True
# 102        NaN    False    False      NaN       True  False            False
# 103      False     True    False     True       True   True             True
# 104        NaN     True    False      NaN       True   True            False
#
#     low_mcv  low_plt bora_hb_ait
# 0     False    False       False
# 1     False    False        True
# 2      True     True       False
# 3      True     True       False
# 4     False    False        True
# ..      ...      ...         ...
# 100   False     True        True
# 101   False     True        True
# 102   False    False       False
# 103    True    False        True
# 104   False     True       False
#
# [105 rows x 21 columns]

# %%
# Check if any row has all True values (excluding the 'pseudo_id' column)
all_true_row = df_final_complete.drop(columns=['pseudo_id']).all(axis=1)

# Find the rows where all columns are True
patients_with_all_true = df_final_complete[all_true_row]

# Display the result
print(patients_with_all_true)
# Out:
# Empty DataFrame
# Columns: [pseudo_id, agib_final, gib_final, scopie_final, treatment_final, is_seh, is_scopie, scopie_after_seh, signficant_hb_drop_7_days, signficant_hb_drop_7_days_max_min, sigh_hb_drop_text, high_aptt, high_inr, high_mcv, high_pt, high_ureum, low_hb, low_hematocriet, low_mcv, low_plt, bora_hb_ait]
# Index: []
#
# [0 rows x 21 columns]

# %%
# df_final_complete.to_csv('a:/bloeding-met-patientenlijst-gedetailleerd/df_final_complete1.csv', index=False)
    
if path == 'a:/bloeding-met-patientenlijst-gedetailleerd':
    print('bloeding-met-patientenlijst-gedetailleerd')
    file_final = 'df_final_complete2'
    df_final.to_csv(f'{path}/{file_final}.csv', index=False)


if path == 'a:/test-data':
    print('test-data')
    file_final = 'df_final_complete'
    df_final_complete.to_csv(f'{path}/{file_final}.csv')

if path == 'a:/test-date-past-month':
    print('test-date-past-month')
    file_final = 'df_final_complete3'
    df_final_complete.to_csv(f'{path}/{file_final}.csv')


if path == 'a:/test-date-past-month-copy':
    print('test-date-past-month-copy')
    file_final = 'df_final_complete4'
    df_final_complete.to_csv(f'{path}/{file_final}.csv')
