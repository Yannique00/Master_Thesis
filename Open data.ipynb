# %%
import pandas as pd

# Replace 'your_file.csv' with the path to your CSV file
df = pd.read_csv('A:bloeding-nlp-26bf921d-4b78-4f29-9f36-1e0789055f37-2024-11-25-14-49-00/bloeding-nlp-1-q-1.csv')

# Display the first few rows of the dataframe
df
# Out:
#                                      pseudo_id q_1_admission_specialism  \
# 0     00067EE4483868D5C3EEA1E072648CA61959714D                      NaN
# 1     00067EE4483868D5C3EEA1E072648CA61959714D                      NaN
# 2     00067EE4483868D5C3EEA1E072648CA61959714D                      NaN
# 3     00067EE4483868D5C3EEA1E072648CA61959714D                      NaN
# 4     00067EE4483868D5C3EEA1E072648CA61959714D                      NaN
# ...                                        ...                      ...
# 7845  115D46912DEF028BC3E44FBF0764DE776753207E                      NaN
# 7846  115D46912DEF028BC3E44FBF0764DE776753207E                      NaN
# 7847  115D46912DEF028BC3E44FBF0764DE776753207E                      NaN
# 7848  115D46912DEF028BC3E44FBF0764DE776753207E                      NaN
# 7849  115D46912DEF028BC3E44FBF0764DE776753207E                      NaN
#
#      q_1_admission_status q_1_admission_start_date q_1_admission_end_date  \
# ...

# %%
# Replace 'your_file.csv' with the path to your CSV file
df = pd.read_csv('A:bloeding-nlp-26bf921d-4b78-4f29-9f36-1e0789055f37-2024-11-25-14-49-00/bloeding-nlp-metadata.csv')

# Display the first few rows of the dataframe
df.head()
# Out:
#                started             finished  last_data_update  \
# 0  2024-11-25 14:49:00  2024-11-25 14:52:35     1732468531390
#
#           user_email                                        app_version
# 0  Y.vanMegen@mmc.nl  4.12.1-8ce204527d51ffbca0357477343a932d03d8502...

# %%
# Replace 'your_file.csv' with the path to your CSV file
df = pd.read_csv('A:bloeding-nlp-26bf921d-4b78-4f29-9f36-1e0789055f37-2024-11-25-14-49-00/bloeding-nlp-overview.csv')

# Display the first few rows of the dataframe
df
# Out:
#                                     pseudo_id gender  age  year_of_birth  \
# 0    00067EE4483868D5C3EEA1E072648CA61959714D      M   71           1952
# 1    001475FC9851BAC69BED4FE050FC826DF3963111      M   62           1961
# 2    001996233F68CCA1CCD448017C18B725822E91E0      F   22           2002
# 3    001EA214DD839E9E30458FBCA0296513538B847F      M   75           1949
# 4    00267A4BE05605C18DED8A6760AB975CC753DC85      M   60           1964
# ..                                        ...    ...  ...            ...
# 205  110AF06D3545786CF7A917D81F35D96AAC04C97B      F   67           1957
# 206  111132E588F783ED704370919B4186444148163C      F   44           1980
# 207  111BB15D786825F6B365B90E4C8ACB8F919E3F84      F   68           1955
# 208  1158602DC6DA90C85229CB3B097686212B05944B      F   59           1965
# 209  115D46912DEF028BC3E44FBF0764DE776753207E      M   56           1968
#
#        cohort  q_1_collection_count
# 0    Included                    18
# ...
