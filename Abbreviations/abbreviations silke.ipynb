# %%
import pandas as pd
import re

from typing import Dict, Tuple, Union, List
from re import Pattern

import language_tool_python
tool = language_tool_python.LanguageTool('nl')

# %%
# pip install language-tool-python

# %%
# Ensure the required library is installed
# %pip install openpyxl

file_path_abbreviations = "Abbreviations.xlsx"
abbreviations_excel = pd.read_excel(file_path_abbreviations)
abbreviations_excel
# Out:
#      afkorting         betekenis context word in front context word behind  \
# 0         inco     incontinentie                   NaN                 NaN
# 1         Cath          katheter                   NaN                 NaN
# 2         Mw\.           mevrouw                   NaN                 NaN
# 3    i\.v\.m\.    in verband met                   NaN                 NaN
# 4       Haldol      haldoperidol                   NaN                 NaN
# ..         ...               ...                   ...                 ...
# 359       prod         productie                   NaN                 NaN
# 360       tele        telemetrie                   NaN                 NaN
# 361        wkn             weken                   NaN                 NaN
# 362         PA  doktersassistent                   NaN                 NaN
# 363     streef      streefwaarde                   NaN                 NaN
#
#      context word somewhere before context not behind  \
# 0                              NaN                NaN
# 1                              NaN                NaN
# 2                              NaN                NaN
# 3                              NaN                NaN
# 4                              NaN                NaN
# ..                             ...                ...
# 359                            NaN                NaN
# 360                            NaN                NaN
# 361                            NaN                NaN
# 362                            NaN                NaN
# 363                            NaN                NaN
#
#                           other spellings Nederlands woord? Medicatie?  \
# 0                      inco\., inc\., inc               nee        NaN
# 1    catheter, cad, CAD, cateter, kateter               nee        NaN
# 2                   mw, mevr\., mevr, mvr               nee        NaN
# 3                                     ivm               nee        NaN
# 4                                     NaN               nee        NaN
# ..                                    ...               ...        ...
# 359                                   NaN               nee        NaN
# 360                                   NaN               nee        NaN
# 361                                    wk               nee        NaN
# 362                                   NaN                ja        NaN
# 363                                   NaN               nee        NaN
#
#     Uitleg woord
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 359          NaN
# 360          NaN
# 361          NaN
# 362          NaN
# 363          NaN
#
# [364 rows x 10 columns]

# %%
def replacement_dict(abbreviations_df: pd.DataFrame) -> Dict[Pattern, Tuple[str, str]]:
    """
    Create a dictionary of regular expressions for abbreviations based on a DataFrame.

    Args:
        abbreviations_df (pd.DataFrame): DataFrame containing the abbreviations, their meanings, and contexts.

    Returns:
        Dict[Pattern, Tuple[str, str]]: A dictionary where the keys are compiled regex patterns and the values are tuples of abbreviation and its meaning.
    """
    abbreviations_dict = {}
    #special_characters = r'/:+'

    for index, row in abbreviations_df.iterrows():
        abbreviation = row['afkorting']
        other_spellings = row['other spellings']
        meaning = row['betekenis']
        context_front = row['context word in front']
        context_behind = row['context word behind']
        context_not_behind = row['context not behind']
        context_somewhere_front = row['context word somewhere before']
        #context_not_somewhere_front = row['context not somewhere before']
        dutch_word = row['Nederlands woord?']

        all_words = []
        if isinstance(abbreviation, str):
            if dutch_word != 'nee':
                 all_words.append(abbreviation)
            else:
                all_words.append(abbreviation.lower())
        if isinstance(other_spellings, str):
            all_words += [spelling.lower() for spelling in other_spellings.split(", ")]

        # Iterate over each word in all_words
        for word in all_words:
            # Check if the word is "+/-"
            if word == "+/-":
                pattern = r'\+/-'
                # Compile the regex pattern and add it to the abbreviations_dict
                abbreviations_dict[re.compile(pattern)] = (word, meaning)
                continue
            elif word == "+-":
                pattern = r'\+-'
                # Compile the regex pattern and add it to the abbreviations_dict
                abbreviations_dict[re.compile(pattern)] = (word, meaning)
                continue
            elif "->" in word:
                pattern = rf'({re.escape("->")}|{re.escape("-->")})'
                # Compile the regex pattern and add it to the abbreviations_dict
                abbreviations_dict[re.compile(pattern)] = (word, meaning)
                continue
            elif word == ">":
                pattern = rf'(?<!-)+{word}'
                # Compile the regex pattern and add it to the abbreviations_dict
                abbreviations_dict[re.compile(pattern)] = (word, meaning)
                continue
            elif word == "x-":
                pattern = rf'{word}\w+'
                # Compile the regex pattern and add it to the abbreviations_dict
                abbreviations_dict[re.compile(pattern)] = (word, meaning)
                continue
            elif "#" in word:
                pattern = rf'{word}\b'
                # Compile the regex pattern and add it to the abbreviations_dict
                abbreviations_dict[re.compile(pattern)] = (word, meaning)
                continue
            else:
                # If not, use the word as is for the pattern
                pattern = word

            # Handle context-based regular expressions
            if isinstance(context_somewhere_front, str):
                pattern = rf'((?<!\w){re.escape(context_somewhere_front.lower())})?\s*{re.escape(word)}\b'
            #elif isinstance(context_not_somewhere_front, str):
            #    pattern = rf'{word}(?!.*?(?<!\w){context_not_somewhere_front.lower()})'
            elif isinstance(context_behind, str) and isinstance(context_front, str):
                if context_behind == '[getal]' and context_front == '[getal]':
                    if isinstance(context_not_behind, str):
                        pattern = rf'(\d+){pattern}(\d+)(?! ?{context_not_behind})(?!\w)'
                    else: 
                        pattern = rf'(\d+){pattern}(\d+)'
                elif context_behind == '[getal]':
                    if isinstance(context_not_behind, str):
                        pattern = rf'(?<!\w){re.escape(context_front)}{pattern}(\d+)(?! ?{context_not_behind})(?!\w)'
                    else:
                        pattern = rf'(?<!\w){re.escape(context_front)}{pattern}(\d+)(?!\w)'
                elif context_front == '[getal]':
                    if isinstance(context_not_behind, str):
                        pattern = rf'(?<!\w)(\d+){pattern}{re.escape(context_behind)}(?! ?{context_not_behind})(?!\w)'
                    else:
                        pattern = rf'(?<!\w)(\d+){pattern}{re.escape(context_behind)}(?!\w)'
                else:
                    if isinstance(context_not_behind, str):
                        pattern = rf'(?<!\w){re.escape(context_front)} {pattern} {re.escape(context_behind)}(?! ?{context_not_behind})(?!\w)'
                    else:
                        pattern = rf'(?<!\w){re.escape(context_front)} {pattern} {re.escape(context_behind)}(?!\w)'
            elif isinstance(context_behind, str):
                if context_behind == '[getal]':
                    if isinstance(context_not_behind, str):
                        pattern = rf'(?<!\w){pattern}(\d+)(?! ?{context_not_behind})(?!\w)'
                    else:
                        pattern = rf'(?<!\w){pattern}(\d+)(?!\w)'
                else:
                    if isinstance(context_not_behind, str):
                        pattern = rf'(?<!\w){pattern} {re.escape(context_behind)}(?! ?{context_not_behind})(?!\w)'
                    else:
                        pattern = rf'(?<!\w){pattern} {re.escape(context_behind)}(?!\w)'
            elif isinstance(context_front, str):
                if context_front == '[getal]':
                    if isinstance(context_not_behind, str):
                        pattern = rf'(?<!\w)(\d+){pattern}(?! ?{context_not_behind})(?!\w)'
                    else:
                        pattern = rf'(?<!\w)(\d+){pattern}(?!\w)'
                else:
                    if isinstance(context_not_behind, str):
                        pattern = rf'(?<!\w){re.escape(context_front)} {pattern}(?! ?{context_not_behind})(?!\w)'
                    else:
                        pattern = rf'(?<!\w){re.escape(context_front)} {pattern}(?!\w)'
            else:
                if isinstance(context_not_behind, str):
                    pattern = rf'(?<!\w){pattern}(?! ?{context_not_behind})(?!\w)'
                else:
                    pattern = rf'(?<!\w){pattern}(?!\w)'

            # Compile the regex pattern and add it to the abbreviations_dict
            abbreviations_dict[re.compile(pattern)] = (word, meaning)

    return abbreviations_dict

# %%
abbreviations_dict = replacement_dict(abbreviations_excel)

# %%
# Function to replace the abbreviations in the text

def replace_abbreviations(text: str, abbreviations_dict: Dict[Pattern, Tuple[str, str]]) -> str:

    """

    Replace abbreviations in the text with their meanings based on the provided dictionary.

 

    Args:

        text (str): The input text containing abbreviations.

        abbreviations_dict (Dict[Pattern, Tuple[str, str]]): Dictionary of regex patterns and their corresponding abbreviation and meaning.

 

    Returns:

        str: The text with abbreviations replaced by their meanings.

    """

    matched_patterns = []

    matched_patterns_lower = []

    for pattern, (abbreviation, meaning) in abbreviations_dict.items():

        if isinstance(meaning, str) and isinstance(text, str):

            matches = re.findall(pattern, text)

            for match in matches:

                if isinstance(match, tuple):

                    meaning = meaning.replace('[getal1]', match[0]).replace('[getal2]', match[1])

                else:

                    try:

                        integer = int(match)

                        meaning = meaning.replace('[getal]', match)

                    except:

                        meaning = meaning.replace('[woord]', re.sub(r'^x-', '', match))

                matched_patterns.append((match, meaning))

            text = re.sub(pattern, meaning, text)

    for pattern, (abbreviation, meaning) in abbreviations_dict.items():

        if isinstance(meaning, str) and isinstance(text, str):

            matches = re.findall(pattern, text.lower())

            for match in matches:

                if isinstance(match, tuple):

                    meaning = meaning.replace('[getal1]', match[0]).replace('[getal2]', match[1])

                else:

                    try:

                        integer = int(match)

                        meaning = meaning.replace('[getal]', match)

                    except:

                        meaning = meaning.replace('[woord]', re.sub(r'^x-', '', match))

                matched_patterns_lower.append((match, meaning))

            text = re.sub(pattern, meaning, text.lower())

    return text

# %%
# df = pd.read_csv('a:/df_cleaned.csv')
df = pd.read_csv('a:/bloeding-met-patientenlijst-gedetailleerd/bloeding-met-patientenlijst-4-verslagen.csv')
# df = pd.read_csv('a:/test-data/bloeding-met-patientenlijst-copy-4-verslagen.csv')
df.head()
# Out:
#                                   pseudo_id             verslagen_report_tags  \
# 0  046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6                   Klinische Brief
# 1  046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6  Consult, Kliniek: vervolgconsult
# 2  046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6               Poliklinische Brief
# 3  046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6               Poliklinische Brief
# 4  046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6  Consult, Kliniek: vervolgconsult
#
#                             verslagen_report_content  \
# 0  Dhr. A.J. Dingemans, huisarts\r\n[STREETNAME] ...
# 1  Samenvatting: \nRectaal bloedverlies obv diver...
# 2  COLOSCOPIE\r\n\r\nBetreft\r\nMw. [INITIALS] [L...
# 3  GASTROSCOPIE\r\n\r\nBetreft\r\nMw. [INITIALS] ...
# 4  Samenvatting: \nRectaal bloedverlies ; eenmali...
#
#    verslagen_report_age_at_time_of_event   verslagen_report_specialism  \
# 0                                     87  Maag-, Darm- en Leverziekten
# 1                                     87  Maag-, Darm- en Leverziekten
# 2                                     87  Maag-, Darm- en Leverziekten
# 3                                     87  Maag-, Darm- en Leverziekten
# 4                                     87  Maag-, Darm- en Leverziekten
#
#   verslagen_report_start_date
# 0         2020-11-26 15:06:00
# 1         2020-11-26 09:53:00
# 2         2020-11-25 14:13:00
# 3         2020-11-25 13:48:00
# 4         2020-11-25 08:47:00

# %%
print("abbreviations_dict:", abbreviations_dict)
# Out:
# abbreviations_dict: {re.compile('(?<!\\w)inco(?!\\w)'): ('inco', 'incontinentie'), re.compile('(?<!\\w)inco\\.(?!\\w)'): ('inco\\.', 'incontinentie'), re.compile('(?<!\\w)inc\\.(?!\\w)'): ('inc\\.', 'incontinentie'), re.compile('(?<!\\w)inc(?!\\w)'): ('inc', 'incontinentie'), re.compile('(?<!\\w)cath(?!\\w)'): ('cath', 'katheter'), re.compile('(?<!\\w)catheter(?!\\w)'): ('catheter', 'katheter'), re.compile('(?<!\\w)cad(?!\\w)'): ('cad', 'katheter'), re.compile('(?<!\\w)cateter(?!\\w)'): ('cateter', 'katheter'), re.compile('(?<!\\w)kateter(?!\\w)'): ('kateter', 'katheter'), re.compile('(?<!\\w)mw\\.(?!\\w)'): ('mw\\.', 'mevrouw'), re.compile('(?<!\\w)mw(?!\\w)'): ('mw', 'mevrouw'), re.compile('(?<!\\w)mevr\\.(?!\\w)'): ('mevr\\.', 'mevrouw'), re.compile('(?<!\\w)mevr(?!\\w)'): ('mevr', 'mevrouw'), re.compile('(?<!\\w)mvr(?!\\w)'): ('mvr', 'mevrouw'), re.compile('(?<!\\w)i\\.v\\.m\\.(?!\\w)'): ('i\\.v\\.m\\.', 'in verband met'), re.compile('(?<!\\w)ivm(?!\\w)'): ('ivm', 'in verband met'), re.compile('(?<!\\w)haldol(?!\\w)'): ('haldol', 'haldoperidol'), re.compile('(?<!\\w)med(?!\\w)'): ('med', 'medicatie'), re.compile('(?<!\\w)sat(?!\\w)'): ('sat', 'saturatie'), re.compile('(?<!\\w)up(?!\\w)'): ('up', 'urine productie'), re.compile('(?<!\\w)dyspnoe(?!\\w)'): ('dyspnoe', 'dyspneu'), re.compile('(?<!\\w)sara steady(?!\\w)'): ('sara steady', 'Sara Stedy'), re.compile('(?<!\\w)sara-steady(?!\\w)'): ('sara-steady', 'Sara Stedy'), re.compile('(?<!\\w)sara-stedy(?!\\w)'): ('sara-stedy', 'Sara Stedy'), re.compile('(?<!\\w)sara stedy(?!\\w)'): ('sara stedy', 'Sara Stedy'), re.compile('(?<!\\w)sarah stedy(?!\\w)'): ('sarah stedy', 'Sara Stedy'), re.compile('(?<!\\w)sarah steady(?!\\w)'): ('sarah steady', 'Sara Stedy'), re.compile('(?<!\\w)sarah-steady(?!\\w)'): ('sarah-steady', 'Sara Stedy'), re.compile('(?<!\\w)sarah-stedy(?!\\w)'): ('sarah-stedy', 'Sara Stedy'), re.compile('(?<!\\w)de stedy(?!\\w)'): ('de stedy', 'Sara Stedy'), re.compile('(?<!\\w)de steady(?!\\w)'): ('de steady', 'Sara Stedy'), re.compile('(?<!\\w)tv(?!\\w)'): ('tv', 'televisie'), re.compile('(?<!\\w)ttp(?!\\w)'): ('ttp', 'tijd-plaats-persoon'), re.compile('(?<!\\w)triplo(?!\\w)'): ('triplo', 'tijd-plaats-persoon'), re.compile('(?<!\\w)tpp(?!\\w)'): ('tpp', 'tijd-plaats-persoon'), re.compile('(?<!\\w)t + p(?!\\w)'): ('t + p', 'tijd-plaats-persoon'), re.compile('(?<!\\w)ptt(?!\\w)'): ('ptt', 'tijd-plaats-persoon'), re.compile('(?<!\\w)ah(?!\\w)'): ('ah', 'ademhaling'), re.compile('(?<!\\w)vbi(?!\\w)'): ('vbi', 'vrijheidsbeperkende interventie'), re.compile('(?<!\\w)gb\\.(?!\\w)'): ('gb\\.', 'geen bijzonderheden'), re.compile('(?<!\\w)gb(?!\\w)'): ('gb', 'geen bijzonderheden'), re.compile('(?<!\\w)g.b.(?!\\w)'): ('g.b.', 'geen bijzonderheden'), re.compile('(?<!\\w)HOK(?!\\w)'): ('HOK', 'hoog opgaand klysma'), re.compile('(?<!\\w)zkh(?!\\w)'): ('zkh', 'ziekenhuis'), re.compile('(?<!\\w)pt(?!\\w)'): ('pt', 'patient'), re.compile('(?<!\\w)pt.(?!\\w)'): ('pt.', 'patient'), re.compile('(?<!\\w)(\\d+)vpk(?!\\w)'): ('vpk', '[getal] verpleegkundige'), re.compile('(?<!\\w)(\\d+)verplk(?!\\w)'): ('verplk', '[getal] verpleegkundige'), re.compile('(?<!\\w)(\\d+)vkp(?!\\w)'): ('vkp', '[getal] verpleegkundige'), re.compile('(?<!\\w)(\\d+)verpleegkundigen(?!\\w)'): ('verpleegkundigen', '[getal] verpleegkundige'), re.compile('(?<!\\w)(\\d+)verpl(?!\\w)'): ('verpl', '[getal] verpleegkundige'), re.compile('(?<!\\w)(\\d+)vp(?!\\w)'): ('vp', '[getal] verpleegkundige'), re.compile('(?<!\\w)(\\d+)pvk(?!\\w)'): ('pvk', '[getal] verpleegkundige'), re.compile('(?<!\\w)vpk(?!\\w)'): ('vpk', 'verpleegkundige'), re.compile('(?<!\\w)verplk(?!\\w)'): ('verplk', 'verpleegkundige'), re.compile('(?<!\\w)vkp(?!\\w)'): ('vkp', 'verpleegkundige'), re.compile('(?<!\\w)verpleegkundigen(?!\\w)'): ('verpleegkundigen', 'verpleegkundige'), re.compile('(?<!\\w)verpl(?!\\w)'): ('verpl', 'verpleegkundige'), re.compile('(?<!\\w)vp(?!\\w)'): ('vp', 'verpleegkundige'), re.compile('(?<!\\w)pvk(?!\\w)'): ('pvk', 'verple ...

# %%
# # Apply the function to the first column and store the result in a new column
# df_abbreviations = df.copy()
# # print(df_abbreviations.head())
# df_abbreviations['abbreviations_corrected'] = df['verslagen_report_content'].apply(lambda x: replace_abbreviations(x, abbreviations_dict))

# %%
# df_abbreviations.to_csv('a:/bloeding-met-patientenlijst-gedetailleerd/verslagen-abb-corrected.csv', index=False)
df_abbreviations = pd.read_csv('a:/bloeding-met-patientenlijst-gedetailleerd/verslagen-abb-corrected.csv')

# %%
df_abbreviations.head()
# Out:
#                                   pseudo_id             verslagen_report_tags  \
# 0  046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6                   Klinische Brief
# 1  046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6  Consult, Kliniek: vervolgconsult
# 2  046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6               Poliklinische Brief
# 3  046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6               Poliklinische Brief
# 4  046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6  Consult, Kliniek: vervolgconsult
#
#                             verslagen_report_content  \
# 0  Dhr. A.J. Dingemans, huisarts\r\n[STREETNAME] ...
# 1  Samenvatting: \nRectaal bloedverlies obv diver...
# 2  COLOSCOPIE\r\n\r\nBetreft\r\nMw. [INITIALS] [L...
# 3  GASTROSCOPIE\r\n\r\nBetreft\r\nMw. [INITIALS] ...
# 4  Samenvatting: \nRectaal bloedverlies ; eenmali...
#
#    verslagen_report_age_at_time_of_event   verslagen_report_specialism  \
# 0                                     87  Maag-, Darm- en Leverziekten
# 1                                     87  Maag-, Darm- en Leverziekten
# 2                                     87  Maag-, Darm- en Leverziekten
# 3                                     87  Maag-, Darm- en Leverziekten
# 4                                     87  Maag-, Darm- en Leverziekten
#
#   verslagen_report_start_date  \
# 0         2020-11-26 15:06:00
# 1         2020-11-26 09:53:00
# 2         2020-11-25 14:13:00
# 3         2020-11-25 13:48:00
# 4         2020-11-25 08:47:00
#
#                              abbreviations_corrected
# 0  meneer a.j. dingemans, huisarts\r\n[streetname...
# 1  samenvatting: \nrectaal bloedverlies onder beg...
# 2  coloscopie\r\n\r\nbetreft\r\nmevrouw [initials...
# 3  gastroscopie\r\n\r\nbetreft\r\nmevrouw [initia...
# 4  samenvatting: \nrectaal bloedverlies ; eenmali...

# %%
specific_id = df_abbreviations[df_abbreviations['pseudo_id'] == '046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6']
specific_id['pseudo_id'].unique()
# Out:
# array(['046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6'], dtype=object)

# %%
for i, row in specific_id[specific_id['pseudo_id'].notnull()].iterrows():
    print(f"🩸 Pseudo ID: {row['pseudo_id']}")
    # print(f"🩸 Date: {row['date']}")
    print(f"📜 Content: {row['verslagen_report_content']}")
    print("-------")
    print(f"📜 Corrected: {row['abbreviations_corrected']}")
    print("----------------------------")
# Out:
# 🩸 Pseudo ID: 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 📜 Content: Dhr. A.J. Dingemans, huisarts
# [STREETNAME] NR  [CITY]
#
#
#
#
#
# datum
# 29-11-2020
# kenmerk
# 0007475372 / [PATIENTID]
# BSN nr.
# [BSN]
# betreft
# mevrouw [INITIALS] [LASTNAME], geb. [BIRTHDATE] (87)
# [STREETNAME], [ZIP]  [CITY]
# tel. [PHONENUMBER]
#
#
# Geachte collega,
#
# Bovengenoemde patiënte was opgenomen van 24-11-2020 tot en met 26-11-2020 op de afdeling Maag-, Darm- en Leverziekten in verband met melaena en rectaal bloedverlies.
#
# Voorgeschiedenis
# 2002 Diep veneuze trombose en longembolie
# 2013 Cholecystectomie
# 2015 Diverticulitis
# 2016 Atriumfibrilleren met spontane conversie naar sinusritme
# 2016 Melena, waarvoor geen verklaring werd gevonden. In verband met stabiel Hb en in overleg met patiënte expectatief beleid.
# 2018 Vermoeidheid bij sinusbradycardie waarvoor stop metoprolol en tambocor.
#
# Anamnese
# Vanmiddag rond 13.30u fors helderrood bloedverlies met stolsels. Vermengd met ontlasting, mogelijk was deze zwart van kleur. Sinds 5 dagen zeurende pijn in de bovenbuik; maagpijn, waarvoor ze is gestopt met koffie drinken en vet eten. In de afgelopen dagen wat minder ontlasting, bij ook minder intake, maar geen bloed / zwart verkleuring bemerkt.
# Tractus anamnese: verder niet bijdragend, m.n. geen LW-klachten.
#
# All/ Penicillines -> urticaria
#
# Lichamelijk onderzoek
# Controles:
# SpO2	%	96
# HR	bpm	95
# NIBP	mmHg	132/71(91)
# Temp	°C	37,2
#
# Alg: niet acuut ziek, niet duidelijk anemisch
# H/H: PEARL, geen lymfadenopathie
# Cor: S1S2, geen souffles
# Pulm: VAG beiderzijds, geen bijgeluiden
# Abd: Normale peristaltiek, wisselende tympanie, soepel abdomen, mild drukpijn epigastrio - geen loslaatpijn, Murphy -
# RT: helderrood bloed aan de handschoen, geen feces, geen afwijkingen palpabel, geen hemorroïden
#
# Aanvullend onderzoek
# Laboratorium 24-11-2020
# HEMATOLOGIE: CRP (H): 36 mg/L (< 5), Hemoglobine: 7.8 mmol/L (7.5 - 10.0), Hematocriet: 0.38 L/L (0.35 - 0.45), Erytrocyten: 4.10 x10^12/L (4.00 - 5.00), MCV: 93 fL (80 - 100), Leukocyten: 10.0 x10^9/L (4.0 - 10.0), Trombocyten: 176 x10^9/L (150 - 400)
# Hemostase: APTT (H): 38 sec (25 - 34), PT (H): 39.5 sec (12.1 - 15.6), INR (H): 2.8 (0.8 - 1.2)
# Bloedgroep: Bloedgroep: A neg, IAT: neg. (negatief)
# CHEMIE: Glucose (H): 8.0 mmol/l (4.0 - 7.8), Natrium: 141 mmol/L (135 - 145), Kalium: 4.3 mmol/L (3.5 - 5.0), Ureum (H): 13.2 mmol/L (2.5 - 6.4), Kreatinine: 82 µmol/L (49 - 90), eGFR CKD-EPI (L): 55 ml/m/1.73m^2 (> 90), Bilirubine totaal: 7 µmol/L (< 17), Alkalische Fosfatase (AF) (H): 111 U/L (33 - 98), GGT: 16 U/L (< 38), ASAT: 28 U/L (< 31), ALAT: 18 U/L (< 34), LD: 240 U/L (< 247), Lipase: 28 U/L (13 - 60), Albumine: 35 g/L (35 - 50)
#
# Gastroscopie 25-11-2020
# Geen bloed of bloedingsbron bij gastroscopie.
#
# Coloscopie 25-11-2020
# Coloscopie tot in het colon ascendens.
# Lange darm, scopie tot bij de klep. Bloeding gestopt, geen bloedingsbron gevonden. Pandiverticulose maar vooral in sigmoid. Waarschijnlijkheidsdiagnose is divertikelbloeding
#
# Laboratorium 26-11-2020
# HEMATOLOGIE: Hemoglobine (L): 6.8 mmol/L (7.5 - 10.0), MCV: 97 fL (80 - 100)
#
# Beloop
# De patiënte werd op 24-11-2020 opgenomen in verband met melaena en hierbij ook helderrood rectaal bloedverlies onder acenocoumarol. De acenocoumarol werd gestaakt en gecoupeerd. Bij een verdenking van zowel hoge als lage tractus digestivus bloeding werd er gestart met een pantoprazol perfusor en werd de patiënte voorbereid voor zowel een gastro- als coloscopie. Gedurende de avond werd de patiënte na nogmaals fors melaena gehad te hebben hypotensief (RR 100/58) waarvoor er een 1L infuus werd gestart. De patiënte had hierbij geen klachten. De volgende dag kreeg de patiënte zowel de gasto- als coloscopie waarop uitgebreide diverticulose gezien werd en geen actieve bloedingsbron waardoor de werkdiagnose divertikelbloeding werd. Op de coloscopie kon de coecumbodem niet volledig beoordeeld worden. Dit hebben we met de patiënte en familie besproken, theoretisch zou hier een coecumproces kunnen zitten echter is deze kans klein omdat caecum redelijk te overzien was. Hiervoor zou nog een CT-colografie gemaakt kunnen worden echter in samenspraak met de patiënte en familie werd hiervan afgezien. Na de endoscopieën is er geen rectaal bloedverlies meer waargenomen.
# Op 26-11-2020 kon de patiënte in goede conditie met ontslag naar huis.
#
# Medicatie
# Latanoprost oogdruppel 50ug/ml minim 0,2ml; oog; 1 x per dag 1 druppel in beide ogen
# Hyaluronzuur oogdruppels 1mg/ml fl 10ml; oog; zo nodig 4 x per dag 1 druppel
# Acenocoumarol tablet 1mg; oraal; 1 x per dag volgens trombosedienst
# Macrogol/zouten pdr v drank (movicolon+generiek); oraal; 1 x per dag 1 stuk
# Furosemide tablet 20mg; oraal; 1 x per dag 1 stuk tijdelijk gestopt
# Metoclopramide tablet 10mg; oraal; zo nodig 3 x per dag 1 stuk
#
# Behandelbeperking
# Gekozen behandelbeperking: Reanimeren: nee IC opname: niet beslist Beademen: nee
#
#
# Conclusie
# 1. Divertikelbloeding onder acenocoumarol.
# 2. Gedurende opname meermaals hypotensie (tot RR 94/52) zonder klachten.
#
# Beleid
# Ad1: - Acenocoumarol 26-11 in eigen dosering hervatten
# Ad2: - Furosemide tijdelijk gestaakt i.v.m. lage tensies, patiënte meet 27-11 de bloeddruk thuis overnieuw en neemt hierover contact met u op.
#
# Met vriendelijke groet,
#
#
# L. Bukkems, semi-arts maag-darm-leverziekten
#
# Met vriendelijke groet,
#
# J.T. Kamphuis, maag-darm-leverarts
# AGB: 03018377
#
# Deze brief is elektronisch geaccordeerd en daarom niet ondertekend.
# -------
# 📜 Corrected: meneer a.j. dingemans, huisarts
# [streetname] nr  [city]
#
#
#
#
#
# datum
# 29-11-2020
# kenmerk
# 0007475372 / [patientid]
# bsn nr.
# [bsn]
# betreft
# mevrouw [initials] [lastname], geen bijzonderheden [birthdate] (87)
# [streetname], [zip]  [city]
# tel. [phonenumber]
#
#
# geachte collega,
#
# bovengenoemde patiënte was opgenomen van 24-11-2020 tot en met 26-11-2020 op de afdeling maag-, darm- en leverziekten in verband met melaena en rectaal bloedverlies.
#
# voorgeschiedenis
# 2002 diep veneuze trombose en longembolie
# 2013 cholecystectomie
# 2015 diverticulitis
# 2016 atriumfibrilleren met spontane conversie naar sinusritme
# 2016 melena, waarvoor geen verklaring werd gevonden. in verband met stabiel hemoglobine en in overleg met patiënte expectatief beleid.
# 2018 vermoeidheid bij sinusbradycardie waarvoor stop metoprolol en tambocor.
#
# anamnese
# vanmiddag rond 13.30 uur fors helderrood bloedverlies met stolsels. vermengd met ontlasting, mogelijk was deze zwart van kleur. sinds 5 dagen zeurende pijn in de bovenbuik; maagpijn, waarvoor ze is gestopt met koffie drinken en vet eten. in de afgelopen dagen wat minder ontlasting, bij ook minder intake, maar geen bloed / zwart verkleuring bemerkt.
# tractus anamnese: verder niet bijdragend, m.n. geen lw-klachten.
#
# all/ penicillines -> urticaria
#
# lichamelijk onderzoek
# controles:
# perifere zuurstofsaturatie	%	96
# hartfrequentie	bpm	95
# nibp	mmhg	132/71(91)
# temperatuur	°c	37,2
#
# alg: niet acuut ziek, niet duidelijk anemisch
# h/h: pearl, geen lymfadenopathie
# cor: s1s2, geen souffles
# pulm: vag beiderzijds, geen bijgeluiden
# abd: normale peristaltiek, wisselende tympanie, soepel abdomen, mild drukpijn epigastrio - geen loslaatpijn, murphy -
# rt: helderrood bloed aan de handschoen, geen feces, geen afwijkingen palpabel, geen hemorroïden
#
# aanvullend onderzoek
# laboratorium 24-11-2020
# hematologie: c-reactieve proteine (h): 36 mg/l (minder dan 5), hemoglobine: 7.8 mmol/l (7.5 - 10.0), hematocriet: 0.38 l/l (0.35 - 0.45), erytrocyten: 4.10 x10^12/l (4.00 - 5.00), mcv: 93 fl (80 - 100), leukocyten: 10.0 x10^9/l (4.0 - 10.0), trombocyten: 176 x10^9/l (150 - 400)
# hemostase: aptt (h): 38 sec (25 - 34), patient (h): 39.5 sec (12.1 - 15.6), inr stollingswaarde (h): 2.8 (0.8 - 1.2)
# bloedgroep: bloedgroep: a neg, iat: neg. (negatief)
# chemie: glucose (h): 8.0 mmol/l (4.0 - 7.8), natrium: 141 mmol/l (135 - 145), kalium: 4.3 mmol/l (3.5 - 5.0), ureum (h): 13.2 mmol/l (2.5 - 6.4), kreatinine: 82 µmol/l (49 - 90), egfr ckd-epiduraal (l): 55 ml/m/1.73m^2 (> 90), bilirubine totaal: 7 µmol/l (minder dan 17), alkalische fosfatase (atrium fibilaire) (h): 111 u/l (33 - 98), ggt: 16 u/l (minder dan 38), asat: 28 u/l (minder dan 31), alat: 18 u/l (minder dan 34), ld: 240 u/l (minder dan 247), lipase: 28 u/l (13 - 60), albumine: 35 g/l (35 - 50)
#
# gastroscopie 25-11-2020
# geen bloed of bloedingsbron bij gastroscopie.
#
# coloscopie 25-11-2020
# coloscopie tot in het colon ascendens.
# lange darm, scopie tot bij de klep. bloeding gestopt, geen bloedingsbron gevonden. pandiverticulose maar vooral in sigmoid. waarschijnlijkheidsdiagnose is divertikelbloeding
#
# laboratorium 26-11-2020
# hematologie: hemoglobine (l): 6.8 mmol/l (7.5 - 10.0), mcv: 97 fl (80 - 100)
#
# beloop
# de patiënte werd op 24-11-2020 opgenomen in verband met melaena en hierbij ook helderrood rectaal bloedverlies onder acenocoumarol. de acenocoumarol werd gestaakt en gecoupeerd. bij een verdenking van zowel hoge als lage tractus digestivus bloeding werd er gestart met een pantoprazol perfusor en werd de patiënte voorbereid voor zowel een gastro- als coloscopie. gedurende de avond werd de patiënte na nogmaals fors melaena gehad te hebben hypotensief (bloeddruk 100/58) waarvoor er een 1l infuus werd gestart. de patiënte had hierbij geen klachten. de volgende dag kreeg de patiënte zowel de gasto- als coloscopie waarop uitgebreide diverticulose gezien werd en geen actieve bloedingsbron waardoor de werkdiagnose divertikelbloeding werd. op de coloscopie kon de coecumbodem niet volledig beoordeeld worden. dit hebben we met de patiënte en familie besproken, theoretisch zou hier een coecumproces kunnen zitten echter is deze kans klein omdat caecum redelijk te overzien was. hiervoor zou nog een ct-scan-colografie gemaakt kunnen worden echter in samenspraak met de patiënte en familie werd hiervan afgezien. na de endoscopieën is er geen rectaal bloedverlies meer waargenomen.
# op 26-11-2020 kon de patiënte in goede conditie met ontslag naar huis.
#
# medicatie
# latanoprost oogdruppel 50ug/ml minim 0,2ml; oog; 1 x per dag 1 druppel in beide ogen
# hyaluronzuur oogdruppels 1mg/ml fl 10ml; oog; zo nodig 4 x per dag 1 druppel
# acenocoumarol tablet 1mg; oraal; 1 x per dag volgens trombosedienst
# macrogol/zouten pdr v drank (movicolon+generiek); oraal; 1 x per dag 1 stuk
# furosemide tablet 20mg; oraal; 1 x per dag 1 stuk tijdelijk gestopt
# metoclopramide tablet 10mg; oraal; zo nodig 3 x per dag 1 stuk
#
# behandelbeperking
# gekozen behandelbeperking: reanimeren: nee inter collegiaal consult opname: niet beslist beademen: nee
#
#
# conclusie
# 1. divertikelbloeding onder acenocoumarol.
# 2. gedurende opname meermaals hypotensie (tot bloeddruk 94/52) zonder klachten.
#
# beleid
# ad1: - acenocoumarol 26-11 in eigen dosering hervatten
# ad2: - furosemide tijdelijk gestaakt in verband met lage tensies, patiënte meet 27-11 de bloeddruk thuis overnieuw en neemt hierover contact met u op.
#
# met vriendelijke groet,
#
#
# l. bukkems, semi-arts maag-darm-leverziekten
#
# met vriendelijke groet,
#
# j.t. kamphuis, maag-darm-leverarts
# agb: 03018377
#
# deze brief is elektronisch geaccordeerd en daarom niet ondertekend.
# ----------------------------
# 🩸 Pseudo ID: 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 📜 Content: Samenvatting:
# Rectaal bloedverlies obv divertikelbloeding; onder acenocoumarol (wegens AF), gecoupeerd. Op colo pandiverticulose.
#
#
# Beloop:
# Vpk/
# Geen rectaal bloedverlies meer gehad. Voelt zich goed, geen klachten van lage tensie. Wil graag naar huis. Goed gegeten vanochtend, hierbij geen klachten.
#
# Aan bed/
# Geen klachten meer, goed gevoel over naar huis gaan. Geen bloed meer gezien.
# Met patiënte en schoondochter de uitslag van de coloscopie nog eens besproken. Aangegeven dat de coecum bodem niet volledig in beeld is kunnen brengen, wel grodendeels echter dat een caecumproces niet volledig uitgesloten kan worden. Als de pte hier ongerust over zou zijn zou zij hier een CT-colografie van kunnen laten. Pte en schoondochter geven aan dat ze hier niet ongerust over zijn en dat dit niet hoeft. Aangegeven dat mochten ze zich bedenken ze altijd terug kunnen bellen.
#
#
# Lichamelijk onderzoek:
# HD stabiel, geen koorts. RR wel aan lage kant, 94/52 dus furosemide niet gegeven
#
#
# Conclusie:
# Geen bloedverlies meer waargenomen. Klinisch goed, vandaag met ontslag.
# Wegens hypotensie furosemide niet gegeven en geadviseerd de tensie thuis op te volgen
#
#
# Beleid:
# Iom dr. Kamphuis
# - Acenocoumarol eigen dosering hervatten
# - Nog uitleg geven aan zoon + pte over coecum bodem
# - In brief naar huisarts tensiecontrole vermelden
# -------
# 📜 Corrected: samenvatting:
# rectaal bloedverlies onder begeleiding van divertikelbloeding; onder acenocoumarol (wegens atrium fibilaire), gecoupeerd. op colo pandiverticulose.
#
#
# beloop:
# verpleegkundige/
# geen rectaal bloedverlies meer gehad. voelt zich goed, geen klachten van lage bloeddruk. wil graag naar huis. goed gegeten vanochtend, hierbij geen klachten.
#
# aan bed/
# geen klachten meer, goed gevoel over naar huis gaan. geen bloed meer gezien.
# met patiënte en schoondochter de uitslag van de coloscopie nog eens besproken. aangegeven dat de coecum bodem niet volledig in beeld is kunnen brengen, wel grodendeels echter dat een caecumproces niet volledig uitgesloten kan worden. als de patient hier ongerust over zou zijn zou zij hier een ct-scan-colografie van kunnen laten. patient en schoondochter geven aan dat ze hier niet ongerust over zijn en dat dit niet hoeft. aangegeven dat mochten ze zich bedenken ze altijd terug kunnen bellen.
#
#
# lichamelijk onderzoek:
# hd stabiel, geen koorts. bloeddruk wel aan lage kant, 94/52 dus furosemide niet gegeven
#
#
# conclusie:
# geen bloedverlies meer waargenomen. klinisch goed, vandaag met ontslag.
# wegens hypotensie furosemide niet gegeven en geadviseerd de bloeddruk thuis op te volgen
#
#
# beleid:
# in overleg met dokter kamphuis
# - acenocoumarol eigen dosering hervatten
# - nog uitleg geven aan zoon + patient over coecum bodem
# - in brief naar huisarts tensiecontrole vermelden
# ----------------------------
# 🩸 Pseudo ID: 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 📜 Content: COLOSCOPIE
#
# Betreft
# Mw. [INITIALS] [LASTNAME]
# Adresgegevens:
# [STREETNAME], [ZIP]  [CITY]
# Geboortedatum:
# [BIRTHDATE]
# ASA classificatie:
# 3
# Verwijzer:
# J.T. Kamphuis
# Indicatie:
# bloedverlies-rectaal. Melena en bloedverlies per anum onder acenocoumarol. Afwijkingen?.
# TOP verricht
# Ja
# Informed consent:
# ja
# Endoscoop:
#
#
#
#
# Geachte collega,
#
# Bij uw patiënt werd op 25-11-2020 een coloscopie uitgevoerd.
# Indicatie: bloedverlies-rectaal. Melena en bloedverlies per anum onder acenocoumarol. Afwijkingen?.
#
# Toegediende medicatie:
# Midazolam 3 mg
# Fentanyl 0,05 mg
# Fentanyl 0,025 mg
#
# Introductie:
# Intubatie heeft plaatsgevonden tot in het colon ascendens. Verder opvoeren lukt niet door uitbochten endoscoop.
# De Boston Bowel Preparation score is 9 (3-3-3).
# Terugtrektijd: 6 min.
# Patiëntcomfort: mild ongemak, tijdens de procedure meer dan twee voorvallen van ongemak, voldoende te verdragen.
#
# Voorbereiding:
# Gelaxeerd. Nuchter.
#
#
# Verslag:
# RT: Geen afwijkingen.
# Introductie door lange bochtige darm tot bij de klep; ondanks buikcompressie, verschillende houdingen en introductie van volledige scoop lukt het niet om de caecumbodem te bereiken.
# Nergens bloed of bloedingsbron.
# Pandiverticulose maar vooral in sigmoid.
# Geen poliep of tumor of inflammatie.
# In rectum en bij inversie geen afwijkingen..
#
#
#
# Conclusie:
# Coloscopie tot in het colon ascendens.
# Lange darm, scopie tot bij de klep. Bloeding gestopt, geen bloedingsbron gevonden.
# Waarschijnlijkheidsdiagnose is divertikelbloeding
#
#
# Advies:
# Gegevens van gastro- en coloscopie zo accepteren met waarschijnlijkheidsdiagnose divertikelbloeding of toch nog uitsluiten caecumproces m.b.t. CT-colografie (kans klein dat hier een afwijking is omdat caecum grotendeels wel te overzien was). Te bespreken met patiënte, kan poliklinisch.
# -------
# 📜 Corrected: coloscopie
#
# betreft
# mevrouw [initials] [lastname]
# adresgegevens:
# [streetname], [zip]  [city]
# geboortedatum:
# [birthdate]
# asa classificatie:
# 3
# verwijzer:
# j.t. kamphuis
# indicatie:
# bloedverlies-rectaal. melena en bloedverlies per anum onder acenocoumarol. afwijkingen?.
# top verricht
# ja
# informed consent:
# ja
# endoscoop:
#
#
#
#
# geachte collega,
#
# bij uw patiënt werd op 25-11-2020 een coloscopie uitgevoerd.
# indicatie: bloedverlies-rectaal. melena en bloedverlies per anum onder acenocoumarol. afwijkingen?.
#
# toegediende medicatie:
# midazolam 3 mg
# fentanyl 0,05 mg
# fentanyl 0,025 mg
#
# introductie:
# intubatie heeft plaatsgevonden tot in het colon ascendens. verder opvoeren lukt niet door uitbochten endoscoop.
# de boston bowel preparation score is 9 (3-3-3).
# terugtrektijd: 6 min.
# patiëntcomfort: mild ongemak, tijdens de procedure meer dan twee voorvallen van ongemak, voldoende te verdragen.
#
# voorbereiding:
# gelaxeerd. nuchter.
#
#
# verslag:
# rt: geen afwijkingen.
# introductie door lange bochtige darm tot bij de klep; ondanks buikcompressie, verschillende houdingen en introductie van volledige scoop lukt het niet om de caecumbodem te bereiken.
# nergens bloed of bloedingsbron.
# pandiverticulose maar vooral in sigmoid.
# geen poliep of tumor of inflammatie.
# in rectum en bij inversie geen afwijkingen..
#
#
#
# conclusie:
# coloscopie tot in het colon ascendens.
# lange darm, scopie tot bij de klep. bloeding gestopt, geen bloedingsbron gevonden.
# waarschijnlijkheidsdiagnose is divertikelbloeding
#
#
# advies:
# gegevens van gastro- en coloscopie zo accepteren met waarschijnlijkheidsdiagnose divertikelbloeding of toch nog uitsluiten caecumproces met betrekking tot ct-scan-colografie (kans klein dat hier een afwijking is omdat caecum grotendeels wel te overzien was). te bespreken met patiënte, kan poliklinisch.
# ----------------------------
# 🩸 Pseudo ID: 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 📜 Content: GASTROSCOPIE
#
# Betreft
# Mw. [INITIALS] [LASTNAME]
# Adresgegevens:
# [STREETNAME], [ZIP]  [CITY]
# Geboortedatum:
# [BIRTHDATE]
# ASA classificatie:
# 3
# Verwijzer:
# J.T. Kamphuis
# Indicatie:
# Melena en bloedverlies per anum onder acenocoumarol. Afwijkingen?.
# TOP verricht
# Ja
# Informed consent:
# ja
# Endoscoop:
#
#
#
#
# Geachte collega,
#
# Bij uw patiënt werd op 25-11-2020 een gastroscopie uitgevoerd.
# Indicatie: Melena en bloedverlies per anum onder acenocoumarol. Afwijkingen?.
#
# Toegediende medicatie:
# Midazolam 3 mg
# Fentanyl 0,05 mg
#
# Voorbereiding:
# Nuchter.
#
#
# Verslag:
# Slokdarm: Z-lijn en diafragma op 38 en 40 cm, geen oesofagitis of Barrett.
# Maag: atrofisch en rood aspect slijmvlies, geen echte gastritis of ulcera. Normale inversie.
# Duodenum tot in DII: normaal vlokken- en plooien-patroon, geen ulcera, groot duodenum divertikel.
# Nergens bloed..
#
#
#
# Conclusie:
# Geen bloed of bloedingsbron bij gastroscopie..
# -------
# 📜 Corrected: gastroscopie
#
# betreft
# mevrouw [initials] [lastname]
# adresgegevens:
# [streetname], [zip]  [city]
# geboortedatum:
# [birthdate]
# asa classificatie:
# 3
# verwijzer:
# j.t. kamphuis
# indicatie:
# melena en bloedverlies per anum onder acenocoumarol. afwijkingen?.
# top verricht
# ja
# informed consent:
# ja
# endoscoop:
#
#
#
#
# geachte collega,
#
# bij uw patiënt werd op 25-11-2020 een gastroscopie uitgevoerd.
# indicatie: melena en bloedverlies per anum onder acenocoumarol. afwijkingen?.
#
# toegediende medicatie:
# midazolam 3 mg
# fentanyl 0,05 mg
#
# voorbereiding:
# nuchter.
#
#
# verslag:
# slokdarm: zonder-lijn en diafragma op 38 en 40 cm, geen oesofagitis of barrett.
# maag: atrofisch en rood aspect slijmvlies, geen echte gastritis of ulcera. normale inversie.
# duodenum tot in dii: normaal vlokken- en plooien-patroon, geen ulcera, groot duodenum divertikel.
# nergens bloed..
#
#
#
# conclusie:
# geen bloed of bloedingsbron bij gastroscopie..
# ----------------------------
# 🩸 Pseudo ID: 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 📜 Content: Samenvatting:
# Rectaal bloedverlies ; eenmalig ; HD en Hb-stabiel ; INR 2.8 ; wd divertikelbloeding dd toch maagulcus (gezien pijn epigastrio, mogelijk zwarte ontlasting en ureum 13).  Onder acenocoumarol, gecoupeerd
#
#
# Beloop:
# Vpk/
# Gisteravond melena gehad, vannacht donkerrood bloedverlies gehad. Geen stolsels. Had gisteravond ook pijnklachten van maag gehad, geen pijnstilling meer hiervoor gehad. Voelt zich verder goed.
# Infuus 1L.
#
# Aan bed/
# Voelde zich gisteren plots erg slecht, dacht dat ze doodging, toen opgestaan en naar de keuken gewandeld, hier omgevallen, zegt niet het bewustzijn verloren te hebben echter wel op de grond gevallen. Toen familie gebeld die waren meteen gekomen. Later op de wc lag alles vol bloed.
# Nu gaat het wel weer, geen buikpijnklachten. Net nog naar de wc gehad waarbij ook weer bloed zat.
#
#
# Lichamelijk onderzoek:
# Nu HD stabiel, echter vannacht wel tensiedaling wv 1L infuus.
# Geen koorts
#
#
# Aanvullend onderzoek:
# Lab
# Hemoglobine	6.4	mmol/L
# MCV	93	fL
# INR	1.6
#
# Gastroscopie
# Geen bloed of bloedingsbron bij gastroscopie
#
# Coloscopie
# Coloscopie tot in het colon ascendens.
# Lange darm, scopie tot bij de klep. Bloeding gestopt, geen bloedingsbron gevonden.
# Waarschijnlijkheidsdiagnose is divertikelbloeding. Pandiverticulose.
#
#
# Conclusie:
# Rectaal bloedverlies waarschijnlijk obv divertikelbloeding
#
#
# Beleid:
# iom dr. Kamphuis
# - Gastro/colo vandaag
# - Morgen Hb controle =@
# - Uitslag vertelt aan pte en zoon
#
#
# Beleid:
# Opdrachten aan verpleegkundigen: VOD 27-11 (Voltooid)
# ews 3dd (Voltooid)
# -------
# 📜 Corrected: samenvatting:
# rectaal bloedverlies ; eenmalig ; hd en hemoglobine-stabiel ; inr stollingswaarde 2.8 ; wd divertikelbloeding dienstdoende toch maagulcus (gezien pijn epigastrio, mogelijk zwarte ontlasting en ureum 13).  onder acenocoumarol, gecoupeerd
#
#
# beloop:
# verpleegkundige/
# gisteravond melena gehad, vannacht donkerrood bloedverlies gehad. geen stolsels. had gisteravond ook pijnklachten van maag gehad, geen pijnstilling meer hiervoor gehad. voelt zich verder goed.
# infuus 1l.
#
# aan bed/
# voelde zich gisteren plots erg slecht, dacht dat ze doodging, toen opgestaan en naar de keuken gewandeld, hier omgevallen, zegt niet het bewustzijn verloren te hebben echter wel op de grond gevallen. toen familie gebeld die waren meteen gekomen. later op de wc lag alles vol bloed.
# nu gaat het wel weer, geen buikpijnklachten. net nog naar de wc gehad waarbij ook weer bloed zat.
#
#
# lichamelijk onderzoek:
# nu hd stabiel, echter vannacht wel tensiedaling waarvoor 1l infuus.
# geen koorts
#
#
# aanvullend onderzoek:
# lab
# hemoglobine	6.4	mmol/l
# mcv	93	fl
# inr stollingswaarde	1.6
#
# gastroscopie
# geen bloed of bloedingsbron bij gastroscopie
#
# coloscopie
# coloscopie tot in het colon ascendens.
# lange darm, scopie tot bij de klep. bloeding gestopt, geen bloedingsbron gevonden.
# waarschijnlijkheidsdiagnose is divertikelbloeding. pandiverticulose.
#
#
# conclusie:
# rectaal bloedverlies waarschijnlijk onder begeleiding van divertikelbloeding
#
#
# beleid:
# in overleg met dokter kamphuis
# - gastro/colo vandaag
# - morgen hemoglobine controle =@
# - uitslag vertelt aan patient en zoon
#
#
# beleid:
# opdrachten aan verpleegkundige: voorlopige ontslagdatum 27-11 (voltooid)
# early warning score 3dd (voltooid)
# ----------------------------
# 🩸 Pseudo ID: 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 📜 Content: Medisch beeld is beschikbaar.
# LET OP!! Binnen HiX niet geschikt voor diagnostiek
# -------
# 📜 Corrected: medisch beeld is beschikbaar.
# let op!! binnen hix niet geschikt voor diagnostiek
# ----------------------------
# 🩸 Pseudo ID: 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 📜 Content: Beloop:
# Verpleging belt:
# Patiënte heeft nog 2x forse hoeveelheid melena gehad.
# Hierbij ook tensie daling naar RR 100/58 mm Hg, kwam van RR 131/69 mm Hg.
#
# B/
# - Hb + INR controle.
# - Start infuus: 1L NaCl 0.9%.
# - PM: beriplex.
#
#
# 21.30u:
# Hb 8.2
# INR 2.5
#
# B/
# - Geen actie voor nu.
#
#
# 23.00u
# RR 103/51 mm Hg.
# Nu waterdunne ontlasting vermengd met bloedverlies.
#
# B/
# - Zo door.
# - Laagdrempelig opnieuw contact.
# -------
# 📜 Corrected: beloop:
# verpleging belt:
# patiënte heeft nog 2 keer forse hoeveelheid melena gehad.
# hierbij ook bloeddruk daling naar bloeddruk 100/58 mm hg, kwam van bloeddruk 131/69 mm hg.
#
# ademhaling:
# - hemoglobine + inr stollingswaarde controle.
# - start infuus: 1l natriumchloride 0.9%.
# - in te toekomst: beriplex.
#
#
# 21.30 uur:
# hemoglobine 8.2
# inr stollingswaarde 2.5
#
# ademhaling:
# - geen actie voor nu.
#
#
# 23.30 uur
# bloeddruk 103/51 mm hg.
# nu waterdunne ontlasting vermengd met bloedverlies.
#
# ademhaling:
# - zo door.
# - laagdrempelig opnieuw contact.
# ----------------------------
# 🩸 Pseudo ID: 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 📜 Content: Dhr. A.J. Dingemans, huisarts
# [STREETNAME] NR  [CITY]
#
#
#
#
#
# datum
# 24-11-2020
# kenmerk
# 0007471629 / [PATIENTID]
# BSN nr.
# [BSN]
# betreft
# mevrouw [INITIALS] [LASTNAME], geb. [BIRTHDATE] (87)
# [STREETNAME], [ZIP]  [CITY]
# tel. [PHONENUMBER]
#
#
# Geachte collega,
#
# Bovengenoemde patiënt bezocht op 24-11-2020 de spoedeisende hulp.
#
# Reden van komst
# RBV
#
# Conclusie
# Bovenstaande 87-jarige patiënte ; o.a. bekend met diverticulose, passagère melena e.c.i. in 2016 en AF w.v. Acenocoumarol ; wordt beoordeeld op de SEH met nu rectaal bloedverlies.
#
# C/ Rectaal bloedverlies ; eenmalig ; HD en Hb-stabiel ; INR 2.8 ; wd divertikelbloeding dd toch maagulcus (gezien pijn epigastrio, mogelijk zwarte ontlasting en ureum 13).
#
# Beleid
# Op de SEH:
# - 10mg Fytomenadion (vit. K) oraal
# - Pantoprazol 80mg i.v.
#
# Iom dr. Kamphuis MDL:
# - Opname voor MDL ; geen isolatie indicatie
# - Klinisch scopie ; morgen beoordelend colo / gastro of beide
# - Acenocoumarol t.n.o. pauzeren
# - Pantoprazol door op de perfusor
# - Vanavond start voorbereiding scopie middels 500cc Pleinvue
# - Morgen andere 500cc Pleinvue
# - Po-inspectie ; indien meer bloedverlies vanavond Hb en INR controle - evt. Beriplex iom assistent INT
# - Niet reanimeren en beademen op wens patiënt
#
# Anamnese
# Vanmiddag rond 13.30u fors helderrood bloedverlies met stolsels. Vermengd met ontlasting, mogelijk was deze zwart van kleur. Sinds 5 dagen zeurende pijn in de bovenbuik ; maagpijn, waarvoor ze is gestopt met koffie drinken en vet eten. In de afgelopen dagen wat minder ontlasting, bij ook minder intake, maar geen bloed / zwart verkleuring bemerkt.
#
# Tractus anamnese: verder niet bijdragend, m.n. geen LW-klachten.
#
# rVG/
# 2002 Diep veneuze trombose en longembolie
# 2013 Cholecystectomie
# 2015 Diverticulitis. CT-abdomen: diverticulitis, geen maligniteit. Sigmoïdoscopie: geen RIP
# 2016 Atriumfibrilleren met spontane conversie naar sinusritme
# 2016 Melena, waarvoor geen verklaring werd gevonden. In verband met stabiel Hb en in overleg met patiënte expectatief beleid.
# 2018 Vermoeidheid bij sinusbradycardie waarvoor stop metoprolol en tambocor.
#
# Med/ o.a. Acenocoumarol
#
# All/ Penicillines -> urticaria
#
# Lichamelijk onderzoek
# controles:
# SpO2	%	96
# HR	bpm	95
# NIBP	mmHg	132/71(91)
# Temp	°C	37,2
#
# Alg: niet acuut ziek, niet duidelijk anemisch
# H/H: PEARL, geen klieren
# Cor: S1S2, geen souffles
# Pulm: bdz VAG, geen bijgeluiden
# Abd: NP, WT, soepel abdomen, mild drukpijn epigastrio - geen loslaatpijn, Murphy -
# RT: helderrood bloed aan de handschoen, geen feces, geen afwijkingen palpabel, geen hemorroïden
#
# Aanvullend onderzoek
# CRP	36	mg/L
# Hemoglobine	7.8	mmol/L
# Hematocriet	0.38	L/L
# Erytrocyten	4.10	x10^12/L
# MCV	93	fL
# Leukocyten	10.0	x10^9/L
# Trombocyten	176	x10^9/L
# APTT	38	sec
# PT	39.5	sec
# INR	2.8
# Glucose	8.0	mmol/l
# Natrium	141	mmol/L
# Kalium	4.3	mmol/L
# Ureum	13.2	mmol/L
# Kreatinine	82	µmol/L
# eGFR CKD-EPI	55	ml/m/1.73m^2
# Bilirubine totaal	7	µmol/L
# Alkalische Fosfatase (AF)	111	U/L
# GGT	16	U/L
# ASAT	28	U/L
# ALAT	18	U/L
# LD	240	U/L
# Lipase	28	U/L
# Albumine	35	g/L
#
# Medicatie actueel
# Fytomenadion injvlst 10mg/ml (par/oraal) amp 1ml; iv; 1 x per dag 10 milligram
# Latanoprost oogdruppel 50ug/ml minim 0,2ml; oog; 1 x per dag 1 druppel in beide ogen
# Hyaluronzuur oogdruppels 1mg/ml fl 10ml; oog; zo nodig 4 x per dag 1 druppel
# Pantoprazol injectiepoeder 40mg fl; intraveneus continu;  8 mg/uur *pomp 8mg/uur, bolus 80mg in 30 minuten.
# Acenocoumarol tablet 1mg; oraal; 1 x per dag volgens trombosedienst; stopdatum: t.n.o. gestopt
# Furosemide tablet 20mg; oraal; 1 x per dag 1 stuk; stopdatum: t.n.o. gestopt
# Macrogol/zouten pdr v drank (pleinvue); oraal; * volgens voorbereiding scopie ; start vanavond met eerste 500cc
# Macrogol/zouten pdr v drank (movicolon+generiek); oraal; 1 x per dag 1 stuk; stopdatum: t.n.o. gestopt
# -------
# 📜 Corrected: meneer a.j. dingemans, huisarts
# [streetname] nr  [city]
#
#
#
#
#
# datum
# 24-11-2020
# kenmerk
# 0007471629 / [patientid]
# bsn nr.
# [bsn]
# betreft
# mevrouw [initials] [lastname], geen bijzonderheden [birthdate] (87)
# [streetname], [zip]  [city]
# tel. [phonenumber]
#
#
# geachte collega,
#
# bovengenoemde patiënt bezocht op 24-11-2020 de spoedeisende hulp.
#
# reden van komst
# rbv
#
# conclusie
# bovenstaande 87-jarige patiënte ; onder andere bekend met diverticulose, passagère melena e.c.i. in 2016 en atrium fibilaire w.v. acenocoumarol ; wordt beoordeeld op de spoedeisende hulp met nu rectaal bloedverlies.
#
# circulatie: rectaal bloedverlies ; eenmalig ; hd en hemoglobine-stabiel ; inr stollingswaarde 2.8 ; wd divertikelbloeding dienstdoende toch maagulcus (gezien pijn epigastrio, mogelijk zwarte ontlasting en ureum 13).
#
# beleid
# op de spoedeisende hulp:
# - 10mg fytomenadion (vit. kalium) oraal
# - pantoprazol 80mg infuus
#
# in overleg met dokter kamphuis mdl:
# - opname voor mdl ; geen isolatie indicatie
# - klinisch scopie ; morgen beoordelend colo / gastro of beide
# - acenocoumarol tot nader order pauzeren
# - pantoprazol door op de perfusor
# - vanavond start voorbereiding scopie middels 500cc pleinvue
# - morgen andere 500cc pleinvue
# - po-inspectie ; indien meer bloedverlies vanavond hemoglobine en inr stollingswaarde controle - eventueel. beriplex in overleg met assistent internist
# - niet reanimeren en beademen op wens patiënt
#
# anamnese
# vanmiddag rond 13.30 uur fors helderrood bloedverlies met stolsels. vermengd met ontlasting, mogelijk was deze zwart van kleur. sinds 5 dagen zeurende pijn in de bovenbuik ; maagpijn, waarvoor ze is gestopt met koffie drinken en vet eten. in de afgelopen dagen wat minder ontlasting, bij ook minder intake, maar geen bloed / zwart verkleuring bemerkt.
#
# tractus anamnese: verder niet bijdragend, m.n. geen lw-klachten.
#
# rvg/
# 2002 diep veneuze trombose en longembolie
# 2013 cholecystectomie
# 2015 diverticulitis. ct-scan-abdomen: diverticulitis, geen maligniteit. sigmoïdoscopie: geen rip
# 2016 atriumfibrilleren met spontane conversie naar sinusritme
# 2016 melena, waarvoor geen verklaring werd gevonden. in verband met stabiel hemoglobine en in overleg met patiënte expectatief beleid.
# 2018 vermoeidheid bij sinusbradycardie waarvoor stop metoprolol en tambocor.
#
# medicatie/ onder andere acenocoumarol
#
# all/ penicillines -> urticaria
#
# lichamelijk onderzoek
# controles:
# perifere zuurstofsaturatie	%	96
# hartfrequentie	bpm	95
# nibp	mmhg	132/71(91)
# temperatuur	°c	37,2
#
# alg: niet acuut ziek, niet duidelijk anemisch
# h/h: pearl, geen klieren
# cor: s1s2, geen souffles
# pulm: beiderzijds vag, geen bijgeluiden
# abd: np, wt, soepel abdomen, mild drukpijn epigastrio - geen loslaatpijn, murphy -
# rt: helderrood bloed aan de handschoen, geen feces, geen afwijkingen palpabel, geen hemorroïden
#
# aanvullend onderzoek
# c-reactieve proteine	36	mg/l
# hemoglobine	7.8	mmol/l
# hematocriet	0.38	l/l
# erytrocyten	4.10	x10^12/l
# mcv	93	fl
# leukocyten	10.0	x10^9/l
# trombocyten	176	x10^9/l
# aptt	38	sec
# patient	39.5	sec
# inr stollingswaarde	2.8
# glucose	8.0	mmol/l
# natrium	141	mmol/l
# kalium	4.3	mmol/l
# ureum	13.2	mmol/l
# kreatinine	82	µmol/l
# egfr ckd-epiduraal	55	ml/m/1.73m^2
# bilirubine totaal	7	µmol/l
# alkalische fosfatase (atrium fibilaire)	111	u/l
# ggt	16	u/l
# asat	28	u/l
# alat	18	u/l
# ld	240	u/l
# lipase	28	u/l
# albumine	35	g/l
#
# medicatie actueel
# fytomenadion injvlst 10mg/ml (par/oraal) amp 1ml; infuus; 1 x per dag 10 milligram
# latanoprost oogdruppel 50ug/ml minim 0,2ml; oog; 1 x per dag 1 druppel in beide ogen
# hyaluronzuur oogdruppels 1mg/ml fl 10ml; oog; zo nodig 4 x per dag 1 druppel
# pantoprazol injectiepoeder 40mg fl; intraveneus continu;  8 mg/uur *pomp 8mg/uur, bolus 80mg in 30 minuten.
# acenocoumarol tablet 1mg; oraal; 1 x per dag volgens trombosedienst; stopdatum: tot nader order gestopt
# furosemide tablet 20mg; oraal; 1 x per dag 1 stuk; stopdatum: tot nader order gestopt
# macrogol/zouten pdr v drank (pleinvue); oraal; * volgens voorbereiding scopie ; start vanavond met eerste 500cc
# macrogol/zouten pdr v drank (movicolon+generiek); oraal; 1 x per dag 1 stuk; stopdatum: tot nader order gestopt
# ----------------------------
# 🩸 Pseudo ID: 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 📜 Content: Reden van komst / Verwijzing:
# Reden van komst (brief): RBV
#
# Anamnese:
# Vanmiddag rond 13.30u fors helderrood bloedverlies met stolsels. Vermengd met ontlasting, mogelijk was deze zwart van kleur. Sinds 5 dagen zeurende pijn in de bovenbuik ; maagpijn, waarvoor ze is gestopt met koffie drinken en vet eten. In de afgelopen dagen wat minder ontlasting, bij ook minder intake, maar geen bloed / zwart verkleuring bemerkt.
#
# Tractus anamnese: verder niet bijdragend, m.n. geen LW-klachten.
#
# rVG/
# 2002 Diep veneuze trombose en longembolie
# 2013 Cholecystectomie
# 2015 Diverticulitis. CT-abdomen: diverticulitis, geen maligniteit. Sigmoïdoscopie: geen RIP
# 2016 Atriumfibrilleren met spontane conversie naar sinusritme
# 2016 Melena, waarvoor geen verklaring werd gevonden. In verband met stabiel Hb en in overleg met patiënte expectatief beleid.
# 2018 Vermoeidheid bij sinusbradycardie waarvoor stop metoprolol en tambocor.
#
# Med/ o.a. Acenocoumarol
#
# All/ Penicillines -> urticaria
#
#
# Lichamelijk onderzoek:
# controles:
# SpO2	%	96
# HR	bpm	95
# NIBP	mmHg	132/71(91)
# Temp	°C	37,2
#
# Alg: niet acuut ziek, niet duidelijk anemisch
# H/H: PEARL, geen klieren
# Cor: S1S2, geen souffles
# Pulm: bdz VAG, geen bijgeluiden
# Abd: NP, WT, soepel abdomen, mild drukpijn epigastrio - geen loslaatpijn, Murphy -
# RT: helderrood bloed aan de handschoen, geen feces, geen afwijkingen palpabel, geen hemorroïden
#
#
# Aanvullend onderzoek:
# Lab:
# CRP	36	mg/L
# Hemoglobine	7.8	mmol/L
# Hematocriet	0.38	L/L
# Erytrocyten	4.10	x10^12/L
# MCV	93	fL
# Leukocyten	10.0	x10^9/L
# Trombocyten	176	x10^9/L
# APTT	38	sec
# PT	39.5	sec
# INR	2.8
# Glucose	8.0	mmol/l
# Natrium	141	mmol/L
# Kalium	4.3	mmol/L
# Ureum	13.2	mmol/L
# Kreatinine	82	µmol/L
# eGFR CKD-EPI	55	ml/m/1.73m^2
# Bilirubine totaal	7	µmol/L
# Alkalische Fosfatase (AF)	111	U/L
# GGT	16	U/L
# ASAT	28	U/L
# ALAT	18	U/L
# LD	240	U/L
# Lipase	28	U/L
# Albumine	35	g/L
#
#
# Conclusie:
# Bovenstaande 87-jarige patiënte ; o.a. bekend met diverticulose, passagère melena e.c.i. in 2016 en AF w.v. Acenocoumarol ; wordt beoordeeld op de SEH met nu rectaal bloedverlies.
#
# C/ Rectaal bloedverlies ; eenmalig ; HD en Hb-stabiel ; INR 2.8 ; wd divertikelbloeding dd toch maagulcus (gezien pijn epigastrio, mogelijk zwarte ontlasting en ureum 13).
#
#
# Beleid:
# Algemeen: Opname voor MDL ; geen isolatie indicatie (Te accepteren)
# Klinisch scopie ; morgen beoordelend colo / gastro of beide (Te accepteren)
# Acenocoumarol t.n.o. pauzeren (Te accepteren)
# Pantoprazol door op de perfusor (Te accepteren)
# Vanavond start voorbereiding scopie middels 500cc Pleinvue (Te accepteren)
# Morgen andere 500cc Pleinvue (Te accepteren)
# Po-inspectie ; indien meer bloedverlies vanavond Hb en INR controle - evt. Beriplex iom assistent INT (Te accepteren)
# Niet reanimeren op wens patiënt (Te accepteren)
#
# Beleid:
# Op de SEH:
# - 10mg Fytomenadion (vit. K) oraal
# - Pantoprazol 80mg i.v.
#
# Iom dr. Kamphuis MDL:
# - Opname voor MDL ; geen isolatie indicatie
# - Klinisch scopie ; morgen beoordelend colo / gastro of beide
# - Acenocoumarol t.n.o. pauzeren
# - Pantoprazol door op de perfusor
# - Vanavond start voorbereiding scopie middels 500cc Pleinvue
# - Morgen andere 500cc Pleinvue
# - Po-inspectie ; indien meer bloedverlies vanavond Hb en INR controle - evt. Beriplex iom assistent INT
# - Niet reanimeren en beademen op wens patiënt
# -------
# 📜 Corrected: reden van komst / verwijzing:
# reden van komst (brief): rbv
#
# anamnese:
# vanmiddag rond 13.30 uur fors helderrood bloedverlies met stolsels. vermengd met ontlasting, mogelijk was deze zwart van kleur. sinds 5 dagen zeurende pijn in de bovenbuik ; maagpijn, waarvoor ze is gestopt met koffie drinken en vet eten. in de afgelopen dagen wat minder ontlasting, bij ook minder intake, maar geen bloed / zwart verkleuring bemerkt.
#
# tractus anamnese: verder niet bijdragend, m.n. geen lw-klachten.
#
# rvg/
# 2002 diep veneuze trombose en longembolie
# 2013 cholecystectomie
# 2015 diverticulitis. ct-scan-abdomen: diverticulitis, geen maligniteit. sigmoïdoscopie: geen rip
# 2016 atriumfibrilleren met spontane conversie naar sinusritme
# 2016 melena, waarvoor geen verklaring werd gevonden. in verband met stabiel hemoglobine en in overleg met patiënte expectatief beleid.
# 2018 vermoeidheid bij sinusbradycardie waarvoor stop metoprolol en tambocor.
#
# medicatie/ onder andere acenocoumarol
#
# all/ penicillines -> urticaria
#
#
# lichamelijk onderzoek:
# controles:
# perifere zuurstofsaturatie	%	96
# hartfrequentie	bpm	95
# nibp	mmhg	132/71(91)
# temperatuur	°c	37,2
#
# alg: niet acuut ziek, niet duidelijk anemisch
# h/h: pearl, geen klieren
# cor: s1s2, geen souffles
# pulm: beiderzijds vag, geen bijgeluiden
# abd: np, wt, soepel abdomen, mild drukpijn epigastrio - geen loslaatpijn, murphy -
# rt: helderrood bloed aan de handschoen, geen feces, geen afwijkingen palpabel, geen hemorroïden
#
#
# aanvullend onderzoek:
# lab:
# c-reactieve proteine	36	mg/l
# hemoglobine	7.8	mmol/l
# hematocriet	0.38	l/l
# erytrocyten	4.10	x10^12/l
# mcv	93	fl
# leukocyten	10.0	x10^9/l
# trombocyten	176	x10^9/l
# aptt	38	sec
# patient	39.5	sec
# inr stollingswaarde	2.8
# glucose	8.0	mmol/l
# natrium	141	mmol/l
# kalium	4.3	mmol/l
# ureum	13.2	mmol/l
# kreatinine	82	µmol/l
# egfr ckd-epiduraal	55	ml/m/1.73m^2
# bilirubine totaal	7	µmol/l
# alkalische fosfatase (atrium fibilaire)	111	u/l
# ggt	16	u/l
# asat	28	u/l
# alat	18	u/l
# ld	240	u/l
# lipase	28	u/l
# albumine	35	g/l
#
#
# conclusie:
# bovenstaande 87-jarige patiënte ; onder andere bekend met diverticulose, passagère melena e.c.i. in 2016 en atrium fibilaire w.v. acenocoumarol ; wordt beoordeeld op de spoedeisende hulp met nu rectaal bloedverlies.
#
# circulatie: rectaal bloedverlies ; eenmalig ; hd en hemoglobine-stabiel ; inr stollingswaarde 2.8 ; wd divertikelbloeding dienstdoende toch maagulcus (gezien pijn epigastrio, mogelijk zwarte ontlasting en ureum 13).
#
#
# beleid:
# algemeen: opname voor mdl ; geen isolatie indicatie (te accepteren)
# klinisch scopie ; morgen beoordelend colo / gastro of beide (te accepteren)
# acenocoumarol tot nader order pauzeren (te accepteren)
# pantoprazol door op de perfusor (te accepteren)
# vanavond start voorbereiding scopie middels 500cc pleinvue (te accepteren)
# morgen andere 500cc pleinvue (te accepteren)
# po-inspectie ; indien meer bloedverlies vanavond hemoglobine en inr stollingswaarde controle - eventueel. beriplex in overleg met assistent internist (te accepteren)
# niet reanimeren op wens patiënt (te accepteren)
#
# beleid:
# op de spoedeisende hulp:
# - 10mg fytomenadion (vit. kalium) oraal
# - pantoprazol 80mg infuus
#
# in overleg met dokter kamphuis mdl:
# - opname voor mdl ; geen isolatie indicatie
# - klinisch scopie ; morgen beoordelend colo / gastro of beide
# - acenocoumarol tot nader order pauzeren
# - pantoprazol door op de perfusor
# - vanavond start voorbereiding scopie middels 500cc pleinvue
# - morgen andere 500cc pleinvue
# - po-inspectie ; indien meer bloedverlies vanavond hemoglobine en inr stollingswaarde controle - eventueel. beriplex in overleg met assistent internist
# - niet reanimeren en beademen op wens patiënt
# ----------------------------
# 🩸 Pseudo ID: 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 📜 Content: Máxima Medisch Centrum,
# maag-darm-leverziekten
# dr. M.L. Verhulst, maag-darm-leverarts
# tel. [PHONENUMBER]
#
#
# Aan de weledelgeleerde heer
# A.J. Dingemans, huisarts
# [STREETNAME] NR  [CITY]
#
#
#
#
# datum	: 23-08-2016
# kenmerk: 0005146439 / [PATIENTID] / SLW
# BSN nr.	: [BSN] niet geïdentificeerd
# betreft	: mevr. [INITIALS] [LASTNAME]
# 		  geb. [BIRTHDATE] (83)
# 		  [STREETNAME] AD  [CITY]
#
#
#
#
# Geachte collega,
#
# Van 22-08-2016 tot 23-08-2016 was uw patiënte opgenomen op de afdeling Maag-Darm-Leverziekten.
#
# Reden van opname: melaena
#
# Voorgeschiedenis:
# 2002 	Diep veneuze trombose en longembolie
# 2013 	Cholecystectomie
# 2015 	Diverticulitis. CT-abdomen: diverticulitis, geen maligniteit. Sigmoïdoscopie: behoudens divertikels geen afwijkingen.
# 2016 	Atriumfibrilleren met spontane conversie naar sinusritme
#
# Anamnese:
# Patiënte vertelde dat hij drie dagen pikzwarte ontlasting heeft gehad, die plakte aan de toiletpot en  anders van geur was. Daarbij had zij al langer last van maagzuur.
#
# Lichamelijk onderzoek:
# Niet acuut ziek. Rectaal toucher: melaena aan de handschoen.
#
# Laboratorium onderzoek: Hemoglobine 7.8 mmol/l; Kreatinine 86 umol/l ; Ferritine 83 ug/l.
# Gastroscopie: geen relevante afwijkingen.
#
# Bespreking:
# patiente werd opgenomen onder verdenking van een hoge tractus digestivus bloeding . Een gastroscopie liet geen afwijkingen zien en het hemoglobine bleef stabiel tijdens de opname. In overleg met patiente werd besloten om geen verdere diagnostiek te doen. Recent onderzoek van de darm (sigmoidoscopie en CT-abdomen) lieten geen aanwijzingen zien voor een maligniteit. Bij persisteren van de melena kan nog worden overwogen om alsnog een colonoscopie te verrichten.
# Op 23.08.2016 werd patiente ontslagen. Er werd geen vervolgafspraak gemaakt op de polikliniek MDL. Natuurlijk zijn wij bereid patiënte bij recidiverende klachten terug te zien..
#
# Conclusie: melena, waarvoor geen verklaring werd gevonden. In verband met stabiel Hb en in overleg met patiënte expectatief beleid.
#
# Actuele medicatie (ongewijzigd):
# latanoprost oogdruppels 50ug/ml minim 0,2ml  (oculair), 1 x per dag 1 druppel
# estriol ovule 0,5mg  (vaginaal),  2 weken voor de nacht vaginaal 1 ovule plaatsen. hierna 2 maal per week op maandag en vrijdag continueren.
# acenocoumarol tablet 1mg  (oraal), 1 x per dag volgens trombosedienst
# flecainide capsule mga  50mg  (oraal), 1 x per dag 1 stuk
# furosemide tablet 20mg  (oraal), 1 x per dag 1 stuk
# simvastatine tablet fo 20mg  (oraal), 1 x per dag 1 stuk
#
# Vertrouwende u hiermee voldoende te hebben geïnformeerd.
#
# Met vriendelijke groet,
#
#
# dr. M.L. Verhulst, maag-darm-leverarts
# T.T. van Sloten,
# arts assistent interne geneeskunde
#
#
# Deze brief is elektronisch geaccordeerd en daardoor niet voorzien van een handtekening.
# -------
# 📜 Corrected: máxima medisch centrum,
# maag-darm-leverziekten
# dokter m.l. verhulst, maag-darm-leverarts
# tel. [phonenumber]
#
#
# aan de weledelgeleerde meneer
# a.j. dingemans, huisarts
# [streetname] nr  [city]
#
#
#
#
# datum	: 23-08-2016
# kenmerk: 0005146439 / [patientid] / slw
# bsn nr.	: [bsn] niet geïdentificeerd
# betreft	: mevrouw [initials] [lastname]
# 		  geen bijzonderheden [birthdate] (83)
# 		  [streetname] ad  [city]
#
#
#
#
# geachte collega,
#
# van 22-08-2016 tot 23-08-2016 was uw patiënte opgenomen op de afdeling maag-darm-leverziekten.
#
# reden van opname: melaena
#
# voorgeschiedenis:
# 2002 	diep veneuze trombose en longembolie
# 2013 	cholecystectomie
# 2015 	diverticulitis. ct-scan-abdomen: diverticulitis, geen maligniteit. sigmoïdoscopie: behoudens divertikels geen afwijkingen.
# 2016 	atriumfibrilleren met spontane conversie naar sinusritme
#
# anamnese:
# patiënte vertelde dat hij drie dagen pikzwarte ontlasting heeft gehad, die plakte aan de toiletpot en  anders van geur was. daarbij had zij al langer last van maagzuur.
#
# lichamelijk onderzoek:
# niet acuut ziek. rectaal toucher: melaena aan de handschoen.
#
# laboratorium onderzoek: hemoglobine 7.8 mmol/l; kreatinine 86 umol/l ; ferritine 83 ug/l.
# gastroscopie: geen relevante afwijkingen.
#
# bespreking:
# patiente werd opgenomen onder verdenking van een hoge tractus digestivus bloeding . een gastroscopie liet geen afwijkingen zien en het hemoglobine bleef stabiel tijdens de opname. in overleg met patiente werd besloten om geen verdere diagnostiek te doen. recent onderzoek van de darm (sigmoidoscopie en ct-scan-abdomen) lieten geen aanwijzingen zien voor een maligniteit. bij persisteren van de melena kan nog worden overwogen om alsnog een colonoscopie te verrichten.
# op 23.08.2016 werd patiente ontslagen. er werd geen vervolgafspraak gemaakt op de polikliniek mdl. natuurlijk zijn wij bereid patiënte bij recidiverende klachten terug te zien..
#
# conclusie: melena, waarvoor geen verklaring werd gevonden. in verband met stabiel hemoglobine en in overleg met patiënte expectatief beleid.
#
# actuele medicatie (ongewijzigd):
# latanoprost oogdruppels 50ug/ml minim 0,2ml  (oculair), 1 x per dag 1 druppel
# estriol ovule 0,5mg  (vaginaal),  2 weken voor de nacht vaginaal 1 ovule plaatsen. hierna 2 maal per week op maandag en vrijdag continueren.
# acenocoumarol tablet 1mg  (oraal), 1 x per dag volgens trombosedienst
# flecainide capsule met gereguleerde afgifte  50mg  (oraal), 1 x per dag 1 stuk
# furosemide tablet 20mg  (oraal), 1 x per dag 1 stuk
# simvastatine tablet fo 20mg  (oraal), 1 x per dag 1 stuk
#
# vertrouwende u hiermee voldoende te hebben geïnformeerd.
#
# met vriendelijke groet,
#
#
# dokter m.l. verhulst, maag-darm-leverarts
# t.t. van sloten,
# arts assistent interne geneeskunde
#
#
# deze brief is elektronisch geaccordeerd en daardoor niet voorzien van een handtekening.
# ----------------------------
# 🩸 Pseudo ID: 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 📜 Content: Samenvatting:
# Decursus
# -Reden van opname: Melena
# -Speciële anamnese: Gastroscopie: behoudens atrofische gastritis, geen afwijkingen. Uitleg aan familie en patiente: geen duidelijke verklaring voor bloedverlies, maar wel ernstige afwijkingen uitgesloten middels gastroscopie. Bovendien stabiel Hb. Patiente wil graag naar huis.
# [ Conclusie ]
# -Samenvatting: Melena bij acenocoumarol gebruik. Gastroscopie: geen afwijjkingen B/ ontslag, expectatief beleid
# [ Beleid ]
# -Beleid: Ontslag
# Opstarten acenocoumerol, staken pantopazol
# Verdere follow-up (Hb controle) via huisarts
# Bij persisteren melena en anemie: zo nodig colonoscopie
# -Supervisor: M.L. Verhulst
# [ Visite opdrachten ]
# [ Visite opdrachten BMD sub ]
# -Algemeen: Vanmiddag ontslag (Voltooid)
# -Infuusbeleid: Geen poliklinische controle MDL (Voltooid)
# -------
# 📜 Corrected: samenvatting:
# decursus
# -reden van opname: melena
# -speciële anamnese: gastroscopie: behoudens atrofische gastritis, geen afwijkingen. uitleg aan familie en patiente: geen duidelijke verklaring voor bloedverlies, maar wel ernstige afwijkingen uitgesloten middels gastroscopie. bovendien stabiel hemoglobine. patiente wil graag naar huis.
# [ conclusie ]
# -samenvatting: melena bij acenocoumarol gebruik. gastroscopie: geen afwijjkingen ademhaling: ontslag, expectatief beleid
# [ beleid ]
# -beleid: ontslag
# opstarten acenocoumerol, staken pantopazol
# verdere follow-urine productie (hemoglobine controle) via huisarts
# bij persisteren melena en anemie: zo nodig colonoscopie
# -supervisor: m.l. verhulst
# [ visite opdrachten ]
# [ visite opdrachten bmd sub ]
# -algemeen: vanmiddag ontslag (voltooid)
# -infuusbeleid: geen poliklinische controle mdl (voltooid)
# ----------------------------
# 🩸 Pseudo ID: 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 📜 Content: Samenvatting:
# Conclusie
# -Samenvatting: Melena bij acenocoumarol gebruik. Gastroscopie: geen afwijjkingen B/ ontslag, expectatief beleid
# [ Beleid ]
# -Beleid: Ontslag
# Opstarten acenocoumerol, staken pantopazol
# Verdere follow-up (Hb controle) via huisarts
# Bij persisteren melena en anemie: zo nodig colonoscopie
# -Supervisor: M.L. Verhulst
# [ Visite opdrachten ]
# [ Visite opdrachten BMD sub ]
# -Algemeen: Vanmiddag ontslag (Voltooid)
# -Infuusbeleid: Geen poliklinische controle MDL (Voltooid)
# -------
# 📜 Corrected: samenvatting:
# conclusie
# -samenvatting: melena bij acenocoumarol gebruik. gastroscopie: geen afwijjkingen ademhaling: ontslag, expectatief beleid
# [ beleid ]
# -beleid: ontslag
# opstarten acenocoumerol, staken pantopazol
# verdere follow-urine productie (hemoglobine controle) via huisarts
# bij persisteren melena en anemie: zo nodig colonoscopie
# -supervisor: m.l. verhulst
# [ visite opdrachten ]
# [ visite opdrachten bmd sub ]
# -algemeen: vanmiddag ontslag (voltooid)
# -infuusbeleid: geen poliklinische controle mdl (voltooid)
# ----------------------------
# 🩸 Pseudo ID: 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 📜 Content: Máxima Medisch Centrum,
# maag-darm-leverziekten
# dr. P.J. Boekema, maag-darm-leverarts
# tel. [PHONENUMBER]
#
#
# Aan de weledelzeergeleerde vrouwe
# ...
# -registratie datum spoedeisende hulp: 22-10-2013
# -verantwoordelijk assistent: <objectgegevens>
# -verantwoordelijk arts: <objectgegevens>
# -dienstdoend specialist: <objectgegevens>
# -tijd eerste patientcontact: 21:15
# -reden van komst: <objectgegevens>
# [ medisch dossier ]
# [ anamnese ]
# -anamnese: rvk/ buikpijn en ziek bij cholelithiasis
# luchtwegen: patient is gisteren op poli geweest met koliekpijnen onder begeleiding van cholelithiasis, op echo sludge in galblaas. nu koorts 38.3c, zelfde koliekpijnen rechts, continu aanwezig. n-v-, geen vervoerspijn. patient heeft de hele dag alleen maar op bed kunnen liggen, beweegt het liefst niet. eten en drinken ging moeizaam. mictie geen bijzonderheden. ontlasting leek wat geler, niet echt veel gehad. volgens familie ziet patient geler dan normaal.
#
# all/ amoxicilline
#
# medicatie/ oa acenocoumarol
# voorgeschiedenis/ longembolieen 2002, decompensatio cordis, gynaecologische buikok icm appendectomie
# -a = allergieën (alleen verpleegkundig): augmentin
# [ onderzoek ]
# -lichamelijk onderzoek: matig zieke patiënte.
# abdomen: inspectie: litteken van onderbuikslaparotomie oogt rustig. peristaltiek namelijk, wt, soepel abdomen, diffuus drukpijnlijk, in te toekomst rechts boven. murphey sign positief. loslaatpijn +
# -aanvullend onderzoek: ja
# -lab: c-reactieve proteine 277 l 18.3 hemoglobine 8.9 bili 28 inr stollingswaarde 4.4
# [ conclusie ]
# -(werk)diagnose: cholecystits
# [ beleid ]
# -beleid: opname chirurgie
# start cefuroxim
# vit-kalium, morgen inr stollingswaarde-co
# morgen herbeoordelen en lap chol danwel percutane drainage
# [ opdrachten ]
# [ opdrachten verpleegafdeling v2 ]
# -algemeen: 10 mg vit-kalium (voltooid)
# -infuusbeleid: morgen lab inr stollingswaarde, l, c-reactieve proteine, bili (voltooid)
# -zuurstofbeleid: opname chirurgie (voltooid)
# [ overig ]
# -gezien door (naam, functie): r.l. den dekker, arts-asisstent chirurgie
# -in overleg met (naam, functie): m. loos, chirurg io
# ----------------------------
# 🩸 Pseudo ID: 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 📜 Content: Samenvatting:
# Verpleegkundige verslaglegging
# -Verantwoordelijk verpleegkundige:: <ObjectGegevens>
# [ Vplk SPUTOVAMO ]
# -Leeftijd: 80
# [ Collumcare ]
# -Collumcare patiënt: Nee
# [ Sepsis ]
# -Bestaat er op basis van de anamnese een verdenking op een infectie: Ja
# [ Anamnese ]
# -Leeftijd anamnese: 80
# -(Hoofd)klacht: <ObjectGegevens>
# -A = Allergieën (alleen verpleegkundig): augmentin
# -P = Past: DVT
# longembolien
# hernia
# appendectomie
# -E = Event: Gisteren op de seh geweest, galstenen geconstateerd.
# Pijn is niet weg geweest, nu VAS 2
# Gammel gevoel, eetlust -
# Def: geel/oranje
# Mictie: gb
# Fam vind mw icterisch
# -Gebruikt u antistolling via de Trombosedienst?: Ja
# -Pijnscore invullen?: Ja
# [ Pijnscore ]
# -Pijnscore: 2
# -Score tbv grafiek: 2
# -Medicatie toegediend op de SEH: Ja, Ja
# -Tijd toediening Medicatie: 22:49
# -Toegediende medicatie: Antibiotica
# -Antibiotica: Cefuroxim en 1500
# -Wijze van toediening medicatie: I.V
# -Toegediend door: leonie
# -Bijwerkingen / resultaten: leonie
# -Tijd toediening Medicatie: 22:49
# -Toegediende medicatie: Diversen
# -Diversen: vitamine k 10 mg
# -Wijze van toediening medicatie: P.O.
# -Labaanvraag SEH: Labaanvraag SEH
# -Verpleegkundige handelingen: IV canule (V) en Lab
# [ Verrichtingen registreren 2 ]
# -Verrichting invoeren: Geen
# -Bestemming na SEH: Opgenomen
# -Afdeling: aoa
# [ Contacten ]
# [ Contactpersonen ]
# -Met wie dienen, indien nodig, verpleging en/of artsen contact op te nemen als u in het ziekenhuis ligt?: danny van asten
# -Wat is de relatie met deze persoon?: zoon en/of dochter
# -Wat is zijn/haar telefoonnummer?: [PHONENUMBER]
#
# [PHONENUMBER]
# [ MTS triage ]
# -Triagekeuze: Buikpijn volwassene
# -Buikpijn volwassene: Recent probleem
# -Triage: Nee
# -Triage: Nee
# -Triage: Nee
# -Triage: Ja
# -Triage: Nee
# [ SEPSIS - VPK ]
# -Bestaat er op basis van de anamnese een verdenking op een infectie: Ja
# -------
# 📜 Corrected: samenvatting:
# verpleegkundige verslaglegging
# -verantwoordelijk verpleegkundige:: <objectgegevens>
# [ vplk sputovamo ]
# -leeftijd: 80
# [ collumcare ]
# -collumcare patiënt: nee
# [ sepsis ]
# -bestaat er op basis van de anamnese een verdenking op een infectie: ja
# [ anamnese ]
# -leeftijd anamnese: 80
# -(hoofd)klacht: <objectgegevens>
# -a = allergieën (alleen verpleegkundig): augmentin
# -p = past: deep veneuze trombose
# longembolien
# hernia
# appendectomie
# -e = event: gisteren op de spoedeisende hulp geweest, galstenen geconstateerd.
# pijn is niet weg geweest, nu visual analog scale 2
# gammel gevoel, eetlust -
# defecatie: geel/oranje
# mictie: geen bijzonderheden
# familie vind mevrouw icterisch
# -gebruikt u antistolling via de trombosedienst?: ja
# -pijnscore invullen?: ja
# [ pijnscore ]
# -pijnscore: 2
# -score tbv grafiek: 2
# -medicatie toegediend op de spoedeisende hulp: ja, ja
# -tijd toediening medicatie: 22:49
# -toegediende medicatie: antibiotica
# -antibiotica: cefuroxim en 1500
# -wijze van toediening medicatie: infuus
# -toegediend door: leonie
# -bijwerkingen / resultaten: leonie
# -tijd toediening medicatie: 22:49
# -toegediende medicatie: diversen
# -diversen: vitamine kalium 10 mg
# -wijze van toediening medicatie: per order
# -labaanvraag spoedeisende hulp: labaanvraag spoedeisende hulp
# -verpleegkundige handelingen: infuus canule (v) en lab
# [ verrichtingen registreren 2 ]
# -verrichting invoeren: geen
# -bestemming na spoedeisende hulp: opgenomen
# -afdeling: acute opname afdeling
# [ contacten ]
# [ contactpersonen ]
# -met wie dienen, indien nodig, verpleging en/of artsen contact op te nemen als u in het ziekenhuis ligt?: danny van asten
# -wat is de relatie met deze personen?: zoon en/of dochter
# -wat is zijn/haar telefoonnummer?: [phonenumber]
#
# [phonenumber]
# [ mts triage ]
# -triagekeuze: buikpijn volwassene
# -buikpijn volwassene: recent probleem
# -triage: nee
# -triage: nee
# -triage: nee
# -triage: ja
# -triage: nee
# [ sepsis - verpleegkundige ]
# -bestaat er op basis van de anamnese een verdenking op een infectie: ja
# ----------------------------
# 🩸 Pseudo ID: 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 📜 Content: Samenvatting:
# Medisch Dossier
# [ Vk Sputovamo ]
# -Leeftijd in jaren: 80
# -Registratie datum SEH: 21-10-2013
# -Verantwoordelijk assistent: <ObjectGegevens>
# -Verantwoordelijk arts: <ObjectGegevens>
# -Dienstdoend specialist: <ObjectGegevens>
# -Reden van komst: <ObjectGegevens>
# [ Medisch dossier ]
# [ Anamnese ]
# -Anamnese: VG:
# Hartritmestoornissen
# DVT, Longembolie
# Erdere periodes van pijn op de borst, niet gerelateerd aan inspanning
#
# Patient wordt vannacht rond 1 uur wakker van een stekende pijn over de gehele bovenbuik. Trekt naar de rug en schouders. Pijn is nu continue. Drie keer gebraakt vanochtend. N+, geen bloed erbij. R-. Gister avond frietjes gegeten. Geen awijkingen bij ontlasting of mictie.
# Niet dyspneuisch
# -Intoxicatie: rookt niet, geen alcohol
# -Familieanamnese: cardiovasc. neg, vader galstenen
# -Medicatie: Acenocoumarol, Tambocor, "plastablett"
# -A = Allergieën (alleen verpleegkundig): onbekend
# [ Onderzoek ]
# -Lichamelijk onderzoek: Bij inspectie geen bijzonderheden
# Abd/Normale darmgeruisen, wisselnde tympanie. Geen percussiepijn. Drukpijnlijk met defense RBB. Geen loslaatpijn.
# Cor/ S1 S2 S-
# Pul/ VAG
# -Aanvullend onderzoek: Ja
# -Lab: crp <5 milde LFstoornissen amylase 129
# -Medische beelden: Echo Bovenbuik: concrementen, geen duidelijke cholecystitis
# x-Thorax: geen pneumonie
# -Overig: ECG: Geen aanwijzingen voor ischemie (beoordeeld dr Lichteveld SEH)
# [ Conclusie ]
# -(Werk)diagnose: Sympt cholecystolithiasis goede reactie op pijnstilling
# [ Beleid ]
# -Beleid: Poliklinisch vervolg 2dgn co + lab: indien gb inplannen lap chol
# uitleg
# tramal, buscopan mee voor zn bij klachten
# na pijnstilling op SEH pijn vrij
# [ Overig ]
# -Gezien door (naam, functie): S. Smeets aios chirurgie
# [ hulplijst sepsis ]
# -Bestaat er op basis van de anamnese een verdenking op een infectie: Nee
# -------
# 📜 Corrected: samenvatting:
# medisch dossier
# [ vk sputovamo ]
# -leeftijd in jaren: 80
# -registratie datum spoedeisende hulp: 21-10-2013
# -verantwoordelijk assistent: <objectgegevens>
# -verantwoordelijk arts: <objectgegevens>
# -dienstdoend specialist: <objectgegevens>
# -reden van komst: <objectgegevens>
# [ medisch dossier ]
# [ anamnese ]
# -anamnese: voorgeschiedenis:
# hartritmestoornissen
# deep veneuze trombose, longembolie
# erdere periodes van pijn op de borst, niet gerelateerd aan inspanning
#
# patient wordt vannacht rond 1 uur wakker van een stekende pijn over de gehele bovenbuik. trekt naar de rug en schouders. pijn is nu continue. drie keer gebraakt vanochtend. n+, geen bloed erbij. r-. gister avond frietjes gegeten. geen awijkingen bij ontlasting of mictie.
# niet dyspneuisch
# -intoxicatie: rookt niet, geen alcohol
# -familieanamnese: cardiovasc. neg, vader galstenen
# -medicatie: acenocoumarol, tambocor, "plastablett"
# -a = allergieën (alleen verpleegkundig): onbekend
# [ onderzoek ]
# -lichamelijk onderzoek: bij inspectie geen bijzonderheden
# abd/normale darmgeruisen, wisselnde tympanie. geen percussiepijn. drukpijnlijk met defense rbb. geen loslaatpijn.
# cor/ s1 s2 s-
# pul/ vag
# -aanvullend onderzoek: ja
# -lab: c-reactieve proteine <5 milde lfstoornissen amylase 129
# -medische beelden: echo bovenbuik: concrementen, geen duidelijke cholecystitis
# röntgenfoto van thorax: geen pneumonie
# -overig: ecg: geen aanwijzingen voor ischemie (beoordeeld dr lichteveld spoedeisende hulp)
# [ conclusie ]
# -(werk)diagnose: sympt cholecystolithiasis goede reactie op pijnstilling
# [ beleid ]
# -beleid: poliklinisch vervolg 2dgn co + lab: indien geen bijzonderheden inplannen lap chol
# uitleg
# tramal, buscopan mee voor zo nodig bij klachten
# na pijnstilling op spoedeisende hulp pijn vrij
# [ overig ]
# -gezien door (naam, functie): s. smeets aios chirurgie
# [ hulplijst sepsis ]
# -bestaat er op basis van de anamnese een verdenking op een infectie: nee
# ----------------------------
# 🩸 Pseudo ID: 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 📜 Content: Samenvatting:
# vocht in vocht uit
# -Tijd: 10:41
# [ Toediening ]
# -Soort infuus: Anders
# -Memo medicatie: paracetamol iv
# -Aan: 100
# -In: 100
# -Totaal in tijdens seh-periode: 100
# -------
# 📜 Corrected: samenvatting:
# vocht in vocht uit
# -tijd: 10:41
# [ toediening ]
# -soort infuus: anders
# -memo medicatie: paracetamol infuus
# -aan: 100
# -in: 100
# -totaal in tijdens spoedeisende hulp-periode: 100
# ----------------------------
# 🩸 Pseudo ID: 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 📜 Content: Samenvatting:
# vocht in vocht uit
# -Tijd: 10:40
# [ Toediening ]
# -Soort infuus: NaCL 0,9%
# -Aan: 500
# -------
# 📜 Corrected: samenvatting:
# vocht in vocht uit
# -tijd: 10:40
# [ toediening ]
# -soort infuus: natriumchloride 0,9%
# -aan: 500
# ----------------------------
# 🩸 Pseudo ID: 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 📜 Content: Samenvatting:
# Verpleegkundige verslaglegging
# -Verantwoordelijk verpleegkundige:: <ObjectGegevens>
# [ Vplk SPUTOVAMO ]
# -Leeftijd: 80
# [ Collumcare ]
# -Collumcare patiënt: Nee
# [ Sepsis ]
# -Bestaat er op basis van de anamnese een verdenking op een infectie: Nee
# [ Anamnese ]
# -Leeftijd anamnese: 80
# -(Hoofd)klacht: <ObjectGegevens>
# -A = Allergieën (alleen verpleegkundig): onbekend
# -M = Medication: tambocor, plastablet, sintrom
# -P = Past: baarmoeder verwijderd. AF. epstaxis. longembolieen.
# -L = Last meal: gisteren
# -E = Event: Vannacht wakker geworden met pijn in de bovenbuik, uitstralend naar de rug. Pijn is continue aanwezig. Zit niet vast aan de ademhaling, geen lange reis gemaakt. N: + V: +. Def: bruin als anders, geen bloedbijmenging. Gisteren friet gegeten, eet nooit zo vet.
# A: Vrij.
# B: VAG beiderzijds. Symmetrische thoraxexcursies. Geen gebruik ha-spieren.
# C: Krachtige regulaire radialis. Bleke huidskleur. Droge huid. Cap refill normaal. rr: re=li.
# D: A
# -Gebruikt u antistolling via de Trombosedienst?: Ja
# -Pijnscore invullen?: Ja
# -Patientkenmerk: SEH patiënt
# [ Pijnscore ]
# -Pijnscore: 8
# -Score tbv grafiek: 8
# [ Extra pijnscore SEH ]
# -Medicatie toegediend op de SEH: Ja, Ja, Ja, Ja
# -Tijd toediening Medicatie: 10:40
# -Toegediende medicatie: Pijnstilling
# -Pijnstilling: Paracetamol en 1000 mg
# -Wijze van toediening medicatie: I.V
# -Toegediend door: wendy + leonie
# -Tijd toediening Medicatie: 11:51
# -Toegediende medicatie: Pijnstilling
# -Pijnstilling: Buscopan en 20 mg
# -Wijze van toediening medicatie: I.V
# -Toegediend door: wendy + diane
# -Tijd toediening Medicatie: 13:42
# -Toegediende medicatie: Pijnstilling
# -Pijnstilling: Diclofenac en 75
# -Wijze van toediening medicatie: I.M
# -Toegediend door: wendy + leonie
# -Tijd toediening Medicatie: 13:42
# -Toegediende medicatie: Anders
# -Andere medicatie: pantozol 40 mg
# -Wijze van toediening medicatie: P.O.
# -Labaanvraag SEH: Labaanvraag SEH, Labaanvraag SEH
# -Verpleegkundige handelingen: IV canule (V), Lab, Urinesediment, Urinekweek, Röntgen, ECHO en ECG (V)
# -Aanvullende informatie: Mw wil nog geen morfine daar ze daar misselijk van word en de pijn zakt iets op paracetamol.
# x-thorax
# echo bovenbuik
# [ Contacten ]
# [ Contactpersonen ]
# -Wat is zijn/haar telefoonnummer?: [PHONENUMBER]
# [ MTS triage ]
# -Triagekeuze: Buikpijn volwassene
# -Buikpijn volwassene: Matige pijn
# -Triage: Nee
# -Triage: Nee
# -Triage: Ja
# -Triage: Nee
# -Triage: Nee
# -Pijnscore bij ontslag: Ja
# -Algemene toelichting bij vertrek: co 23-10 om 8:45 lab en later om 9:45 op poli. Recept buscopan + tramadol. Mw kreeg info hierover. Bij toename klachten retour seh.
# -Pijnscore: 2
# -------
# 📜 Corrected: samenvatting:
# verpleegkundige verslaglegging
# -verantwoordelijk verpleegkundige:: <objectgegevens>
# [ vplk sputovamo ]
# -leeftijd: 80
# [ collumcare ]
# -collumcare patiënt: nee
# [ sepsis ]
# -bestaat er op basis van de anamnese een verdenking op een infectie: nee
# [ anamnese ]
# -leeftijd anamnese: 80
# -(hoofd)klacht: <objectgegevens>
# -a = allergieën (alleen verpleegkundig): onbekend
# -m = medication: tambocor, plastablet, sintrom
# -p = past: baarmoeder verwijderd. atrium fibilaire. epstaxis. longembolieen.
# -l = last meal: gisteren
# -e = event: vannacht wakker geworden met pijn in de bovenbuik, uitstralend naar de rug. pijn is continue aanwezig. zit niet vast aan de ademhaling, geen lange reis gemaakt. n: + v: +. defecatie: bruin als anders, geen bloedbijmenging. gisteren friet gegeten, eet nooit zo vet.
# luchtwegen: vrij.
# ademhaling: vag beiderzijds. symmetrische thoraxexcursies. geen gebruik huisarts-spieren.
# circulatie: krachtige regulaire radialis. bleke huidskleur. droge huid. cap refill normaal. bloeddruk: rechter=linker.
# onbekwaamheid: a
# -gebruikt u antistolling via de trombosedienst?: ja
# -pijnscore invullen?: ja
# -patientkenmerk: spoedeisende hulp patiënt
# [ pijnscore ]
# -pijnscore: 8
# -score tbv grafiek: 8
# [ extra pijnscore spoedeisende hulp ]
# -medicatie toegediend op de spoedeisende hulp: ja, ja, ja, ja
# -tijd toediening medicatie: 10:40
# -toegediende medicatie: pijnstilling
# -pijnstilling: paracetamol en 1000 mg
# -wijze van toediening medicatie: infuus
# -toegediend door: wendy + leonie
# -tijd toediening medicatie: 11:51
# -toegediende medicatie: pijnstilling
# -pijnstilling: buscopan en 20 mg
# -wijze van toediening medicatie: infuus
# -toegediend door: wendy + diane
# -tijd toediening medicatie: 13:42
# -toegediende medicatie: pijnstilling
# -pijnstilling: diclofenac en 75
# -wijze van toediening medicatie: i.m
# -toegediend door: wendy + leonie
# -tijd toediening medicatie: 13:42
# -toegediende medicatie: anders
# -andere medicatie: pantozol 40 mg
# -wijze van toediening medicatie: per order
# -labaanvraag spoedeisende hulp: labaanvraag spoedeisende hulp, labaanvraag spoedeisende hulp
# -verpleegkundige handelingen: infuus canule (v), lab, urinesediment, urinekweek, röntgen, echo en ecg (v)
# -aanvullende informatie: mevrouw wil nog geen morfine daar ze daar misselijk van word en de pijn zakt iets op paracetamol.
# röntgenfoto van thorax
# echo bovenbuik
# [ contacten ]
# [ contactpersonen ]
# -wat is zijn/haar telefoonnummer?: [phonenumber]
# [ mts triage ]
# -triagekeuze: buikpijn volwassene
# -buikpijn volwassene: matige pijn
# -triage: nee
# -triage: nee
# -triage: ja
# -triage: nee
# -triage: nee
# -pijnscore bij ontslag: ja
# -algemene toelichting bij vertrek: co 23-10 om 8:45 lab en later om 9:45 op poli. recept buscopan + tramadol. mevrouw kreeg info hierover. bij toename klachten retour spoedeisende hulp.
# -pijnscore: 2
# ----------------------------

# %% [markdown]
# Preprocessing for spelling check

# %%
import pandas as pd
import re
import unicodedata

def clean_text_column(df, column_name, new_column_name=None):
    """
    Cleans formatting and placeholders in a text column of a DataFrame.
    
    Parameters:
    - df: pandas DataFrame
    - column_name: name of the column to clean
    - new_column_name: optional, name of the new column to store cleaned text
                       (if None, it will overwrite the original column)
    
    Returns:
    - df with the cleaned column
    """
    
    def clean_text(text):
        if pd.isnull(text):
            return text  # leave NaN as-is

        # Step 1: Replace \r, \n, \t with space
        text = re.sub(r'[\r\n\t]+', ' ', text)

        # Step 2: Remove placeholder tokens like [INITIALS], [LASTNAME]
        text = re.sub(r'\[[^\]]*\]', '', text)

        # Step 3: Collapse multiple spaces
        text = re.sub(r'\s+', ' ', text).strip()

        # Step 4: Remove ASCII control characters (including \x07)
        text = re.sub(r'[\x00-\x1F\x7F]', '', text)

        # Step 5: Normalize Unicode (optional but helps with accents)
        text = unicodedata.normalize('NFKC', text)

        return text

    # Apply cleaning
    cleaned = df[column_name].apply(clean_text)

    # Assign to the desired column
    if new_column_name:
        df[new_column_name] = cleaned
    else:
        df[column_name] = cleaned

    return df

# %%
df_abbreviations = clean_text_column(df_abbreviations, 'abbreviations_corrected', 'abbreviations_corrected_cleaned')
df_abbreviations
# Out:
#                                       pseudo_id  \
# 0      046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 1      046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 2      046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 3      046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 4      046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# ...                                         ...
# 11085  FD8C682C1F4FDA1E5EC0B760D30875556419BD71
# 11086  FD8C682C1F4FDA1E5EC0B760D30875556419BD71
# 11087  FD8C682C1F4FDA1E5EC0B760D30875556419BD71
# 11088  FD8C682C1F4FDA1E5EC0B760D30875556419BD71
# 11089  FD8C682C1F4FDA1E5EC0B760D30875556419BD71
#
#                   verslagen_report_tags  \
# 0                       Klinische Brief
# 1      Consult, Kliniek: vervolgconsult
# 2                   Poliklinische Brief
# 3                   Poliklinische Brief
# 4      Consult, Kliniek: vervolgconsult
# ...                                 ...
# 11085                           Consult
# 11086  Consult, Kliniek: vervolgconsult
# 11087                      Consult, SEH
# 11088                      Consult, SEH
# 11089                      Consult, SEH
#
#                                 verslagen_report_content  \
# 0      Dhr. A.J. Dingemans, huisarts\r\n[STREETNAME] ...
# 1      Samenvatting: \nRectaal bloedverlies obv diver...
# 2      COLOSCOPIE\r\n\r\nBetreft\r\nMw. [INITIALS] [L...
# 3      GASTROSCOPIE\r\n\r\nBetreft\r\nMw. [INITIALS] ...
# 4      Samenvatting: \nRectaal bloedverlies ; eenmali...
# ...                                                  ...
# 11085  Samenvatting: \n1e consult\r\n-Type 1e consult...
# 11086  Samenvatting: \nDecursus\r\n-Type decursus: De...
# 11087  Samenvatting: \nVerpleegkundige verslaglegging...
# 11088  Samenvatting: \nMedisch Dossier\r\n[ Vk Sputov...
# 11089  Samenvatting: \nVerpleegkundige verslaglegging...
#
#        verslagen_report_age_at_time_of_event   verslagen_report_specialism  \
# 0                                         87  Maag-, Darm- en Leverziekten
# 1                                         87  Maag-, Darm- en Leverziekten
# 2                                         87  Maag-, Darm- en Leverziekten
# 3                                         87  Maag-, Darm- en Leverziekten
# 4                                         87  Maag-, Darm- en Leverziekten
# ...                                      ...                           ...
# 11085                                     83           Interne Geneeskunde
# 11086                                     83           Interne Geneeskunde
# 11087                                     83             Spoedeisende Hulp
# 11088                                     79             Spoedeisende Hulp
# 11089                                     79             Spoedeisende Hulp
#
#       verslagen_report_start_date  \
# 0             2020-11-26 15:06:00
# 1             2020-11-26 09:53:00
# 2             2020-11-25 14:13:00
# 3             2020-11-25 13:48:00
# 4             2020-11-25 08:47:00
# ...                           ...
# 11085         2015-03-20 08:13:00
# 11086         2015-01-14 15:39:00
# 11087         2014-12-21 09:31:00
# 11088         2010-11-10 21:03:00
# 11089         2010-11-10 20:29:00
#
#                                  abbreviations_corrected  \
# 0      meneer a.j. dingemans, huisarts\r\n[streetname...
# 1      samenvatting: \nrectaal bloedverlies onder beg...
# 2      coloscopie\r\n\r\nbetreft\r\nmevrouw [initials...
# 3      gastroscopie\r\n\r\nbetreft\r\nmevrouw [initia...
# 4      samenvatting: \nrectaal bloedverlies ; eenmali...
# ...                                                  ...
# 11085  samenvatting: \neerste consult\r\n-type eerste...
# 11086  samenvatting: \ndecursus\r\n-type decursus: de...
# 11087  samenvatting: \nverpleegkundige verslaglegging...
# 11088  samenvatting: \nmedisch dossier\r\n[ vk sputov...
# 11089  samenvatting: \nverpleegkundige verslaglegging...
#
#                          abbreviations_corrected_cleaned
# 0      meneer a.j. dingemans, huisarts nr datum 29-11...
# 1      samenvatting: rectaal bloedverlies onder begel...
# 2      coloscopie betreft mevrouw adresgegevens: , ge...
# 3      gastroscopie betreft mevrouw adresgegevens: , ...
# 4      samenvatting: rectaal bloedverlies ; eenmalig ...
# ...                                                  ...
# 11085  samenvatting: eerste consult -type eerste cons...
# 11086  samenvatting: decursus -type decursus: decursu...
# 11087  samenvatting: verpleegkundige verslaglegging -...
# 11088  samenvatting: medisch dossier -leeftijd in jar...
# 11089  samenvatting: verpleegkundige verslaglegging -...
#
# [11090 rows x 8 columns]

# %%
specific_id = df_abbreviations[df_abbreviations['pseudo_id'] == '046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6']
specific_id['pseudo_id'].unique()  

for i, row in specific_id[specific_id['pseudo_id'].notnull()].iterrows():
    print(f"🩸 Pseudo ID: {row['pseudo_id']}")
    # print(f"🩸 Date: {row['date']}")
    print(f"📜 Content: {row['verslagen_report_content']}")
    print("---------------- corrected:") 
    print(f"📜 Corrected: {row['abbreviations_corrected']}")
    print("---------------------------- cleaned:")
    print(f"📜 Cleaned: {row['abbreviations_corrected_cleaned']}")
    print("----------------------------")
# Out:
# 🩸 Pseudo ID: 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 📜 Content: Dhr. A.J. Dingemans, huisarts
# [STREETNAME] NR  [CITY]
#
#
#
#
#
# datum
# 29-11-2020
# kenmerk
# 0007475372 / [PATIENTID]
# BSN nr.
# [BSN]
# betreft
# mevrouw [INITIALS] [LASTNAME], geb. [BIRTHDATE] (87)
# [STREETNAME], [ZIP]  [CITY]
# tel. [PHONENUMBER]
#
#
# Geachte collega,
#
# Bovengenoemde patiënte was opgenomen van 24-11-2020 tot en met 26-11-2020 op de afdeling Maag-, Darm- en Leverziekten in verband met melaena en rectaal bloedverlies.
#
# Voorgeschiedenis
# 2002 Diep veneuze trombose en longembolie
# 2013 Cholecystectomie
# 2015 Diverticulitis
# 2016 Atriumfibrilleren met spontane conversie naar sinusritme
# 2016 Melena, waarvoor geen verklaring werd gevonden. In verband met stabiel Hb en in overleg met patiënte expectatief beleid.
# 2018 Vermoeidheid bij sinusbradycardie waarvoor stop metoprolol en tambocor.
#
# Anamnese
# Vanmiddag rond 13.30u fors helderrood bloedverlies met stolsels. Vermengd met ontlasting, mogelijk was deze zwart van kleur. Sinds 5 dagen zeurende pijn in de bovenbuik; maagpijn, waarvoor ze is gestopt met koffie drinken en vet eten. In de afgelopen dagen wat minder ontlasting, bij ook minder intake, maar geen bloed / zwart verkleuring bemerkt.
# Tractus anamnese: verder niet bijdragend, m.n. geen LW-klachten.
#
# All/ Penicillines -> urticaria
#
# Lichamelijk onderzoek
# Controles:
# SpO2	%	96
# HR	bpm	95
# NIBP	mmHg	132/71(91)
# Temp	°C	37,2
#
# Alg: niet acuut ziek, niet duidelijk anemisch
# H/H: PEARL, geen lymfadenopathie
# Cor: S1S2, geen souffles
# Pulm: VAG beiderzijds, geen bijgeluiden
# Abd: Normale peristaltiek, wisselende tympanie, soepel abdomen, mild drukpijn epigastrio - geen loslaatpijn, Murphy -
# RT: helderrood bloed aan de handschoen, geen feces, geen afwijkingen palpabel, geen hemorroïden
#
# Aanvullend onderzoek
# Laboratorium 24-11-2020
# HEMATOLOGIE: CRP (H): 36 mg/L (< 5), Hemoglobine: 7.8 mmol/L (7.5 - 10.0), Hematocriet: 0.38 L/L (0.35 - 0.45), Erytrocyten: 4.10 x10^12/L (4.00 - 5.00), MCV: 93 fL (80 - 100), Leukocyten: 10.0 x10^9/L (4.0 - 10.0), Trombocyten: 176 x10^9/L (150 - 400)
# Hemostase: APTT (H): 38 sec (25 - 34), PT (H): 39.5 sec (12.1 - 15.6), INR (H): 2.8 (0.8 - 1.2)
# Bloedgroep: Bloedgroep: A neg, IAT: neg. (negatief)
# CHEMIE: Glucose (H): 8.0 mmol/l (4.0 - 7.8), Natrium: 141 mmol/L (135 - 145), Kalium: 4.3 mmol/L (3.5 - 5.0), Ureum (H): 13.2 mmol/L (2.5 - 6.4), Kreatinine: 82 µmol/L (49 - 90), eGFR CKD-EPI (L): 55 ml/m/1.73m^2 (> 90), Bilirubine totaal: 7 µmol/L (< 17), Alkalische Fosfatase (AF) (H): 111 U/L (33 - 98), GGT: 16 U/L (< 38), ASAT: 28 U/L (< 31), ALAT: 18 U/L (< 34), LD: 240 U/L (< 247), Lipase: 28 U/L (13 - 60), Albumine: 35 g/L (35 - 50)
#
# Gastroscopie 25-11-2020
# Geen bloed of bloedingsbron bij gastroscopie.
#
# Coloscopie 25-11-2020
# Coloscopie tot in het colon ascendens.
# Lange darm, scopie tot bij de klep. Bloeding gestopt, geen bloedingsbron gevonden. Pandiverticulose maar vooral in sigmoid. Waarschijnlijkheidsdiagnose is divertikelbloeding
#
# Laboratorium 26-11-2020
# HEMATOLOGIE: Hemoglobine (L): 6.8 mmol/L (7.5 - 10.0), MCV: 97 fL (80 - 100)
#
# Beloop
# De patiënte werd op 24-11-2020 opgenomen in verband met melaena en hierbij ook helderrood rectaal bloedverlies onder acenocoumarol. De acenocoumarol werd gestaakt en gecoupeerd. Bij een verdenking van zowel hoge als lage tractus digestivus bloeding werd er gestart met een pantoprazol perfusor en werd de patiënte voorbereid voor zowel een gastro- als coloscopie. Gedurende de avond werd de patiënte na nogmaals fors melaena gehad te hebben hypotensief (RR 100/58) waarvoor er een 1L infuus werd gestart. De patiënte had hierbij geen klachten. De volgende dag kreeg de patiënte zowel de gasto- als coloscopie waarop uitgebreide diverticulose gezien werd en geen actieve bloedingsbron waardoor de werkdiagnose divertikelbloeding werd. Op de coloscopie kon de coecumbodem niet volledig beoordeeld worden. Dit hebben we met de patiënte en familie besproken, theoretisch zou hier een coecumproces kunnen zitten echter is deze kans klein omdat caecum redelijk te overzien was. Hiervoor zou nog een CT-colografie gemaakt kunnen worden echter in samenspraak met de patiënte en familie werd hiervan afgezien. Na de endoscopieën is er geen rectaal bloedverlies meer waargenomen.
# Op 26-11-2020 kon de patiënte in goede conditie met ontslag naar huis.
#
# Medicatie
# Latanoprost oogdruppel 50ug/ml minim 0,2ml; oog; 1 x per dag 1 druppel in beide ogen
# Hyaluronzuur oogdruppels 1mg/ml fl 10ml; oog; zo nodig 4 x per dag 1 druppel
# Acenocoumarol tablet 1mg; oraal; 1 x per dag volgens trombosedienst
# Macrogol/zouten pdr v drank (movicolon+generiek); oraal; 1 x per dag 1 stuk
# Furosemide tablet 20mg; oraal; 1 x per dag 1 stuk tijdelijk gestopt
# Metoclopramide tablet 10mg; oraal; zo nodig 3 x per dag 1 stuk
#
# Behandelbeperking
# Gekozen behandelbeperking: Reanimeren: nee IC opname: niet beslist Beademen: nee
#
#
# Conclusie
# 1. Divertikelbloeding onder acenocoumarol.
# 2. Gedurende opname meermaals hypotensie (tot RR 94/52) zonder klachten.
#
# Beleid
# Ad1: - Acenocoumarol 26-11 in eigen dosering hervatten
# Ad2: - Furosemide tijdelijk gestaakt i.v.m. lage tensies, patiënte meet 27-11 de bloeddruk thuis overnieuw en neemt hierover contact met u op.
#
# Met vriendelijke groet,
#
#
# L. Bukkems, semi-arts maag-darm-leverziekten
#
# Met vriendelijke groet,
#
# J.T. Kamphuis, maag-darm-leverarts
# AGB: 03018377
#
# Deze brief is elektronisch geaccordeerd en daarom niet ondertekend.
# ---------------- corrected:
# 📜 Corrected: meneer a.j. dingemans, huisarts
# [streetname] nr  [city]
#
#
#
#
#
# datum
# 29-11-2020
# kenmerk
# 0007475372 / [patientid]
# bsn nr.
# [bsn]
# betreft
# mevrouw [initials] [lastname], geen bijzonderheden [birthdate] (87)
# [streetname], [zip]  [city]
# tel. [phonenumber]
#
#
# geachte collega,
#
# bovengenoemde patiënte was opgenomen van 24-11-2020 tot en met 26-11-2020 op de afdeling maag-, darm- en leverziekten in verband met melaena en rectaal bloedverlies.
#
# voorgeschiedenis
# 2002 diep veneuze trombose en longembolie
# 2013 cholecystectomie
# 2015 diverticulitis
# 2016 atriumfibrilleren met spontane conversie naar sinusritme
# 2016 melena, waarvoor geen verklaring werd gevonden. in verband met stabiel hemoglobine en in overleg met patiënte expectatief beleid.
# 2018 vermoeidheid bij sinusbradycardie waarvoor stop metoprolol en tambocor.
#
# anamnese
# vanmiddag rond 13.30 uur fors helderrood bloedverlies met stolsels. vermengd met ontlasting, mogelijk was deze zwart van kleur. sinds 5 dagen zeurende pijn in de bovenbuik; maagpijn, waarvoor ze is gestopt met koffie drinken en vet eten. in de afgelopen dagen wat minder ontlasting, bij ook minder intake, maar geen bloed / zwart verkleuring bemerkt.
# tractus anamnese: verder niet bijdragend, m.n. geen lw-klachten.
#
# all/ penicillines -> urticaria
#
# lichamelijk onderzoek
# controles:
# perifere zuurstofsaturatie	%	96
# hartfrequentie	bpm	95
# nibp	mmhg	132/71(91)
# temperatuur	°c	37,2
#
# alg: niet acuut ziek, niet duidelijk anemisch
# h/h: pearl, geen lymfadenopathie
# cor: s1s2, geen souffles
# pulm: vag beiderzijds, geen bijgeluiden
# abd: normale peristaltiek, wisselende tympanie, soepel abdomen, mild drukpijn epigastrio - geen loslaatpijn, murphy -
# rt: helderrood bloed aan de handschoen, geen feces, geen afwijkingen palpabel, geen hemorroïden
#
# aanvullend onderzoek
# laboratorium 24-11-2020
# hematologie: c-reactieve proteine (h): 36 mg/l (minder dan 5), hemoglobine: 7.8 mmol/l (7.5 - 10.0), hematocriet: 0.38 l/l (0.35 - 0.45), erytrocyten: 4.10 x10^12/l (4.00 - 5.00), mcv: 93 fl (80 - 100), leukocyten: 10.0 x10^9/l (4.0 - 10.0), trombocyten: 176 x10^9/l (150 - 400)
# hemostase: aptt (h): 38 sec (25 - 34), patient (h): 39.5 sec (12.1 - 15.6), inr stollingswaarde (h): 2.8 (0.8 - 1.2)
# bloedgroep: bloedgroep: a neg, iat: neg. (negatief)
# chemie: glucose (h): 8.0 mmol/l (4.0 - 7.8), natrium: 141 mmol/l (135 - 145), kalium: 4.3 mmol/l (3.5 - 5.0), ureum (h): 13.2 mmol/l (2.5 - 6.4), kreatinine: 82 µmol/l (49 - 90), egfr ckd-epiduraal (l): 55 ml/m/1.73m^2 (> 90), bilirubine totaal: 7 µmol/l (minder dan 17), alkalische fosfatase (atrium fibilaire) (h): 111 u/l (33 - 98), ggt: 16 u/l (minder dan 38), asat: 28 u/l (minder dan 31), alat: 18 u/l (minder dan 34), ld: 240 u/l (minder dan 247), lipase: 28 u/l (13 - 60), albumine: 35 g/l (35 - 50)
#
# gastroscopie 25-11-2020
# geen bloed of bloedingsbron bij gastroscopie.
#
# coloscopie 25-11-2020
# coloscopie tot in het colon ascendens.
# lange darm, scopie tot bij de klep. bloeding gestopt, geen bloedingsbron gevonden. pandiverticulose maar vooral in sigmoid. waarschijnlijkheidsdiagnose is divertikelbloeding
#
# laboratorium 26-11-2020
# hematologie: hemoglobine (l): 6.8 mmol/l (7.5 - 10.0), mcv: 97 fl (80 - 100)
#
# beloop
# de patiënte werd op 24-11-2020 opgenomen in verband met melaena en hierbij ook helderrood rectaal bloedverlies onder acenocoumarol. de acenocoumarol werd gestaakt en gecoupeerd. bij een verdenking van zowel hoge als lage tractus digestivus bloeding werd er gestart met een pantoprazol perfusor en werd de patiënte voorbereid voor zowel een gastro- als coloscopie. gedurende de avond werd de patiënte na nogmaals fors melaena gehad te hebben hypotensief (bloeddruk 100/58) waarvoor er een 1l infuus werd gestart. de patiënte had hierbij geen klachten. de volgende dag kreeg de patiënte zowel de gasto- als coloscopie waarop uitgebreide diverticulose gezien werd en geen actieve bloedingsbron waardoor de werkdiagnose divertikelbloeding werd. op de coloscopie kon de coecumbodem niet volledig beoordeeld worden. dit hebben we met de patiënte en familie besproken, theoretisch zou hier een coecumproces kunnen zitten echter is deze kans klein omdat caecum redelijk te overzien was. hiervoor zou nog een ct-scan-colografie gemaakt kunnen worden echter in samenspraak met de patiënte en familie werd hiervan afgezien. na de endoscopieën is er geen rectaal bloedverlies meer waargenomen.
# op 26-11-2020 kon de patiënte in goede conditie met ontslag naar huis.
#
# medicatie
# latanoprost oogdruppel 50ug/ml minim 0,2ml; oog; 1 x per dag 1 druppel in beide ogen
# hyaluronzuur oogdruppels 1mg/ml fl 10ml; oog; zo nodig 4 x per dag 1 druppel
# acenocoumarol tablet 1mg; oraal; 1 x per dag volgens trombosedienst
# macrogol/zouten pdr v drank (movicolon+generiek); oraal; 1 x per dag 1 stuk
# furosemide tablet 20mg; oraal; 1 x per dag 1 stuk tijdelijk gestopt
# metoclopramide tablet 10mg; oraal; zo nodig 3 x per dag 1 stuk
#
# behandelbeperking
# gekozen behandelbeperking: reanimeren: nee inter collegiaal consult opname: niet beslist beademen: nee
#
#
# conclusie
# 1. divertikelbloeding onder acenocoumarol.
# 2. gedurende opname meermaals hypotensie (tot bloeddruk 94/52) zonder klachten.
#
# beleid
# ad1: - acenocoumarol 26-11 in eigen dosering hervatten
# ad2: - furosemide tijdelijk gestaakt in verband met lage tensies, patiënte meet 27-11 de bloeddruk thuis overnieuw en neemt hierover contact met u op.
#
# met vriendelijke groet,
#
#
# l. bukkems, semi-arts maag-darm-leverziekten
#
# met vriendelijke groet,
#
# j.t. kamphuis, maag-darm-leverarts
# agb: 03018377
#
# deze brief is elektronisch geaccordeerd en daarom niet ondertekend.
# ---------------------------- cleaned:
# 📜 Cleaned: meneer a.j. dingemans, huisarts nr datum 29-11-2020 kenmerk 0007475372 / bsn nr. betreft mevrouw , geen bijzonderheden (87) , tel. geachte collega, bovengenoemde patiënte was opgenomen van 24-11-2020 tot en met 26-11-2020 op de afdeling maag-, darm- en leverziekten in verband met melaena en rectaal bloedverlies. voorgeschiedenis 2002 diep veneuze trombose en longembolie 2013 cholecystectomie 2015 diverticulitis 2016 atriumfibrilleren met spontane conversie naar sinusritme 2016 melena, waarvoor geen verklaring werd gevonden. in verband met stabiel hemoglobine en in overleg met patiënte expectatief beleid. 2018 vermoeidheid bij sinusbradycardie waarvoor stop metoprolol en tambocor. anamnese vanmiddag rond 13.30 uur fors helderrood bloedverlies met stolsels. vermengd met ontlasting, mogelijk was deze zwart van kleur. sinds 5 dagen zeurende pijn in de bovenbuik; maagpijn, waarvoor ze is gestopt met koffie drinken en vet eten. in de afgelopen dagen wat minder ontlasting, bij ook minder intake, maar geen bloed / zwart verkleuring bemerkt. tractus anamnese: verder niet bijdragend, m.n. geen lw-klachten. all/ penicillines -> urticaria lichamelijk onderzoek controles: perifere zuurstofsaturatie % 96 hartfrequentie bpm 95 nibp mmhg 132/71(91) temperatuur °c 37,2 alg: niet acuut ziek, niet duidelijk anemisch h/h: pearl, geen lymfadenopathie cor: s1s2, geen souffles pulm: vag beiderzijds, geen bijgeluiden abd: normale peristaltiek, wisselende tympanie, soepel abdomen, mild drukpijn epigastrio - geen loslaatpijn, murphy - rt: helderrood bloed aan de handschoen, geen feces, geen afwijkingen palpabel, geen hemorroïden aanvullend onderzoek laboratorium 24-11-2020 hematologie: c-reactieve proteine (h): 36 mg/l (minder dan 5), hemoglobine: 7.8 mmol/l (7.5 - 10.0), hematocriet: 0.38 l/l (0.35 - 0.45), erytrocyten: 4.10 x10^12/l (4.00 - 5.00), mcv: 93 fl (80 - 100), leukocyten: 10.0 x10^9/l (4.0 - 10.0), trombocyten: 176 x10^9/l (150 - 400) hemostase: aptt (h): 38 sec (25 - 34), patient (h): 39.5 sec (12.1 - 15.6), inr stollingswaarde (h): 2.8 (0.8 - 1.2) bloedgroep: bloedgroep: a neg, iat: neg. (negatief) chemie: glucose (h): 8.0 mmol/l (4.0 - 7.8), natrium: 141 mmol/l (135 - 145), kalium: 4.3 mmol/l (3.5 - 5.0), ureum (h): 13.2 mmol/l (2.5 - 6.4), kreatinine: 82 μmol/l (49 - 90), egfr ckd-epiduraal (l): 55 ml/m/1.73m^2 (> 90), bilirubine totaal: 7 μmol/l (minder dan 17), alkalische fosfatase (atrium fibilaire) (h): 111 u/l (33 - 98), ggt: 16 u/l (minder dan 38), asat: 28 u/l (minder dan 31), alat: 18 u/l (minder dan 34), ld: 240 u/l (minder dan 247), lipase: 28 u/l (13 - 60), albumine: 35 g/l (35 - 50) gastroscopie 25-11-2020 geen bloed of bloedingsbron bij gastroscopie. coloscopie 25-11-2020 coloscopie tot in het colon ascendens. lange darm, scopie tot bij de klep. bloeding gestopt, geen bloedingsbron gevonden. pandiverticulose maar vooral in sigmoid. waarschijnlijkheidsdiagnose is divertikelbloeding laboratorium 26-11-2020 hematologie: hemoglobine (l): 6.8 mmol/l (7.5 - 10.0), mcv: 97 fl (80 - 100) beloop de patiënte werd op 24-11-2020 opgenomen in verband met melaena en hierbij ook helderrood rectaal bloedverlies onder acenocoumarol. de acenocoumarol werd gestaakt en gecoupeerd. bij een verdenking van zowel hoge als lage tractus digestivus bloeding werd er gestart met een pantoprazol perfusor en werd de patiënte voorbereid voor zowel een gastro- als coloscopie. gedurende de avond werd de patiënte na nogmaals fors melaena gehad te hebben hypotensief (bloeddruk 100/58) waarvoor er een 1l infuus werd gestart. de patiënte had hierbij geen klachten. de volgende dag kreeg de patiënte zowel de gasto- als coloscopie waarop uitgebreide diverticulose gezien werd en geen actieve bloedingsbron waardoor de werkdiagnose divertikelbloeding werd. op de coloscopie kon de coecumbodem niet volledig beoordeeld worden. dit hebben we met de patiënte en familie besproken, theoretisch zou hier een coecumproces kunnen zitten echter is deze kans klein omda ...
# ----------------------------
# 🩸 Pseudo ID: 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 📜 Content: Samenvatting:
# Rectaal bloedverlies obv divertikelbloeding; onder acenocoumarol (wegens AF), gecoupeerd. Op colo pandiverticulose.
#
#
# Beloop:
# Vpk/
# Geen rectaal bloedverlies meer gehad. Voelt zich goed, geen klachten van lage tensie. Wil graag naar huis. Goed gegeten vanochtend, hierbij geen klachten.
#
# Aan bed/
# Geen klachten meer, goed gevoel over naar huis gaan. Geen bloed meer gezien.
# Met patiënte en schoondochter de uitslag van de coloscopie nog eens besproken. Aangegeven dat de coecum bodem niet volledig in beeld is kunnen brengen, wel grodendeels echter dat een caecumproces niet volledig uitgesloten kan worden. Als de pte hier ongerust over zou zijn zou zij hier een CT-colografie van kunnen laten. Pte en schoondochter geven aan dat ze hier niet ongerust over zijn en dat dit niet hoeft. Aangegeven dat mochten ze zich bedenken ze altijd terug kunnen bellen.
#
#
# Lichamelijk onderzoek:
# HD stabiel, geen koorts. RR wel aan lage kant, 94/52 dus furosemide niet gegeven
#
#
# Conclusie:
# Geen bloedverlies meer waargenomen. Klinisch goed, vandaag met ontslag.
# Wegens hypotensie furosemide niet gegeven en geadviseerd de tensie thuis op te volgen
#
#
# Beleid:
# Iom dr. Kamphuis
# - Acenocoumarol eigen dosering hervatten
# - Nog uitleg geven aan zoon + pte over coecum bodem
# - In brief naar huisarts tensiecontrole vermelden
# ---------------- corrected:
# 📜 Corrected: samenvatting:
# rectaal bloedverlies onder begeleiding van divertikelbloeding; onder acenocoumarol (wegens atrium fibilaire), gecoupeerd. op colo pandiverticulose.
#
#
# beloop:
# verpleegkundige/
# geen rectaal bloedverlies meer gehad. voelt zich goed, geen klachten van lage bloeddruk. wil graag naar huis. goed gegeten vanochtend, hierbij geen klachten.
#
# aan bed/
# geen klachten meer, goed gevoel over naar huis gaan. geen bloed meer gezien.
# met patiënte en schoondochter de uitslag van de coloscopie nog eens besproken. aangegeven dat de coecum bodem niet volledig in beeld is kunnen brengen, wel grodendeels echter dat een caecumproces niet volledig uitgesloten kan worden. als de patient hier ongerust over zou zijn zou zij hier een ct-scan-colografie van kunnen laten. patient en schoondochter geven aan dat ze hier niet ongerust over zijn en dat dit niet hoeft. aangegeven dat mochten ze zich bedenken ze altijd terug kunnen bellen.
#
#
# lichamelijk onderzoek:
# hd stabiel, geen koorts. bloeddruk wel aan lage kant, 94/52 dus furosemide niet gegeven
#
#
# conclusie:
# geen bloedverlies meer waargenomen. klinisch goed, vandaag met ontslag.
# wegens hypotensie furosemide niet gegeven en geadviseerd de bloeddruk thuis op te volgen
#
#
# beleid:
# in overleg met dokter kamphuis
# - acenocoumarol eigen dosering hervatten
# - nog uitleg geven aan zoon + patient over coecum bodem
# - in brief naar huisarts tensiecontrole vermelden
# ---------------------------- cleaned:
# 📜 Cleaned: samenvatting: rectaal bloedverlies onder begeleiding van divertikelbloeding; onder acenocoumarol (wegens atrium fibilaire), gecoupeerd. op colo pandiverticulose. beloop: verpleegkundige/ geen rectaal bloedverlies meer gehad. voelt zich goed, geen klachten van lage bloeddruk. wil graag naar huis. goed gegeten vanochtend, hierbij geen klachten. aan bed/ geen klachten meer, goed gevoel over naar huis gaan. geen bloed meer gezien. met patiënte en schoondochter de uitslag van de coloscopie nog eens besproken. aangegeven dat de coecum bodem niet volledig in beeld is kunnen brengen, wel grodendeels echter dat een caecumproces niet volledig uitgesloten kan worden. als de patient hier ongerust over zou zijn zou zij hier een ct-scan-colografie van kunnen laten. patient en schoondochter geven aan dat ze hier niet ongerust over zijn en dat dit niet hoeft. aangegeven dat mochten ze zich bedenken ze altijd terug kunnen bellen. lichamelijk onderzoek: hd stabiel, geen koorts. bloeddruk wel aan lage kant, 94/52 dus furosemide niet gegeven conclusie: geen bloedverlies meer waargenomen. klinisch goed, vandaag met ontslag. wegens hypotensie furosemide niet gegeven en geadviseerd de bloeddruk thuis op te volgen beleid: in overleg met dokter kamphuis - acenocoumarol eigen dosering hervatten - nog uitleg geven aan zoon + patient over coecum bodem - in brief naar huisarts tensiecontrole vermelden
# ----------------------------
# 🩸 Pseudo ID: 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 📜 Content: COLOSCOPIE
#
# Betreft
# Mw. [INITIALS] [LASTNAME]
# Adresgegevens:
# [STREETNAME], [ZIP]  [CITY]
# Geboortedatum:
# [BIRTHDATE]
# ASA classificatie:
# 3
# Verwijzer:
# J.T. Kamphuis
# Indicatie:
# bloedverlies-rectaal. Melena en bloedverlies per anum onder acenocoumarol. Afwijkingen?.
# TOP verricht
# Ja
# Informed consent:
# ja
# Endoscoop:
#
#
#
#
# Geachte collega,
#
# Bij uw patiënt werd op 25-11-2020 een coloscopie uitgevoerd.
# Indicatie: bloedverlies-rectaal. Melena en bloedverlies per anum onder acenocoumarol. Afwijkingen?.
#
# Toegediende medicatie:
# Midazolam 3 mg
# Fentanyl 0,05 mg
# Fentanyl 0,025 mg
#
# Introductie:
# Intubatie heeft plaatsgevonden tot in het colon ascendens. Verder opvoeren lukt niet door uitbochten endoscoop.
# De Boston Bowel Preparation score is 9 (3-3-3).
# Terugtrektijd: 6 min.
# Patiëntcomfort: mild ongemak, tijdens de procedure meer dan twee voorvallen van ongemak, voldoende te verdragen.
#
# Voorbereiding:
# Gelaxeerd. Nuchter.
#
#
# Verslag:
# RT: Geen afwijkingen.
# Introductie door lange bochtige darm tot bij de klep; ondanks buikcompressie, verschillende houdingen en introductie van volledige scoop lukt het niet om de caecumbodem te bereiken.
# Nergens bloed of bloedingsbron.
# Pandiverticulose maar vooral in sigmoid.
# Geen poliep of tumor of inflammatie.
# In rectum en bij inversie geen afwijkingen..
#
#
#
# Conclusie:
# Coloscopie tot in het colon ascendens.
# Lange darm, scopie tot bij de klep. Bloeding gestopt, geen bloedingsbron gevonden.
# Waarschijnlijkheidsdiagnose is divertikelbloeding
#
#
# Advies:
# Gegevens van gastro- en coloscopie zo accepteren met waarschijnlijkheidsdiagnose divertikelbloeding of toch nog uitsluiten caecumproces m.b.t. CT-colografie (kans klein dat hier een afwijking is omdat caecum grotendeels wel te overzien was). Te bespreken met patiënte, kan poliklinisch.
# ---------------- corrected:
# 📜 Corrected: coloscopie
#
# betreft
# mevrouw [initials] [lastname]
# adresgegevens:
# [streetname], [zip]  [city]
# geboortedatum:
# [birthdate]
# asa classificatie:
# 3
# verwijzer:
# j.t. kamphuis
# indicatie:
# bloedverlies-rectaal. melena en bloedverlies per anum onder acenocoumarol. afwijkingen?.
# top verricht
# ja
# informed consent:
# ja
# endoscoop:
#
#
#
#
# geachte collega,
#
# bij uw patiënt werd op 25-11-2020 een coloscopie uitgevoerd.
# indicatie: bloedverlies-rectaal. melena en bloedverlies per anum onder acenocoumarol. afwijkingen?.
#
# toegediende medicatie:
# midazolam 3 mg
# fentanyl 0,05 mg
# fentanyl 0,025 mg
#
# introductie:
# intubatie heeft plaatsgevonden tot in het colon ascendens. verder opvoeren lukt niet door uitbochten endoscoop.
# de boston bowel preparation score is 9 (3-3-3).
# terugtrektijd: 6 min.
# patiëntcomfort: mild ongemak, tijdens de procedure meer dan twee voorvallen van ongemak, voldoende te verdragen.
#
# voorbereiding:
# gelaxeerd. nuchter.
#
#
# verslag:
# rt: geen afwijkingen.
# introductie door lange bochtige darm tot bij de klep; ondanks buikcompressie, verschillende houdingen en introductie van volledige scoop lukt het niet om de caecumbodem te bereiken.
# nergens bloed of bloedingsbron.
# pandiverticulose maar vooral in sigmoid.
# geen poliep of tumor of inflammatie.
# in rectum en bij inversie geen afwijkingen..
#
#
#
# conclusie:
# coloscopie tot in het colon ascendens.
# lange darm, scopie tot bij de klep. bloeding gestopt, geen bloedingsbron gevonden.
# waarschijnlijkheidsdiagnose is divertikelbloeding
#
#
# advies:
# gegevens van gastro- en coloscopie zo accepteren met waarschijnlijkheidsdiagnose divertikelbloeding of toch nog uitsluiten caecumproces met betrekking tot ct-scan-colografie (kans klein dat hier een afwijking is omdat caecum grotendeels wel te overzien was). te bespreken met patiënte, kan poliklinisch.
# ---------------------------- cleaned:
# 📜 Cleaned: coloscopie betreft mevrouw adresgegevens: , geboortedatum: asa classificatie: 3 verwijzer: j.t. kamphuis indicatie: bloedverlies-rectaal. melena en bloedverlies per anum onder acenocoumarol. afwijkingen?. top verricht ja informed consent: ja endoscoop: geachte collega, bij uw patiënt werd op 25-11-2020 een coloscopie uitgevoerd. indicatie: bloedverlies-rectaal. melena en bloedverlies per anum onder acenocoumarol. afwijkingen?. toegediende medicatie: midazolam 3 mg fentanyl 0,05 mg fentanyl 0,025 mg introductie: intubatie heeft plaatsgevonden tot in het colon ascendens. verder opvoeren lukt niet door uitbochten endoscoop. de boston bowel preparation score is 9 (3-3-3). terugtrektijd: 6 min. patiëntcomfort: mild ongemak, tijdens de procedure meer dan twee voorvallen van ongemak, voldoende te verdragen. voorbereiding: gelaxeerd. nuchter. verslag: rt: geen afwijkingen. introductie door lange bochtige darm tot bij de klep; ondanks buikcompressie, verschillende houdingen en introductie van volledige scoop lukt het niet om de caecumbodem te bereiken. nergens bloed of bloedingsbron. pandiverticulose maar vooral in sigmoid. geen poliep of tumor of inflammatie. in rectum en bij inversie geen afwijkingen.. conclusie: coloscopie tot in het colon ascendens. lange darm, scopie tot bij de klep. bloeding gestopt, geen bloedingsbron gevonden. waarschijnlijkheidsdiagnose is divertikelbloeding advies: gegevens van gastro- en coloscopie zo accepteren met waarschijnlijkheidsdiagnose divertikelbloeding of toch nog uitsluiten caecumproces met betrekking tot ct-scan-colografie (kans klein dat hier een afwijking is omdat caecum grotendeels wel te overzien was). te bespreken met patiënte, kan poliklinisch.
# ----------------------------
# 🩸 Pseudo ID: 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 📜 Content: GASTROSCOPIE
#
# Betreft
# Mw. [INITIALS] [LASTNAME]
# Adresgegevens:
# [STREETNAME], [ZIP]  [CITY]
# Geboortedatum:
# [BIRTHDATE]
# ASA classificatie:
# 3
# Verwijzer:
# J.T. Kamphuis
# Indicatie:
# Melena en bloedverlies per anum onder acenocoumarol. Afwijkingen?.
# TOP verricht
# Ja
# Informed consent:
# ja
# Endoscoop:
#
#
#
#
# Geachte collega,
#
# Bij uw patiënt werd op 25-11-2020 een gastroscopie uitgevoerd.
# Indicatie: Melena en bloedverlies per anum onder acenocoumarol. Afwijkingen?.
#
# Toegediende medicatie:
# Midazolam 3 mg
# Fentanyl 0,05 mg
#
# Voorbereiding:
# Nuchter.
#
#
# Verslag:
# Slokdarm: Z-lijn en diafragma op 38 en 40 cm, geen oesofagitis of Barrett.
# Maag: atrofisch en rood aspect slijmvlies, geen echte gastritis of ulcera. Normale inversie.
# Duodenum tot in DII: normaal vlokken- en plooien-patroon, geen ulcera, groot duodenum divertikel.
# Nergens bloed..
#
#
#
# Conclusie:
# Geen bloed of bloedingsbron bij gastroscopie..
# ---------------- corrected:
# 📜 Corrected: gastroscopie
#
# betreft
# mevrouw [initials] [lastname]
# adresgegevens:
# [streetname], [zip]  [city]
# geboortedatum:
# [birthdate]
# asa classificatie:
# 3
# verwijzer:
# j.t. kamphuis
# indicatie:
# melena en bloedverlies per anum onder acenocoumarol. afwijkingen?.
# top verricht
# ja
# informed consent:
# ja
# endoscoop:
#
#
#
#
# geachte collega,
#
# bij uw patiënt werd op 25-11-2020 een gastroscopie uitgevoerd.
# indicatie: melena en bloedverlies per anum onder acenocoumarol. afwijkingen?.
#
# toegediende medicatie:
# midazolam 3 mg
# fentanyl 0,05 mg
#
# voorbereiding:
# nuchter.
#
#
# verslag:
# slokdarm: zonder-lijn en diafragma op 38 en 40 cm, geen oesofagitis of barrett.
# maag: atrofisch en rood aspect slijmvlies, geen echte gastritis of ulcera. normale inversie.
# duodenum tot in dii: normaal vlokken- en plooien-patroon, geen ulcera, groot duodenum divertikel.
# nergens bloed..
#
#
#
# conclusie:
# geen bloed of bloedingsbron bij gastroscopie..
# ---------------------------- cleaned:
# 📜 Cleaned: gastroscopie betreft mevrouw adresgegevens: , geboortedatum: asa classificatie: 3 verwijzer: j.t. kamphuis indicatie: melena en bloedverlies per anum onder acenocoumarol. afwijkingen?. top verricht ja informed consent: ja endoscoop: geachte collega, bij uw patiënt werd op 25-11-2020 een gastroscopie uitgevoerd. indicatie: melena en bloedverlies per anum onder acenocoumarol. afwijkingen?. toegediende medicatie: midazolam 3 mg fentanyl 0,05 mg voorbereiding: nuchter. verslag: slokdarm: zonder-lijn en diafragma op 38 en 40 cm, geen oesofagitis of barrett. maag: atrofisch en rood aspect slijmvlies, geen echte gastritis of ulcera. normale inversie. duodenum tot in dii: normaal vlokken- en plooien-patroon, geen ulcera, groot duodenum divertikel. nergens bloed.. conclusie: geen bloed of bloedingsbron bij gastroscopie..
# ----------------------------
# 🩸 Pseudo ID: 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 📜 Content: Samenvatting:
# Rectaal bloedverlies ; eenmalig ; HD en Hb-stabiel ; INR 2.8 ; wd divertikelbloeding dd toch maagulcus (gezien pijn epigastrio, mogelijk zwarte ontlasting en ureum 13).  Onder acenocoumarol, gecoupeerd
#
#
# Beloop:
# Vpk/
# Gisteravond melena gehad, vannacht donkerrood bloedverlies gehad. Geen stolsels. Had gisteravond ook pijnklachten van maag gehad, geen pijnstilling meer hiervoor gehad. Voelt zich verder goed.
# Infuus 1L.
#
# Aan bed/
# Voelde zich gisteren plots erg slecht, dacht dat ze doodging, toen opgestaan en naar de keuken gewandeld, hier omgevallen, zegt niet het bewustzijn verloren te hebben echter wel op de grond gevallen. Toen familie gebeld die waren meteen gekomen. Later op de wc lag alles vol bloed.
# Nu gaat het wel weer, geen buikpijnklachten. Net nog naar de wc gehad waarbij ook weer bloed zat.
#
#
# Lichamelijk onderzoek:
# Nu HD stabiel, echter vannacht wel tensiedaling wv 1L infuus.
# Geen koorts
#
#
# Aanvullend onderzoek:
# Lab
# Hemoglobine	6.4	mmol/L
# MCV	93	fL
# INR	1.6
#
# Gastroscopie
# Geen bloed of bloedingsbron bij gastroscopie
#
# Coloscopie
# Coloscopie tot in het colon ascendens.
# Lange darm, scopie tot bij de klep. Bloeding gestopt, geen bloedingsbron gevonden.
# Waarschijnlijkheidsdiagnose is divertikelbloeding. Pandiverticulose.
#
#
# Conclusie:
# Rectaal bloedverlies waarschijnlijk obv divertikelbloeding
#
#
# Beleid:
# iom dr. Kamphuis
# - Gastro/colo vandaag
# - Morgen Hb controle =@
# - Uitslag vertelt aan pte en zoon
#
#
# Beleid:
# Opdrachten aan verpleegkundigen: VOD 27-11 (Voltooid)
# ews 3dd (Voltooid)
# ---------------- corrected:
# 📜 Corrected: samenvatting:
# rectaal bloedverlies ; eenmalig ; hd en hemoglobine-stabiel ; inr stollingswaarde 2.8 ; wd divertikelbloeding dienstdoende toch maagulcus (gezien pijn epigastrio, mogelijk zwarte ontlasting en ureum 13).  onder acenocoumarol, gecoupeerd
#
#
# beloop:
# verpleegkundige/
# gisteravond melena gehad, vannacht donkerrood bloedverlies gehad. geen stolsels. had gisteravond ook pijnklachten van maag gehad, geen pijnstilling meer hiervoor gehad. voelt zich verder goed.
# infuus 1l.
#
# aan bed/
# voelde zich gisteren plots erg slecht, dacht dat ze doodging, toen opgestaan en naar de keuken gewandeld, hier omgevallen, zegt niet het bewustzijn verloren te hebben echter wel op de grond gevallen. toen familie gebeld die waren meteen gekomen. later op de wc lag alles vol bloed.
# nu gaat het wel weer, geen buikpijnklachten. net nog naar de wc gehad waarbij ook weer bloed zat.
#
#
# lichamelijk onderzoek:
# nu hd stabiel, echter vannacht wel tensiedaling waarvoor 1l infuus.
# geen koorts
#
#
# aanvullend onderzoek:
# lab
# hemoglobine	6.4	mmol/l
# mcv	93	fl
# inr stollingswaarde	1.6
#
# gastroscopie
# geen bloed of bloedingsbron bij gastroscopie
#
# coloscopie
# coloscopie tot in het colon ascendens.
# lange darm, scopie tot bij de klep. bloeding gestopt, geen bloedingsbron gevonden.
# waarschijnlijkheidsdiagnose is divertikelbloeding. pandiverticulose.
#
#
# conclusie:
# rectaal bloedverlies waarschijnlijk onder begeleiding van divertikelbloeding
#
#
# beleid:
# in overleg met dokter kamphuis
# - gastro/colo vandaag
# - morgen hemoglobine controle =@
# - uitslag vertelt aan patient en zoon
#
#
# beleid:
# opdrachten aan verpleegkundige: voorlopige ontslagdatum 27-11 (voltooid)
# early warning score 3dd (voltooid)
# ---------------------------- cleaned:
# 📜 Cleaned: samenvatting: rectaal bloedverlies ; eenmalig ; hd en hemoglobine-stabiel ; inr stollingswaarde 2.8 ; wd divertikelbloeding dienstdoende toch maagulcus (gezien pijn epigastrio, mogelijk zwarte ontlasting en ureum 13). onder acenocoumarol, gecoupeerd beloop: verpleegkundige/ gisteravond melena gehad, vannacht donkerrood bloedverlies gehad. geen stolsels. had gisteravond ook pijnklachten van maag gehad, geen pijnstilling meer hiervoor gehad. voelt zich verder goed. infuus 1l. aan bed/ voelde zich gisteren plots erg slecht, dacht dat ze doodging, toen opgestaan en naar de keuken gewandeld, hier omgevallen, zegt niet het bewustzijn verloren te hebben echter wel op de grond gevallen. toen familie gebeld die waren meteen gekomen. later op de wc lag alles vol bloed. nu gaat het wel weer, geen buikpijnklachten. net nog naar de wc gehad waarbij ook weer bloed zat. lichamelijk onderzoek: nu hd stabiel, echter vannacht wel tensiedaling waarvoor 1l infuus. geen koorts aanvullend onderzoek: lab hemoglobine 6.4 mmol/l mcv 93 fl inr stollingswaarde 1.6 gastroscopie geen bloed of bloedingsbron bij gastroscopie coloscopie coloscopie tot in het colon ascendens. lange darm, scopie tot bij de klep. bloeding gestopt, geen bloedingsbron gevonden. waarschijnlijkheidsdiagnose is divertikelbloeding. pandiverticulose. conclusie: rectaal bloedverlies waarschijnlijk onder begeleiding van divertikelbloeding beleid: in overleg met dokter kamphuis - gastro/colo vandaag - morgen hemoglobine controle =@ - uitslag vertelt aan patient en zoon beleid: opdrachten aan verpleegkundige: voorlopige ontslagdatum 27-11 (voltooid) early warning score 3dd (voltooid)
# ----------------------------
# 🩸 Pseudo ID: 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 📜 Content: Medisch beeld is beschikbaar.
# LET OP!! Binnen HiX niet geschikt voor diagnostiek
# ---------------- corrected:
# 📜 Corrected: medisch beeld is beschikbaar.
# let op!! binnen hix niet geschikt voor diagnostiek
# ---------------------------- cleaned:
# 📜 Cleaned: medisch beeld is beschikbaar. let op!! binnen hix niet geschikt voor diagnostiek
# ----------------------------
# 🩸 Pseudo ID: 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 📜 Content: Beloop:
# Verpleging belt:
# Patiënte heeft nog 2x forse hoeveelheid melena gehad.
# Hierbij ook tensie daling naar RR 100/58 mm Hg, kwam van RR 131/69 mm Hg.
#
# B/
# - Hb + INR controle.
# - Start infuus: 1L NaCl 0.9%.
# - PM: beriplex.
#
#
# 21.30u:
# Hb 8.2
# INR 2.5
#
# B/
# - Geen actie voor nu.
#
#
# 23.00u
# RR 103/51 mm Hg.
# Nu waterdunne ontlasting vermengd met bloedverlies.
#
# B/
# - Zo door.
# - Laagdrempelig opnieuw contact.
# ---------------- corrected:
# 📜 Corrected: beloop:
# verpleging belt:
# patiënte heeft nog 2 keer forse hoeveelheid melena gehad.
# hierbij ook bloeddruk daling naar bloeddruk 100/58 mm hg, kwam van bloeddruk 131/69 mm hg.
#
# ademhaling:
# - hemoglobine + inr stollingswaarde controle.
# - start infuus: 1l natriumchloride 0.9%.
# - in te toekomst: beriplex.
#
#
# 21.30 uur:
# hemoglobine 8.2
# inr stollingswaarde 2.5
#
# ademhaling:
# - geen actie voor nu.
#
#
# 23.30 uur
# bloeddruk 103/51 mm hg.
# nu waterdunne ontlasting vermengd met bloedverlies.
#
# ademhaling:
# - zo door.
# - laagdrempelig opnieuw contact.
# ---------------------------- cleaned:
# 📜 Cleaned: beloop: verpleging belt: patiënte heeft nog 2 keer forse hoeveelheid melena gehad. hierbij ook bloeddruk daling naar bloeddruk 100/58 mm hg, kwam van bloeddruk 131/69 mm hg. ademhaling: - hemoglobine + inr stollingswaarde controle. - start infuus: 1l natriumchloride 0.9%. - in te toekomst: beriplex. 21.30 uur: hemoglobine 8.2 inr stollingswaarde 2.5 ademhaling: - geen actie voor nu. 23.30 uur bloeddruk 103/51 mm hg. nu waterdunne ontlasting vermengd met bloedverlies. ademhaling: - zo door. - laagdrempelig opnieuw contact.
# ----------------------------
# 🩸 Pseudo ID: 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 📜 Content: Dhr. A.J. Dingemans, huisarts
# [STREETNAME] NR  [CITY]
#
#
#
#
#
# datum
# 24-11-2020
# kenmerk
# 0007471629 / [PATIENTID]
# BSN nr.
# [BSN]
# betreft
# mevrouw [INITIALS] [LASTNAME], geb. [BIRTHDATE] (87)
# [STREETNAME], [ZIP]  [CITY]
# tel. [PHONENUMBER]
#
#
# Geachte collega,
#
# Bovengenoemde patiënt bezocht op 24-11-2020 de spoedeisende hulp.
#
# Reden van komst
# RBV
#
# Conclusie
# Bovenstaande 87-jarige patiënte ; o.a. bekend met diverticulose, passagère melena e.c.i. in 2016 en AF w.v. Acenocoumarol ; wordt beoordeeld op de SEH met nu rectaal bloedverlies.
#
# C/ Rectaal bloedverlies ; eenmalig ; HD en Hb-stabiel ; INR 2.8 ; wd divertikelbloeding dd toch maagulcus (gezien pijn epigastrio, mogelijk zwarte ontlasting en ureum 13).
#
# Beleid
# Op de SEH:
# - 10mg Fytomenadion (vit. K) oraal
# - Pantoprazol 80mg i.v.
#
# Iom dr. Kamphuis MDL:
# - Opname voor MDL ; geen isolatie indicatie
# - Klinisch scopie ; morgen beoordelend colo / gastro of beide
# - Acenocoumarol t.n.o. pauzeren
# - Pantoprazol door op de perfusor
# - Vanavond start voorbereiding scopie middels 500cc Pleinvue
# - Morgen andere 500cc Pleinvue
# - Po-inspectie ; indien meer bloedverlies vanavond Hb en INR controle - evt. Beriplex iom assistent INT
# - Niet reanimeren en beademen op wens patiënt
#
# Anamnese
# Vanmiddag rond 13.30u fors helderrood bloedverlies met stolsels. Vermengd met ontlasting, mogelijk was deze zwart van kleur. Sinds 5 dagen zeurende pijn in de bovenbuik ; maagpijn, waarvoor ze is gestopt met koffie drinken en vet eten. In de afgelopen dagen wat minder ontlasting, bij ook minder intake, maar geen bloed / zwart verkleuring bemerkt.
#
# Tractus anamnese: verder niet bijdragend, m.n. geen LW-klachten.
#
# rVG/
# 2002 Diep veneuze trombose en longembolie
# 2013 Cholecystectomie
# 2015 Diverticulitis. CT-abdomen: diverticulitis, geen maligniteit. Sigmoïdoscopie: geen RIP
# 2016 Atriumfibrilleren met spontane conversie naar sinusritme
# 2016 Melena, waarvoor geen verklaring werd gevonden. In verband met stabiel Hb en in overleg met patiënte expectatief beleid.
# 2018 Vermoeidheid bij sinusbradycardie waarvoor stop metoprolol en tambocor.
#
# Med/ o.a. Acenocoumarol
#
# All/ Penicillines -> urticaria
#
# Lichamelijk onderzoek
# controles:
# SpO2	%	96
# HR	bpm	95
# NIBP	mmHg	132/71(91)
# Temp	°C	37,2
#
# Alg: niet acuut ziek, niet duidelijk anemisch
# H/H: PEARL, geen klieren
# Cor: S1S2, geen souffles
# Pulm: bdz VAG, geen bijgeluiden
# Abd: NP, WT, soepel abdomen, mild drukpijn epigastrio - geen loslaatpijn, Murphy -
# RT: helderrood bloed aan de handschoen, geen feces, geen afwijkingen palpabel, geen hemorroïden
#
# Aanvullend onderzoek
# CRP	36	mg/L
# Hemoglobine	7.8	mmol/L
# Hematocriet	0.38	L/L
# Erytrocyten	4.10	x10^12/L
# MCV	93	fL
# Leukocyten	10.0	x10^9/L
# Trombocyten	176	x10^9/L
# APTT	38	sec
# PT	39.5	sec
# INR	2.8
# Glucose	8.0	mmol/l
# Natrium	141	mmol/L
# Kalium	4.3	mmol/L
# Ureum	13.2	mmol/L
# Kreatinine	82	µmol/L
# eGFR CKD-EPI	55	ml/m/1.73m^2
# Bilirubine totaal	7	µmol/L
# Alkalische Fosfatase (AF)	111	U/L
# GGT	16	U/L
# ASAT	28	U/L
# ALAT	18	U/L
# LD	240	U/L
# Lipase	28	U/L
# Albumine	35	g/L
#
# Medicatie actueel
# Fytomenadion injvlst 10mg/ml (par/oraal) amp 1ml; iv; 1 x per dag 10 milligram
# Latanoprost oogdruppel 50ug/ml minim 0,2ml; oog; 1 x per dag 1 druppel in beide ogen
# Hyaluronzuur oogdruppels 1mg/ml fl 10ml; oog; zo nodig 4 x per dag 1 druppel
# Pantoprazol injectiepoeder 40mg fl; intraveneus continu;  8 mg/uur *pomp 8mg/uur, bolus 80mg in 30 minuten.
# Acenocoumarol tablet 1mg; oraal; 1 x per dag volgens trombosedienst; stopdatum: t.n.o. gestopt
# Furosemide tablet 20mg; oraal; 1 x per dag 1 stuk; stopdatum: t.n.o. gestopt
# Macrogol/zouten pdr v drank (pleinvue); oraal; * volgens voorbereiding scopie ; start vanavond met eerste 500cc
# Macrogol/zouten pdr v drank (movicolon+generiek); oraal; 1 x per dag 1 stuk; stopdatum: t.n.o. gestopt
# ---------------- corrected:
# 📜 Corrected: meneer a.j. dingemans, huisarts
# [streetname] nr  [city]
#
#
#
#
#
# datum
# 24-11-2020
# kenmerk
# 0007471629 / [patientid]
# bsn nr.
# [bsn]
# betreft
# mevrouw [initials] [lastname], geen bijzonderheden [birthdate] (87)
# [streetname], [zip]  [city]
# tel. [phonenumber]
#
#
# geachte collega,
#
# bovengenoemde patiënt bezocht op 24-11-2020 de spoedeisende hulp.
#
# reden van komst
# rbv
#
# conclusie
# bovenstaande 87-jarige patiënte ; onder andere bekend met diverticulose, passagère melena e.c.i. in 2016 en atrium fibilaire w.v. acenocoumarol ; wordt beoordeeld op de spoedeisende hulp met nu rectaal bloedverlies.
#
# circulatie: rectaal bloedverlies ; eenmalig ; hd en hemoglobine-stabiel ; inr stollingswaarde 2.8 ; wd divertikelbloeding dienstdoende toch maagulcus (gezien pijn epigastrio, mogelijk zwarte ontlasting en ureum 13).
#
# beleid
# op de spoedeisende hulp:
# - 10mg fytomenadion (vit. kalium) oraal
# - pantoprazol 80mg infuus
#
# in overleg met dokter kamphuis mdl:
# - opname voor mdl ; geen isolatie indicatie
# - klinisch scopie ; morgen beoordelend colo / gastro of beide
# - acenocoumarol tot nader order pauzeren
# - pantoprazol door op de perfusor
# - vanavond start voorbereiding scopie middels 500cc pleinvue
# - morgen andere 500cc pleinvue
# - po-inspectie ; indien meer bloedverlies vanavond hemoglobine en inr stollingswaarde controle - eventueel. beriplex in overleg met assistent internist
# - niet reanimeren en beademen op wens patiënt
#
# anamnese
# vanmiddag rond 13.30 uur fors helderrood bloedverlies met stolsels. vermengd met ontlasting, mogelijk was deze zwart van kleur. sinds 5 dagen zeurende pijn in de bovenbuik ; maagpijn, waarvoor ze is gestopt met koffie drinken en vet eten. in de afgelopen dagen wat minder ontlasting, bij ook minder intake, maar geen bloed / zwart verkleuring bemerkt.
#
# tractus anamnese: verder niet bijdragend, m.n. geen lw-klachten.
#
# rvg/
# 2002 diep veneuze trombose en longembolie
# 2013 cholecystectomie
# 2015 diverticulitis. ct-scan-abdomen: diverticulitis, geen maligniteit. sigmoïdoscopie: geen rip
# 2016 atriumfibrilleren met spontane conversie naar sinusritme
# 2016 melena, waarvoor geen verklaring werd gevonden. in verband met stabiel hemoglobine en in overleg met patiënte expectatief beleid.
# 2018 vermoeidheid bij sinusbradycardie waarvoor stop metoprolol en tambocor.
#
# medicatie/ onder andere acenocoumarol
#
# all/ penicillines -> urticaria
#
# lichamelijk onderzoek
# controles:
# perifere zuurstofsaturatie	%	96
# hartfrequentie	bpm	95
# nibp	mmhg	132/71(91)
# temperatuur	°c	37,2
#
# alg: niet acuut ziek, niet duidelijk anemisch
# h/h: pearl, geen klieren
# cor: s1s2, geen souffles
# pulm: beiderzijds vag, geen bijgeluiden
# abd: np, wt, soepel abdomen, mild drukpijn epigastrio - geen loslaatpijn, murphy -
# rt: helderrood bloed aan de handschoen, geen feces, geen afwijkingen palpabel, geen hemorroïden
#
# aanvullend onderzoek
# c-reactieve proteine	36	mg/l
# hemoglobine	7.8	mmol/l
# hematocriet	0.38	l/l
# erytrocyten	4.10	x10^12/l
# mcv	93	fl
# leukocyten	10.0	x10^9/l
# trombocyten	176	x10^9/l
# aptt	38	sec
# patient	39.5	sec
# inr stollingswaarde	2.8
# glucose	8.0	mmol/l
# natrium	141	mmol/l
# kalium	4.3	mmol/l
# ureum	13.2	mmol/l
# kreatinine	82	µmol/l
# egfr ckd-epiduraal	55	ml/m/1.73m^2
# bilirubine totaal	7	µmol/l
# alkalische fosfatase (atrium fibilaire)	111	u/l
# ggt	16	u/l
# asat	28	u/l
# alat	18	u/l
# ld	240	u/l
# lipase	28	u/l
# albumine	35	g/l
#
# medicatie actueel
# fytomenadion injvlst 10mg/ml (par/oraal) amp 1ml; infuus; 1 x per dag 10 milligram
# latanoprost oogdruppel 50ug/ml minim 0,2ml; oog; 1 x per dag 1 druppel in beide ogen
# hyaluronzuur oogdruppels 1mg/ml fl 10ml; oog; zo nodig 4 x per dag 1 druppel
# pantoprazol injectiepoeder 40mg fl; intraveneus continu;  8 mg/uur *pomp 8mg/uur, bolus 80mg in 30 minuten.
# acenocoumarol tablet 1mg; oraal; 1 x per dag volgens trombosedienst; stopdatum: tot nader order gestopt
# furosemide tablet 20mg; oraal; 1 x per dag 1 stuk; stopdatum: tot nader order gestopt
# macrogol/zouten pdr v drank (pleinvue); oraal; * volgens voorbereiding scopie ; start vanavond met eerste 500cc
# macrogol/zouten pdr v drank (movicolon+generiek); oraal; 1 x per dag 1 stuk; stopdatum: tot nader order gestopt
# ---------------------------- cleaned:
# 📜 Cleaned: meneer a.j. dingemans, huisarts nr datum 24-11-2020 kenmerk 0007471629 / bsn nr. betreft mevrouw , geen bijzonderheden (87) , tel. geachte collega, bovengenoemde patiënt bezocht op 24-11-2020 de spoedeisende hulp. reden van komst rbv conclusie bovenstaande 87-jarige patiënte ; onder andere bekend met diverticulose, passagère melena e.c.i. in 2016 en atrium fibilaire w.v. acenocoumarol ; wordt beoordeeld op de spoedeisende hulp met nu rectaal bloedverlies. circulatie: rectaal bloedverlies ; eenmalig ; hd en hemoglobine-stabiel ; inr stollingswaarde 2.8 ; wd divertikelbloeding dienstdoende toch maagulcus (gezien pijn epigastrio, mogelijk zwarte ontlasting en ureum 13). beleid op de spoedeisende hulp: - 10mg fytomenadion (vit. kalium) oraal - pantoprazol 80mg infuus in overleg met dokter kamphuis mdl: - opname voor mdl ; geen isolatie indicatie - klinisch scopie ; morgen beoordelend colo / gastro of beide - acenocoumarol tot nader order pauzeren - pantoprazol door op de perfusor - vanavond start voorbereiding scopie middels 500cc pleinvue - morgen andere 500cc pleinvue - po-inspectie ; indien meer bloedverlies vanavond hemoglobine en inr stollingswaarde controle - eventueel. beriplex in overleg met assistent internist - niet reanimeren en beademen op wens patiënt anamnese vanmiddag rond 13.30 uur fors helderrood bloedverlies met stolsels. vermengd met ontlasting, mogelijk was deze zwart van kleur. sinds 5 dagen zeurende pijn in de bovenbuik ; maagpijn, waarvoor ze is gestopt met koffie drinken en vet eten. in de afgelopen dagen wat minder ontlasting, bij ook minder intake, maar geen bloed / zwart verkleuring bemerkt. tractus anamnese: verder niet bijdragend, m.n. geen lw-klachten. rvg/ 2002 diep veneuze trombose en longembolie 2013 cholecystectomie 2015 diverticulitis. ct-scan-abdomen: diverticulitis, geen maligniteit. sigmoïdoscopie: geen rip 2016 atriumfibrilleren met spontane conversie naar sinusritme 2016 melena, waarvoor geen verklaring werd gevonden. in verband met stabiel hemoglobine en in overleg met patiënte expectatief beleid. 2018 vermoeidheid bij sinusbradycardie waarvoor stop metoprolol en tambocor. medicatie/ onder andere acenocoumarol all/ penicillines -> urticaria lichamelijk onderzoek controles: perifere zuurstofsaturatie % 96 hartfrequentie bpm 95 nibp mmhg 132/71(91) temperatuur °c 37,2 alg: niet acuut ziek, niet duidelijk anemisch h/h: pearl, geen klieren cor: s1s2, geen souffles pulm: beiderzijds vag, geen bijgeluiden abd: np, wt, soepel abdomen, mild drukpijn epigastrio - geen loslaatpijn, murphy - rt: helderrood bloed aan de handschoen, geen feces, geen afwijkingen palpabel, geen hemorroïden aanvullend onderzoek c-reactieve proteine 36 mg/l hemoglobine 7.8 mmol/l hematocriet 0.38 l/l erytrocyten 4.10 x10^12/l mcv 93 fl leukocyten 10.0 x10^9/l trombocyten 176 x10^9/l aptt 38 sec patient 39.5 sec inr stollingswaarde 2.8 glucose 8.0 mmol/l natrium 141 mmol/l kalium 4.3 mmol/l ureum 13.2 mmol/l kreatinine 82 μmol/l egfr ckd-epiduraal 55 ml/m/1.73m^2 bilirubine totaal 7 μmol/l alkalische fosfatase (atrium fibilaire) 111 u/l ggt 16 u/l asat 28 u/l alat 18 u/l ld 240 u/l lipase 28 u/l albumine 35 g/l medicatie actueel fytomenadion injvlst 10mg/ml (par/oraal) amp 1ml; infuus; 1 x per dag 10 milligram latanoprost oogdruppel 50ug/ml minim 0,2ml; oog; 1 x per dag 1 druppel in beide ogen hyaluronzuur oogdruppels 1mg/ml fl 10ml; oog; zo nodig 4 x per dag 1 druppel pantoprazol injectiepoeder 40mg fl; intraveneus continu; 8 mg/uur *pomp 8mg/uur, bolus 80mg in 30 minuten. acenocoumarol tablet 1mg; oraal; 1 x per dag volgens trombosedienst; stopdatum: tot nader order gestopt furosemide tablet 20mg; oraal; 1 x per dag 1 stuk; stopdatum: tot nader order gestopt macrogol/zouten pdr v drank (pleinvue); oraal; * volgens voorbereiding scopie ; start vanavond met eerste 500cc macrogol/zouten pdr v drank (movicolon+generiek); oraal; 1 x per dag 1 stuk; stopdatum: tot nader order gestopt
# ----------------------------
# 🩸 Pseudo ID: 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 📜 Content: Reden van komst / Verwijzing:
# Reden van komst (brief): RBV
#
# Anamnese:
# Vanmiddag rond 13.30u fors helderrood bloedverlies met stolsels. Vermengd met ontlasting, mogelijk was deze zwart van kleur. Sinds 5 dagen zeurende pijn in de bovenbuik ; maagpijn, waarvoor ze is gestopt met koffie drinken en vet eten. In de afgelopen dagen wat minder ontlasting, bij ook minder intake, maar geen bloed / zwart verkleuring bemerkt.
#
# Tractus anamnese: verder niet bijdragend, m.n. geen LW-klachten.
#
# rVG/
# 2002 Diep veneuze trombose en longembolie
# 2013 Cholecystectomie
# 2015 Diverticulitis. CT-abdomen: diverticulitis, geen maligniteit. Sigmoïdoscopie: geen RIP
# 2016 Atriumfibrilleren met spontane conversie naar sinusritme
# 2016 Melena, waarvoor geen verklaring werd gevonden. In verband met stabiel Hb en in overleg met patiënte expectatief beleid.
# 2018 Vermoeidheid bij sinusbradycardie waarvoor stop metoprolol en tambocor.
#
# Med/ o.a. Acenocoumarol
#
# All/ Penicillines -> urticaria
#
#
# Lichamelijk onderzoek:
# controles:
# SpO2	%	96
# HR	bpm	95
# ...
# ----------------------------
# 🩸 Pseudo ID: 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 📜 Content: Samenvatting:
# Medisch Dossier
# [ Vk Sputovamo ]
# -Leeftijd in jaren: 80
# -Registratie datum SEH: 21-10-2013
# -Verantwoordelijk assistent: <ObjectGegevens>
# -Verantwoordelijk arts: <ObjectGegevens>
# -Dienstdoend specialist: <ObjectGegevens>
# -Reden van komst: <ObjectGegevens>
# [ Medisch dossier ]
# [ Anamnese ]
# -Anamnese: VG:
# Hartritmestoornissen
# DVT, Longembolie
# Erdere periodes van pijn op de borst, niet gerelateerd aan inspanning
#
# Patient wordt vannacht rond 1 uur wakker van een stekende pijn over de gehele bovenbuik. Trekt naar de rug en schouders. Pijn is nu continue. Drie keer gebraakt vanochtend. N+, geen bloed erbij. R-. Gister avond frietjes gegeten. Geen awijkingen bij ontlasting of mictie.
# Niet dyspneuisch
# -Intoxicatie: rookt niet, geen alcohol
# -Familieanamnese: cardiovasc. neg, vader galstenen
# -Medicatie: Acenocoumarol, Tambocor, "plastablett"
# -A = Allergieën (alleen verpleegkundig): onbekend
# [ Onderzoek ]
# -Lichamelijk onderzoek: Bij inspectie geen bijzonderheden
# Abd/Normale darmgeruisen, wisselnde tympanie. Geen percussiepijn. Drukpijnlijk met defense RBB. Geen loslaatpijn.
# Cor/ S1 S2 S-
# Pul/ VAG
# -Aanvullend onderzoek: Ja
# -Lab: crp <5 milde LFstoornissen amylase 129
# -Medische beelden: Echo Bovenbuik: concrementen, geen duidelijke cholecystitis
# x-Thorax: geen pneumonie
# -Overig: ECG: Geen aanwijzingen voor ischemie (beoordeeld dr Lichteveld SEH)
# [ Conclusie ]
# -(Werk)diagnose: Sympt cholecystolithiasis goede reactie op pijnstilling
# [ Beleid ]
# -Beleid: Poliklinisch vervolg 2dgn co + lab: indien gb inplannen lap chol
# uitleg
# tramal, buscopan mee voor zn bij klachten
# na pijnstilling op SEH pijn vrij
# [ Overig ]
# -Gezien door (naam, functie): S. Smeets aios chirurgie
# [ hulplijst sepsis ]
# -Bestaat er op basis van de anamnese een verdenking op een infectie: Nee
# ---------------- corrected:
# 📜 Corrected: samenvatting:
# medisch dossier
# [ vk sputovamo ]
# -leeftijd in jaren: 80
# -registratie datum spoedeisende hulp: 21-10-2013
# -verantwoordelijk assistent: <objectgegevens>
# -verantwoordelijk arts: <objectgegevens>
# -dienstdoend specialist: <objectgegevens>
# -reden van komst: <objectgegevens>
# [ medisch dossier ]
# [ anamnese ]
# -anamnese: voorgeschiedenis:
# hartritmestoornissen
# deep veneuze trombose, longembolie
# erdere periodes van pijn op de borst, niet gerelateerd aan inspanning
#
# patient wordt vannacht rond 1 uur wakker van een stekende pijn over de gehele bovenbuik. trekt naar de rug en schouders. pijn is nu continue. drie keer gebraakt vanochtend. n+, geen bloed erbij. r-. gister avond frietjes gegeten. geen awijkingen bij ontlasting of mictie.
# niet dyspneuisch
# -intoxicatie: rookt niet, geen alcohol
# -familieanamnese: cardiovasc. neg, vader galstenen
# -medicatie: acenocoumarol, tambocor, "plastablett"
# -a = allergieën (alleen verpleegkundig): onbekend
# [ onderzoek ]
# -lichamelijk onderzoek: bij inspectie geen bijzonderheden
# abd/normale darmgeruisen, wisselnde tympanie. geen percussiepijn. drukpijnlijk met defense rbb. geen loslaatpijn.
# cor/ s1 s2 s-
# pul/ vag
# -aanvullend onderzoek: ja
# -lab: c-reactieve proteine <5 milde lfstoornissen amylase 129
# -medische beelden: echo bovenbuik: concrementen, geen duidelijke cholecystitis
# röntgenfoto van thorax: geen pneumonie
# -overig: ecg: geen aanwijzingen voor ischemie (beoordeeld dr lichteveld spoedeisende hulp)
# [ conclusie ]
# -(werk)diagnose: sympt cholecystolithiasis goede reactie op pijnstilling
# [ beleid ]
# -beleid: poliklinisch vervolg 2dgn co + lab: indien geen bijzonderheden inplannen lap chol
# uitleg
# tramal, buscopan mee voor zo nodig bij klachten
# na pijnstilling op spoedeisende hulp pijn vrij
# [ overig ]
# -gezien door (naam, functie): s. smeets aios chirurgie
# [ hulplijst sepsis ]
# -bestaat er op basis van de anamnese een verdenking op een infectie: nee
# ---------------------------- cleaned:
# 📜 Cleaned: samenvatting: medisch dossier -leeftijd in jaren: 80 -registratie datum spoedeisende hulp: 21-10-2013 -verantwoordelijk assistent: <objectgegevens> -verantwoordelijk arts: <objectgegevens> -dienstdoend specialist: <objectgegevens> -reden van komst: <objectgegevens> -anamnese: voorgeschiedenis: hartritmestoornissen deep veneuze trombose, longembolie erdere periodes van pijn op de borst, niet gerelateerd aan inspanning patient wordt vannacht rond 1 uur wakker van een stekende pijn over de gehele bovenbuik. trekt naar de rug en schouders. pijn is nu continue. drie keer gebraakt vanochtend. n+, geen bloed erbij. r-. gister avond frietjes gegeten. geen awijkingen bij ontlasting of mictie. niet dyspneuisch -intoxicatie: rookt niet, geen alcohol -familieanamnese: cardiovasc. neg, vader galstenen -medicatie: acenocoumarol, tambocor, "plastablett" -a = allergieën (alleen verpleegkundig): onbekend -lichamelijk onderzoek: bij inspectie geen bijzonderheden abd/normale darmgeruisen, wisselnde tympanie. geen percussiepijn. drukpijnlijk met defense rbb. geen loslaatpijn. cor/ s1 s2 s- pul/ vag -aanvullend onderzoek: ja -lab: c-reactieve proteine <5 milde lfstoornissen amylase 129 -medische beelden: echo bovenbuik: concrementen, geen duidelijke cholecystitis röntgenfoto van thorax: geen pneumonie -overig: ecg: geen aanwijzingen voor ischemie (beoordeeld dr lichteveld spoedeisende hulp) -(werk)diagnose: sympt cholecystolithiasis goede reactie op pijnstilling -beleid: poliklinisch vervolg 2dgn co + lab: indien geen bijzonderheden inplannen lap chol uitleg tramal, buscopan mee voor zo nodig bij klachten na pijnstilling op spoedeisende hulp pijn vrij -gezien door (naam, functie): s. smeets aios chirurgie -bestaat er op basis van de anamnese een verdenking op een infectie: nee
# ----------------------------
# 🩸 Pseudo ID: 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 📜 Content: Samenvatting:
# vocht in vocht uit
# -Tijd: 10:41
# [ Toediening ]
# -Soort infuus: Anders
# -Memo medicatie: paracetamol iv
# -Aan: 100
# -In: 100
# -Totaal in tijdens seh-periode: 100
# ---------------- corrected:
# 📜 Corrected: samenvatting:
# vocht in vocht uit
# -tijd: 10:41
# [ toediening ]
# -soort infuus: anders
# -memo medicatie: paracetamol infuus
# -aan: 100
# -in: 100
# -totaal in tijdens spoedeisende hulp-periode: 100
# ---------------------------- cleaned:
# 📜 Cleaned: samenvatting: vocht in vocht uit -tijd: 10:41 -soort infuus: anders -memo medicatie: paracetamol infuus -aan: 100 -in: 100 -totaal in tijdens spoedeisende hulp-periode: 100
# ----------------------------
# 🩸 Pseudo ID: 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 📜 Content: Samenvatting:
# vocht in vocht uit
# -Tijd: 10:40
# [ Toediening ]
# -Soort infuus: NaCL 0,9%
# -Aan: 500
# ---------------- corrected:
# 📜 Corrected: samenvatting:
# vocht in vocht uit
# -tijd: 10:40
# [ toediening ]
# -soort infuus: natriumchloride 0,9%
# -aan: 500
# ---------------------------- cleaned:
# 📜 Cleaned: samenvatting: vocht in vocht uit -tijd: 10:40 -soort infuus: natriumchloride 0,9% -aan: 500
# ----------------------------
# 🩸 Pseudo ID: 046D1FFEBDD40E1665D0ABA6DD8FC9F8BC4351C6
# 📜 Content: Samenvatting:
# Verpleegkundige verslaglegging
# -Verantwoordelijk verpleegkundige:: <ObjectGegevens>
# [ Vplk SPUTOVAMO ]
# -Leeftijd: 80
# [ Collumcare ]
# -Collumcare patiënt: Nee
# [ Sepsis ]
# -Bestaat er op basis van de anamnese een verdenking op een infectie: Nee
# [ Anamnese ]
# -Leeftijd anamnese: 80
# -(Hoofd)klacht: <ObjectGegevens>
# -A = Allergieën (alleen verpleegkundig): onbekend
# -M = Medication: tambocor, plastablet, sintrom
# -P = Past: baarmoeder verwijderd. AF. epstaxis. longembolieen.
# -L = Last meal: gisteren
# -E = Event: Vannacht wakker geworden met pijn in de bovenbuik, uitstralend naar de rug. Pijn is continue aanwezig. Zit niet vast aan de ademhaling, geen lange reis gemaakt. N: + V: +. Def: bruin als anders, geen bloedbijmenging. Gisteren friet gegeten, eet nooit zo vet.
# A: Vrij.
# B: VAG beiderzijds. Symmetrische thoraxexcursies. Geen gebruik ha-spieren.
# C: Krachtige regulaire radialis. Bleke huidskleur. Droge huid. Cap refill normaal. rr: re=li.
# D: A
# -Gebruikt u antistolling via de Trombosedienst?: Ja
# -Pijnscore invullen?: Ja
# -Patientkenmerk: SEH patiënt
# [ Pijnscore ]
# -Pijnscore: 8
# -Score tbv grafiek: 8
# [ Extra pijnscore SEH ]
# -Medicatie toegediend op de SEH: Ja, Ja, Ja, Ja
# -Tijd toediening Medicatie: 10:40
# -Toegediende medicatie: Pijnstilling
# -Pijnstilling: Paracetamol en 1000 mg
# -Wijze van toediening medicatie: I.V
# -Toegediend door: wendy + leonie
# -Tijd toediening Medicatie: 11:51
# -Toegediende medicatie: Pijnstilling
# -Pijnstilling: Buscopan en 20 mg
# -Wijze van toediening medicatie: I.V
# -Toegediend door: wendy + diane
# -Tijd toediening Medicatie: 13:42
# -Toegediende medicatie: Pijnstilling
# -Pijnstilling: Diclofenac en 75
# -Wijze van toediening medicatie: I.M
# -Toegediend door: wendy + leonie
# -Tijd toediening Medicatie: 13:42
# -Toegediende medicatie: Anders
# -Andere medicatie: pantozol 40 mg
# -Wijze van toediening medicatie: P.O.
# -Labaanvraag SEH: Labaanvraag SEH, Labaanvraag SEH
# -Verpleegkundige handelingen: IV canule (V), Lab, Urinesediment, Urinekweek, Röntgen, ECHO en ECG (V)
# -Aanvullende informatie: Mw wil nog geen morfine daar ze daar misselijk van word en de pijn zakt iets op paracetamol.
# x-thorax
# echo bovenbuik
# [ Contacten ]
# [ Contactpersonen ]
# -Wat is zijn/haar telefoonnummer?: [PHONENUMBER]
# [ MTS triage ]
# -Triagekeuze: Buikpijn volwassene
# -Buikpijn volwassene: Matige pijn
# -Triage: Nee
# -Triage: Nee
# -Triage: Ja
# -Triage: Nee
# -Triage: Nee
# -Pijnscore bij ontslag: Ja
# -Algemene toelichting bij vertrek: co 23-10 om 8:45 lab en later om 9:45 op poli. Recept buscopan + tramadol. Mw kreeg info hierover. Bij toename klachten retour seh.
# -Pijnscore: 2
# ---------------- corrected:
# 📜 Corrected: samenvatting:
# verpleegkundige verslaglegging
# -verantwoordelijk verpleegkundige:: <objectgegevens>
# [ vplk sputovamo ]
# -leeftijd: 80
# [ collumcare ]
# -collumcare patiënt: nee
# [ sepsis ]
# -bestaat er op basis van de anamnese een verdenking op een infectie: nee
# [ anamnese ]
# -leeftijd anamnese: 80
# -(hoofd)klacht: <objectgegevens>
# -a = allergieën (alleen verpleegkundig): onbekend
# -m = medication: tambocor, plastablet, sintrom
# -p = past: baarmoeder verwijderd. atrium fibilaire. epstaxis. longembolieen.
# -l = last meal: gisteren
# -e = event: vannacht wakker geworden met pijn in de bovenbuik, uitstralend naar de rug. pijn is continue aanwezig. zit niet vast aan de ademhaling, geen lange reis gemaakt. n: + v: +. defecatie: bruin als anders, geen bloedbijmenging. gisteren friet gegeten, eet nooit zo vet.
# luchtwegen: vrij.
# ademhaling: vag beiderzijds. symmetrische thoraxexcursies. geen gebruik huisarts-spieren.
# circulatie: krachtige regulaire radialis. bleke huidskleur. droge huid. cap refill normaal. bloeddruk: rechter=linker.
# onbekwaamheid: a
# -gebruikt u antistolling via de trombosedienst?: ja
# -pijnscore invullen?: ja
# -patientkenmerk: spoedeisende hulp patiënt
# [ pijnscore ]
# -pijnscore: 8
# -score tbv grafiek: 8
# [ extra pijnscore spoedeisende hulp ]
# -medicatie toegediend op de spoedeisende hulp: ja, ja, ja, ja
# -tijd toediening medicatie: 10:40
# -toegediende medicatie: pijnstilling
# -pijnstilling: paracetamol en 1000 mg
# -wijze van toediening medicatie: infuus
# -toegediend door: wendy + leonie
# -tijd toediening medicatie: 11:51
# -toegediende medicatie: pijnstilling
# -pijnstilling: buscopan en 20 mg
# -wijze van toediening medicatie: infuus
# -toegediend door: wendy + diane
# -tijd toediening medicatie: 13:42
# -toegediende medicatie: pijnstilling
# -pijnstilling: diclofenac en 75
# -wijze van toediening medicatie: i.m
# -toegediend door: wendy + leonie
# -tijd toediening medicatie: 13:42
# -toegediende medicatie: anders
# -andere medicatie: pantozol 40 mg
# -wijze van toediening medicatie: per order
# -labaanvraag spoedeisende hulp: labaanvraag spoedeisende hulp, labaanvraag spoedeisende hulp
# -verpleegkundige handelingen: infuus canule (v), lab, urinesediment, urinekweek, röntgen, echo en ecg (v)
# -aanvullende informatie: mevrouw wil nog geen morfine daar ze daar misselijk van word en de pijn zakt iets op paracetamol.
# röntgenfoto van thorax
# echo bovenbuik
# [ contacten ]
# [ contactpersonen ]
# -wat is zijn/haar telefoonnummer?: [phonenumber]
# [ mts triage ]
# -triagekeuze: buikpijn volwassene
# -buikpijn volwassene: matige pijn
# -triage: nee
# -triage: nee
# -triage: ja
# -triage: nee
# -triage: nee
# -pijnscore bij ontslag: ja
# -algemene toelichting bij vertrek: co 23-10 om 8:45 lab en later om 9:45 op poli. recept buscopan + tramadol. mevrouw kreeg info hierover. bij toename klachten retour spoedeisende hulp.
# -pijnscore: 2
# ---------------------------- cleaned:
# 📜 Cleaned: samenvatting: verpleegkundige verslaglegging -verantwoordelijk verpleegkundige:: <objectgegevens> -leeftijd: 80 -collumcare patiënt: nee -bestaat er op basis van de anamnese een verdenking op een infectie: nee -leeftijd anamnese: 80 -(hoofd)klacht: <objectgegevens> -a = allergieën (alleen verpleegkundig): onbekend -m = medication: tambocor, plastablet, sintrom -p = past: baarmoeder verwijderd. atrium fibilaire. epstaxis. longembolieen. -l = last meal: gisteren -e = event: vannacht wakker geworden met pijn in de bovenbuik, uitstralend naar de rug. pijn is continue aanwezig. zit niet vast aan de ademhaling, geen lange reis gemaakt. n: + v: +. defecatie: bruin als anders, geen bloedbijmenging. gisteren friet gegeten, eet nooit zo vet. luchtwegen: vrij. ademhaling: vag beiderzijds. symmetrische thoraxexcursies. geen gebruik huisarts-spieren. circulatie: krachtige regulaire radialis. bleke huidskleur. droge huid. cap refill normaal. bloeddruk: rechter=linker. onbekwaamheid: a -gebruikt u antistolling via de trombosedienst?: ja -pijnscore invullen?: ja -patientkenmerk: spoedeisende hulp patiënt -pijnscore: 8 -score tbv grafiek: 8 -medicatie toegediend op de spoedeisende hulp: ja, ja, ja, ja -tijd toediening medicatie: 10:40 -toegediende medicatie: pijnstilling -pijnstilling: paracetamol en 1000 mg -wijze van toediening medicatie: infuus -toegediend door: wendy + leonie -tijd toediening medicatie: 11:51 -toegediende medicatie: pijnstilling -pijnstilling: buscopan en 20 mg -wijze van toediening medicatie: infuus -toegediend door: wendy + diane -tijd toediening medicatie: 13:42 -toegediende medicatie: pijnstilling -pijnstilling: diclofenac en 75 -wijze van toediening medicatie: i.m -toegediend door: wendy + leonie -tijd toediening medicatie: 13:42 -toegediende medicatie: anders -andere medicatie: pantozol 40 mg -wijze van toediening medicatie: per order -labaanvraag spoedeisende hulp: labaanvraag spoedeisende hulp, labaanvraag spoedeisende hulp -verpleegkundige handelingen: infuus canule (v), lab, urinesediment, urinekweek, röntgen, echo en ecg (v) -aanvullende informatie: mevrouw wil nog geen morfine daar ze daar misselijk van word en de pijn zakt iets op paracetamol. röntgenfoto van thorax echo bovenbuik -wat is zijn/haar telefoonnummer?: -triagekeuze: buikpijn volwassene -buikpijn volwassene: matige pijn -triage: nee -triage: nee -triage: ja -triage: nee -triage: nee -pijnscore bij ontslag: ja -algemene toelichting bij vertrek: co 23-10 om 8:45 lab en later om 9:45 op poli. recept buscopan + tramadol. mevrouw kreeg info hierover. bij toename klachten retour spoedeisende hulp. -pijnscore: 2
# ----------------------------

# %%
# def correct_spelling(text: Union[str, None], vocab: List[str]) -> Union[str, None]:
#     """
#     Correct spelling mistakes in the input text using LanguageTool and a specified vocabulary.

#     Args:
#         text (Union[str, None]): The input text to correct spelling.
#         vocab (List[str]): A list of words considered correct, which are not flagged as misspellings.

#     Returns:
#         Union[str, None]: The corrected text if input is a string; otherwise, the original input.
#     """
#     spelling_mistakes = []
#     if isinstance(text, str):
#         matches = tool.check(text)
#         is_correctly_spelled = lambda rule: rule.ruleIssueType == 'misspelling' and rule.matchedText in vocab
#         contains_digit = lambda s: any(char.isdigit() for char in s)
        
#         for match in matches:
#             if not is_correctly_spelled(match) and not contains_digit(match.matchedText):
#                 spelling_mistakes.append(match)
        
#         corrected_text = language_tool_python.utils.correct(text, spelling_mistakes)
#         return corrected_text
#     else:
#         return text

# %%
from typing import Union, List
import language_tool_python

# Initialize globally once
tool = language_tool_python.LanguageTool('nl')

# Define the function
def correct_spelling(text: Union[str, None], vocab: List[str]) -> Union[str, None]:
    if not isinstance(text, str):
        return text
    
    matches = tool.check(text)
    is_correctly_spelled = lambda rule: rule.ruleIssueType == 'misspelling' and rule.matchedText in vocab
    contains_digit = lambda s: any(char.isdigit() for char in s)

    spelling_mistakes = [
        match for match in matches
        if not is_correctly_spelled(match) and not contains_digit(match.matchedText)
    ]

    corrected_text = language_tool_python.utils.correct(text, spelling_mistakes)
    return corrected_text

# %%
# Create cache dictionary
cache = {}
vocab_tuple = tuple(abbreviations_dict)  # Convert to tuple if needed for hashing

# Function to wrap with cache
def correct_spelling_cached(text):
    print(f"Checking spelling for: {text}")
    if text in cache:
        print(f"Using cached result for: {text}")
        return cache[text]
    result = correct_spelling(text, vocab=abbreviations_dict)
    cache[text] = result
    
    return result

# %%
# Select one patient's row — you can also use df.loc[...] to filter by ID
sample_row = df_abbreviations.iloc[0]  # First row

# Extract the text
text_before = sample_row['abbreviations_corrected_cleaned']

# Clean + correct
text_after = correct_spelling(text_before, vocab=abbreviations_dict)

# Create a comparison DataFrame
comparison_df = pd.DataFrame({
    'Original': [text_before],
    'Corrected': [text_after]
})

comparison_df
print(comparison_df['Original'][])
print('--------------------')
print(comparison_df['Corrected'])
# Out:
# 0    meneer a.j. dingemans, huisarts nr datum 29-11...
# Name: Original, dtype: object
# --------------------
# 0    Meneer a.j. Dingemans, huisarts nr. datum 29-1...
# Name: Corrected, dtype: object

# %%
comparison_df
print(comparison_df['Original'][0])
print('--------------------')
print(comparison_df['Corrected'][0])
# Out:
# meneer a.j. dingemans, huisarts nr datum 29-11-2020 kenmerk 0007475372 / bsn nr. betreft mevrouw , geen bijzonderheden (87) , tel. geachte collega, bovengenoemde patiënte was opgenomen van 24-11-2020 tot en met 26-11-2020 op de afdeling maag-, darm- en leverziekten in verband met melaena en rectaal bloedverlies. voorgeschiedenis 2002 diep veneuze trombose en longembolie 2013 cholecystectomie 2015 diverticulitis 2016 atriumfibrilleren met spontane conversie naar sinusritme 2016 melena, waarvoor geen verklaring werd gevonden. in verband met stabiel hemoglobine en in overleg met patiënte expectatief beleid. 2018 vermoeidheid bij sinusbradycardie waarvoor stop metoprolol en tambocor. anamnese vanmiddag rond 13.30 uur fors helderrood bloedverlies met stolsels. vermengd met ontlasting, mogelijk was deze zwart van kleur. sinds 5 dagen zeurende pijn in de bovenbuik; maagpijn, waarvoor ze is gestopt met koffie drinken en vet eten. in de afgelopen dagen wat minder ontlasting, bij ook minder intake, maar geen bloed / zwart verkleuring bemerkt. tractus anamnese: verder niet bijdragend, m.n. geen lw-klachten. all/ penicillines -> urticaria lichamelijk onderzoek controles: perifere zuurstofsaturatie % 96 hartfrequentie bpm 95 nibp mmhg 132/71(91) temperatuur °c 37,2 alg: niet acuut ziek, niet duidelijk anemisch h/h: pearl, geen lymfadenopathie cor: s1s2, geen souffles pulm: vag beiderzijds, geen bijgeluiden abd: normale peristaltiek, wisselende tympanie, soepel abdomen, mild drukpijn epigastrio - geen loslaatpijn, murphy - rt: helderrood bloed aan de handschoen, geen feces, geen afwijkingen palpabel, geen hemorroïden aanvullend onderzoek laboratorium 24-11-2020 hematologie: c-reactieve proteine (h): 36 mg/l (minder dan 5), hemoglobine: 7.8 mmol/l (7.5 - 10.0), hematocriet: 0.38 l/l (0.35 - 0.45), erytrocyten: 4.10 x10^12/l (4.00 - 5.00), mcv: 93 fl (80 - 100), leukocyten: 10.0 x10^9/l (4.0 - 10.0), trombocyten: 176 x10^9/l (150 - 400) hemostase: aptt (h): 38 sec (25 - 34), patient (h): 39.5 sec (12.1 - 15.6), inr stollingswaarde (h): 2.8 (0.8 - 1.2) bloedgroep: bloedgroep: a neg, iat: neg. (negatief) chemie: glucose (h): 8.0 mmol/l (4.0 - 7.8), natrium: 141 mmol/l (135 - 145), kalium: 4.3 mmol/l (3.5 - 5.0), ureum (h): 13.2 mmol/l (2.5 - 6.4), kreatinine: 82 μmol/l (49 - 90), egfr ckd-epiduraal (l): 55 ml/m/1.73m^2 (> 90), bilirubine totaal: 7 μmol/l (minder dan 17), alkalische fosfatase (atrium fibilaire) (h): 111 u/l (33 - 98), ggt: 16 u/l (minder dan 38), asat: 28 u/l (minder dan 31), alat: 18 u/l (minder dan 34), ld: 240 u/l (minder dan 247), lipase: 28 u/l (13 - 60), albumine: 35 g/l (35 - 50) gastroscopie 25-11-2020 geen bloed of bloedingsbron bij gastroscopie. coloscopie 25-11-2020 coloscopie tot in het colon ascendens. lange darm, scopie tot bij de klep. bloeding gestopt, geen bloedingsbron gevonden. pandiverticulose maar vooral in sigmoid. waarschijnlijkheidsdiagnose is divertikelbloeding laboratorium 26-11-2020 hematologie: hemoglobine (l): 6.8 mmol/l (7.5 - 10.0), mcv: 97 fl (80 - 100) beloop de patiënte werd op 24-11-2020 opgenomen in verband met melaena en hierbij ook helderrood rectaal bloedverlies onder acenocoumarol. de acenocoumarol werd gestaakt en gecoupeerd. bij een verdenking van zowel hoge als lage tractus digestivus bloeding werd er gestart met een pantoprazol perfusor en werd de patiënte voorbereid voor zowel een gastro- als coloscopie. gedurende de avond werd de patiënte na nogmaals fors melaena gehad te hebben hypotensief (bloeddruk 100/58) waarvoor er een 1l infuus werd gestart. de patiënte had hierbij geen klachten. de volgende dag kreeg de patiënte zowel de gasto- als coloscopie waarop uitgebreide diverticulose gezien werd en geen actieve bloedingsbron waardoor de werkdiagnose divertikelbloeding werd. op de coloscopie kon de coecumbodem niet volledig beoordeeld worden. dit hebben we met de patiënte en familie besproken, theoretisch zou hier een coecumproces kunnen zitten echter is deze kans klein omdat caecum re ...
# --------------------
# Meneer a.j. Dingemans, huisarts nr. datum 29-11-2020 kenmerk 0007475372 / bsn nr. betreft mevrouw, geen bijzonderheden (87), tel. geachte collega, bovengenoemde patiënte was opgenomen van 24-11-2020 tot en met 26-11-2020 op de afdeling maag-, darm- en leverziekten in verband met melden en rectaal bloedverlies. Voorgeschiedenis 2002 diep veneuze trombose en longembolie 2013 cholecystectomie 2015 diverticulitis 2016 atriumfibrilleren met spontane conversie naar sinusritme 2016 Elena, waarvoor geen verklaring werd gevonden. In verband met stabiel hemoglobine en in overleg met patiënte executief beleid. 2018 vermoeidheid bij sinusbradycardie waarvoor stop metoprolol en tamboer. Anamnese vanmiddag rond 13.30 uur fors helderrood bloedverlies met stolsels. Vermengd met ontlasting, mogelijk was deze zwart van kleur. Sinds 5 dagen zeurende pijn in de bovenbuik; maagpijn, waarvoor ze is gestopt met koffie drinken en vet eten. In de afgelopen dagen wat minder ontlasting, bij ook minder intake, maar geen bloed / zwart verkleuring bemerkt. Tactus anamnese: verder niet bijdragend, m.n. geen ME-klachten. All/ penicillines → Ricarda lichamelijk onderzoek controles: perifere zuurstofsaturatie % 96 hartfrequentie bpm 95 nip mag 132/71(91) temperatuur ° c 37,2 alg: niet acuut ziek, niet duidelijk anemisch h/h: Pearl, geen lymfadenopathie cor: s1s2, geen souffles Pulm: van beiderzijds, geen bijgeluiden Abd: normale peristaltiek, wisselende tympanie, soepel abdomen, mild drukpijn Pilastro - geen loslaatpijn, Murphy - RT: helderrood bloed aan de handschoen, geen feces, geen afwijkingen palpabel, geen hemorroïden aanvullend onderzoek laboratorium 24-11-2020 hematologie: creatieve proteïne (h): 36 mg/l (minder dan 5), hemoglobine: 7.8 mmol/l (7.5 - 10.0), hematocriet: 0.38 l/l (0.35 - 0.45), erytrocyten: 4.10 x10^12/l (4.00 - 5.00), mcv: 93 fl (80 - 100), leukocyten: 10.0 x10^9/l (4.0 - 10.0), trombocyten: 176 x10^9/l (150 - 400) homeostase: PTT (h): 38 sec (25 - 34), patiënt (h): 39.5 sec (12.1 - 15.6), in stollingswaarde (h): 2.8 (0.8 - 1.2) bloedgroep: bloedgroep: a neg, dat: neg. (negatief) chemie: glucose (h): 8.0 mmol/l (4.0 - 7.8), natrium: 141 mmol/l (135 - 145), kalium: 4.3 mmol/l (3.5 - 5.0), ureum (h): 13.2 mmol/l (2.5 - 6.4), creatinine: 82 Mol/l (49 - 90), EGR ckd-epiduraal (l): 55 ml/m/1.73m^2 (> 90), bilirubine totaal: 7 Mol/l (minder dan 17), alkalische fosfatase (atrium bifilaire) (h): 111 u/l (33 - 98), gat: 16 u/l (minder dan 38), aast: 28 u/l (minder dan 31), laat: 18 u/l (minder dan 34), Ld: 240 u/l (minder dan 247), lipase: 28 u/l (13 - 60), albumine: 35 g/l (35 - 50) gastroscopie 25-11-2020 geen bloed of bloedingsbron bij gastroscopie. Coloscopie 25-11-2020 coloscopie tot in het colon ascendent. Lange darm, scope tot bij de klep. Bloeding gestopt, geen bloedingsbron gevonden. pandiverticulose maar vooral in Sigmond. Waarschijnlijkheidsdiagnose is divertikelbloeding laboratorium 26-11-2020 hematologie: hemoglobine (l): 6.8 mmol/l (7.5 - 10.0), mcv: 97 fl (80 - 100) beloop de patiënte werd op 24-11-2020 opgenomen in verband met melden en hierbij ook helderrood rectaal bloedverlies onder acenocoumarol. De acenocoumarol werd gestaakt en gecoupeerd. Bij een verdenking van zowel hoge als lage Tactus digesties bloeding werd er gestart met een pantoprazol perfusie en werd de patiënte voorbereid voor zowel een gastrol als coloscopie. Gedurende de avond werd de patiënte na nogmaals fors melden gehad te hebben hypotensief (bloeddruk 100/58) waarvoor er een 1l infuus werd gestart. De patiënte had hierbij geen klachten. De volgende dag kreeg de patiënte zowel de Gaston als coloscopie waarop uitgebreide diverticulose gezien werd en geen actieve bloedingsbron waardoor de werkdiagnose divertikelbloeding werd. Op de coloscopie kon de boezembodem niet volledig beoordeeld worden. Dit hebben we met de patiënte en familie besproken, theoretisch zou hier een coachproces kunnen zitten echter is deze kans klein omdat calcium redelijk te overzien was.  ...

# %%
# # Apply to DataFrame
# df_abbreviations['spelling_corrected'] = df_abbreviations['abbreviations_corrected_cleaned'].apply(correct_spelling_cached)
# Out:
# Checking spelling for: meneer a.j. dingemans, huisarts nr datum 29-11-2020 kenmerk 0007475372 / bsn nr. betreft mevrouw , geen bijzonderheden (87) , tel. geachte collega, bovengenoemde patiënte was opgenomen van 24-11-2020 tot en met 26-11-2020 op de afdeling maag-, darm- en leverziekten in verband met melaena en rectaal bloedverlies. voorgeschiedenis 2002 diep veneuze trombose en longembolie 2013 cholecystectomie 2015 diverticulitis 2016 atriumfibrilleren met spontane conversie naar sinusritme 2016 melena, waarvoor geen verklaring werd gevonden. in verband met stabiel hemoglobine en in overleg met patiënte expectatief beleid. 2018 vermoeidheid bij sinusbradycardie waarvoor stop metoprolol en tambocor. anamnese vanmiddag rond 13.30 uur fors helderrood bloedverlies met stolsels. vermengd met ontlasting, mogelijk was deze zwart van kleur. sinds 5 dagen zeurende pijn in de bovenbuik; maagpijn, waarvoor ze is gestopt met koffie drinken en vet eten. in de afgelopen dagen wat minder ontlasting, bij ook minder intake, maar geen bloed / zwart verkleuring bemerkt. tractus anamnese: verder niet bijdragend, m.n. geen lw-klachten. all/ penicillines -> urticaria lichamelijk onderzoek controles: perifere zuurstofsaturatie % 96 hartfrequentie bpm 95 nibp mmhg 132/71(91) temperatuur °c 37,2 alg: niet acuut ziek, niet duidelijk anemisch h/h: pearl, geen lymfadenopathie cor: s1s2, geen souffles pulm: vag beiderzijds, geen bijgeluiden abd: normale peristaltiek, wisselende tympanie, soepel abdomen, mild drukpijn epigastrio - geen loslaatpijn, murphy - rt: helderrood bloed aan de handschoen, geen feces, geen afwijkingen palpabel, geen hemorroïden aanvullend onderzoek laboratorium 24-11-2020 hematologie: c-reactieve proteine (h): 36 mg/l (minder dan 5), hemoglobine: 7.8 mmol/l (7.5 - 10.0), hematocriet: 0.38 l/l (0.35 - 0.45), erytrocyten: 4.10 x10^12/l (4.00 - 5.00), mcv: 93 fl (80 - 100), leukocyten: 10.0 x10^9/l (4.0 - 10.0), trombocyten: 176 x10^9/l (150 - 400) hemostase: aptt (h): 38 sec (25 - 34), patient (h): 39.5 sec (12.1 - 15.6), inr stollingswaarde (h): 2.8 (0.8 - 1.2) bloedgroep: bloedgroep: a neg, iat: neg. (negatief) chemie: glucose (h): 8.0 mmol/l (4.0 - 7.8), natrium: 141 mmol/l (135 - 145), kalium: 4.3 mmol/l (3.5 - 5.0), ureum (h): 13.2 mmol/l (2.5 - 6.4), kreatinine: 82 μmol/l (49 - 90), egfr ckd-epiduraal (l): 55 ml/m/1.73m^2 (> 90), bilirubine totaal: 7 μmol/l (minder dan 17), alkalische fosfatase (atrium fibilaire) (h): 111 u/l (33 - 98), ggt: 16 u/l (minder dan 38), asat: 28 u/l (minder dan 31), alat: 18 u/l (minder dan 34), ld: 240 u/l (minder dan 247), lipase: 28 u/l (13 - 60), albumine: 35 g/l (35 - 50) gastroscopie 25-11-2020 geen bloed of bloedingsbron bij gastroscopie. coloscopie 25-11-2020 coloscopie tot in het colon ascendens. lange darm, scopie tot bij de klep. bloeding gestopt, geen bloedingsbron gevonden. pandiverticulose maar vooral in sigmoid. waarschijnlijkheidsdiagnose is divertikelbloeding laboratorium 26-11-2020 hematologie: hemoglobine (l): 6.8 mmol/l (7.5 - 10.0), mcv: 97 fl (80 - 100) beloop de patiënte werd op 24-11-2020 opgenomen in verband met melaena en hierbij ook helderrood rectaal bloedverlies onder acenocoumarol. de acenocoumarol werd gestaakt en gecoupeerd. bij een verdenking van zowel hoge als lage tractus digestivus bloeding werd er gestart met een pantoprazol perfusor en werd de patiënte voorbereid voor zowel een gastro- als coloscopie. gedurende de avond werd de patiënte na nogmaals fors melaena gehad te hebben hypotensief (bloeddruk 100/58) waarvoor er een 1l infuus werd gestart. de patiënte had hierbij geen klachten. de volgende dag kreeg de patiënte zowel de gasto- als coloscopie waarop uitgebreide diverticulose gezien werd en geen actieve bloedingsbron waardoor de werkdiagnose divertikelbloeding werd. op de coloscopie kon de coecumbodem niet volledig beoordeeld worden. dit hebben we met de patiënte en familie besproken, theoretisch zou hier een coecumproces kunnen zitten echter is deze kan ...
# Checking spelling for: samenvatting: rectaal bloedverlies onder begeleiding van divertikelbloeding; onder acenocoumarol (wegens atrium fibilaire), gecoupeerd. op colo pandiverticulose. beloop: verpleegkundige/ geen rectaal bloedverlies meer gehad. voelt zich goed, geen klachten van lage bloeddruk. wil graag naar huis. goed gegeten vanochtend, hierbij geen klachten. aan bed/ geen klachten meer, goed gevoel over naar huis gaan. geen bloed meer gezien. met patiënte en schoondochter de uitslag van de coloscopie nog eens besproken. aangegeven dat de coecum bodem niet volledig in beeld is kunnen brengen, wel grodendeels echter dat een caecumproces niet volledig uitgesloten kan worden. als de patient hier ongerust over zou zijn zou zij hier een ct-scan-colografie van kunnen laten. patient en schoondochter geven aan dat ze hier niet ongerust over zijn en dat dit niet hoeft. aangegeven dat mochten ze zich bedenken ze altijd terug kunnen bellen. lichamelijk onderzoek: hd stabiel, geen koorts. bloeddruk wel aan lage kant, 94/52 dus furosemide niet gegeven conclusie: geen bloedverlies meer waargenomen. klinisch goed, vandaag met ontslag. wegens hypotensie furosemide niet gegeven en geadviseerd de bloeddruk thuis op te volgen beleid: in overleg met dokter kamphuis - acenocoumarol eigen dosering hervatten - nog uitleg geven aan zoon + patient over coecum bodem - in brief naar huisarts tensiecontrole vermelden
# Checking spelling for: coloscopie betreft mevrouw adresgegevens: , geboortedatum: asa classificatie: 3 verwijzer: j.t. kamphuis indicatie: bloedverlies-rectaal. melena en bloedverlies per anum onder acenocoumarol. afwijkingen?. top verricht ja informed consent: ja endoscoop: geachte collega, bij uw patiënt werd op 25-11-2020 een coloscopie uitgevoerd. indicatie: bloedverlies-rectaal. melena en bloedverlies per anum onder acenocoumarol. afwijkingen?. toegediende medicatie: midazolam 3 mg fentanyl 0,05 mg fentanyl 0,025 mg introductie: intubatie heeft plaatsgevonden tot in het colon ascendens. verder opvoeren lukt niet door uitbochten endoscoop. de boston bowel preparation score is 9 (3-3-3). terugtrektijd: 6 min. patiëntcomfort: mild ongemak, tijdens de procedure meer dan twee voorvallen van ongemak, voldoende te verdragen. voorbereiding: gelaxeerd. nuchter. verslag: rt: geen afwijkingen. introductie door lange bochtige darm tot bij de klep; ondanks buikcompressie, verschillende houdingen en introductie van volledige scoop lukt het niet om de caecumbodem te bereiken. nergens bloed of bloedingsbron. pandiverticulose maar vooral in sigmoid. geen poliep of tumor of inflammatie. in rectum en bij inversie geen afwijkingen.. conclusie: coloscopie tot in het colon ascendens. lange darm, scopie tot bij de klep. bloeding gestopt, geen bloedingsbron gevonden. waarschijnlijkheidsdiagnose is divertikelbloeding advies: gegevens van gastro- en coloscopie zo accepteren met waarschijnlijkheidsdiagnose divertikelbloeding of toch nog uitsluiten caecumproces met betrekking tot ct-scan-colografie (kans klein dat hier een afwijking is omdat caecum grotendeels wel te overzien was). te bespreken met patiënte, kan poliklinisch.
# Checking spelling for: gastroscopie betreft mevrouw adresgegevens: , geboortedatum: asa classificatie: 3 verwijzer: j.t. kamphuis indicatie: melena en bloedverlies per anum onder acenocoumarol. afwijkingen?. top verricht ja informed consent: ja endoscoop: geachte collega, bij uw patiënt werd op 25-11-2020 een gastroscopie uitgevoerd. indicatie: melena en bloedverlies per anum onder acenocoumarol. afwijkingen?. toegediende medicatie: midazolam 3 mg fentanyl 0,05 mg voorbereiding: nuchter. verslag: slokdarm: zonder-lijn en diafragma op 38 en 40 cm, geen oesofagitis of barrett. maag: atrofisch en rood aspect slijmvlies, geen echte gastritis of ulcera. normale inversie. duodenum tot in dii: normaal vlokken- en plooien-patroon, geen ulcera, groot duodenum divertikel. nergens bloed.. conclusie: geen bloed of bloedingsbron bij gastroscopie..
# Checking spelling for: samenvatting: rectaal bloedverlies ; eenmalig ; hd en hemoglobine-stabiel ; inr stollingswaarde 2.8 ; wd divertikelbloeding dienstdoende toch maagulcus (gezien pijn epigastrio, mogelijk zwarte ontlasting en ureum 13). onder acenocoumarol, gecoupeerd beloop: verpleegkundige/ gisteravond melena gehad, vannacht donkerrood bloedverlies gehad. geen stolsels. had gisteravond ook pijnklachten van maag gehad, geen pijnstilling meer hiervoor gehad. voelt zich verder goed. infuus 1l. aan bed/ voelde zich gisteren plots erg slecht, dacht dat ze doodging, toen opgestaan en naar de keuken gewandeld, hier omgevallen, zegt niet het bewustzijn verloren te hebben echter wel op de grond gevallen. toen familie gebeld die waren meteen gekomen. later op de wc lag alles vol bloed. nu gaat het wel weer, geen buikpijnklachten. net nog naar de wc gehad waarbij ook weer bloed zat. lichamelijk onderzoek: nu hd stabiel, echter vannacht wel tensiedaling waarvoor 1l infuus. geen koorts aanvullend onderzoek: lab hemoglobine 6.4 mmol/l mcv 93 fl inr stollingswaarde 1.6 gastroscopie geen bloed of bloedingsbron bij gastroscopie coloscopie coloscopie tot in het colon ascendens. lange darm, scopie tot bij de klep. bloeding gestopt, geen bloedingsbron gevonden. waarschijnlijkheidsdiagnose is divertikelbloeding. pandiverticulose. conclusie: rectaal bloedverlies waarschijnlijk onder begeleiding van divertikelbloeding beleid: in overleg met dokter kamphuis - gastro/colo vandaag - morgen hemoglobine controle =@ - uitslag vertelt aan patient en zoon beleid: opdrachten aan verpleegkundige: voorlopige ontslagdatum 27-11 (voltooid) early warning score 3dd (voltooid)
# Checking spelling for: medisch beeld is beschikbaar. let op!! binnen hix niet geschikt voor diagnostiek
# Checking spelling for: beloop: verpleging belt: patiënte heeft nog 2 keer forse hoeveelheid melena gehad. hierbij ook bloeddruk daling naar bloeddruk 100/58 mm hg, kwam van bloeddruk 131/69 mm hg. ademhaling: - hemoglobine + inr stollingswaarde controle. - start infuus: 1l natriumchloride 0.9%. - in te toekomst: beriplex. 21.30 uur: hemoglobine 8.2 inr stollingswaarde 2.5 ademhaling: - geen actie voor nu. 23.30 uur bloeddruk 103/51 mm hg. nu waterdunne ontlasting vermengd met bloedverlies. ademhaling: - zo door. - laagdrempelig opnieuw contact.
# Checking spelling for: meneer a.j. dingemans, huisarts nr datum 24-11-2020 kenmerk 0007471629 / bsn nr. betreft mevrouw , geen bijzonderheden (87) , tel. geachte collega, bovengenoemde patiënt bezocht op 24-11-2020 de spoedeisende hulp. reden van komst rbv conclusie bovenstaande 87-jarige patiënte ; onder andere bekend met diverticulose, passagère melena e.c.i. in 2016 en atrium fibilaire w.v. acenocoumarol ; wordt beoordeeld op de spoedeisende hulp met nu rectaal bloedverlies. circulatie: rectaal bloedverlies ; eenmalig ; hd en hemoglobine-stabiel ; inr stollingswaarde 2.8 ; wd divertikelbloeding dienstdoende toch maagulcus (gezien pijn epigastrio, mogelijk zwarte ontlasting en ureum 13). beleid op de spoedeisende hulp: - 10mg fytomenadion (vit. kalium) oraal - pantoprazol 80mg infuus in overleg met dokter kamphuis mdl: - opname voor mdl ; geen isolatie indicatie - klinisch scopie ; morgen beoordelend colo / gastro of beide - acenocoumarol tot nader order pauzeren - pantoprazol door op de perfusor - vanavond start voorbereiding scopie middels 500cc pleinvue - morgen andere 500cc pleinvue - po-inspectie ; indien meer bloedverlies vanavond hemoglobine en inr stollingswaarde controle - eventueel. beriplex in overleg met assistent internist - niet reanimeren en beademen op wens patiënt anamnese vanmiddag rond 13.30 uur fors helderrood bloedverlies met stolsels. vermengd met ontlasting, mogelijk was deze zwart van kleur. sinds 5 dagen zeurende pijn in de bovenbuik ; maagpijn, waarvoor ze is gestopt met koffie drinken en vet eten. in de afgelopen dagen wat minder ontlasting, bij ook minder intake, maar geen bloed / zwart verkleuring bemerkt. tractus anamnese: verder niet bijdragend, m.n. geen lw-klachten. rvg/ 2002 diep veneuze trombose en longembolie 2013 cholecystectomie 2015 diverticulitis. ct-scan-abdomen: diverticulitis, geen maligniteit. sigmoïdoscopie: geen rip 2016 atriumfibrilleren met spontane conversie naar sinusritme 2016 melena, waarvoor geen verklaring werd gevonden. in verband met stabiel hemoglobine en in overleg met patiënte expectatief beleid. 2018 vermoeidheid bij sinusbradycardie waarvoor stop metoprolol en tambocor. medicatie/ onder andere acenocoumarol all/ penicillines -> urticaria lichamelijk onderzoek controles: perifere zuurstofsaturatie % 96 hartfrequentie bpm 95 nibp mmhg 132/71(91) temperatuur °c 37,2 alg: niet acuut ziek, niet duidelijk anemisch h/h: pearl, geen klieren cor: s1s2, geen souffles pulm: beiderzijds vag, geen bijgeluiden abd: np, wt, soepel abdomen, mild drukpijn epigastrio - geen loslaatpijn, murphy - rt: helderrood bloed aan de handschoen, geen feces, geen afwijkingen palpabel, geen hemorroïden aanvullend onderzoek c-reactieve proteine 36 mg/l hemoglobine 7.8 mmol/l hematocriet 0.38 l/l erytrocyten 4.10 x10^12/l mcv 93 fl leukocyten 10.0 x10^9/l trombocyten 176 x10^9/l aptt 38 sec patient 39.5 sec inr stollingswaarde 2.8 glucose 8.0 mmol/l natrium 141 mmol/l kalium 4.3 mmol/l ureum 13.2 mmol/l kreatinine 82 μmol/l egfr ckd-epiduraal 55 ml/m/1.73m^2 bilirubine totaal 7 μmol/l alkalische fosfatase (atrium fibilaire) 111 u/l ggt 16 u/l asat 28 u/l alat 18 u/l ld 240 u/l lipase 28 u/l albumine 35 g/l medicatie actueel fytomenadion injvlst 10mg/ml (par/oraal) amp 1ml; infuus; 1 x per dag 10 milligram latanoprost oogdruppel 50ug/ml minim 0,2ml; oog; 1 x per dag 1 druppel in beide ogen hyaluronzuur oogdruppels 1mg/ml fl 10ml; oog; zo nodig 4 x per dag 1 druppel pantoprazol injectiepoeder 40mg fl; intraveneus continu; 8 mg/uur *pomp 8mg/uur, bolus 80mg in 30 minuten. acenocoumarol tablet 1mg; oraal; 1 x per dag volgens trombosedienst; stopdatum: tot nader order gestopt furosemide tablet 20mg; oraal; 1 x per dag 1 stuk; stopdatum: tot nader order gestopt macrogol/zouten pdr v drank (pleinvue); oraal; * volgens voorbereiding scopie ; start vanavond met eerste 500cc macrogol/zouten pdr v drank (movicolon+generiek); oraal; 1 x per dag 1 stuk; stopdatum: tot nader order gestopt
# Checking spelling for: reden van komst / verwijzing: reden van komst (brief): rbv anamnese: vanmiddag rond 13.30 uur fors helderrood bloedverlies met stolsels. vermengd met ontlasting, mogelijk was deze zwart van kleur. sinds 5 dagen zeurende pijn in de bovenbuik ; maagpijn, waarvoor ze is gestopt met koffie drinken en vet eten. in de afgelopen dagen wat minder ontlasting, bij ook minder intake, maar geen bloed / zwart verkleuring bemerkt. tractus anamnese: verder niet bijdragend, m.n. geen lw-klachten. rvg/ 2002 diep veneuze trombose en longembolie 2013 cholecystectomie 2015 diverticulitis. ct-scan-abdomen: diverticulitis, geen maligniteit. sigmoïdoscopie: geen rip 2016 atriumfibrilleren met spontane conversie naar sinusritme 2016 melena, waarvoor geen verklaring werd gevonden. in verband met stabiel hemoglobine en in overleg met patiënte expectatief beleid. 2018 vermoeidheid bij sinusbradycardie waarvoor stop metoprolol en tambocor. medicatie/ onder andere acenocoumarol all/ penicillines -> urticaria lichamelijk onderzoek: controles: perifere zuurstofsaturatie % 96 hartfrequentie bpm 95 nibp mmhg 132/71(91) temperatuur °c 37,2 alg: niet acuut ziek, niet duidelijk anemisch h/h: pearl, geen klieren cor: s1s2, geen souffles pulm: beiderzijds vag, geen bijgeluiden abd: np, wt, soepel abdomen, mild drukpijn epigastrio - geen loslaatpijn, murphy - rt: helderrood bloed aan de handschoen, geen feces, geen afwijkingen palpabel, geen hemorroïden aanvullend onderzoek: lab: c-reactieve proteine 36 mg/l hemoglobine 7.8 mmol/l hematocriet 0.38 l/l erytrocyten 4.10 x10^12/l mcv 93 fl leukocyten 10.0 x10^9/l trombocyten 176 x10^9/l aptt 38 sec patient 39.5 sec inr stollingswaarde 2.8 glucose 8.0 mmol/l natrium 141 mmol/l kalium 4.3 mmol/l ureum 13.2 mmol/l kreatinine 82 μmol/l egfr ckd-epiduraal 55 ml/m/1.73m^2 bilirubine totaal 7 μmol/l alkalische fosfatase (atrium fibilaire) 111 u/l ggt 16 u/l asat 28 u/l alat 18 u/l ld 240 u/l lipase 28 u/l albumine 35 g/l conclusie: bovenstaande 87-jarige patiënte ; onder andere bekend met diverticulose, passagère melena e.c.i. in 2016 en atrium fibilaire w.v. acenocoumarol ; wordt beoordeeld op de spoedeisende hulp met nu rectaal bloedverlies. circulatie: rectaal bloedverlies ; eenmalig ; hd en hemoglobine-stabiel ; inr stollingswaarde 2.8 ; wd divertikelbloeding dienstdoende toch maagulcus (gezien pijn epigastrio, mogelijk zwarte ontlasting en ureum 13). beleid: algemeen: opname voor mdl ; geen isolatie indicatie (te accepteren) klinisch scopie ; morgen beoordelend colo / gastro of beide (te accepteren) acenocoumarol tot nader order pauzeren (te accepteren) pantoprazol door op de perfusor (te accepteren) vanavond start voorbereiding scopie middels 500cc pleinvue (te accepteren) morgen andere 500cc pleinvue (te accepteren) po-inspectie ; indien meer bloedverlies vanavond hemoglobine en inr stollingswaarde controle - eventueel. beriplex in overleg met assistent internist (te accepteren) niet reanimeren op wens patiënt (te accepteren) beleid: op de spoedeisende hulp: - 10mg fytomenadion (vit. kalium) oraal - pantoprazol 80mg infuus in overleg met dokter kamphuis mdl: - opname voor mdl ; geen isolatie indicatie - klinisch scopie ; morgen beoordelend colo / gastro of beide - acenocoumarol tot nader order pauzeren - pantoprazol door op de perfusor - vanavond start voorbereiding scopie middels 500cc pleinvue - morgen andere 500cc pleinvue - po-inspectie ; indien meer bloedverlies vanavond hemoglobine en inr stollingswaarde controle - eventueel. beriplex in overleg met assistent internist - niet reanimeren en beademen op wens patiënt
# Checking spelling for: máxima medisch centrum, maag-darm-leverziekten dokter m.l. verhulst, maag-darm-leverarts tel.  aan de weledelgeleerde meneer a.j. dingemans, huisarts nr   datum : 23-08-2016 kenmerk: 0005146439 / / slw bsn nr. : niet geïdentificeerd betreft : mevrouw geen bijzonderheden (83) ad    geachte collega, van 22-08-2016 tot 23-08-2016 was uw patiënte opgenomen op de afdeling maag-darm-leverziekten. reden van opname: melaena voorgeschiedenis: 2002 diep veneuze trombose en longembolie 2013 cholecystectomie 2015 diverticulitis. ct-scan-abdomen: diverticulitis, geen maligniteit. sigmoïdoscopie: behoudens divertikels geen afwijkingen. 2016 atriumfibrilleren met spontane conversie naar sinusritme anamnese: patiënte vertelde dat hij drie dagen pikzwarte ontlasting heeft gehad, die plakte aan de toiletpot en anders van geur was. daarbij had zij al langer last van maagzuur. lichamelijk onderzoek: niet acuut ziek. rectaal toucher: melaena aan de handschoen. laboratorium onderzoek: hemoglobine 7.8 mmol/l; kreatinine 86 umol/l ; ferritine 83 ug/l. gastroscopie: geen relevante afwijkingen. bespreking: patiente werd opgenomen onder verdenking van een hoge tractus digestivus bloeding . een gastroscopie liet geen afwijkingen zien en het hemoglobine bleef stabiel tijdens de opname. in overleg met patiente werd besloten om geen verdere diagnostiek te doen. recent onderzoek van de darm (sigmoidoscopie en ct-scan-abdomen) lieten geen aanwijzingen zien voor een maligniteit. bij persisteren van de melena kan nog worden overwogen om alsnog een colonoscopie te verrichten. op 23.08.2016 werd patiente ontslagen. er werd geen vervolgafspraak gemaakt op de polikliniek mdl. natuurlijk zijn wij bereid patiënte bij recidiverende klachten terug te zien.. conclusie: melena, waarvoor geen verklaring werd gevonden. in verband met stabiel hemoglobine en in overleg met patiënte expectatief beleid. actuele medicatie (ongewijzigd): latanoprost oogdruppels 50ug/ml minim 0,2ml (oculair), 1 x per dag 1 druppel estriol ovule 0,5mg (vaginaal), 2 weken voor de nacht vaginaal 1 ovule plaatsen. hierna 2 maal per week op maandag en vrijdag continueren. acenocoumarol tablet 1mg (oraal), 1 x per dag volgens trombosedienst flecainide capsule met gereguleerde afgifte 50mg (oraal), 1 x per dag 1 stuk furosemide tablet 20mg (oraal), 1 x per dag 1 stuk simvastatine tablet fo 20mg (oraal), 1 x per dag 1 stuk vertrouwende u hiermee voldoende te hebben geïnformeerd. met vriendelijke groet, dokter m.l. verhulst, maag-darm-leverarts t.t. van sloten, arts assistent interne geneeskunde  deze brief is elektronisch geaccordeerd en daardoor niet voorzien van een handtekening.
# Checking spelling for: samenvatting: decursus -reden van opname: melena -speciële anamnese: gastroscopie: behoudens atrofische gastritis, geen afwijkingen. uitleg aan familie en patiente: geen duidelijke verklaring voor bloedverlies, maar wel ernstige afwijkingen uitgesloten middels gastroscopie. bovendien stabiel hemoglobine. patiente wil graag naar huis. -samenvatting: melena bij acenocoumarol gebruik. gastroscopie: geen afwijjkingen ademhaling: ontslag, expectatief beleid -beleid: ontslag opstarten acenocoumerol, staken pantopazol verdere follow-urine productie (hemoglobine controle) via huisarts bij persisteren melena en anemie: zo nodig colonoscopie -supervisor: m.l. verhulst -algemeen: vanmiddag ontslag (voltooid) -infuusbeleid: geen poliklinische controle mdl (voltooid)
# Checking spelling for: samenvatting: conclusie -samenvatting: melena bij acenocoumarol gebruik. gastroscopie: geen afwijjkingen ademhaling: ontslag, expectatief beleid -beleid: ontslag opstarten acenocoumerol, staken pantopazol verdere follow-urine productie (hemoglobine controle) via huisarts bij persisteren melena en anemie: zo nodig colonoscopie -supervisor: m.l. verhulst -algemeen: vanmiddag ontslag (voltooid) -infuusbeleid: geen poliklinische controle mdl (voltooid)
# Checking spelling for: máxima medisch centrum, maag-darm-leverziekten dokter p.j. boekema, maag-darm-leverarts tel.  aan de weledelzeergeleerde vrouwe dokter m.l. verhulst, maag-darm-leverarts máxima medisch centrum veldhoven   datum : 23-08-2016 kenmerk: 0005145777 / / b47 bsn nr. : niet geïdentificeerd betreft : mevrouw geen bijzonderheden (83) ad    geachte collega, op 23-08-2016 werd bij bovengenoemde patiënte een gastroscopie verricht door p. boekema. verwijzer: m.l. verhulst, mdl-arts. indicatie: melaena en reflux premedicatie: midazolam 3 mg condities: asa-klasse: 2 beleving: niet of nauwelijks belastend beoordeelbaarheid: goed verslag scopie: kleine sliding hernia diafragmatica, zonder verder afwijkingen. atrofiërende (antrum)gastritis zonder relevante lesies. in het duodenum tot ver geen afwijkingen. conclusie: geen relevante afwijkingen. met vriendelijke groet, dokter p.j. boekema, maag-darm-leverarts   deze brief is elektronisch geaccordeerd en daardoor niet voorzien van een handtekening.
# Checking spelling for: samenvatting: endoscopie verslag -datum onderzoek: 23-08-2016 -aanvrager: mdl-arts -mdl arts: m.l. verhulst -endoscopist: p. boekema -indicatie aanvraag: melena en reflux -asa klasse: 2 -cumarinederivaat: ja -naamgeving medicatie: acenocoumarol (sintrom®) -acenocoumarol (sintrom®): gestopt -antibiotische profylaxe: nvt -endoscopische verrichting: gastroscopie -timeout: ja -premedicatie: midazolam -hoeveelheid midazolam (mg): 3 -introductie: vlot -beleving: niet of nauwelijks belastend -type gastroscopie: algemeen -beoordeelbaarheid: goed -slokdarm: kleine sliding hernia diafragmatica, zonder verder afwijkingen. -maag: atrofiërende (antrum)gastritis zonder relevante lesies. -duodenum: in het duodenum tot ver geen afwijkingen. -conclusie: geen relevante afwijkingen.
# Checking spelling for: samenvatting: decursus -reden van opname: melena -uitslagen: hemoglobine stabiel. -grote visite: boekema/verhulst: vanmorgen nog een beetje melaena gehad. hemoglobine stabiel. vandaag gastroscopie, afhankelijk van uitslag verder beleid. -samenvatting: rede van opname/ melena bij acenocoumarol gebruik dienstdoende ulcus ademhaling: gastroscopie volgt 23.08
# Checking spelling for: samenvatting: conclusie -samenvatting: rede van opname/ melena bij acenocoumarol gebruik dienstdoende ulcus ademhaling: gastroscopie volgt 23.08
# Checking spelling for: samenvatting: opnameregistratie -verwijzer: spoedeisende hulp -spoedeisende hulp informatie laatste bezoek: datum: 22-08-2016 verantwoordelijk arts:spoedeisende hulp arts mdl arts assistent: l.e.g. de vaan reden van komst: melena anamnese: voorgeschiedenis: cholecystectomie deep veneuze trombose + longembolie supraventriculaire aritmien met geringe mitralisklepprolaps atriumfibrilleren diverticulitis 06-2015: ct-scan-abdomen: diverticulitis met gedekte perforatie linker onderkwadrant. geen aanwijzingen maligniteit. 07-2015: sigmoidoscopie uitwendige huidflap/aambeitje. conclusie: bochtig diverticuleus sigmoïd. al langer klachten van maagzuur, met name na het eten, soms zo erg dat er van moet hoesten. afgelopen weken toename in frequentie en ernst. sinds een week ook pijn in de buik, net onder de maag. herkent de buikpijn niet van diverticulitis. niet misselijk geweest, niet gebraakt (geen hematemesis). sinds drie dagen is de ontlasting pikzwart, plakt aan de toiletpot, anders van geur. sinds zaterdag via huisarts omeprazol gekregen. niet afgevallen, voor melena ontlasting zoals anders, geen helderrood bloed, geen slijmbijmenging. recent nitrofurantoine in verband met urineweginfectie (daarna start buikpijn). geen mictieklachten nu. voelt zich erg moe, verder niet licht in het hoofd of duizelig, geen pob, geen palpitaties. intoxicatie: roken -, alcohol -, nsdaid's - drinkt eenmaal daags kop koffie. medicatie: estriol, flecainide, oogdruppels, simvastatine, paracetamol, furosemide, acenocoumarol, pantoprazol. lichamelijk onderzoek: luchtwegen: vrij ademhaling: normaal ademgeruis, tympane percussie, saturatie. 97% zonder zuurstof, ahf 20/min circulatie: cor: s1s2, geen souffle, bloeddruk 188/80, pols 63 regulair, perifeer warm en goed gecirculeerd onbekwaamheid: e4m6v5, pearl, geen lateralisatie blootstelling omgeving: temperatuur 37.2 abd: levendige peristaltiek, bij diepe palpatie wel pijn ter hoogte van epigastrio, abdomen volledig soepel. rt: melena aan handschoen. laboratorium: hemoglobine 7.8 (normaal ~8, hemoglobine 9.1 6 weken geleden) inr stollingswaarde 3.1 c-reactieve proteine 7.5, l 7.5 ureum verhoogd ten opzichte van kreatinine. egfr 55 (45). samenvatting:83-jarige vrouw bekend met oa deep veneuze trombose, longembolie en atrium fibilaire waarvoor acenocoumarol. komt in verband met langer bestaande klachten van maagzuur, recent toegenomen, periode van buikpijn en melena. bij lo abdomen soepel, melena aan handschoen. lab: hemoglobine 7.8 (9.1 6 weken geleden) en inr stollingswaarde 3.1 (werk)diagnose: melena bij hoge tractus digestivusbloeding, dienstdoende ulcus ventriculi/duodeni, maagbloeding onder antistolling, maligniteit minder waarschijnlijk bij schone ct-scan/colonoscopie 07-2015, anamnestisch ook geen aanwijzingen voor. beleid bij vertrek spoedeisende hulp: opname acute opname afdeling voor mdl - dieet helder vloeibaar, nuchter vanaf 00:00 - morgen gastroscopie (aanvraag in systeem) - pantoprazol 2 dienstdoende 40 mg - acenocoumarol vandaag overslaan - morgenochtend hemoglobine en inr stollingswaarde controle - early warning score controles elke 2 uur - 1l natriumchloride infuus -samenvatting: diverticulitis.
# Checking spelling for: samenvatting: decursus -reden van opname: melena -samenvatting: rede van opname/ melena bij acenocoumarol gebruik dienstdoende ulcus ademhaling: gastroscopie volgt 23.08 -supervisor: m.l. verhulst -algemeen: algemeen: morgenvroeg hemoglobine + inr stollingswaarde (voltooid)
# Checking spelling for: samenvatting: conclusie -samenvatting: rede van opname/ melena bij acenocoumarol gebruik dienstdoende ulcus ademhaling: gastroscopie volgt 23.08 -supervisor: m.l. verhulst -algemeen: algemeen: morgenvroeg hemoglobine + inr stollingswaarde (voltooid)
# Checking spelling for: samenvatting: aanvraag endoscopie -locatie: veldhoven (tel 6350) -datum aanvraag: 22-08-2016 -aanvrager: mdl-arts -mdl arts: m.l. verhulst -arts assistent: l.e.g. de vaan, arts assistant spoedeisende hulp -sein: 6610 -afdeling: acute opname afdeling/zadm/2 -soort onderzoek: gastroscopie -indicatie aanvraag: melena bij maagzuur -asa klasse: 2 -cumarinederivaat: ja -naamgeving medicatie: acenocoumarol (sintrom®) -antibiotische profylaxe: nvt
# Checking spelling for: máxima medisch centrum, spoedeisende hulp maag-darm-leverziekten spoedeisende hulp arts mdl, spoedeisende hulp arts tel. dit is een automatisch gegenereerd spoedeisende hulp verslag   aan de weledelgeleerde meneer a.j. dingemans, huisarts nr   datum : 22-08-2016  kenmerk : 0005145102 / / 73s bsn nr. : niet geïdentificeerd  betreft : mevrouw , geen bijzonderheden (83), , spec. : maag-darm-leverziekten locatie : veldhoven   geachte collega, op 22-08-2016 zag ik bovengenoemde patiënte op de afdeling spoedeisende hulp. thuismedicatie: estriol, flecainide, oogdruppels, simvastatine, paracetamol, furosemide, acenocoumarol, pantoprazol. anamnese: voorgeschiedenis: cholecystectomie deep veneuze trombose + longembolie supraventriculaire aritmien met geringe mitralisklepprolaps atriumfibrilleren diverticulitis 06-2015: ct-scan-abdomen: diverticulitis met gedekte perforatie linker onderkwadrant. geen aanwijzingen maligniteit. 07-2015: sigmoidoscopie uitwendige huidflap/aambeitje. conclusie: bochtig diverticuleus sigmoïd. al langer klachten van maagzuur, met name na het eten, soms zo erg dat er van moet hoesten. afgelopen weken toename in frequentie en ernst. sinds een week ook pijn in de buik, net onder de maag. herkent de buikpijn niet van diverticulitis. niet misselijk geweest, niet gebraakt (geen hematemesis). sinds drie dagen is de ontlasting pikzwart, plakt aan de toiletpot, anders van geur. sinds zaterdag via huisarts omeprazol gekregen. niet afgevallen, voor melena ontlasting zoals anders, geen helderrood bloed, geen slijmbijmenging. recent nitrofurantoine in verband met urineweginfectie (daarna start buikpijn). geen mictieklachten nu. voelt zich erg moe, verder niet licht in het hoofd of duizelig, geen pob, geen palpitaties. intoxicatie: roken -, alcohol -, nsdaid's - drinkt eenmaal daags kop koffie. allergieën: amoxicilline penicillines amoxicilline/ampicilline amoxicilline / penicillines / amoxicilline/ampicilline / lichamelijk onderzoek: luchtwegen: vrij ademhaling: normaal ademgeruis, tympane percussie, saturatie. 97% zonder zuurstof, ahf 20/min circulatie: cor: s1s2, geen souffle, bloeddruk 188/80, pols 63 regulair, perifeer warm en goed gecirculeerd onbekwaamheid: e4m6v5, pearl, geen lateralisatie blootstelling omgeving: temperatuur 37.2 abd: levendige peristaltiek, bij diepe palpatie wel pijn ter hoogte van epigastrio, abdomen volledig soepel. rt: melena aan handschoen. aanvullend onderzoek: laboratorium: hemoglobine 7.8 (normaal ~8, hemoglobine 9.1 6 weken geleden) inr stollingswaarde 3.1 c-reactieve proteine 7.5, l 7.5 ureum verhoogd ten opzichte van kreatinine. egfr 55 (45). samenvatting: 83-jarige vrouw bekend met oa deep veneuze trombose, longembolie en atrium fibilaire waarvoor acenocoumarol. komt in verband met langer bestaande klachten van maagzuur, recent toegenomen, periode van buikpijn en melena. bij lo abdomen soepel, melena aan handschoen. lab: hemoglobine 7.8 (9.1 6 weken geleden) en inr stollingswaarde 3.1 diagnose: melena bij hoge tractus digestivusbloeding, dienstdoende ulcus ventriculi/duodeni, maagbloeding onder antistolling, maligniteit minder waarschijnlijk bij schone ct-scan/colonoscopie 07-2015, anamnestisch ook geen aanwijzingen voor. beleid: opname acute opname afdeling voor mdl - dieet helder vloeibaar, nuchter vanaf 00:00 - morgen gastroscopie - pantoprazol 2 dienstdoende 40 mg - acenocoumarol vandaag overslaan - morgenochtend hemoglobine en inr stollingswaarde controle - early warning score controles elke 2 uur - 1l natriumchloride infuus met vriendelijke groet, l. de vaan, arts assistant spoedeisende hulp dokter verhulst, mdl-arts   disclaimer: deze brief bevat een conclusie (en behandeling) die gebaseerd is op de op dat moment beschikbare medische gegevens. het is mogelijk dat het verdere ziektebeloop andere inzichten geeft dan nu in deze brief zijn vermeld. indien de patiënt wordt opgenomen naar aanleiding van deze presentatie op de spoedeisende hulp, dan volgt een defi ...
# Checking spelling for: samenvatting: medisch dossier -leeftijd in jaren: 83 -registratie datum spoedeisende hulp: 22-08-2016 -verantwoordelijk assistent: <objectgegevens> -verantwoordelijk arts: <objectgegevens> -dienstdoend specialist: <objectgegevens> -ecg-direct afgenomen op: - - -anamnese: voorgeschiedenis: cholecystectomie deep veneuze trombose + longembolie supraventriculaire aritmien met geringe mitralisklepprolaps atriumfibrilleren diverticulitis 06-2015: ct-scan-abdomen: diverticulitis met gedekte perforatie linker onderkwadrant. geen aanwijzingen maligniteit. 07-2015: sigmoidoscopie uitwendige huidflap/aambeitje. conclusie: bochtig diverticuleus sigmoïd. al langer klachten van maagzuur, met name na het eten, soms zo erg dat er van moet hoesten. afgelopen weken toename in frequentie en ernst. sinds een week ook pijn in de buik, net onder de maag. herkent de buikpijn niet van diverticulitis. niet misselijk geweest, niet gebraakt (geen hematemesis). sinds drie dagen is de ontlasting pikzwart, plakt aan de toiletpot, anders van geur. sinds zaterdag via huisarts omeprazol gekregen. niet afgevallen, voor melena ontlasting zoals anders, geen helderrood bloed, geen slijmbijmenging. recent nitrofurantoine in verband met urineweginfectie (daarna start buikpijn). geen mictieklachten nu. voelt zich erg moe, verder niet licht in het hoofd of duizelig, geen pob, geen palpitaties. -intoxicatie: roken -, alcohol -, nsdaid's - drinkt eenmaal daags kop koffie. -medicatie: estriol, flecainide, oogdruppels, simvastatine, paracetamol, furosemide, acenocoumarol, pantoprazol. -a = allergieën (alleen verpleegkundig): amoxicilline / penicillines / amoxicilline/ampicilline / -lichamelijk onderzoek: luchtwegen: vrij ademhaling: normaal ademgeruis, tympane percussie, saturatie. 97% zonder zuurstof, ahf 20/min circulatie: cor: s1s2, geen souffle, bloeddruk 188/80, pols 63 regulair, perifeer warm en goed gecirculeerd onbekwaamheid: e4m6v5, pearl, geen lateralisatie blootstelling omgeving: temperatuur 37.2 abd: levendige peristaltiek, bij diepe palpatie wel pijn ter hoogte van epigastrio, abdomen volledig soepel. rt: melena aan handschoen. -aanvullend onderzoek: ja -lab: hemoglobine 7.8 (normaal ~8, hemoglobine 9.1 6 weken geleden) inr stollingswaarde 3.1 c-reactieve proteine 7.5, l 7.5 ureum verhoogd ten opzichte van kreatinine. egfr 55 (45). -samenvatting: 83-jarige vrouw bekend met oa deep veneuze trombose, longembolie en atrium fibilaire waarvoor acenocoumarol. komt in verband met langer bestaande klachten van maagzuur, recent toegenomen, periode van buikpijn en melena. bij lo abdomen soepel, melena aan handschoen. lab: hemoglobine 7.8 (9.1 6 weken geleden) en inr stollingswaarde 3.1 -(werk)diagnose: melena bij hoge tractus digestivusbloeding, dienstdoende ulcus ventriculi/duodeni, maagbloeding onder antistolling, maligniteit minder waarschijnlijk bij schone ct-scan/colonoscopie 07-2015, anamnestisch ook geen aanwijzingen voor. -beleid: opname acute opname afdeling voor mdl - dieet helder vloeibaar, nuchter vanaf 00:00 - morgen gastroscopie (aanvraag in systeem) - pantoprazol 2 dienstdoende 40 mg - acenocoumarol vandaag overslaan - morgenochtend hemoglobine en inr stollingswaarde controle - early warning score controles elke 2 uur - 1l natriumchloride infuus -algemeen: - 1l natriumchloride infuus (voltooid) -infuusbeleid: - early warning score controles elke 2 uur (voltooid) -zuurstofbeleid: - morgenochtend hemoglobine en inr stollingswaarde controle (voltooid) -onderzoeken: - acenocoumarol vandaag overslaan (voltooid) -observaties: - pantoprazol 2 dienstdoende 40 mg (voltooid) -metingen: - morgen gastroscopie (aanvraag in systeem) (voltooid) -voeding: - dieet helder vloeibaar, nuchter vanaf 00:00 (voltooid) -gezien door (naam, functie): l. de vaan, arts assistant spoedeisende hulp -in overleg met (naam, functie): dokter verhulst, mdl-arts
# Checking spelling for: samenvatting: verpleegkundige verslaglegging -verantwoordelijk verpleegkundige:: <objectgegevens> -leeftijd: 83 -leeftijd anamnese: 83 -(hoofd)klacht: <objectgegevens> -a = allergieën (alleen verpleegkundig): amoxicilline / penicillines / amoxicilline/ampicilline / -m = medication: zie lijst -p = past: atrium fibilaire -l = last meal: 12.30 uur -e = event: rectaal bloedverlies donker sinds zaterdag begonnen met buikpijn na gebruik antibiotica zwaar gevoel in de buik a vrij b geen bijzonderheden c rectaal bloedverlies d alert -pijnscore invullen?: ja -patientkenmerk: spoedeisende hulp patiënt -pijnscore: 1 -score tbv grafiek: 1 -verpleegkundige handelingen: infuus canule (v), lab, urinesediment en urinekweek -met wie dienen, indien nodig, verpleging en/of artsen contact op te nemen als u in het ziekenhuis ligt?: danny van asten -wat is de relatie met deze personen?: zoon en/of dochter -wat is zijn/haar telefoonnummer?: -triagekeuze: gastro instinaal-bloeding -gastro instinaal-bloeding: zwarte of donkerrode ontlasting -triage: nee -triage: nee -triage: ja -triage: nee -triage: nee
# Checking spelling for: patient : van*jm v klinische gegevens: rectaalbloeverlies buikklachten. antibiotica:nee materiaal urine gramkleuring + plaveiselepitheelcellen + gram negatieve staven + gemengde flora kwantitatieve kweek > 10e5 kve/ml escherichia coli antibiogram 1 amoxicilline s amoxicilline/clavulaanzuur s cefuroxim s gentamicine s trimethoprim s trimethoprim/sulfamethoxazol s nitrofurantoïne s norfloxacine s ciprofloxacine s legenda 1. escherichia coli s=sensitief - r=resistent - i=intermediair - x=ongeschikt,intrinsiek resistent - n=negatief - p=positief l=synergisme met penicilline is waarschijnlijk - h=synergisme met penicilline is niet waarschijnlijk
# Checking spelling for: samenvatting: apotheek -apotheek akkoord: ja
# Checking spelling for:    máxima medisch centrum, maag-darm-leverziekten j.t. kamphuis, maag-darm-leverarts functie afdeling 2 tel.     aan de weledelzeergeleerde meneer dokter t. lubbers, arts assistent maximá medisch centrum eindhoven / veldhoven   datum : 29-07-2015  kenmerk: 0004713748 / / voorlopige ontslagdatum  bsn nr. : niet geïdentificeerd  betreft : mevrouw , geen bijzonderheden (82), ,   geachte collega, op 29-07-2015 verrichtte ik bij bovengenoemde patiënte een sigmoïdoscopie. indicatie: vorm van de ontlasting is veranderd (potloodvormig). in het verleden diverticulitiden. patiënt draagt verzakkingsring. verslag: rectaal toucher: uitwendige huidflap/aambeitje, verder is de ring palpabel. introductie door een bochtig diverticuleus sigmoïd zonder inflammatie tot waarschijnlijk flexura lienalis. dit is ongeveer 90 cm. bij terugtrekken geen actieve inflammatie (meer). geen poliepen of tumoren. in het rectum bij inversie geen bijzonderheden. conclusie: bochtig diverticuleus sigmoïd. met vriendelijke groet, j.t. kamphuis, maag-darm-leverarts   dit verslag is elektronisch geaccordeerd en daardoor niet voorzien van een handtekening.
# Checking spelling for: samenvatting: vervolgconsult -type registratie: uitgebreid -verwijzer: intern -intern: dr lubbers/ dr slooter -verwijsreden: overig -toelichting: multipele episodes van diverticulitis. februari 2015 scopie gehad, nadien nog een episode. nu persistrerend afvallen, moeite met defectatie, potlood ontlasting. stenose? -anamnese: scopie febr 2015 scopie febr 2015 coloscopie: in het sigmoïd op 15 cm. sterk gezwollen plooien. niet duidelijk of we met diverticulitis of toch met een adenoom te maken hebben. plaats gebiopteerd en gemarkeerd. diverticulose in het sigmoïd. verder geen afwijkingen. pathologie: sigmoïdbiopten met reactieve veranderingen. beeld is niet specifiek maar kan wel passen bij biopten in de omgeving van een diverticulitis. geen aanwijzingen voor adenoom. laatste week minder buikpijn. defecatie 3-4 keer/dag nu gewoon van vorm was paar weken terug potlood dik. geen bloedverlies, voorheen slijmverlies maar is nu niet meer. 4 kg afgevallen sinds juni medicatie: acenocoumarol tabl 1mg td 22-01-2015 tambocor cr caps met gereguleerde afgifte 50mg 1.1c 05-12-2014 furosemide tabl 20mg m 1t -samenvatting: diverticulitis.
# Checking spelling for: samenvatting: medisch dossier -leeftijd in jaren: 81 -registratie datum spoedeisende hulp: 03-06-2015 -verantwoordelijk assistent: <objectgegevens> -verantwoordelijk arts: <objectgegevens> -dienstdoend specialist: <objectgegevens> -reden van komst: <objectgegevens> -anamnese: rvk/ buikpijn onderbuik voorgeschiedenis/ baarmoeder operatie kamer, denkt dat appendix ook verwijderd is maar weet dit niet zeker. cholecystectomie longembolieen 02-2015 diverticulitis, diverticulose in sigmoid luchtwegen: vanochtend om 9 uur plots maagkrampen met uitstraling onder linker mamma. daarna pijn in de onderbuik beiderzijds, steken en drukkend gevoel, continue aanwezig. toename bij beweging , vervoerspijn+. nu geen maagklachten meer. geen eetlust meer, normaal goed. voelt zich niet lekker. n- v-. opgeblazen gevoel, heeft al ruimere broek aangetrokken. vanochtend defecatie gehad: normaal, bloed-slijm-. urine: geen dysurie. allergie: augmentin (urticaria) -medicatie: sintrom simvastatine 1dd20mg tambocor furosemide 1dd20mg monoprost oogdruppels -a = allergieën (alleen verpleegkundig): antibiotica -lichamelijk onderzoek: t38.6. niet lekker. abdomen: ausc namelijk peristaltiek. percussie: wisselende tympanie. pijnlijk linker zijde van d ebuik palpatie: evidente druk- en loslaatpijn onderbuik linker>>rechter, linker zijde van d ebuik drukpijnlijk tot net boven navelhoogte. geen afwijkingen intra abdominaal palpabel. -(werk)diagnose: diverticulitis -beleid: opname acute opname afdeling, niets per os, infuus. sintrom tijdelijk stop morgen herbeoordelen met infectielab. pijnstilling -algemeen: urinesediment (voltooid) -infuusbeleid: 1,5 l nacl0.9% (voltooid) -onderzoeken: 4-6 ochtend labcontrole: leukocyten's, c-reactieve proteine (voltooid) -voeding: niets per os (voltooid) -algemeen: sintrom tijdelijk stop (voltooid) -gezien door (naam, functie): a. welkamp, amaio, s. mans, spoedeisende hulp arts, w. truin aios chirurgie -bestaat er op basis van de anamnese een verdenking op een infectie: nee
# Checking spelling for: samenvatting: verpleegkundige verslaglegging -verantwoordelijk verpleegkundige:: <objectgegevens> -leeftijd: 81 -collumcare patiënt: nee -bestaat er op basis van de anamnese een verdenking op een infectie: nee -leeftijd anamnese: 81 -(hoofd)klacht: <objectgegevens> -a = allergieën (alleen verpleegkundig): antibiotica -m = medication: zie lijst -p = past: longembolie diverticulitis -l = last meal: 08:30 ontbijt 2 glazen vocht -e = event: sinds 09:00 vanochtend buikpijn. mevrouw voelt zich moe. niet meer pijn dan vanochtend. heeft wel meer pijn bij hobbels nemen. pijn begon in de buik en nu in de onderbuik vanmorgen paracetamol ingenomen zonder resultaat. pijn wordt herkend als de ontsteking die mevrouw eeerder heeft gehad n + v-, diarree- -gebruikt u antistolling via de trombosedienst?: ja -pijnscore invullen?: ja -pijnscore: 5 -score tbv grafiek: 5 -verpleegkundige handelingen: infuus canule (v), lab en urinesediment -verrichting invoeren: geen -met wie dienen, indien nodig, verpleging en/of artsen contact op te nemen als u in het ziekenhuis ligt?: corrine v asten -wat is de relatie met deze personen?: zoon en/of dochter -wat is zijn/haar telefoonnummer?: -triagekeuze: buikpijn volwassene -buikpijn volwassene: koorts volwassene -triage: nee -triage: nee -triage: ja -triage: nee -triage: nee
# Checking spelling for:    máxima medisch centrum, maag-darm-leverziekten dokter m.j. ter borg, maag-darm-leverarts tel.     aan de weledelgeleerde meneer a.j. dingemans, huisarts nr   datum : 05-03-2015  kenmerk: 0004547232 / / bqc  bsn nr. :  betreft : mevrouw , geen bijzonderheden (81), ,   geachte collega, bovengenoemde patiënte zag ik op 05-03-2015 op de polikliniek maag-darm-leverziekten. voorgeschiedenis: 2013 galwegen, laparoscopische cholecystectomie anamnese: gaat een stuk beter, helemaal geen buikpijn meer. nog wat frequentere ontlasting. doet nog aan volksdansen en dergelijken coloscopie: in het sigmoïd op 15 cm. sterk gezwollen plooien. niet duidelijk of we met diverticulitis of toch met een adenoom te maken hebben. plaats gebiopteerd en gemarkeerd. diverticulose in het sigmoïd. verder geen afwijkingen. pathologie: sigmoïdbiopten met reactieve veranderingen. beeld is niet specifiek maar kan wel passen bij biopten in de omgeving van een diverticulitis. geen aanwijzingen voor adenoom. conclusie: diverticulitis. beleid: einde behandeling. een folder over diverticulose / diverticulitis werd meegegeven. actuele medicatie: pantoprazol tablet msr 40mg (oraal), 1 x per dag 1 stuk paracetamol tablet 500mg (oraal), 4 x per dag 1000 milligram diclofenac-natrium tablet msr 50mg (oraal), 3 x per dag 1 stuk dalteparine injv wwsp 5000ie=0,2ml (25.000ie/ml) (subcutaan), 1 x per dag 5000 internat.eenh. acenocoumarol tablet 1mg (oraal), 1 x per dag volgens trombosedienst hydrochloorthiazide tablet 25mg (oraal), 1 x per dag 1 stuk tambocor cr capsule met gereguleerde afgifte 50mg (oraal), 1 x per dag 1 stuk salbutamol/ipratropium vernevelvlst 1/0,2mg/ml fl (inhalatie), 4 x per dag 2,5 milliliter estriol ovule 0,5mg (vaginaal), 14 dagen dagelijks voor de nacht vaginaal 1 ovule inbrengen hierna 2 maal per week op maandag en vrijdag continueren. met vriendelijke groet, dokter m.j. ter borg, maag-darm-leverarts   deze brief is elektronisch geaccordeerd en daardoor niet voorzien van een handtekening.
# Checking spelling for: samenvatting: opdrachten -afspraak over: geen afspraak
# Checking spelling for: samenvatting: vervolgconsult -type registratie: uitgebreid -verwijzer: huisarts - naam:: dingemans -anamnese: gaat een stuk beter, helemaal geen buikpijn meer. nog wat frequentere ontlasting. doet nog aan volksdansen en dergelijken -uitslagen: coloscopie: in het sigmoïd op 15 cm. sterk gezwollen plooien. niet duidelijk of we met diverticulitis of toch met een adenoom te maken hebben. plaats gebiopteerd en gemarkeerd. diverticulose in het sigmoïd. verder geen afwijkingen. pathologie: sigmoïdbiopten met reactieve veranderingen. beeld is niet specifiek maar kan wel passen bij biopten in de omgeving van een diverticulitis. geen aanwijzingen voor adenoom. -samenvatting: diverticulitis. -beleid: einde behandeling. -opdrachten poli-medewerker: poli opdrachten - afspraak over: geen afspraak; -afspraak over: geen afspraak
# Checking spelling for: naam: van*jm v klinische gegevens: weefsel afgenomen voor bvo; nee rectaal bloedverlies. diverticulose sigmoid. vraagstelling: niet duidelijk. diverticulitis? adenoom? macroscopie: 5 rafelige biopten 2 mm. onaangesneden ti,1b microscopie: doorsneden doorheen meerdere colonslijmvliesfragmenten bekleed door een normosecretoir intestinaaltype epitheel. plaatselijk wat pseudovilleuze ombouw. in de lamina propria een oedeem met een wisselend toegenomen overwegend lymfocytair ontstekingsinfiltraat. het geheel imponeert als reactief. kan in die zin goed passen bij slijmvliesbiopten in de buurt van diverticulitis. deze bevindingen zijn evenwel niet specifiek. in elk geval geen aanwijzingen voor adenoom. conclusie: sigmoïdbiopten met reactieve veranderingen. beeld is niet specifiek maar kan wel passen bij biopten in de omgeving van een diverticulitis. geen aanwijzingen voor adenoom. verantwoordelijke patholoog: t. demeyere dit is een geautoriseerd verslag
# ...
# Checking spelling for: samenvatting: symptomatische anemie van 3,7 met ijzertekort: packetcel en ferinject in maart 2021 en juli 2021. mogelijk melaena gehad enkele weken terug. heden geen actief bloedverlies meer; gastroscopie toont varices, coloscopie geen afwijkingen. verdenking levercirrose child a voorgeschiedenis: alcoholabusus. beloop: huisarts belt; bloeddruk 130/70 in recente verleden. ze gaat carvidelol 6,25mg starten naast de hct en cozaar.
# Checking spelling for: samenvatting: symptomatische anemie van 3,7 met ijzertekort: packetcel en ferinject in maart 2021 en juli 2021. mogelijk melaena gehad enkele weken terug. heden geen actief bloedverlies meer; gastroscopie toont varices, coloscopie geen afwijkingen. verdenking levercirrose child a voorgeschiedenis: alcoholabusus. beloop: memo: zou jij huisarts bellen en overleggen over medicatie verandering of was het de bedoeling dat mevrouw het zelf zou doen? jk: ik heb huisarts afgelopen vrijdag gebeld en zij zou mij terugbellen, heeft ze nog niet gedaan, dus deze week ergens. zet maar als memo 4 november erbij (huisarts bellen), met 1 week later tcd
# Checking spelling for: samenvatting: symptomatische anemie van 3,7 met ijzertekort: packetcel en ferinject in maart 2021 en juli 2021. mogelijk melaena gehad enkele weken terug. heden geen actief bloedverlies meer; gastroscopie toont varices, coloscopie geen afwijkingen. verdenking levercirrose child a voorgeschiedenis: alcoholabusus. beloop: bloedverlies: geen helder: ja geelzucht: geen alcohol: al lange tijd negatief medicatie: pantzol, levoceterizine, ascal, zolpidem zo nodig, oxazepam, losartan, hct. bloeddruk bij huisarts goed. nu ook emdr in verband met problemen in verleden en man erg ziek aanvullend onderzoek: hemoglobine 7.0 mmol/l mcv 100 fl leukocyten 3.2 10*9/l trombocyten 46 10*9/l patient 15.3 s kreatinine 79 μmol/l egfr ckd-epiduraal 64 ml/min/{1.73_m2} bilirubine totaal 12 μmol/l alkalische fosfatase (atrium fibilaire) 92 u/l ggt 81 u/l asat 39 u/l alat 28 u/l ferritine 140 μg/l ijzer 16 μmol/l transferrine 2.6 g/l transferrine verzadiging 25 % transferpunt/log ferr 1.21 albumine 39 g/l conclusie: levercirrose child a; gebruikt al langere tijd geen alcohol meer. portale hypertensie. hemoglobine gestegen, ijzerstatus normaal. nog minimale levertestafwijkingen. beroerd van de ferinject. beleid: carvdilol? (in plaats van andere antihypertensiva?) nieuwe echo en lab over 3 maanden, dan contactpersoon. overleg huisarts welk antihypertensivum te stoppen en te veranderen in carvidelol omdat bloeddruk bij huisarts altijd wel goed zou zijn. overige acties: - afspraak overige acties: - laboratorium: alat, alkalische fosfatase, asat, bilirubine totaal, c-reactieve proteine, gamma-gt, hemoglobine, kalium, leukocyten, natrium, patient, trombocyten, kreatinine + egfr ckd epiduraal overige acties: - radiologie: echo abdomen
# Checking spelling for: samenvatting: symptomatische anemie van 3,7 met ijzertekort: packetcel en ferinject in maart 2021. mogelijk melaena gehad enkele weken terug. heden geen actief bloedverlies meer; gastroscopie toont varices, coloscopie geen afwijkingen. verdenking levercirrose child a voorgeschiedenis: alcoholabusus. beloop: sinds ijzerinfuus hoofdpijn/misselijk/ kouwelijk/spierpijn, nu gedurende 4 dagen. ze is ook bij huisarts geweest. wat lagere bloeddruk, heeft hct gehalveerd. conclusie: bijwerking ferinject? viraal bleeld? beleid: controle in september met lab, bij klachten eerder contact pantozol minderen naar 20mg parcacetamol doorgaan, eventueel tramadol overige acties: - afspraak overige acties: - laboratorium: ijzer / transferrine + % verz. transferrine, alat, alkalische fosfatase, asat, bilirubine totaal, c-reactieve proteine, ferritine, glucose (willekeurig), hemoglobine, kalium, ld, leukocyten, natrium, reticulocyten, ureum, kreatinine + eventueel. egfr ckd epiduraal
# Checking spelling for: samenvatting: symptomatische anemie van 3,7 met ijzertekort: packetcel en ferinject in maart 2021. mogelijk melaena gehad enkele weken terug. heden geen actief bloedverlies meer; gastroscopie toont varices, coloscopie geen afwijkingen. verdenking levercirrose child a voorgeschiedenis: alcoholabusus. beloop: heeft 21-7 laten prikken in best.
# Checking spelling for: samenvatting: symptomatische anemie van 3,7 met ijzertekort: packetcel en ferinject in maart 2021. mogelijk melaena gehad enkele weken terug. heden geen actief bloedverlies meer; gastroscopie toont varices, coloscopie geen afwijkingen. verdenking levercirrose child a voorgeschiedenis: alcoholabusus. beloop: mevrouw heeft gisteren een ferinject gehad, maar klachten zijn eerder vererderd: misselijk, hoofdpijn, rugpijn en heel erg moe. in eerste instantie geen last maar bij thuiskomen eigenlijk al klachten, is nog vermoeider dan ervoor. wat te doen? beleid: jk vandaag lab laten prikken, paracetamol tegen hoofdpijn.. tcd op donderdag plannen. als het bijwerking ferinject is zal het wegtrekken in een dag
# Checking spelling for: samenvatting: symptomatische anemie van 3,7 met ijzertekort: packetcel en ferinject in maart 2021. mogelijk melaena gehad enkele weken terug. heden geen actief bloedverlies meer; gastroscopie toont varices, coloscopie geen afwijkingen. verdenking levercirrose child a voorgeschiedenis: alcoholabusus. beloop: gaat redelijk, veel rugklachten waarvoor fysiotherapeut/chiropracter. ook bij psycholoog. slaapt soms slecht. veel stress. loopt bij dietist, goed dieet, bewust 7 kg afgevallen alcohol gestopt vanaf maart 2021 medicatie: onder andere orthioca ijzercomplex, vitamines b-complex, chroomtabletten, magnesium, pantozol, ascal, zolpidem, oxazepam zo nodig, losartan gehalveerd, hct gehalveerd, levocetirizine aanvullend onderzoek: bezinking 23 mm c-reactieve proteine 2.3 mg/l hemoglobine 6.5 mmol/l hematocriet 0.32 l/l mcv 100 fl leukocyten 3.4 x10^9/l kreatinine 81 μmol/l egfr ckd-epiduraal 62 ml/m/1.73m^2 bilirubine totaal 8 μmol/l alkalische fosfatase (atrium fibilaire) 96 u/l ggt 75 u/l asat 41 u/l alat 30 u/l haptoglobine <0.20 g/l ferritine 37 μg/l ijzer 8 μmol/l transferrine 3.4 g/l transferrine verzadiging 10 % transferpunt/log ferr 2.14 folaat >45 nmol/l vitamine b12 920 pmol/l elek.forese geen m-proteine conclusie: levercirrose met varices anemie: lijkt wel ijzergebrek beleid: ferinject 1000mg via dagbehandeling regelen in ehv over 3 maanden lab en tcd (medio oktober) lab uitslagen naar patient sturen alcohol gestopt houden overige acties: - aanvraag opname overige acties: - afspraak overige acties: - laboratorium: ijzer / transferrine + % verz. transferrine, alat, albumine, alkalische fosfatase, asat, bilirubine totaal, ferritine, gamma-gt, hemoglobine, leukocyten, mcv, patient, trombocyten, kreatinine + eventueel. egfr ckd epiduraal
# Checking spelling for: samenvatting: symptomatische anemie van 3,7 met ijzertekort: packetcel en ferinject in maart 2021. mogelijk melaena gehad enkele weken terug. heden geen actief bloedverlies meer; gastroscopie toont varices, coloscopie geen afwijkingen. verdenking levercirrose child a voorgeschiedenis: alcoholabusus. beloop: geen bloedverlies, geen melena, wel donkere defecatie met soms staaltabletten, wat moe. bijwerkingen op staalpillen veel rugklachten, erg druk loopt ook bij chiropracter medicatie: ppi en ascal, aanvullend onderzoek: lab 21-5: 6,6 lab 18-6 bij huisarts 5,8 23-6 in mmc 6,1. geen ijzertekort conclusie: anemie, geen manifest bloedverlies beleid: follow urine productie: over 10 dagen lab en tcd. overige acties: - afspraak overige acties: - laboratorium: ijzer / transferrine + % verz. transferrine, alat, alkalische fosfatase, asat, bilirubine totaal, bezinking, c-reactieve proteine, differentiatie leukocyten, ferritine, gamma-gt, haptoglobine, hemoglobine, leukocyten, m-proteine, reticulocyten, vitamine b12, eiwit serum, kreatinine + eventueel. egfr ckd epiduraal, folaat
# Checking spelling for: samenvatting: symptomatische anemie van 3,7 met ijzertekort: packetcel en ferinject in maart 2021. mogelijk melaena gehad enkele weken terug. heden geen actief bloedverlies meer; gastroscopie toont varices, coloscopie geen afwijkingen. verdenking levercirrose child a voorgeschiedenis: alcoholabusus. beloop: memo: lab bij huisarts opgevraagd, wordt gefaxt. pv
# Checking spelling for: samenvatting: symptomatische anemie van 3,7 met ijzertekort: packetcel en ferinject in maart 2021. mogelijk melaena gehad enkele weken terug. heden geen actief bloedverlies meer; gastroscopie toont varices, coloscopie geen afwijkingen. verdenking levercirrose child a voorgeschiedenis: alcoholabusus. beloop: pat belt: hemoglobine is gezakt naar 5,8 afname 18-06-21. wat te doen of te zeggen? beleid: graag alle uitslagen opvragen, dan tc in loop van de week
# Checking spelling for: samenvatting: symptomatische anemie van 3,7 met ijzertekort: packetcel en ferinject in maart 2021. mogelijk melaena gehad enkele weken terug. heden geen actief bloedverlies meer; gastroscopie toont varices, coloscopie geen afwijkingen. verdenking levercirrose child a voorgeschiedenis: alcoholabusus. beloop: geen specifieke klachten alcohol consumptie gestopt sinds maart 2021 spoor enkel oedeem veel afgevallen met dieet. vermoeidheid medicatie: hct 1 daags 12 zakjes,5 en furosemide 40 van de huisarts, losartan, oxazepam/zolpidem, ascal, pantozol, levocetirizine. ferro van orthica. lichamelijk onderzoek: helder aanvullend onderzoek: hemoglobine stijgt langzaam levertesten beter synthese functie goed geen ijzertekort conclusie: levercirrose, alcohol grestopt. anemie beleid: over 3 maanden lab en tcd. geen medicatie mijnerzijds overige acties: - afspraak overige acties: - laboratorium: alat, albumine, alkalische fosfatase, asat, bilirubine totaal, ferritine, gamma-gt, hemoglobine, leukocyten, patient, kreatinine + eventueel. egfr ckd epiduraal
# Checking spelling for: samenvatting: symptomatische anemie van 3,7 met ijzertekort: packetcel en ferinject in maart 2021. mogelijk melaena gehad enkele weken terug. heden geen actief bloedverlies meer; gastroscopie toont varices, coloscopie geen afwijkingen. verdenking levercirrose child a voorgeschiedenis: alcoholabusus. beloop: gaat redelijk goed. mogelijk zwarte ontlasting, maar nu ook ferro oraal. nu ook maagpijn. beginnende diabetes drinkt niet meer sinds de opname loopt bij psycholoog voor angsten. in verleden problemen, in familie meerdere cirrotici. krijgt vitamines van orthomoleculair arts aanvullend onderzoek: hemoglobine 6.1 mmol/l mcv 105 fl natrium 141 mmol/l kalium 4.2 mmol/l kreatinine 79 μmol/l egfr ckd-epiduraal 64 ml/m/1.73m^2 bilirubine totaal 9 μmol/l alkalische fosfatase (atrium fibilaire) 80 u/l ggt 112 u/l asat 57 u/l alat 43 u/l conclusie: levercirrose o.b.v alcohol portale hypertensie met varices en thrombopenie beleid: nog steeds anemie, macrocytair, alcohol of reticulocyten? wel dalend ggt. levercirrose over 6 weken lab en tcd oraal ferro stop. bij laag ferritine ferinject in te toekomst propranolol, eerst herstellen en hemoglobine normalisatie overige acties: - afspraak overige acties: - laboratorium: ijzer / transferrine + % verz. transferrine, alat, albumine, alkalische fosfatase, asat, bilirubine totaal, c-reactieve proteine, ferritine, gamma-gt, hemoglobine, inr stollingswaarde (orale antistolling), leukocyten, mcv, reticulocyten, trombocyten, onderzoek:
# Checking spelling for: aan de weledelgeleerde vrouwe drs. j.h.a. bleiker, huisarts de schakel 4 5684 aw best datum 21-03-2021 kenmerk 0007652402 / bsn nr. betreft mevrouw , geen bijzonderheden (71) , best tel. geachte collega, bovengenoemde patiënt bezocht op 20-03-2021 de spoedeisende hulp. reden van komst anemie, koude rillingen conclusie 71-jarige patiënte bekend met alcoholabusus, bronchitis en recente opname bij anemie onder begeleiding van gastro-intestinale bloeding meldt zich op de spoedeisende hulp met: 1. dyspneu, hoofdpijn en thuis koude rillingen zonder aanwijsbare acute pathologie. 2. bekende souffle. beleid in overleg met kummeling (spoedeisende hulp-arts) en boekema (mdl-arts): - ontslag naar huis bij afwezigheid acute pathologie - retour mdl bij nieuw melena - retour huisarts bij toename dyspneu anamnese voorgeschiedenis: als kind bronchiolitis alcoholabusus 2006 hypertensie 2012 glaucoom 10-2014 angststoornis met paniekaanvallen 12-2014 bronchitis 02-2016 lipodermatosclerose 03-2016 milde veneuze insufficiëntie 01-2019 poli long: dysfunctioneel ademen, geen pulmonale verklaring dyspneu en hoeste anamnese: na ontslag uit het ziekenhuis was patiënte tevreden gezien ze nu weer zonder te veel dyspneu de trap op kon lopen, waarnaast haar pob bij inspanning is verdwenen en ze geen palpitaties meer heeft. ze heeft echter nu sinds 2 dagen toename dyspneu, toename van bekend hoesten en in vlagen atypische hoofdpijn. daarnaast dunne ontlasting sinds ontslag, geen melena meer, geen bloed/slijmbijmenging, geen buikpijn, geen slikklachten. thuis koude rillingen, geen koorts gemeten. tr. anamnese: car/ geen pob, geen palpitaties pulm/ wel dyspneu, wel hoesten, wel sputum, geen hemoptoë digitus/ geen slikklachten, geen nausea/vomitus, geen buikpijn, ontlasting dun zonder slijm/bloedbijminging. urogen/ geen dysurie, geen pollakisurie, geen hematurie. allergie: geen bekend intoxicaties: geen roken, geen drugs, begin deze maand gestopt met alcohol. medicatie: jodiumdruppels en vitaminepreparaten via alternatieve genezer. acetylsalicylzuur 80mg 1dd1 cozaar 100mg 1dd1a hydrochloorthiazide 12.5mg 1dd1 's ochtends oxazepam 10mg zo nodig 1-3dd 1 tablet pantoprazol 20mg 1dd1 xyzal tablet 5mg 1dd1 naproxen 500mg 2dd1 stilnoct 10mg voor de nacht 1 tablet lichamelijk onderzoek niet acuut zieke, heldere en adequate patiënte controles: rr170/85mmhg, p105/min, sat98% bij kamer lucht, ahf22/min, t37.7c hh: pupillen pearl, sclerae wit pulm: vag beiderzijds, minimaal eind-expiratoir piepen cor: s1s2, souffle graad 2/6 met in te toekomst 2e inter collegiaal consult rechts met voortgeleiding over de carotiden. abd: adipositas, np, wt, soepele buik, geen pijn bij palpatie, geen slagpijn nierloges. extr: warme acra, pitting oedeem enkels tot halverwege het onderbeen, soepele kuiten. aanvullend onderzoek lab: c-reactieve proteine 20 mg/l hemoglobine 5.8 mmol/l hematocriet 0.31 l/l erytrocyten 3.41 x10^12/l mcv 91 fl leukocyten 6.6 x10^9/l trombocyten 92 x10^9/l glucose 10.8 mmol/l natrium 136 mmol/l kalium 3.2 mmol/l ureum 2.1 mmol/l kreatinine 75 μmol/l egfr ckd-epiduraal 69 ml/m/1.73m^2 bilirubine totaal 15 μmol/l alkalische fosfatase (atrium fibilaire) 89 u/l ggt 294 u/l alat 44 u/l ld 250 u/l albumine 33 g/l extra buis blauw röntgenfoto van thorax: geen infiltratieve afwijkingen of tekenen van decompensatio cordis. covid sneltest: negatief ecg: sr94/min, linker hartas, normale geleidingstijden, lafb, geen pathologische q's, normale r-top progressie, geen stand-t deviaties. conform 15-03-2021

# %%
# # Apply the function to the first column and store the result in a new column

# df_abbreviations['spelling_corrected'] = df_abbreviations['abbreviations_corrected_cleaned'].apply(lambda x: correct_spelling(x, abbreviations_dict))

# %%
# df_abbreviations.to_csv('a:/bloeding-met-patientenlijst-gedetailleerd/spelling-abb-corrected.csv', index=False)
# df_abbreviations.to_csv('a:/test-data/bloeding-met-patientenlijst-copy-4-verslagen-spelling-abb-corrected.csv')
